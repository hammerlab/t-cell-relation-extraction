# %%
import pronto
import os.path as osp
import re
import os
import pandas as pd
import numpy as np
# %run env.py

# %%
# Download cl.owl from http://purl.obolibrary.org/obo/cl.owl
onto = pronto.Ontology(osp.join(os.environ['DATA_DIR'], 'meta', 'cl', 'cl.owl'))

# %%
# Get term for "T Cell"
# See: https://www.ebi.ac.uk/ols/ontologies/cl/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCL_0000084
parent = onto['CL:0000084']
parent
# Out:
# <CL:0000084: T cell>

# %%
len(list(parent.rchildren()))
# Out:
# 135

# %%
parent.rchildren()
# Out:
# [<CL:0000789: alpha-beta T cell>,
#  <CL:0000798: gamma-delta T cell>,
#  <CL:0002419: mature T cell>,
#  <CL:0002420: immature T cell>,
#  <CL:0000790: immature alpha-beta T cell>,
#  <CL:0000791: mature alpha-beta T cell>,
#  <CL:0000809: double-positive, alpha-beta thymocyte>,
#  <CL:0000810: CD4-positive, alpha-beta thymocyte>,
#  <CL:0000811: CD8-positive, alpha-beta thymocyte>,
#  <CL:0000914: immature NK T cell>,
#  <CL:0002427: resting double-positive thymocyte>,
#  <CL:0002428: double-positive blast>,
#  <CL:0002429: CD69-positive double-positive thymocyte>,
#  <CL:0002430: CD4-intermediate, CD8-positive double-positive thymocyte>,
#  <CL:0002431: CD4-positive, CD8-intermediate double-positive thymocyte>,
#  <CL:0002432: CD24-positive, CD4 single-positive thymocyte>,
#  <CL:0002433: CD69-positive, CD4-positive single-positive thymocyte>,
#  <CL:0002434: CD24-positive, CD8 single-positive thymocyte>,
#  <CL:0002435: CD69-positive, CD8-positive single-positive thymocyte>,
#  <CL:0002039: immature NK T cell stage I>,
#  <CL:0002040: immature NK T cell stage II>,
#  <CL:0002041: immature NK T cell stage III>,
#  <CL:0002042: immature NK T cell stage IV>,
#  <CL:0000624: CD4-positive, alpha-beta T cell>,
#  <CL:0000625: CD8-positive, alpha-beta T cell>,
#  <CL:0000797: alpha-beta intraepithelial T cell>,
#  <CL:0000814: mature NK T cell>,
#  <CL:0000940: mucosal invariant T cell>,
#  <CL:0000492: CD4-positive helper T cell>,
#  <CL:0000792: CD4-positive, CD25-positive, alpha-beta regulatory T cell>,
#  <CL:0000793: CD4-positive, alpha-beta intraepithelial T cell>,
#  <CL:0000895: naive thymus-derived CD4-positive, alpha-beta T cell>,
#  <CL:0000896: activated CD4-positive, alpha-beta T cell>,
#  <CL:0000897: CD4-positive, alpha-beta memory T cell>,
#  <CL:0000934: CD4-positive, alpha-beta cytotoxic T cell>,
#  <CL:0001044: effector CD4-positive, alpha-beta T cell>,
#  <CL:0001051: CD4-positive, CXCR3-negative, CCR6-negative, alpha-beta T cell>,
#  <CL:0002436: mature CD4 single-positive thymocyte>,
#  <CL:0000545: T-helper 1 cell>,
#  <CL:0000546: T-helper 2 cell>,
#  <CL:0000899: T-helper 17 cell>,
#  <CL:0000901: Tr1 cell>,
#  <CL:0001042: T-helper 22 cell>,
#  <CL:0002038: T follicular helper cell>,
#  <CL:0002061: T-helper 9 cell>,
#  <CL:0000902: induced T-regulatory cell>,
#  <CL:0000903: natural T-regulatory cell>,
#  <CL:0001047: CD4-positive, CD25-positive, CCR4-positive, alpha-beta regulatory T cell>,
#  <CL:0002677: naive regulatory T cell>,
#  <CL:0002678: memory regulatory T cell>,
#  <CL:0001045: naive CCR4-positive regulatory T cell>,
#  <CL:0001046: memory CCR4-positive regulatory T cell>,
#  <CL:0001048: activated CD4-positive, CD25-positive, CCR4-positive, alpha-beta regulatory T cell, human>,
#  <CL:0002037: CD2-positive, CD5-positive, CD44-positive alpha-beta intraepithelial T cell>,
#  <CL:0001043: activated CD4-positive, alpha-beta T cell, human>,
#  <CL:0000904: central memory CD4-positive, alpha-beta T cell>,
#  <CL:0000905: effector memory CD4-positive, alpha-beta T cell>,
#  <CL:0000794: CD8-positive, alpha-beta cytotoxic T cell>,
#  <CL:0000795: CD8-positive, alpha-beta regulatory T cell>,
#  <CL:0000900: naive thymus-derived CD8-positive, alpha-beta T cell>,
#  <CL:0000906: activated CD8-positive, alpha-beta T cell>,
#  <CL:0000908: CD8-positive, alpha-beta cytokine secreting effector T cell>,
#  <CL:0000909: CD8-positive, alpha-beta memory T cell>,
#  <CL:0001050: effector CD8-positive, alpha-beta T cell>,
#  <CL:0001052: CD8-positive, CXCR3-negative, CCR6-negative, alpha-beta T cell>,
#  <CL:0001062: effector memory CD8-positive, alpha-beta T cell, terminally differentiated>,
#  <CL:0002437: mature CD8 single-positive thymocyte>,
#  <CL:0000919: CD8-positive, CD25-positive, alpha-beta regulatory T cell>,
#  <CL:0000920: CD8-positive, CD28-negative, alpha-beta regulatory T cell>,
#  <CL:0001041: CD8-positive, CXCR3-positive, alpha-beta regulatory T cell>,
#  <CL:0001049: activated CD8-positive, alpha-beta T cell, human>,
#  <CL:0000917: Tc1 cell>,
#  <CL:0000918: Tc2 cell>,
#  <CL:0002128: Tc17 cell>,
#  <CL:0000907: central memory CD8-positive, alpha-beta T cell>,
#  <CL:0000913: effector memory CD8-positive, alpha-beta T cell>,
#  <CL:0000796: CD8-alpha-beta-positive, alpha-beta intraepithelial T cell>,
#  <CL:0000915: CD8-alpha-alpha-positive, alpha-beta intraepithelial T cell>,
#  <CL:0000935: CD4-negative, CD8-negative, alpha-beta intraepithelial T cell>,
#  <CL:0000921: type I NK T cell>,
#  <CL:0000922: type II NK T cell>,
#  <CL:0000923: CD4-positive type I NK T cell>,
#  <CL:0000924: CD4-negative, CD8-negative type I NK T cell>,
#  <CL:0000925: activated CD4-positive type I NK T cell>,
#  <CL:0000926: CD4-positive type I NK T cell secreting interferon-gamma>,
#  <CL:0000927: CD4-positive type I NK T cell secreting interleukin-4>,
#  <CL:0000928: activated CD4-negative, CD8-negative type I NK T cell>,
#  <CL:0000929: CD4-negative, CD8-negative type I NK T cell secreting interferon-gamma>,
#  <CL:0000930: CD4-negative, CD8-negative type I NK T cell secreting interleukin-4>,
#  <CL:0000931: activated type II NK T cell>,
#  <CL:0000932: type II NK T cell secreting interferon-gamma>,
#  <CL:0000933: type II NK T cell secreting interleukin-4>,
#  <CL:0000799: immature gamma-delta T cell>,
#  <CL:0000800: mature gamma-delta T cell>,
#  <CL:0002405: gamma-delta thymocyte>,
#  <CL:0002126: CD25-positive, CD27-positive immature gamma-delta T cell>,
#  <CL:0000801: gamma-delta intraepithelial T cell>,
#  <CL:0000916: dendritic epidermal T cell>,
#  <CL:0002124: CD27-positive gamma-delta T cell>,
#  <CL:0002125: CD27-negative gamma-delta T cell>,
#  <CL:0000802: CD8-alpha alpha positive, gamma-delta intraepithelial T cell>,
#  <CL:0000803: CD4-negative CD8-negative gamma-delta intraepithelial T cell>,
#  <CL:0002513: Vgamma5-positive CD8alpha alpha positive gamma-delta intraepithelial T cell>,
#  <CL:0002514: Vgamma5-negative CD8alpha alpha positive gamma-delta intraepithelial T cell>,
#  <CL:0002406: immature Vgamma2-positive thymocyte>,
#  <CL:0002407: mature Vgamma2-positive thymocyte>,
#  <CL:0002408: immature Vgamma2-negative thymocyte>,
#  <CL:0002409: mature Vgamma2-negative thymocyte>,
#  <CL:0002411: Vgamma1.1-positive, Vdelta6.3-negative thymocyte>,
#  <CL:0002412: Vgamma1.1-positive, Vdelta6.3-positive thymocyte>,
#  <CL:0002413: mature Vgamma1.1-positive, Vdelta6.3-negative thymocyte>,
#  <CL:0002414: immature Vgamma1.1-positive, Vdelta6.3-negative thymocyte>,
#  <CL:0002415: immature Vgamma1.1-positive, Vdelta6.3-positive thymocyte>,
#  <CL:0002416: mature Vgamma1.1-positive, Vdelta6.3-positive thymocyte>,
#  <CL:0000813: memory T cell>,
#  <CL:0000815: regulatory T cell>,
#  <CL:0000898: naive T cell>,
#  <CL:0000911: effector T cell>,
#  <CL:0002496: intraepithelial lymphocyte>,
#  <CL:0000910: cytotoxic T cell>,
#  <CL:0000912: helper T cell>,
#  <CL:0002127: innate effector T cell>,
#  <CL:0000893: thymocyte>,
#  <CL:0000805: immature single positive thymocyte>,
#  <CL:0002404: fetal thymocyte>,
#  <CL:0002489: double negative thymocyte>,
#  <CL:0002218: immature dendritic epithelial T cell precursor>,
#  <CL:0002378: immature Vgamma2-positive fetal thymocyte>,
#  <CL:0002401: mature dendritic epithelial T cell precursor>,
#  <CL:0002403: mature Vgamma2-positive fetal thymocyte>,
#  <CL:0000806: DN2 thymocyte>,
#  <CL:0000807: DN3 thymocyte>,
#  <CL:0000808: DN4 thymocyte>,
#  <CL:0002423: DN2a thymocyte>,
#  <CL:0002424: DN2b thymocyte>]

# %%
terms = [parent] + list(parent.rchildren())
len(terms)
# Out:
# 136

# %%
pd.Series([
    s.scope
    for t in terms
    for s in t.synonyms
]).value_counts()
# Out:
# EXACT      447
# BROAD       58
# RELATED     18
# NARROW       3
# dtype: int64

# %%
def get_row(t, s):
    dict(
        id=t.id, label=t.name, desc=str(t.desc),
        syn=s if isinstance(s, str) else s.desc,
        syn_typ='label' if isinstance(s, str) else s.scope.lower(),
        syn_typ_v=None if isinstance(s, str) else s.scope.lower(),
    )

def get_frame(syn_fn, syn_typ):    
    return pd.DataFrame(

        for t in terms
        for s in list(t.synonyms) + [pronto.Synonym(t.name)]
    )

# %%
t = onto['CL:0000899']
t
# Out:
# <CL:0000899: T-helper 17 cell>

# %%
t.id, t.name, t.synonyms, str(t.desc)
# Out:
# ('CL:0000899',
#  'T-helper 17 cell',
#  {<Synonym: "IL-17-producing CD4+ T helper" EXACT []>,
#   <Synonym: "T helper cells type 17" EXACT []>,
#   <Synonym: "T(H)-17 cell" EXACT []>,
#   <Synonym: "Th17 CD4+ T cell" EXACT []>,
#   <Synonym: "Th17 T cell" EXACT []>,
#   <Synonym: "Th17 T lymphocyte" EXACT []>,
#   <Synonym: "Th17 T-cell" EXACT []>,
#   <Synonym: "Th17 T-lymphocyte" EXACT []>,
#   <Synonym: "Th17 cell" EXACT []>,
#   <Synonym: "helper T cell type 17" EXACT []>},
#  'CD4-positive, alpha-beta T cell with the phenotype RORgamma-t-positive, CXCR3-negative, CCR6-positive, and capable of producing IL-17.')

# %%
s = list(t.synonyms)[0]

# %%
s.scope, s.syn_type, s.desc
# Out:
# ('EXACT', None, str)

# %%
dict()
for t in terms
dict(
        id=cid, namespace=namespace, 
        name=c.name, label=label, syn=syn,
        category=category_map.get(cid), 
        parent=parent, ancestors=ancestors,
        syn_typ=syn_typ
    )

# %%
category_regex = re.compile(r'(?<=Category=)[a-z-]+(?=\.)')

def get_class_category(c):
    if c.comment:
        cats = category_regex.findall(c.comment[0])
        return cats[0] if cats else None
    return None

def get_class_id(c):
    if hasattr(c, 'id'):
        return c.id[0]
    return None

# Built map from ID -> Category to be used for faster ancestor category lookups
category_map = {
    get_class_id(c): get_class_category(c) 
    for c in onto.classes() if get_class_id(c) is not None
}
len(category_map)
# Out:
# 316242

# %%
def get_row(c, label, syn, syn_typ):
    # Extract from strings like:
    # "get_ontology("http://purl.obolibrary.org/obo/pr.owl#").get_namespace("http://purl.obolibrary.org/obo/")"
    namespace = str(c.namespace).split('/')[-2]
    
    # Get ancestor ID list
    ancestors = [get_class_id(a) for a in c.ancestors() if get_class_id(a) is not None]
    
    # Assign "parent" as first ancestor in "gene" category 
    # (e.g. "interferon gamma isoform 1 (human)" gets parent "interferon gamma")
    parent = [aid for aid in ancestors if category_map.get(aid) == 'gene']
    parent = parent[0] if parent else None
    
    cid = get_class_id(c)
    
    return dict(
        id=cid, namespace=namespace, 
        name=c.name, label=label, syn=syn,
        category=category_map.get(cid), 
        parent=parent, ancestors=ancestors,
        syn_typ=syn_typ
    )

def get_frame(syn_typ, syn_fn):
    return pd.DataFrame([
        get_row(c, l, s, syn_typ)
        for c in onto.classes()
        for l in (c.label or [None])
        for s in syn_fn(c)
    ])
    
SPECIES = {'any': 3, 'human': 2, 'mouse': 1}
SYN_TYPS = {'label': 3, 'exact': 2, 'related': 1}

df = pd.concat([
    get_frame('exact', lambda c: c.hasExactSynonym or [None]),
    get_frame('related', lambda c: c.hasRelatedSynonym or [None]),
    get_frame('label', lambda c: c.label or [None])
])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1236944 entries, 0 to 316241
# Data columns (total 9 columns):
# ancestors    1236944 non-null object
# category     1226853 non-null object
# id           1236944 non-null object
# label        1236944 non-null object
# name         1236944 non-null object
# namespace    1236944 non-null object
# parent       717720 non-null object
# syn          903995 non-null object
# syn_typ      1236944 non-null object
# dtypes: object(9)
# memory usage: 94.4+ MB

# %%
df['category'].value_counts()
# Out:
# organism-gene            502458
# external                 296956
# organism-sequence        226870
# gene                     126820
# organism-modification     29120
# sequence                  24836
# modification              15282
# family                     1630
# organism-complex           1299
# complex                     695
# organism-seqgroup           623
# organism-family             103
# organism-genegroup           81
# union                        80
# Name: category, dtype: int64

# %%
df['species'] = np.where(
    df['category'].str.contains('organism'), 
    df['label'].str.strip().str.extract(r'(?<=\()([a-z ]+?)(?=\)$)', expand=False),
    None
)
# Replace unknown species classifications with "any", as these are more generic 
# ontology elements that could apply to any organism (but not necessarily all of them)
df['species'] = df['species'].fillna('any')
df['species'].value_counts()
# Out:
# any                    665569
# human                  251844
# mouse                  148564
# rat                     61209
# yeast                   30591
# fruit fly               24521
# worm                    23722
# zebrafish               16528
# chicken                 12221
# cow                       912
# pig                       303
# rabbit                    261
# dog                       140
# frog                      139
# guinea pig                129
# spinach                    54
# sheep                      41
# rice                       35
# maize                      30
# opium poppy                27
# wheat                      24
# green monkey               16
# turkey                     15
# horse                      12
# honeybee                   11
# kidney bean                 7
# horseradish                 7
# cat                         6
# great scarlet poppy         3
# cobra                       3
# Name: species, dtype: int64

# %%
df['namespace'].value_counts()
# Out:
# obo        956824
# cgi-bin     77194
# gene        65364
# marker      50457
# locus       47496
# result      15375
# reports     11751
# view         9834
# cgnc         1659
# id            990
# Name: namespace, dtype: int64

# %%
df['syn_typ'].value_counts()
# Out:
# exact      540266
# related    380436
# label      316242
# Name: syn_typ, dtype: int64

# %%
# Create a set of all proteins with either IDs explicitly associated with target 
# organisms are that are ancestors of such proteins

def get_target_ids(df):
    return list(set(df['id'].tolist() + [v for a in df['ancestors'] for v in a]))
    
target_ids = get_target_ids(df[df['species'].isin(list(SPECIES.keys()))])
len(target_ids)
# Out:
# 277154

# %%
# Filter to OBO records and subtrees relevant to target species
species_regex = '|'.join('\({}\)'.format(v) for v in SPECIES.values())
dff = (
    df
    .pipe(lambda df: df[df['namespace'] == 'obo'])
    # Restrict to species-specific sub-trees noting that a couple
    # ancestors end up being for off-target species (hence the 
    # second filter on species again)
    .pipe(lambda df: df[df['id'].isin(target_ids)])
    .pipe(lambda df: df[df['species'].isin(list(SPECIES.keys()))])
    .pipe(lambda df: df[df['syn'].notnull()])
    # Remove substrings like "(human)" from synonyms
    .assign(syn=lambda df: df['syn'].str.replace(species_regex, '').str.strip())
    .drop_duplicates(['id', 'label', 'name', 'syn', 'syn_typ', 'species'])
    .drop('ancestors', axis=1)
)
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 659126 entries, 2 to 316241
# Data columns (total 9 columns):
# category     654656 non-null object
# id           659126 non-null object
# label        659126 non-null object
# name         659126 non-null object
# namespace    659126 non-null object
# parent       516227 non-null object
# syn          659126 non-null object
# syn_typ      659126 non-null object
# species      659126 non-null object
# dtypes: object(9)
# memory usage: 50.3+ MB

# %%
dff.groupby(['syn', 'syn_typ', 'species'])['id'].nunique().rename('n_ids').reset_index()\
    .groupby(['syn_typ', 'species', 'n_ids']).size()
# Out:
# syn_typ  species  n_ids
# exact    any      1        165438
#                   2           262
#                   3             8
#          human    1        119153
#                   2             3
#          mouse    1         72195
#                   2            19
# label    any      1         87178
#                   2            33
#                   3             2
#          human    1         60960
#                   2             3
#          mouse    1         35556
#                   2             4
# related  any      1         68456
#                   2          4125
#                   3           358
#                   4            80
#                   5            24
#                   6            13
#                   7             4
#                   8             1
#                   9             2
#                   10            1
#                   13            5
#                   15            2
#          human    1         22136
#                   2          1031
#                   3            93
#                   4            11
#                   5             1
#                   7             1
#                   9             1
#                   10            1
#          mouse    1         13723
#                   2           552
#                   3            35
#                   4             3
#                   6             1
#                   9             1
# dtype: int64

# %%
# When a synonym exists for multiple records within same species, resolve by using
# synonym source preference (equal to label = highest, exact synonym = next, related synonym = lowest)
# * when a synonym has multiple records for the same species and synonym type, use the highest id
dfd = (
    dff
    .assign(syn_typ_id=lambda df: df['syn_typ'].map(SYN_TYPS))
    # Note that NA values will are last by default (i.e. lowest)
    .sort_values(['species', 'syn', 'syn_typ_id', 'id'], ascending=False)
    .groupby(['species', 'syn'], group_keys=False).head(1)
)
assert dfd.groupby(['species', 'syn']).size().max() == 1
dfd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 649105 entries, 537614 to 295741
# Data columns (total 10 columns):
# category      644657 non-null object
# id            649105 non-null object
# label         649105 non-null object
# name          649105 non-null object
# namespace     649105 non-null object
# parent        508057 non-null object
# syn           649105 non-null object
# syn_typ       649105 non-null object
# species       649105 non-null object
# syn_typ_id    649105 non-null int64
# dtypes: int64(1), object(9)
# memory usage: 54.5+ MB

# %%
dfd['species'].value_counts()
# Out:
# any      323965
# human    203233
# mouse    121907
# Name: species, dtype: int64

# %%
# Finally, resolve make synonyms unique by choosing based on species preference
# * This may not be desirable in the future as it will do something like make "IL12A"
# always point the IL12A record for humans rather than humans or mice

def assign_species_id(df):
    df['species_id'] = df['species'].map(SPECIES)
    assert df['species_id'].notnull().all()
    return df

dfe = (
    dfd
    .pipe(assign_species_id)
    # Note that NA values will are last by default (i.e. lowest)
    .sort_values(['syn', 'species_id', 'id'], ascending=False)
    .groupby(['syn'], group_keys=False).head(1)
)
assert dfe.groupby('syn').size().max() == 1
assert dfe['species_id'].notnull().all()
dfe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 629165 entries, 537614 to 295741
# Data columns (total 11 columns):
# category      624717 non-null object
# id            629165 non-null object
# label         629165 non-null object
# name          629165 non-null object
# namespace     629165 non-null object
# parent        488344 non-null object
# syn           629165 non-null object
# syn_typ       629165 non-null object
# species       629165 non-null object
# syn_typ_id    629165 non-null int64
# species_id    629165 non-null int64
# dtypes: int64(2), object(9)
# memory usage: 57.6+ MB

# %%
dfe[dfe['syn'].str.contains('^IL2')]
#dfe[dfe['syn'] == 'IL12A']
#dfe[dfe['syn'] == 'TGFB']
# Out:
#              category            id  \
# 127151   modification  PR:000018417
# 70983            gene  PR:000001340
# 127180   modification  PR:000018446
# 71197            gene  PR:000001381
# 127178   modification  PR:000018444
# 71191            gene  PR:000001380
# 69450            gene  PR:000001476
# 80576            gene  PR:000009003
# 69441            gene  PR:000001470
# 69440            gene  PR:000001470
# 69437            gene  PR:000001469
# 71221            gene  PR:000001385
# 96160            gene  PR:000009002
# 69293            gene  PR:000001386
# 69292            gene  PR:000001385
# 432324  organism-gene     PR:Q8K3I6
# 179067  organism-gene     PR:Q8NEV9
# 71220            gene  PR:000001385
# 71219            gene  PR:000001385
# 71669            gene  PR:000001475
# 127073   modification  PR:000018341
# 70017            gene  PR:000001113
# 152233       sequence  PR:000035509
# 152232       sequence  PR:000035507
# 127241   modification  PR:000018506
# 71663            gene  PR:000001474
# 96155            gene  PR:000009001
# 162421       sequence  PR:000043148
# 164060   modification  PR:000044520
# 71214            gene  PR:000001384
# 129027   modification  PR:000020303
# 96147            gene  PR:000009000
# 96136            gene  PR:000008999
# 80571            gene  PR:000008999
# 413920  organism-gene     PR:Q80XF5
# 179034  organism-gene     PR:Q969J5
# 96146            gene  PR:000009000
# 162463       sequence  PR:000043190
# 127182   modification  PR:000018448
# 71208            gene  PR:000001383
# 129025   modification  PR:000020301
# 96126            gene  PR:000008998
# 162436       sequence  PR:000043163
# 71201            gene  PR:000001382
# 129023   modification  PR:000020299
# 96122            gene  PR:000008997
# 129021   modification  PR:000020297
# 96113            gene  PR:000008996
# 162961       sequence  PR:000043670
# 127239   modification  PR:000018504
# 71659            gene  PR:000001473
# 127176   modification  PR:000018442
# 238758  organism-gene     PR:P01590
# 179089  organism-gene     PR:P01589
# 71190            gene  PR:000001380
# 71182            gene  PR:000001379
#
#                                                     label          name  \
# 127151  cytokine receptor common subunit gamma, signal...  PR_000018417
# 70983              cytokine receptor common subunit gamma  PR_000001340
# 127180  interleukin-2 receptor subunit beta, signal pe...  PR_000018446
# 71197                 interleukin-2 receptor subunit beta  PR_000001381
# 127178  interleukin-2 receptor subunit alpha, signal p...  PR_000018444
# 71191                interleukin-2 receptor subunit alpha  PR_000001380
# 69450                                      interleukin-29  PR_000001476
# 80576                 interleukin-28 receptor alpha chain  PR_000009003
# 69441                                     interleukin-28B  PR_000001470
# 69440                                     interleukin-28B  PR_000001470
# 69437                                     interleukin-28A  PR_000001469
# 71221                        interleukin-27 subunit alpha  PR_000001385
# 96160               interleukin-27 receptor subunit alpha  PR_000009002
# 69293                         interleukin-27 subunit beta  PR_000001386
# 69292                        interleukin-27 subunit alpha  PR_000001385
# 432324               interleukin-27 subunit alpha (mouse)     PR_Q8K3I6
# 179067               interleukin-27 subunit alpha (human)     PR_Q8NEV9
# 71220                        interleukin-27 subunit alpha  PR_000001385
# 71219                        interleukin-27 subunit alpha  PR_000001385
# 71669                                      interleukin-26  PR_000001475
# 127073        interleukin-25, signal peptide removed form  PR_000018341
# 70017                                      interleukin-25  PR_000001113
# 152233                           interleukin-24 isoform 2  PR_000035509
# 152232                           interleukin-24 isoform 1  PR_000035507
# 127241        interleukin-24, signal peptide removed form  PR_000018506
# 71663                                      interleukin-24  PR_000001474
# 96155                             interleukin-23 receptor  PR_000009001
# 162421             interleukin-23 subunit alpha isoform 1  PR_000043148
# 164060  interleukin-23 subunit alpha, signal peptide r...  PR_000044520
# 71214                        interleukin-23 subunit alpha  PR_000001384
# 129027  interleukin-22 receptor subunit alpha-2, signa...  PR_000020303
# 96147             interleukin-22 receptor subunit alpha-2  PR_000009000
# 96136             interleukin-22 receptor subunit alpha-1  PR_000008999
# 80571             interleukin-22 receptor subunit alpha-1  PR_000008999
# 413920    interleukin-22 receptor subunit alpha-2 (mouse)     PR_Q80XF5
# 179034    interleukin-22 receptor subunit alpha-2 (human)     PR_Q969J5
# 96146             interleukin-22 receptor subunit alpha-2  PR_000009000
# 162463                           interleukin-22 isoform 1  PR_000043190
# 127182        interleukin-22, signal peptide removed form  PR_000018448
# 71208                                      interleukin-22  PR_000001383
# 129025  interleukin-21 receptor, signal peptide remove...  PR_000020301
# 96126                             interleukin-21 receptor  PR_000008998
# 162436                           interleukin-21 isoform 1  PR_000043163
# 71201                                      interleukin-21  PR_000001382
# 129023  interleukin-20 receptor subunit beta, signal p...  PR_000020299
# 96122                interleukin-20 receptor subunit beta  PR_000008997
# 129021  interleukin-20 receptor subunit alpha, signal ...  PR_000020297
# 96113               interleukin-20 receptor subunit alpha  PR_000008996
# 162961                           interleukin-20 isoform 1  PR_000043670
# 127239        interleukin-20, signal peptide removed form  PR_000018504
# 71659                                      interleukin-20  PR_000001473
# 127176         interleukin-2, signal peptide removed form  PR_000018442
# 238758       interleukin-2 receptor subunit alpha (mouse)     PR_P01590
# 179089       interleukin-2 receptor subunit alpha (human)     PR_P01589
# 71190                interleukin-2 receptor subunit alpha  PR_000001380
# 71182                                       interleukin-2  PR_000001379
#
#        namespace        parent              syn  syn_typ species  syn_typ_id  \
# 127151       obo  PR:000001340    IL2RG/SigPep-    exact     any           2
# 70983        obo  PR:000001340            IL2RG    exact     any           2
# 127180       obo  PR:000001381    IL2RB/SigPep-    exact     any           2
# 71197        obo  PR:000001381            IL2RB    exact     any           2
# 127178       obo  PR:000001380    IL2RA/SigPep-    exact     any           2
# 71191        obo  PR:000001380            IL2RA    exact     any           2
# 69450        obo  PR:000001476             IL29  related     any           1
# 80576        obo  PR:000009003           IL28RA  related     any           1
# 69441        obo  PR:000001470            IL28C  related     any           1
# 69440        obo  PR:000001470            IL28B  related     any           1
# 69437        obo  PR:000001469            IL28A  related     any           1
# 71221        obo  PR:000001385          IL27p28    exact     any           2
# 96160        obo  PR:000009002           IL27RA    exact     any           2
# 69293        obo  PR:000001386            IL27B  related     any           1
# 69292        obo  PR:000001385            IL27A  related     any           1
# 432324       obo  PR:000001385   IL27-A (mouse)    exact   mouse           2
# 179067       obo  PR:000001385   IL27-A (human)    exact   human           2
# 71220        obo  PR:000001385           IL27-A    exact     any           2
# 71219        obo  PR:000001385             IL27    exact     any           2
# 71669        obo  PR:000001475             IL26    exact     any           2
# 127073       obo  PR:000001113     IL25/SigPep-    exact     any           2
# 70017        obo  PR:000001113             IL25    exact     any           2
# 152233       obo  PR:000001474       IL24/iso:2    exact     any           2
# 152232       obo  PR:000001474       IL24/iso:1    exact     any           2
# 127241       obo  PR:000001474     IL24/SigPep-    exact     any           2
# 71663        obo  PR:000001474             IL24    exact     any           2
# 96155        obo  PR:000009001            IL23R    exact     any           2
# 162421       obo  PR:000001384      IL23A/iso:1    exact     any           2
# 164060       obo  PR:000001384    IL23A/SigPep-    exact     any           2
# 71214        obo  PR:000001384            IL23A    exact     any           2
# 129027       obo  PR:000009000  IL22RA2/SigPep-    exact     any           2
# 96147        obo  PR:000009000          IL22RA2    exact     any           2
# 96136        obo  PR:000008999          IL22RA1    exact     any           2
# 80571        obo  PR:000008999            IL22R  related     any           1
# 413920       obo  PR:000009000   IL22BP (mouse)    exact   mouse           2
# 179034       obo  PR:000009000   IL22BP (human)    exact   human           2
# 96146        obo  PR:000009000           IL22BP    exact     any           2
# 162463       obo  PR:000001383       IL22/iso:1    exact     any           2
# 127182       obo  PR:000001383     IL22/SigPep-    exact     any           2
# 71208        obo  PR:000001383             IL22    exact     any           2
# 129025       obo  PR:000008998    IL21R/SigPep-    exact     any           2
# 96126        obo  PR:000008998            IL21R    exact     any           2
# 162436       obo  PR:000001382       IL21/iso:1    exact     any           2
# 71201        obo  PR:000001382             IL21    exact     any           2
# 129023       obo  PR:000008997   IL20RB/SigPep-    exact     any           2
# 96122        obo  PR:000008997           IL20RB    exact     any           2
# 129021       obo  PR:000008996   IL20RA/SigPep-    exact     any           2
# 96113        obo  PR:000008996           IL20RA    exact     any           2
# 162961       obo  PR:000001473       IL20/iso:1    exact     any           2
# 127239       obo  PR:000001473     IL20/SigPep-    exact     any           2
# 71659        obo  PR:000001473             IL20    exact     any           2
# 127176       obo  PR:000001379      IL2/SigPep-    exact     any           2
# 238758       obo  PR:000001380   IL2-RA (mouse)    exact   mouse           2
# 179089       obo  PR:000001380   IL2-RA (human)    exact   human           2
# 71190        obo  PR:000001380           IL2-RA    exact     any           2
# 71182        obo  PR:000001379              IL2    exact     any           2
#
#         species_id
# 127151           3
# 70983            3
# 127180           3
# 71197            3
# 127178           3
# 71191            3
# 69450            3
# 80576            3
# 69441            3
# 69440            3
# 69437            3
# 71221            3
# 96160            3
# 69293            3
# 69292            3
# 432324           1
# 179067           2
# 71220            3
# 71219            3
# 71669            3
# 127073           3
# 70017            3
# 152233           3
# 152232           3
# 127241           3
# 71663            3
# 96155            3
# 162421           3
# 164060           3
# 71214            3
# 129027           3
# 96147            3
# 96136            3
# 80571            3
# 413920           1
# 179034           2
# 96146            3
# 162463           3
# 127182           3
# 71208            3
# 129025           3
# 96126            3
# 162436           3
# 71201            3
# 129023           3
# 96122            3
# 129021           3
# 96113            3
# 162961           3
# 127239           3
# 71659            3
# 127176           3
# 238758           1
# 179089           2
# 71190            3
# 71182            3

# %%
path = osp.join(os.environ['META_DATA_DIR'], 'raw', 'pro.raw.csv')
dfe.to_csv(path, index=False)
path
# Out:
# '/Users/eczech/repos/hammer/t-cell-relation-extraction/pm_subtype_protein_relations/data/meta/raw/pro.raw.csv'
