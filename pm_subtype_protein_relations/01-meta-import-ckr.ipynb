# %% [markdown]
# ## Cytokine Registry Import
#
# See https://www.immport.org/resources/cytokineRegistry

# %%
import os
import os.path as osp
import pandas as pd
import numpy as np
# %run env.py

# %%
# Download from https://www.immport.org/docs/CytokineRegistry.November_2015.xls
df = pd.read_excel(osp.join(DATA_DIR, 'meta', 'cytokine_registry', 'CytokineRegistry.November_2015.xls'))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 30 columns):
# UNIQUE ID                                    275 non-null object
# REFERENCE NAME                               275 non-null object
# HGNC ID                                      250 non-null object
# EntrezGene official name (Human)             255 non-null object
# EntrezGeneID (Human)                         255 non-null float64
# EntrezGene Symbol (Human)                    255 non-null object
# EntrezGene Aliases (Human)                   252 non-null object
# EntrezGene Additional Names (Human)          242 non-null object
# MGI ID                                       231 non-null object
# EntrezGeneofficial name (Mouse)              230 non-null object
# EntrezGeneID (Mouse)                         231 non-null float64
# EntrezGene Symbol (Mouse)                    231 non-null object
# EntrezGene Aliases (Mouse)                   221 non-null object
# ...

# %%
df.head()
# Out:
#   UNIQUE ID            REFERENCE NAME     HGNC ID  \
# 0     CID_1  B-Cell Activating Factor  HGNC:11929
# 1    CID_10            Chemokine CCL1  HGNC:10609
# 2   CID_100            Interleukin-15   HGNC:5977
# 3   CID_101            Interleukin-16   HGNC:5980
# 4   CID_102            Interleukin-17         NaN
#
#                     EntrezGene official name (Human)  EntrezGeneID (Human)  \
# 0  tumor necrosis factor (ligand) superfamily, me...               10673.0
# 1                     chemokine (C-C motif) ligand 1                6346.0
# 2                                     interleukin 15                3600.0
# 3                                     interleukin 16                3603.0
# 4                                                NaN                   NaN
#
#   EntrezGene Symbol (Human)  \
# 0                  TNFSF13B
# 1                     CCL1
# 2                     IL15
# 3                     IL16
# 4                       NaN
#
# ...

# %%
df.tail()
# Out:
#     UNIQUE ID                                     REFERENCE NAME     HGNC ID  \
# 270   CID_273  Tumor necrosis factor ligand superfamily membe...  HGNC:11925
# 271   CID_274                      Macrophage stimulating factor   HGNC:7380
# 272   CID_275                                            IL-18R1   HGNC:5988
# 273   CID_269                                              FASLG  HGNC:11936
# 274   CID_270                                             FLT3LG   HGNC:3766
#
#                       EntrezGene official name (Human)  EntrezGeneID (Human)  \
# 270  tumor necrosis factor (ligand) superfamily, me...                8743.0
# 271                           macrophage stimulating 1                4485.0
# 272                          interleukin 18 receptor 1                8809.0
# 273             Fas ligand (TNF superfamily, member 6)                 356.0
# 274               fms-related tyrosine kinase 3 ligand                2323.0
#
#     EntrezGene Symbol (Human)  \
# ...

# %%
df[df['Protein Ontology ID'].isnull()]
# Out:
#     UNIQUE ID                           REFERENCE NAME     HGNC ID  \
# 17    CID_114                           Interleukin-23         NaN
# 19    CID_116               Interleukin-23 Subunit p40         NaN
# 35    CID_130                           Interleukin-35         NaN
# 44    CID_139   Leukocyte Migration-Inhibitory Factors         NaN
# 48    CID_142         Macrophage Inflammatory Proteins         NaN
# 50    CID_144  Macrophage Migration-Inhibitory Factors         NaN
# 51    CID_145            Macrophage-Activating Factors         NaN
# 52    CID_146        Monocyte Chemoattractant Proteins         NaN
# 57    CID_150           Platelet-Derived Growth Factor         NaN
# 62    CID_155          Suppressor Factors, Immunologic         NaN
# 64    CID_157                                    TDGF3  HGNC:11703
# 66    CID_159                          Transfer Factor         NaN
# 68    CID_160               Transforming Growth Factor         NaN
# ...
