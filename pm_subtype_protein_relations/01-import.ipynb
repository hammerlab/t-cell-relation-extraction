# %%
from Bio import Entrez
import os
import re
import os.path as osp
import logging
import traceback
import pandas as pd
from bs4 import BeautifulSoup
# %run utils/logging.py
# %run env.py
#Entrez.email = 'eric@hammerlab.org'
Entrez.email = 'eczech52@gmail.com'

# %%
def search(query, retstart=0, retmax=1000):
    handle = Entrez.esearch(db='pmc', 
                            sort='relevance', 
                            retmax=str(retmax),
                            retstart=str(retstart),
                            retmode='xml', 
                            term=query)
    results = Entrez.read(handle)
    return results

def fetch_details(id_list):
    ids = ','.join(id_list)
    handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
    return handle.read()

def parse(soup):
    res = {}
    res['id'] = [t for t in soup.find('article-meta').find_all('article-id') if t['pub-id-type'] == 'pmc'][0].text
    res['title'] = soup.find('title-group').find('article-title').text
    res['xml'] = str(soup)
    
    try:
        res['abstract'] = soup.find('abstract').text
    except:
        res['abstract'] = None
    
    try:
        res['has_text'] = len(soup.find('body').text.strip()) > 0
    except:
        res['has_text'] = False
        
    try:
        date = [t for t in soup.find('history').find_all('date') if t['date-type'] == 'received'][0]
        res['date'] = pd.to_datetime('{}-{}-{}'.format(
            date.find('year').text,
            date.find('month').text if date.find('month') else '00',
            date.find('day').text if date.find('day') else '00'
        ))
    except:
        res['date'] = None
    return res

def to_df(dets):
    soup = BeautifulSoup(dets, 'xml')
    return pd.DataFrame([parse(article) for article in soup.find_all('article')])

def collect(query, output_file, start_index=0, batch_size=100, batch_limit=None, max_failures=5):
    i = start_index
    ct = 0
    failures = 0
    if not osp.exists(osp.dirname(output_file)):
        os.makedirs(osp.dirname(output_file))
    while True:
        try:
            ids = search(query, retstart=i, retmax=batch_size)['IdList']
            if len(ids) == 0:
                break
            logger.info('Processing batch at start index {} (num ids = {})'.format(i, len(ids)))
            dets = fetch_details(ids)
            df = to_df(dets)
            df.to_csv(output_file, index=False, header=not osp.exists(output_file), mode='a')
            ct += 1
            i += batch_size
            if batch_limit and ct >= batch_limit:
                break
        except:
            traceback.print_exc()
            failures += 1
            if failures > max_failures:
                raise ValueError('Max failure threshold ({}) exceeded'.format(max_failures))
            logger.warning('Error occurred at index {}. Will retry up to {} times'.format(i, max_failures))
    logger.info('Collection complete (num failures = {})'.format(failures))

# %%
# # https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pmc&id=6089340
# dets = fetch_details(['6089340', '212403'])

# %%
# from bs4 import BeautifulSoup
# soup = BeautifulSoup(dets, 'xml')

# %%
output_file = osp.join(DATA_DIR, 'articles', 'data.csv')
![ -e $output_file ] && rm $output_file

# Efetch docs: https://www.ncbi.nlm.nih.gov/books/NBK25499/#chapter4.EFetch
# Get doc details: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pmc&id=212403
# 124720 results as of 2019-03-11
# Test single article: 
#query = '5360497'
query = '(human) AND ((t cell) OR (t lymphocyte)) AND (cytokine) AND ((differentiate) OR (differentiation) OR (differentiated)) AND ((polarization) OR (polarize) OR (induce) OR (induction))'
collect(
    query, output_file, 
    start_index=0, batch_size=10, max_failures=1000000,
    batch_limit=350
)
# Out:
# 2019-03-14 10:43:48,565:INFO:root: Processing batch at start index 0 (num ids = 10)
# 2019-03-14 10:43:51,818:INFO:root: Processing batch at start index 10 (num ids = 10)
# 2019-03-14 10:43:56,353:INFO:root: Processing batch at start index 20 (num ids = 10)
# 2019-03-14 10:44:01,841:INFO:root: Processing batch at start index 30 (num ids = 10)
# 2019-03-14 10:44:04,812:INFO:root: Processing batch at start index 40 (num ids = 10)
# 2019-03-14 10:44:12,635:INFO:root: Processing batch at start index 50 (num ids = 10)
# 2019-03-14 10:44:18,281:INFO:root: Processing batch at start index 60 (num ids = 10)
# 2019-03-14 10:44:22,010:INFO:root: Processing batch at start index 70 (num ids = 10)
# 2019-03-14 10:44:25,185:INFO:root: Processing batch at start index 80 (num ids = 10)
# 2019-03-14 10:44:31,267:INFO:root: Processing batch at start index 90 (num ids = 10)
# 2019-03-14 10:44:39,867:INFO:root: Processing batch at start index 100 (num ids = 10)
# 2019-03-14 10:44:42,943:INFO:root: Processing batch at start index 110 (num ids = 10)
# 2019-03-14 10:44:49,911:INFO:root: Processing batch at start index 120 (num ids = 10)
# 2019-03-14 10:44:53,943:INFO:root: Processing batch at start index 130 (num ids = 10)
# 2019-03-14 10:45:02,030:INFO:root: Processing batch at start index 140 (num ids = 10)
# 2019-03-14 10:45:06,000:INFO:root: Processing batch at start index 150 (num ids = 10)
# 2019-03-14 10:45:32,340:INFO:root: Processing batch at start index 160 (num ids = 10)
# 2019-03-14 10:45:39,956:INFO:root: Processing batch at start index 170 (num ids = 10)
# 2019-03-14 10:45:45,553:INFO:root: Processing batch at start index 180 (num ids = 10)
# 2019-03-14 10:45:52,618:INFO:root: Processing batch at start index 190 (num ids = 10)
# 2019-03-14 10:45:56,131:INFO:root: Processing batch at start index 200 (num ids = 10)
# 2019-03-14 10:46:03,985:INFO:root: Processing batch at start index 210 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-3-6c5b1272821b>", line 13, in fetch_details
#     handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 184, in efetch
#     return _open(cgi, variables, post=post)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 10:46:34,333:WARNING:root: Error occurred at index 210. Will retry up to 1000000 times
# 2019-03-14 10:46:35,624:INFO:root: Processing batch at start index 210 (num ids = 10)
# 2019-03-14 10:46:43,920:INFO:root: Processing batch at start index 220 (num ids = 10)
# 2019-03-14 10:46:47,031:INFO:root: Processing batch at start index 230 (num ids = 10)
# 2019-03-14 10:46:53,749:INFO:root: Processing batch at start index 240 (num ids = 10)
# 2019-03-14 10:46:58,091:INFO:root: Processing batch at start index 250 (num ids = 10)
# 2019-03-14 10:47:05,729:INFO:root: Processing batch at start index 260 (num ids = 10)
# 2019-03-14 10:47:11,605:INFO:root: Processing batch at start index 270 (num ids = 10)
# 2019-03-14 10:47:15,506:INFO:root: Processing batch at start index 280 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-3-6c5b1272821b>", line 13, in fetch_details
#     handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 184, in efetch
#     return _open(cgi, variables, post=post)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 10:47:45,968:WARNING:root: Error occurred at index 280. Will retry up to 1000000 times
# 2019-03-14 10:47:47,028:INFO:root: Processing batch at start index 280 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-3-6c5b1272821b>", line 13, in fetch_details
#     handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 184, in efetch
#     return _open(cgi, variables, post=post)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 10:48:17,295:WARNING:root: Error occurred at index 280. Will retry up to 1000000 times
# 2019-03-14 10:48:18,447:INFO:root: Processing batch at start index 280 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-3-6c5b1272821b>", line 13, in fetch_details
#     handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 184, in efetch
#     return _open(cgi, variables, post=post)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 10:48:48,821:WARNING:root: Error occurred at index 280. Will retry up to 1000000 times
# 2019-03-14 10:48:50,003:INFO:root: Processing batch at start index 280 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-3-6c5b1272821b>", line 13, in fetch_details
#     handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 184, in efetch
#     return _open(cgi, variables, post=post)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 10:49:23,951:WARNING:root: Error occurred at index 280. Will retry up to 1000000 times
# 2019-03-14 10:49:25,506:INFO:root: Processing batch at start index 280 (num ids = 10)
# 2019-03-14 10:49:47,010:INFO:root: Processing batch at start index 290 (num ids = 10)
# 2019-03-14 10:49:50,497:INFO:root: Processing batch at start index 300 (num ids = 10)
# 2019-03-14 10:49:59,223:INFO:root: Processing batch at start index 310 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-3-6c5b1272821b>", line 13, in fetch_details
#     handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 184, in efetch
#     return _open(cgi, variables, post=post)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 10:50:29,707:WARNING:root: Error occurred at index 310. Will retry up to 1000000 times
# 2019-03-14 10:50:31,248:INFO:root: Processing batch at start index 310 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-3-6c5b1272821b>", line 13, in fetch_details
#     handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 184, in efetch
#     return _open(cgi, variables, post=post)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 10:51:01,529:WARNING:root: Error occurred at index 310. Will retry up to 1000000 times
# 2019-03-14 10:51:03,017:INFO:root: Processing batch at start index 310 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-3-6c5b1272821b>", line 13, in fetch_details
#     handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 184, in efetch
#     return _open(cgi, variables, post=post)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 10:51:36,239:WARNING:root: Error occurred at index 310. Will retry up to 1000000 times
# 2019-03-14 10:51:37,911:INFO:root: Processing batch at start index 310 (num ids = 10)
# 2019-03-14 10:51:42,145:INFO:root: Processing batch at start index 320 (num ids = 10)
# 2019-03-14 10:51:48,970:INFO:root: Processing batch at start index 330 (num ids = 10)
# 2019-03-14 10:51:53,412:INFO:root: Processing batch at start index 340 (num ids = 10)
# 2019-03-14 10:52:01,554:INFO:root: Processing batch at start index 350 (num ids = 10)
# 2019-03-14 10:52:10,475:INFO:root: Processing batch at start index 360 (num ids = 10)
# 2019-03-14 10:52:14,412:INFO:root: Processing batch at start index 370 (num ids = 10)
# 2019-03-14 10:52:19,878:INFO:root: Processing batch at start index 380 (num ids = 10)
# 2019-03-14 10:52:22,399:INFO:root: Processing batch at start index 390 (num ids = 10)
# 2019-03-14 10:52:27,307:INFO:root: Processing batch at start index 400 (num ids = 10)
# 2019-03-14 10:52:30,136:INFO:root: Processing batch at start index 410 (num ids = 10)
# 2019-03-14 10:52:32,703:INFO:root: Processing batch at start index 420 (num ids = 10)
# 2019-03-14 10:52:40,149:INFO:root: Processing batch at start index 430 (num ids = 10)
# 2019-03-14 10:52:50,718:INFO:root: Processing batch at start index 440 (num ids = 10)
# 2019-03-14 10:52:53,791:INFO:root: Processing batch at start index 450 (num ids = 10)
# 2019-03-14 10:53:01,470:INFO:root: Processing batch at start index 460 (num ids = 10)
# 2019-03-14 10:53:03,927:INFO:root: Processing batch at start index 470 (num ids = 10)
# 2019-03-14 10:53:10,993:INFO:root: Processing batch at start index 480 (num ids = 10)
# 2019-03-14 10:53:13,758:INFO:root: Processing batch at start index 490 (num ids = 10)
# 2019-03-14 10:53:20,822:INFO:root: Processing batch at start index 500 (num ids = 10)
# 2019-03-14 10:53:24,512:INFO:root: Processing batch at start index 510 (num ids = 10)
# 2019-03-14 10:53:32,497:INFO:root: Processing batch at start index 520 (num ids = 10)
# 2019-03-14 10:53:36,034:INFO:root: Processing batch at start index 530 (num ids = 10)
# 2019-03-14 10:53:40,791:INFO:root: Processing batch at start index 540 (num ids = 10)
# 2019-03-14 10:53:44,784:INFO:root: Processing batch at start index 550 (num ids = 10)
# 2019-03-14 10:53:51,771:INFO:root: Processing batch at start index 560 (num ids = 10)
# 2019-03-14 10:53:55,924:INFO:root: Processing batch at start index 570 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-3-6c5b1272821b>", line 13, in fetch_details
#     handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 184, in efetch
#     return _open(cgi, variables, post=post)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 10:54:07,903:WARNING:root: Error occurred at index 570. Will retry up to 1000000 times
# 2019-03-14 10:54:10,899:INFO:root: Processing batch at start index 570 (num ids = 10)
# 2019-03-14 10:54:13,356:INFO:root: Processing batch at start index 580 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-3-6c5b1272821b>", line 13, in fetch_details
#     handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 184, in efetch
#     return _open(cgi, variables, post=post)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 10:54:15,704:WARNING:root: Error occurred at index 580. Will retry up to 1000000 times
# 2019-03-14 10:54:32,826:INFO:root: Processing batch at start index 580 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-3-6c5b1272821b>", line 13, in fetch_details
#     handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 184, in efetch
#     return _open(cgi, variables, post=post)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 10:55:03,425:WARNING:root: Error occurred at index 580. Will retry up to 1000000 times
# 2019-03-14 10:55:05,272:INFO:root: Processing batch at start index 580 (num ids = 10)
# 2019-03-14 10:55:22,633:INFO:root: Processing batch at start index 590 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 55, in collect
#     ids = search(query, retstart=i, retmax=batch_size)['IdList']
#   File "<ipython-input-3-6c5b1272821b>", line 7, in search
#     term=query)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 220, in esearch
#     return _open(cgi, variables)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 10:55:55,960:WARNING:root: Error occurred at index 600. Will retry up to 1000000 times
# 2019-03-14 10:55:59,170:INFO:root: Processing batch at start index 600 (num ids = 10)
# 2019-03-14 10:56:06,404:INFO:root: Processing batch at start index 610 (num ids = 10)
# 2019-03-14 10:56:09,955:INFO:root: Processing batch at start index 620 (num ids = 10)
# 2019-03-14 10:56:15,140:INFO:root: Processing batch at start index 630 (num ids = 10)
# 2019-03-14 10:56:18,079:INFO:root: Processing batch at start index 640 (num ids = 10)
# 2019-03-14 10:56:24,396:INFO:root: Processing batch at start index 650 (num ids = 10)
# 2019-03-14 10:56:26,988:INFO:root: Processing batch at start index 660 (num ids = 10)
# 2019-03-14 10:56:31,051:INFO:root: Processing batch at start index 670 (num ids = 10)
# 2019-03-14 10:56:35,898:INFO:root: Processing batch at start index 680 (num ids = 10)
# 2019-03-14 10:56:39,496:INFO:root: Processing batch at start index 690 (num ids = 10)
# 2019-03-14 10:56:45,905:INFO:root: Processing batch at start index 700 (num ids = 10)
# 2019-03-14 10:56:49,668:INFO:root: Processing batch at start index 710 (num ids = 10)
# 2019-03-14 10:56:57,490:INFO:root: Processing batch at start index 720 (num ids = 10)
# 2019-03-14 10:57:03,169:INFO:root: Processing batch at start index 730 (num ids = 10)
# 2019-03-14 10:57:07,913:INFO:root: Processing batch at start index 740 (num ids = 10)
# 2019-03-14 10:57:10,667:INFO:root: Processing batch at start index 750 (num ids = 10)
# 2019-03-14 10:57:16,610:INFO:root: Processing batch at start index 760 (num ids = 10)
# 2019-03-14 10:57:20,335:INFO:root: Processing batch at start index 770 (num ids = 10)
# 2019-03-14 10:57:37,861:INFO:root: Processing batch at start index 780 (num ids = 10)
# 2019-03-14 10:58:03,708:INFO:root: Processing batch at start index 790 (num ids = 10)
# 2019-03-14 10:58:07,753:INFO:root: Processing batch at start index 800 (num ids = 10)
# 2019-03-14 10:58:10,153:INFO:root: Processing batch at start index 810 (num ids = 10)
# 2019-03-14 10:58:17,892:INFO:root: Processing batch at start index 820 (num ids = 10)
# 2019-03-14 10:58:20,634:INFO:root: Processing batch at start index 830 (num ids = 10)
# 2019-03-14 10:58:27,554:INFO:root: Processing batch at start index 840 (num ids = 10)
# 2019-03-14 10:58:30,106:INFO:root: Processing batch at start index 850 (num ids = 10)
# 2019-03-14 10:58:36,070:INFO:root: Processing batch at start index 860 (num ids = 10)
# 2019-03-14 10:58:40,446:INFO:root: Processing batch at start index 870 (num ids = 10)
# 2019-03-14 10:58:46,516:INFO:root: Processing batch at start index 880 (num ids = 10)
# 2019-03-14 10:58:49,530:INFO:root: Processing batch at start index 890 (num ids = 10)
# 2019-03-14 10:58:52,268:INFO:root: Processing batch at start index 900 (num ids = 10)
# 2019-03-14 10:59:01,758:INFO:root: Processing batch at start index 910 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-3-6c5b1272821b>", line 13, in fetch_details
#     handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 184, in efetch
#     return _open(cgi, variables, post=post)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 10:59:05,013:WARNING:root: Error occurred at index 910. Will retry up to 1000000 times
# 2019-03-14 10:59:10,072:INFO:root: Processing batch at start index 910 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-3-6c5b1272821b>", line 13, in fetch_details
#     handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 184, in efetch
#     return _open(cgi, variables, post=post)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 500: Internal Server Error
# 2019-03-14 10:59:10,426:WARNING:root: Error occurred at index 910. Will retry up to 1000000 times
# 2019-03-14 10:59:11,546:INFO:root: Processing batch at start index 910 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 55, in collect
#     ids = search(query, retstart=i, retmax=batch_size)['IdList']
#   File "<ipython-input-3-6c5b1272821b>", line 7, in search
#     term=query)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 220, in esearch
#     return _open(cgi, variables)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 10:59:19,325:WARNING:root: Error occurred at index 920. Will retry up to 1000000 times
# 2019-03-14 10:59:21,429:INFO:root: Processing batch at start index 920 (num ids = 10)
# 2019-03-14 10:59:27,684:INFO:root: Processing batch at start index 930 (num ids = 10)
# 2019-03-14 10:59:30,082:INFO:root: Processing batch at start index 940 (num ids = 10)
# 2019-03-14 10:59:34,266:INFO:root: Processing batch at start index 950 (num ids = 10)
# 2019-03-14 10:59:38,991:INFO:root: Processing batch at start index 960 (num ids = 10)
# 2019-03-14 10:59:41,958:INFO:root: Processing batch at start index 970 (num ids = 10)
# 2019-03-14 10:59:49,131:INFO:root: Processing batch at start index 980 (num ids = 10)
# 2019-03-14 10:59:51,888:INFO:root: Processing batch at start index 990 (num ids = 10)
# 2019-03-14 10:59:59,507:INFO:root: Processing batch at start index 1000 (num ids = 10)
# 2019-03-14 11:00:03,825:INFO:root: Processing batch at start index 1010 (num ids = 10)
# 2019-03-14 11:00:10,324:INFO:root: Processing batch at start index 1020 (num ids = 10)
# 2019-03-14 11:00:12,877:INFO:root: Processing batch at start index 1030 (num ids = 10)
# 2019-03-14 11:00:19,932:INFO:root: Processing batch at start index 1040 (num ids = 10)
# 2019-03-14 11:00:22,699:INFO:root: Processing batch at start index 1050 (num ids = 10)
# 2019-03-14 11:00:37,800:INFO:root: Processing batch at start index 1060 (num ids = 10)
# 2019-03-14 11:00:40,636:INFO:root: Processing batch at start index 1070 (num ids = 10)
# 2019-03-14 11:00:59,476:INFO:root: Processing batch at start index 1080 (num ids = 10)
# 2019-03-14 11:01:03,690:INFO:root: Processing batch at start index 1090 (num ids = 10)
# 2019-03-14 11:01:08,460:INFO:root: Processing batch at start index 1100 (num ids = 10)
# 2019-03-14 11:01:12,690:INFO:root: Processing batch at start index 1110 (num ids = 10)
# 2019-03-14 11:01:15,378:INFO:root: Processing batch at start index 1120 (num ids = 10)
# 2019-03-14 11:01:22,519:INFO:root: Processing batch at start index 1130 (num ids = 10)
# 2019-03-14 11:01:29,953:INFO:root: Processing batch at start index 1140 (num ids = 10)
# 2019-03-14 11:01:34,055:INFO:root: Processing batch at start index 1150 (num ids = 10)
# 2019-03-14 11:01:40,321:INFO:root: Processing batch at start index 1160 (num ids = 10)
# 2019-03-14 11:01:42,971:INFO:root: Processing batch at start index 1170 (num ids = 10)
# 2019-03-14 11:01:45,893:INFO:root: Processing batch at start index 1180 (num ids = 10)
# 2019-03-14 11:01:51,396:INFO:root: Processing batch at start index 1190 (num ids = 10)
# 2019-03-14 11:01:54,187:INFO:root: Processing batch at start index 1200 (num ids = 10)
# 2019-03-14 11:01:59,418:INFO:root: Processing batch at start index 1210 (num ids = 10)
# 2019-03-14 11:02:02,350:INFO:root: Processing batch at start index 1220 (num ids = 10)
# 2019-03-14 11:02:06,348:INFO:root: Processing batch at start index 1230 (num ids = 10)
# 2019-03-14 11:02:12,883:INFO:root: Processing batch at start index 1240 (num ids = 10)
# 2019-03-14 11:02:15,853:INFO:root: Processing batch at start index 1250 (num ids = 10)
# 2019-03-14 11:02:22,731:INFO:root: Processing batch at start index 1260 (num ids = 10)
# 2019-03-14 11:02:25,804:INFO:root: Processing batch at start index 1270 (num ids = 10)
# 2019-03-14 11:02:33,174:INFO:root: Processing batch at start index 1280 (num ids = 10)
# 2019-03-14 11:02:35,943:INFO:root: Processing batch at start index 1290 (num ids = 10)
# 2019-03-14 11:02:42,100:INFO:root: Processing batch at start index 1300 (num ids = 10)
# 2019-03-14 11:02:44,848:INFO:root: Processing batch at start index 1310 (num ids = 10)
# 2019-03-14 11:02:51,518:INFO:root: Processing batch at start index 1320 (num ids = 10)
# 2019-03-14 11:02:54,371:INFO:root: Processing batch at start index 1330 (num ids = 10)
# 2019-03-14 11:03:01,802:INFO:root: Processing batch at start index 1340 (num ids = 10)
# 2019-03-14 11:03:04,643:INFO:root: Processing batch at start index 1350 (num ids = 10)
# 2019-03-14 11:03:06,936:INFO:root: Processing batch at start index 1360 (num ids = 10)
# 2019-03-14 11:03:15,962:INFO:root: Processing batch at start index 1370 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-3-6c5b1272821b>", line 13, in fetch_details
#     handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 184, in efetch
#     return _open(cgi, variables, post=post)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 11:03:17,952:WARNING:root: Error occurred at index 1370. Will retry up to 1000000 times
# 2019-03-14 11:03:22,632:INFO:root: Processing batch at start index 1370 (num ids = 10)
# 2019-03-14 11:03:24,878:INFO:root: Processing batch at start index 1380 (num ids = 10)
# 2019-03-14 11:03:27,547:INFO:root: Processing batch at start index 1390 (num ids = 10)
# 2019-03-14 11:03:35,846:INFO:root: Processing batch at start index 1400 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 55, in collect
#     ids = search(query, retstart=i, retmax=batch_size)['IdList']
#   File "<ipython-input-3-6c5b1272821b>", line 7, in search
#     term=query)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 220, in esearch
#     return _open(cgi, variables)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 11:03:40,105:WARNING:root: Error occurred at index 1410. Will retry up to 1000000 times
# 2019-03-14 11:03:43,100:INFO:root: Processing batch at start index 1410 (num ids = 10)
# 2019-03-14 11:03:45,985:INFO:root: Processing batch at start index 1420 (num ids = 10)
# 2019-03-14 11:03:52,799:INFO:root: Processing batch at start index 1430 (num ids = 10)
# 2019-03-14 11:03:55,814:INFO:root: Processing batch at start index 1440 (num ids = 10)
# 2019-03-14 11:03:58,787:INFO:root: Processing batch at start index 1450 (num ids = 10)
# 2019-03-14 11:04:05,335:INFO:root: Processing batch at start index 1460 (num ids = 10)
# 2019-03-14 11:04:13,630:INFO:root: Processing batch at start index 1470 (num ids = 10)
# 2019-03-14 11:04:17,250:INFO:root: Processing batch at start index 1480 (num ids = 10)
# 2019-03-14 11:04:21,741:INFO:root: Processing batch at start index 1490 (num ids = 10)
# 2019-03-14 11:04:24,999:INFO:root: Processing batch at start index 1500 (num ids = 10)
# 2019-03-14 11:04:28,388:INFO:root: Processing batch at start index 1510 (num ids = 10)
# 2019-03-14 11:04:34,694:INFO:root: Processing batch at start index 1520 (num ids = 10)
# 2019-03-14 11:04:38,329:INFO:root: Processing batch at start index 1530 (num ids = 10)
# 2019-03-14 11:04:45,708:INFO:root: Processing batch at start index 1540 (num ids = 10)
# 2019-03-14 11:04:48,960:INFO:root: Processing batch at start index 1550 (num ids = 10)
# 2019-03-14 11:04:56,329:INFO:root: Processing batch at start index 1560 (num ids = 10)
# 2019-03-14 11:04:59,401:INFO:root: Processing batch at start index 1570 (num ids = 10)
# 2019-03-14 11:05:05,545:INFO:root: Processing batch at start index 1580 (num ids = 10)
# 2019-03-14 11:05:07,992:INFO:root: Processing batch at start index 1590 (num ids = 10)
# 2019-03-14 11:05:14,513:INFO:root: Processing batch at start index 1600 (num ids = 10)
# 2019-03-14 11:05:16,992:INFO:root: Processing batch at start index 1610 (num ids = 10)
# 2019-03-14 11:05:19,646:INFO:root: Processing batch at start index 1620 (num ids = 10)
# 2019-03-14 11:05:26,744:INFO:root: Processing batch at start index 1630 (num ids = 10)
# 2019-03-14 11:05:29,218:INFO:root: Processing batch at start index 1640 (num ids = 10)
# 2019-03-14 11:05:36,265:INFO:root: Processing batch at start index 1650 (num ids = 10)
# 2019-03-14 11:05:39,342:INFO:root: Processing batch at start index 1660 (num ids = 10)
# 2019-03-14 11:05:47,942:INFO:root: Processing batch at start index 1670 (num ids = 10)
# 2019-03-14 11:05:51,114:INFO:root: Processing batch at start index 1680 (num ids = 10)
# 2019-03-14 11:05:58,122:INFO:root: Processing batch at start index 1690 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 55, in collect
#     ids = search(query, retstart=i, retmax=batch_size)['IdList']
#   File "<ipython-input-3-6c5b1272821b>", line 7, in search
#     term=query)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 220, in esearch
#     return _open(cgi, variables)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 11:06:12,048:WARNING:root: Error occurred at index 1700. Will retry up to 1000000 times
# 2019-03-14 11:06:15,894:INFO:root: Processing batch at start index 1700 (num ids = 10)
# 2019-03-14 11:06:18,174:INFO:root: Processing batch at start index 1710 (num ids = 10)
# 2019-03-14 11:06:21,667:INFO:root: Processing batch at start index 1720 (num ids = 10)
# 2019-03-14 11:06:28,488:INFO:root: Processing batch at start index 1730 (num ids = 10)
# 2019-03-14 11:06:31,254:INFO:root: Processing batch at start index 1740 (num ids = 10)
# 2019-03-14 11:06:37,769:INFO:root: Processing batch at start index 1750 (num ids = 10)
# 2019-03-14 11:06:40,778:INFO:root: Processing batch at start index 1760 (num ids = 10)
# 2019-03-14 11:06:47,845:INFO:root: Processing batch at start index 1770 (num ids = 10)
# 2019-03-14 11:06:50,507:INFO:root: Processing batch at start index 1780 (num ids = 10)
# ...
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 1320, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error [Errno 54] Connection reset by peer>
# 2019-03-14 11:15:03,304:WARNING:root: Error occurred at index 2680. Will retry up to 1000000 times
# 2019-03-14 11:15:06,247:INFO:root: Processing batch at start index 2680 (num ids = 10)
# 2019-03-14 11:15:09,562:INFO:root: Processing batch at start index 2690 (num ids = 10)
# 2019-03-14 11:15:14,989:INFO:root: Processing batch at start index 2700 (num ids = 10)
# 2019-03-14 11:15:17,492:INFO:root: Processing batch at start index 2710 (num ids = 10)
# 2019-03-14 11:15:21,133:INFO:root: Processing batch at start index 2720 (num ids = 10)
# 2019-03-14 11:15:28,245:INFO:root: Processing batch at start index 2730 (num ids = 10)
# 2019-03-14 11:15:30,941:INFO:root: Processing batch at start index 2740 (num ids = 10)
# 2019-03-14 11:15:37,390:INFO:root: Processing batch at start index 2750 (num ids = 10)
# 2019-03-14 11:15:39,782:INFO:root: Processing batch at start index 2760 (num ids = 10)
# 2019-03-14 11:15:44,690:INFO:root: Processing batch at start index 2770 (num ids = 10)
# 2019-03-14 11:15:49,440:INFO:root: Processing batch at start index 2780 (num ids = 10)
# 2019-03-14 11:15:56,564:INFO:root: Processing batch at start index 2790 (num ids = 10)
# 2019-03-14 11:15:58,965:INFO:root: Processing batch at start index 2800 (num ids = 10)
# 2019-03-14 11:16:01,727:INFO:root: Processing batch at start index 2810 (num ids = 10)
# 2019-03-14 11:16:07,565:INFO:root: Processing batch at start index 2820 (num ids = 10)
# 2019-03-14 11:16:10,945:INFO:root: Processing batch at start index 2830 (num ids = 10)
# 2019-03-14 11:16:18,010:INFO:root: Processing batch at start index 2840 (num ids = 10)
# 2019-03-14 11:16:20,469:INFO:root: Processing batch at start index 2850 (num ids = 10)
# 2019-03-14 11:16:25,283:INFO:root: Processing batch at start index 2860 (num ids = 10)
# 2019-03-14 11:16:29,036:INFO:root: Processing batch at start index 2870 (num ids = 10)
# 2019-03-14 11:16:31,555:INFO:root: Processing batch at start index 2880 (num ids = 10)
# 2019-03-14 11:16:39,207:INFO:root: Processing batch at start index 2890 (num ids = 10)
# 2019-03-14 11:16:47,254:INFO:root: Processing batch at start index 2900 (num ids = 10)
# 2019-03-14 11:16:51,699:INFO:root: Processing batch at start index 2910 (num ids = 10)
# 2019-03-14 11:16:58,563:INFO:root: Processing batch at start index 2920 (num ids = 10)
# 2019-03-14 11:17:01,098:INFO:root: Processing batch at start index 2930 (num ids = 10)
# 2019-03-14 11:17:03,935:INFO:root: Processing batch at start index 2940 (num ids = 10)
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-3-6c5b1272821b>", line 13, in fetch_details
#     handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 184, in efetch
#     return _open(cgi, variables, post=post)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 545, in _open
#     raise exception
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# 2019-03-14 11:17:10,231:WARNING:root: Error occurred at index 2940. Will retry up to 1000000 times
# 2019-03-14 11:17:11,772:INFO:root: Processing batch at start index 2940 (num ids = 10)
# Traceback (most recent call last):
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 1318, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1400, in connect
#     server_hostname=server_hostname)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/ssl.py", line 407, in wrap_socket
#     _context=self, _session=session)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/ssl.py", line 817, in __init__
#     self.do_handshake()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/ssl.py", line 1077, in do_handshake
#     self._sslobj.do_handshake()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/ssl.py", line 689, in do_handshake
#     self._sslobj.do_handshake()
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 55, in collect
#     ids = search(query, retstart=i, retmax=batch_size)['IdList']
#   File "<ipython-input-3-6c5b1272821b>", line 7, in search
#     term=query)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 220, in esearch
#     return _open(cgi, variables)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 526, in open
#     response = self._open(req, data)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 544, in _open
#     '_open', req)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 1361, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 1320, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error [Errno 54] Connection reset by peer>
# 2019-03-14 11:17:17,039:WARNING:root: Error occurred at index 2950. Will retry up to 1000000 times
# 2019-03-14 11:17:18,099:INFO:root: Processing batch at start index 2950 (num ids = 10)
# 2019-03-14 11:17:23,700:INFO:root: Processing batch at start index 2960 (num ids = 10)
# 2019-03-14 11:17:29,895:INFO:root: Processing batch at start index 2970 (num ids = 10)
# 2019-03-14 11:17:32,545:INFO:root: Processing batch at start index 2980 (num ids = 10)
# 2019-03-14 11:17:38,498:INFO:root: Processing batch at start index 2990 (num ids = 10)
# 2019-03-14 11:17:41,228:INFO:root: Processing batch at start index 3000 (num ids = 10)
# 2019-03-14 11:17:48,389:INFO:root: Processing batch at start index 3010 (num ids = 10)
# 2019-03-14 11:17:51,558:INFO:root: Processing batch at start index 3020 (num ids = 10)
# 2019-03-14 11:17:54,797:INFO:root: Processing batch at start index 3030 (num ids = 10)
# 2019-03-14 11:18:00,922:INFO:root: Processing batch at start index 3040 (num ids = 10)
# 2019-03-14 11:18:03,383:INFO:root: Processing batch at start index 3050 (num ids = 10)
# 2019-03-14 11:18:10,755:INFO:root: Processing batch at start index 3060 (num ids = 10)
# 2019-03-14 11:18:13,312:INFO:root: Processing batch at start index 3070 (num ids = 10)
# 2019-03-14 11:18:21,505:INFO:root: Processing batch at start index 3080 (num ids = 10)
# 2019-03-14 11:18:24,825:INFO:root: Processing batch at start index 3090 (num ids = 10)
# 2019-03-14 11:18:31,336:INFO:root: Processing batch at start index 3100 (num ids = 10)
# 2019-03-14 11:18:34,101:INFO:root: Processing batch at start index 3110 (num ids = 10)
# 2019-03-14 11:18:41,473:INFO:root: Processing batch at start index 3120 (num ids = 10)
# 2019-03-14 11:18:44,020:INFO:root: Processing batch at start index 3130 (num ids = 10)
# 2019-03-14 11:18:50,520:INFO:root: Processing batch at start index 3140 (num ids = 10)
# 2019-03-14 11:18:52,806:INFO:root: Processing batch at start index 3150 (num ids = 10)
# 2019-03-14 11:18:57,221:INFO:root: Processing batch at start index 3160 (num ids = 10)
# Traceback (most recent call last):
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 1318, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1400, in connect
#     server_hostname=server_hostname)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/ssl.py", line 407, in wrap_socket
#     _context=self, _session=session)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/ssl.py", line 817, in __init__
#     self.do_handshake()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/ssl.py", line 1077, in do_handshake
#     self._sslobj.do_handshake()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/ssl.py", line 689, in do_handshake
#     self._sslobj.do_handshake()
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-3-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-3-6c5b1272821b>", line 13, in fetch_details
#     handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 184, in efetch
#     return _open(cgi, variables, post=post)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 526, in open
#     response = self._open(req, data)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 544, in _open
#     '_open', req)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 1361, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 1320, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error [Errno 54] Connection reset by peer>
# 2019-03-14 11:18:59,022:WARNING:root: Error occurred at index 3160. Will retry up to 1000000 times
# 2019-03-14 11:19:00,212:INFO:root: Processing batch at start index 3160 (num ids = 10)
# 2019-03-14 11:19:02,338:INFO:root: Processing batch at start index 3170 (num ids = 10)
# 2019-03-14 11:19:04,820:INFO:root: Processing batch at start index 3180 (num ids = 10)
# 2019-03-14 11:19:11,324:INFO:root: Processing batch at start index 3190 (num ids = 10)
# 2019-03-14 11:19:14,212:INFO:root: Processing batch at start index 3200 (num ids = 10)
# 2019-03-14 11:19:21,103:INFO:root: Processing batch at start index 3210 (num ids = 10)
# 2019-03-14 11:19:23,560:INFO:root: Processing batch at start index 3220 (num ids = 10)
# 2019-03-14 11:19:28,627:INFO:root: Processing batch at start index 3230 (num ids = 10)
# 2019-03-14 11:19:31,548:INFO:root: Processing batch at start index 3240 (num ids = 10)
# 2019-03-14 11:19:34,625:INFO:root: Processing batch at start index 3250 (num ids = 10)
# 2019-03-14 11:19:41,921:INFO:root: Processing batch at start index 3260 (num ids = 10)
# 2019-03-14 11:19:44,145:INFO:root: Processing batch at start index 3270 (num ids = 10)
# 2019-03-14 11:19:47,104:INFO:root: Processing batch at start index 3280 (num ids = 10)
# 2019-03-14 11:19:52,335:INFO:root: Processing batch at start index 3290 (num ids = 10)
# 2019-03-14 11:19:55,136:INFO:root: Processing batch at start index 3300 (num ids = 10)
# 2019-03-14 11:20:02,881:INFO:root: Processing batch at start index 3310 (num ids = 10)
# 2019-03-14 11:20:05,094:INFO:root: Processing batch at start index 3320 (num ids = 10)
# 2019-03-14 11:20:14,248:INFO:root: Processing batch at start index 3330 (num ids = 10)
# 2019-03-14 11:20:17,634:INFO:root: Processing batch at start index 3340 (num ids = 10)
# 2019-03-14 11:20:24,386:INFO:root: Processing batch at start index 3350 (num ids = 10)
# 2019-03-14 11:20:27,868:INFO:root: Processing batch at start index 3360 (num ids = 10)
# 2019-03-14 11:20:33,700:INFO:root: Processing batch at start index 3370 (num ids = 10)
# 2019-03-14 11:20:37,528:INFO:root: Processing batch at start index 3380 (num ids = 10)
# 2019-03-14 11:20:43,774:INFO:root: Processing batch at start index 3390 (num ids = 10)
# 2019-03-14 11:20:46,435:INFO:root: Processing batch at start index 3400 (num ids = 10)
# 2019-03-14 11:20:53,570:INFO:root: Processing batch at start index 3410 (num ids = 10)
# 2019-03-14 11:20:55,761:INFO:root: Processing batch at start index 3420 (num ids = 10)
# 2019-03-14 11:21:02,132:INFO:root: Processing batch at start index 3430 (num ids = 10)
# 2019-03-14 11:21:05,041:INFO:root: Processing batch at start index 3440 (num ids = 10)
# 2019-03-14 11:21:10,590:INFO:root: Processing batch at start index 3450 (num ids = 10)
# 2019-03-14 11:21:14,462:INFO:root: Processing batch at start index 3460 (num ids = 10)
# 2019-03-14 11:21:17,272:INFO:root: Processing batch at start index 3470 (num ids = 10)
# 2019-03-14 11:21:23,372:INFO:root: Processing batch at start index 3480 (num ids = 10)
# 2019-03-14 11:21:27,362:INFO:root: Processing batch at start index 3490 (num ids = 10)
# 2019-03-14 11:21:33,334:INFO:root: Collection complete (num failures = 25)

# %%
df = pd.read_csv(output_file)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 6 columns):
# abstract    3481 non-null object
# date        2155 non-null object
# has_text    3500 non-null bool
# id          3500 non-null int64
# title       3500 non-null object
# xml         3500 non-null object
# dtypes: bool(1), int64(1), object(4)
# memory usage: 140.2+ KB

# %%
df['has_text'].value_counts()
# Out:
# False    1766
# True     1734
# Name: has_text, dtype: int64
