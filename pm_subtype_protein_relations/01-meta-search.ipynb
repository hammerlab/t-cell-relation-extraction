# %%
import os.path as osp
import pandas as pd
import numpy as np
# %run env.py
# %run src/lib.py
# %matplotlib inline

# %%
#path = osp.join(META_DATA_DIR, CYTOKINES + '.csv')
#path = osp.join(META_DATA_DIR, CELL_TYPES + '.csv')
path = osp.join(META_DATA_DIR, TRANSCRIPTION_FACTORS + '.csv')
df = pd.read_csv(path)
df.head()
# Out:
#                    id      src         sym         lbl  spid            extid  \
# 0  TFC491EFF7A86A1701  lambert  AC008770.2  AC008770.2     1  ENSG00000267179
# 1  TF366ACF42CE4CCEBB  lambert  AC008770.3  AC008770.3     1  ENSG00000267179
# 2  TF9837F24D5ADF39CB  lambert  AC023509.3  AC023509.3     1  ENSG00000267281
# 3  TFA91BACA6A8187757  lambert  AC092835.1  AC092835.1     1  ENSG00000233757
# 4  TF25E2A8B125012DB6  lambert  AC138696.1  AC138696.1     1  ENSG00000264668
#
#                prefid
# 0  TFC491EFF7A86A1701
# 1  TF366ACF42CE4CCEBB
# 2  TF9837F24D5ADF39CB
# 3  TFA91BACA6A8187757
# 4  TF25E2A8B125012DB6

# %%
#df[df['sym'].str.upper().str.contains('OX4')]
#df[df['sym'].str.upper().str.contains('ROR')].head(15)
df[df['sym'].str.upper().str.contains('MUS')].head(15)
# Out:
#                       id      src                                    sym  \
# 1557  TFD8B237E252A56E1D  lambert                                MUSTRD1
# 1562  TF23F9C4DD750C99DD  lambert                         hMusTRD1alpha1
# 2509  TF412572EDCBC6468E  lambert  muscleblind like splicing regulator 2
# 2636  TF2C622F4F80A4EF72  lambert                               musculin
#
#            lbl  spid            extid              prefid
# 1557  GTF2IRD1     1  ENSG00000006704  TF4A8F77E47C21007D
# 1562  GTF2IRD1     1  ENSG00000006704  TF4A8F77E47C21007D
# 2509     MBNL2     1  ENSG00000139793  TFC21628B94F388D15
# 2636       MSC     1  ENSG00000178860  TF28BE4CF7E8BDE06F

# %%
df[df['sym'].str.upper().str.contains('ROR')]['lbl'].unique()
# Out:
# array(['RORA', 'RORB', 'RORC'], dtype=object)

# %%
df[df['lbl'].str.upper() == 'RORC']
# Out:
#                       id      src                            sym   lbl  spid  \
# 4029  TF765F9A5B1C495BB2  lambert                           RORC  RORC     1
# 4030  TF60A9F7E7158173A5  lambert  RAR related orphan receptor C  RORC     1
# 4031  TF41F5F4FE0A10A6C8  lambert                          IMD42  RORC     1
# 4032  TFDCC9AABEBEF786D8  lambert                          NR1F3  RORC     1
# 4033  TFFAA0DCD9CD7116F7  lambert                           RORG  RORC     1
# 4034  TF895F457D9E92DCDF  lambert                      RZR-GAMMA  RORC     1
# 4035  TFE8E5BD50A454DE79  lambert                           RZRG  RORC     1
# 4036  TFEA0CF76D98BFD234  lambert                            TOR  RORC     1
#
#                 extid              prefid
# 4029  ENSG00000143365  TF765F9A5B1C495BB2
# 4030  ENSG00000143365  TF765F9A5B1C495BB2
# 4031  ENSG00000143365  TF765F9A5B1C495BB2
# 4032  ENSG00000143365  TF765F9A5B1C495BB2
# 4033  ENSG00000143365  TF765F9A5B1C495BB2
# 4034  ENSG00000143365  TF765F9A5B1C495BB2
# 4035  ENSG00000143365  TF765F9A5B1C495BB2
# 4036  ENSG00000143365  TF765F9A5B1C495BB2
