# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import word2vec
import re
import plotly
import plotly.plotly as py
from plotly import graph_objs as go

# %%
plotly.offline.init_notebook_mode()

# %% [markdown]
# ## Load Cell Type Tags
#
# These tags are a combination of white-listed T cell types and a JNLPA-trained NER model noun phrases from 10k doc PMC corpus

# %%
df = pd.read_csv('/Users/eczech/data/research/hammer/nlp/20190311-pubmed-tcell-relation/articles/corpus/corpus_01/tags.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4007030 entries, 0 to 4007029
# Data columns (total 10 columns):
# id            object
# type          object
# ent_id        object
# ent_lbl       object
# ent_prefid    object
# start_chr     int64
# end_chr       int64
# start_wrd     int64
# end_wrd       int64
# text          object
# dtypes: int64(4), object(6)
# memory usage: 305.7+ MB

# %%
pattern = re.compile('[T][hH][-]?\d{1,2}')
    
def accept(r):
    t = r['text']
    for p in ['T cell', 'T-cell', 'T lymphocyte', 'T-lymphocyte', 'TH-', ' T ', 'T helper', 'T-helper']:
        if p in t:
            return True
    if pattern.search(t):
        return True
    return False

# Filter to t cell types only from NER model (ignore IMMUNE_CELL_TYPE to ignore white-listed cell types)
df = (
    df 
    .pipe(lambda df: df[df['type'].str.contains('CELL_TYPE')])
    .pipe(lambda df: df[df.apply(accept, axis=1)])
    .assign(type=lambda df: df['type'].map(dict(CELL_TYPE='JNLPA-NER', IMMUNE_CELL_TYPE='WHITE-LIST')))
)

df.head()
# Out:
#              id       type ent_id ent_lbl ent_prefid  start_chr  end_chr  \
# 10   PMC5704053  JNLPA-NER    NaN     NaN        NaN        511      529
# 43   PMC5704053  JNLPA-NER    NaN     NaN        NaN       2761     2773
# 45   PMC5704053  JNLPA-NER    NaN     NaN        NaN       2893     2905
# 73   PMC5704053  JNLPA-NER    NaN     NaN        NaN       4346     4370
# 160  PMC5704053  JNLPA-NER    NaN     NaN        NaN      10311    10329
#
#      start_wrd  end_wrd                      text
# 10          94       99        naïve CD4+ T cells
# 43         488      492              CD8+ T cells
# 45         512      516              CD8+ T cells
# 73         791      799  naïve CD4+ CD25− T cells
# 160       1956     1961        CD4+ CD25− T cells

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 358790 entries, 10 to 4007021
# Data columns (total 10 columns):
# id            358790 non-null object
# type          358790 non-null object
# ent_id        124519 non-null object
# ent_lbl       124519 non-null object
# ent_prefid    124519 non-null object
# start_chr     358790 non-null int64
# end_chr       358790 non-null int64
# start_wrd     358790 non-null int64
# end_wrd       358790 non-null int64
# text          358790 non-null object
# dtypes: int64(4), object(6)
# memory usage: 30.1+ MB

# %%
# Breakdown by source
df['type'].value_counts()
# Out:
# JNLPA-NER     234271
# WHITE-LIST    124519
# Name: type, dtype: int64

# %%
# Num unique cell type noun phrases
df['text'].nunique()
# Out:
# 30728

# %%
# Sort cell type phrases by frequency and show horizontal concatentation by rank slice 
# (50 items per slice, starting at various positions within ranked list)
def ct(rng, grp):
    return (
        df['text'].value_counts().rename('count').rename_axis('text', axis=0)
        .sort_values(ascending=False).iloc[slice(*rng)].reset_index()
        .rename(columns=lambda c: (grp, c))
        .pipe(lambda df: df.set_axis(pd.MultiIndex.from_tuples(df.columns.to_list()), axis=1, inplace=False))
    )
pd.concat([ct((i-1, i+50-1), '#%s-%s' % (i, i+50)) for i in [1, 500, 1000, 5000]], axis=1)
# Out:
#                        #1-51                              #500-550        \
#                         text  count                           text count
# 0                    T cells  45886    CD4+ and CD8+ T-lymphocytes    30
# 1                       Th17  41559       freshly isolated T cells    30
# 2                        Th1  32949           primary CD8+ T cells    30
# 3                        Th2  27526                  CD56+ T cells    30
# 4               CD4+ T cells  21958         activated CD4+ T-cells    30
# 5               CD8+ T cells  13059              CD4+ T cell types    30
# 6                CD4 T cells   4985             Naive CD8+ T cells    30
# 7              T lymphocytes   4964            circulating T-cells    30
# 8                       TH17   4212        activated T-lymphocytes    30
# 9                   T helper   4209           CMV-specific T-cells    30
# 10               CD4+ T cell   4030  splenic CD4+ and CD8+ T cells    30
# 11               CD8 T cells   3951            CD4+ T cell lineage    29
# 12                   T-cells   3906       CNS-infiltrating T cells    29
# 13               CD8+ T cell   3059       memory-like CD8+ T cells    29
# 14         activated T cells   3020      pathogen-specific T cells    29
# 15     CD4+ and CD8+ T cells   2630      infiltrating CD4+ T cells    29
# 16                       TH1   2602         CD4 T cell populations    29
# 17                       TH2   2512                 CD8+ T cells\n    29
# 18          effector T cells   2413      antigen-activated T cells    29
# 19                       Th9   2378               non-CD4+ T cells    29
# 20              CD4+ T-cells   1708                    293FT cells    29
# 21                       Th0   1442          memory T-cell subsets    29
# 22            T cell subsets   1438                   GFP+ T cells    29
# 23        naive CD4+ T cells   1432           WT1-specific T cells    29
# 24                    T cell   1372     proliferating CD8+ T cells    29
# 25                  T-helper   1249                hepatic T cells    29
# 26              CD8+ T-cells   1126             engineered T cells    29
# 27             human T cells   1082    T lymphocyte subpopulations    29
# 28              CD3+ T cells   1052  bacteria-specific CD4 T cells    29
# 29        naïve CD4+ T cells    969                    CD8+ T-cell    29
# 30        CD4+ T lymphocytes    922        effector memory T-cells    29
# 31             T-lymphocytes    860             T cell infiltrates    29
# 32                      Th22    834      mature peripheral T cells    29
# 33  antigen-specific T cells    827            resting CD4 T cells    29
# 34       memory CD8+ T cells    711                     BM T cells    29
# 35        CD8+ T lymphocytes    698            primary CD8+ T cell    29
# 36      autoreactive T cells    596                   CD4+ T cells    29
# 37                  WT cells    593        mouse and human T cells    29
# 38       memory CD4+ T cells    586           CD4+ T cell epitopes    28
# 39            T-cell subsets    578             CD3+ T-lymphocytes    28
# 40        T cell populations    548                 spleen T cells    28
# 41        memory CD8 T cells    541    effector T cell populations    28
# 42                CD4 T cell    513            CXCR5+ CD8+ T cells    28
# 43                       TH9    511           B- and T-lymphocytes    28
# 44               CD4+T cells    506     primary CD4+ T lymphocytes    28
# 45              T lymphocyte    488     autoreactive T lymphocytes    28
# 46    activated CD4+ T cells    478  encephalitogenic CD4+ T cells    28
# 47       CD4 and CD8 T cells    473              cytolytic T cells    28
# 48            mature T cells    468    tumor-reactive CD4+ T cells    28
# 49     effector CD8+ T cells    466         cytotoxic T-lymphocyte    28
#
#                          #1000-1050        \
#                                text count
# 0             contaminating T cells    15
# 1     IL-17A-producing CD4+ T cells    15
# 2            anti-tumor CD8+ T cell    15
# 3                      live T cells    15
# 4              CD4+ to CD8+ T cells    15
# 5              CD3-positive T cells    15
# 6          human CD8+ T lymphocytes    15
# 7          Thy1.1+OT-1+CD8+ T cells    14
# 8                 TGF-β1−/− T cells    14
# 9                gated CD8+ T cells    14
# 10                     CD8 + T cell    14
# 11          IL-21-producing T cells    14
# 12    autologous CD4+ T lymphocytes    14
# 13          double-negative T cells    14
# 14             intrahepatic T cells    14
# 15                       RA T-cells    14
# 16                 OT1-CD8+ T cells    14
# 17       blood-derived CD8+ T-cells    14
# 18                    CD57+ T cells    14
# 19             MOG-reactive T cells    14
# 20        SIV-specific CD8+ T cells    14
# 21                 MOG-CD8+ T cells    14
# 22                 CD3+CD4+ T-cells    14
# 23               p110δD910A T cells    14
# 24            CD4 T-cell population    14
# 25                   CD62L+ T cells    14
# 26         memory-like CD4+ T-cells    14
# 27                 resident T cells    14
# 28    CD4+IFN-γ+IL-17+ Th1/17 cells    14
# 29        inflammatory CD4+ T cells    14
# 30  tumor-specific effector T cells    14
# 31  tumor-infiltrating CD4+ T cells    14
# 32             proliferated T cells    14
# 33                  CFSElow T cells    14
# 34            T lymphocyte subtypes    14
# 35       cytokine producing T cells    14
# 36                 ILCs and T cells    14
# 37                syngeneic T cells    14
# 38        CD4+ conventional T cells    14
# 39          CD4+ T-cell compartment    14
# 40              WT effector T cells    14
# 41                Blina-RNA T cells    14
# 42           differentiated T-cells    14
# 43       influenza-specific T cells    14
# 44                CD4CD8 DP T cells    14
# 45              CD4+ and DN T cells    14
# 46         IL-18Rα+DR3+CD4+ T cells    14
# 47             CD4+ splenic T cells    14
# 48                   CD8αα+ T cells    14
# 49         HIV-specific CD4 T cells    14
#
#                                            #5000-5050
#                                                  text count
# 0                     circulating Aβ-reactive T cells     2
# 1                                  young CD8+ T cells     2
# 2                       cytokine-producing CART cells     2
# 3                                     mucosal T-cells     2
# 4                       encephalitogenic CD4+ T-cells     2
# 5                             immune response T cells     2
# 6                           B-cell and T-cell subsets     2
# 7                    proliferating T cell populations     2
# 8                 autoreactive immature T lymphocytes     2
# 9                          CD8+ or CD4+ T lymphocytes     2
# 10                                 total lung T cells     2
# 11                                  sorted Tg T cells     2
# 12                                 local CD4+ T cells     2
# 13                     CD8+ T cell-mediated cytotoxic     2
# 14                            colonic WT CD4+ T cells     2
# 15                                  CD44+ CD4 T cells     2
# 16                                  Pure CD4+ T cells     2
# 17                            Cytotoxic T-lymphocytes     2
# 18                                   adoptive T cells     2
# 19                                 Tim-3−CD3+ T cells     2
# 20                           NLGP-TME exposed T cells     2
# 21  CD4+ T transcriptional-signaling regulatory ne...     2
# 22                       memory effector CD8+ T cells     2
# 23                           high avidity CD8+ T cell     2
# 24                      follicular T-cell populations     2
# 25                               P1A‐specific T cells     2
# 26                 KLRG1+CD127- effector CD8+ T cells     2
# 27                           anti-fungal CD4+ T cells     2
# 28                         non-protective CD4+ T cell     2
# 29                                  antiviral T-cells     2
# 30                         proliferated T lymphocytes     2
# 31                        CD4+ PTM-transduced T cells     2
# 32                                mucosal CD8+ T cell     2
# 33                           CD8 conventional T cells     2
# 34                           circulating CD3+ T-cells     2
# 35                 pancreas infiltrating CD8+ T cells     2
# 36                       tumor-reactive T lymphocytes     2
# 37                              labeled T lymphocytes     2
# 38                activated and proliferating T cells     2
# 39              GP33- and GP276-specific CD8+ T cells     2
# 40                                    PB CD8+ T cells     2
# 41                    Tumor-specific effector T cells     2
# 42                            beads-activated T cells     2
# 43                      ACh-synthesizing CD4+ T cells     2
# 44                            CD69-expressing T cells     2
# 45       viral epitope-specific pentamer+CD8+ T cells     2
# 46                                Spleen T CD4+ cells     2
# 47                       peripheral blood CD4+ T-cell     2
# 48                                  CD45+ and T cells     2
# 49               single-positive CD4+ or CD8+ T cells     2

# %%
re.search(r'^(?:[tT][hHcCr]|[tT][- ][hH]elper )\d{1,2}(?: cell| lympo)?', 'T-helper 17')
# Out:
# <_sre.SRE_Match object; span=(0, 11), match='T-helper 17'>

# %%
# Compare the most common white-listed cell types to those from the NER tagger,
# looking specifically for the very common "Th\d{1,2}" pattern or minor variants
# NOTE: The "Th\d{1,2}" pattern is very frequently missed by the NER model

def get_cts(typ, pattern):
    return df.query('type == "%s"' % typ)\
        .pipe(
            lambda df: df[df['text'].str.contains(pattern)]['text']\
            .value_counts().rename('count').rename_axis('text', axis=0).sort_values().tail(50).reset_index()\
            .add_prefix(typ + ':')
        )
pd.concat([
    # Match to TH17 | Tr1 | Tc0 | T helper 17 etc.
    get_cts('JNLPA-NER', r'^(?:[tT][hHcCr]|[tT][- ][hH]elper )\d{1,2}(?: cell| lympo)?'), 
    get_cts('WHITE-LIST', '.*')
], axis=1)
# Out:
#                                        JNLPA-NER:text  JNLPA-NER:count  \
# 0                                       Th1/Th17 cell                3
# 1                                    Th1/Th17 subsets                3
# 2                                Th1/Th17 lymphocytes                4
# 3                                       TH1/TH2 cells                4
# 4                                  Th1Th17/Th1* cells                4
# 5                                        Th17.1 cells                4
# 6                               Th17/Th1 hybrid cells                4
# 7                                  Th1/Th2/Th17 cells                4
# 8                             Th1/Th17 effector cells                4
# 9                          Th17/Treg cell populations                4
# 10                                      Th17/Th1 cell                4
# 11                                     Th1-Treg cells                4
# 12                           Th1-Treg cell population                4
# 13  Th2-skewed human peripheral blood mononuclear ...                4
# 14                              Th1-polarized T cells                4
# 15                                          Th17-like                4
# 16                                            Th2/Tc2                4
# 17                                      Th1/Tc1 cells                5
# 18                                     TH1/TH17 cells                5
# 19                                   TH1-like subsets                5
# 20                                    Th17/CD4+ cells                5
# 21                              Th1/Th17 hybrid cells                5
# 22                                          Th1-cells                5
# 23                                    Th1/Tc1 T cells                5
# 24                                     Th2-type cells                6
# 25                                   Th2-type T cells                6
# 26                                           Th1/Th17                6
# 27                                   Th1-type T cells                8
# 28                                     Th17/Treg cell                8
# 29                                     Th1/Th17 cells                8
# 30                                    Th1/Th2 subsets                9
# 31                                     Th1-type cells                9
# 32                                       Th1/Th2 cell               10
# 33                        Th2-type innate lymphocytes               10
# 34                                    Th17-like cells               11
# 35                                Th17-negative cells               11
# 36                                          Th17/Treg               13
# 37                                             Th1/17               15
# 38                                            Th1/Th2               15
# 39                                         Th17-cells               17
# 40                                       Th1/17 cells               22
# 41                                           Th17/Th1               23
# 42                                        Th1/2 cells               23
# 43                                        Th2/1 cells               27
# 44                                     Th2-like cells               32
# 45                                     Th17/Th1 cells               37
# 46                                    Th17/Treg cells               51
# 47                                     Th1-like cells               52
# 48                                      Th1/Th2 cells               74
# 49                                     Th1/Th17 cells               85
#
#             WHITE-LIST:text  WHITE-LIST:count
# 0               T helper-17                 7
# 1                 T helper1                 7
# 2                       TH3                 7
# 3   peripheral T regulatory                 7
# 4    inducible T regulatory                 8
# 5               T helper 22                 8
# 6                T helper-2                 9
# 7                  Treg/Th1                 9
# 8                T helper 9                10
# 9                T helper-1                11
# 10          inducible T reg                11
# 11               T helper 3                11
# 12          T helper cell 1                12
# 13                     TH-1                12
# 14                Treg-Th17                13
# 15          T helper (Th) 2                15
# 16     natural T regulatory                16
# 17               T-helper-1                16
# 18     induced T regulatory                17
# 19            natural T reg                18
# 20            induced T reg                19
# 21           T helper (Th)2                23
# 22         T helper (Th) 17                26
# 23          T helper (Th)17                37
# 24                     TH22                40
# 25         peripheral T reg                46
# 26                    TH-17                55
# 27          T helper (Th) 1                66
# 28           T helper (Th)1                71
# 29                     Th-2                85
# 30                      TH0               104
# 31                    Th-17               150
# 32                     Th-1               179
# 33               T helper 2               191
# 34                Treg/Th17               202
# 35                      Th3               234
# 36              T helper 17               315
# 37               T helper 1               372
# 38                      TH9               511
# 39                     Th22               834
# 40                 T-helper              1249
# 41                      Th0              1442
# 42                      Th9              2378
# 43                      TH2              2512
# 44                      TH1              2602
# 45                 T helper              4209
# 46                     TH17              4212
# 47                      Th2             27526
# 48                      Th1             32949
# 49                     Th17             41559

# %%
# Look for cell types with long strings of CD* designations
df[df['text'].str.contains(r'(?:CD\d{1,3}[\+-]){3,}')]['text'].value_counts().sort_values().tail(50)
# Out:
# CD3+CD4+CD25+Foxp3+ T cell                                             1
# Tumor environment CD4+CD25-CD69+Foxp3-LAP+ T cells                     1
# CD3+CD4-CD8- T cell                                                    1
# CD4+CD25+CD44+ T cells                                                 1
# CD45+CD3+CD4+ helper T-cells                                           1
# CD3+CD4+CD25+Forp3+ T cells                                            1
# CD4+CD25-CD127+ effector T-cells                                       1
# CD45+CD3+CD8+ T cells                                                  1
# CD3+CD4-CD8- double-negative (DN) T cells                              1
# CD4+CD45RA+CD45RO−CD62L+CCR7+CD127+CD27+CD28+CD95+CD122+ T cells       1
# CD4+CD25+CD127+ T effector cells                                       1
# CD45+CD3+CD4+ T cells                                                  1
# CD28-CD57-CD8+ T-cells                                                 1
# CD4+CD25+CD73+ T cells                                                 1
# CD4+CD122+CD127+T cells                                                1
# CD4+CD25+CD127- T cells                                                1
# CD3+CD8+CD28+CD45RO−CCR7+ T-cells                                      1
# Recovering CD3+CD4+CD25+Foxp3+ T cells                                 1
# CD3+CD4-CD8-T lymphocytes                                              1
# mature CD34-CD4-CD8+ or CD34-CD4+CD8- T cells                          1
# thymic mature CD4-CD8+CD3+RORγt+T cells                                1
# CD4+CD25+CD152+ T cells                                                1
# CD3+CD8+CD28+ T lymphocytes                                            1
# CD4-CD8-CD3+ (double-negative, DN) T cells                             1
# CD3+CD4+CD56+ immunosuppressive T cells                                1
# IL-17-producing CD3+CD4+CD69+ T cells                                  1
# CD3+CD4-CD8- double-negative (DN) T lymphocyte populations             1
# less-differentiated transitional memory and CD28-CD57-CD8+ T-cells     1
# CD4+CD8-CD14-CD123-CD45RA-CD45RO+ (memory CD4 T cells                  1
# CD8+CD28-CD57+ T cells                                                 1
# CD4+CD161+CD196+ T Cells\n                                             1
# CD4+CD161+CD196+ Th17-cells                                            1
# CD3+CD4-CD8- (double-negative) T cell populations                      1
# CD4+CD28+CD27+ and CD4+CD28+CD27− T cells                              1
# CD3+CD4-CD8- for double-negative T lymphocytes                         1
# naïve (CD4+CD25-CD44-CD62L+) CD4 T cells                               1
# mature CD4-CD8+CD3+RORγt+T cells cells                                 1
# CD4+CD28+CD57+ T-cells                                                 1
# CD25+CD39+CD4+ T cells                                                 2
# CD27+CD28+CD8+ T cells                                                 2
# CD3+CD4+CD69+ T lymphocytes                                            2
# CD3+CD4-CD8- double negative T cells                                   2
# CD4+CD27+CD28+ T cells                                                 2
# CD3+CD4-CD8- T cells                                                   2
# CD3+CD4+CD25+Foxp3+ T cells                                            3
# CD3+CD4+CD25+FoxP3+ T cells                                            3
# CD4+CD25+CD69+ T cells                                                 3
# CD3+CD4+CD44+ T cells                                                  4
# mature CD4-CD8+CD3+RORγt+T cells                                       7
# CD4+CD161+CD196+ T cells                                              12
# Name: text, dtype: int64

# %% [markdown]
# ## Load Embeddings

# %%
# See: https://github.com/danielfrg/word2vec
model = word2vec.load('/Users/eczech/Downloads/PubMed-and-PMC-w2v.bin')
# Out:
# /Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
# Number of words in vocab:
len(model.vocab)
# Out:
# 4087446

# %%
# Check to see if multi-protein modifiers are present in vocab
words = pd.Series(model.vocab)
words[words.str.contains('CD4\+')]
# Out:
# 2312                                          CD4+
# 18996                                    CD4+CD25+
# 36648                                    CD4+CD25-
# 46619                                     CD4+CD8+
# 50250                                    CD4+/CD8+
# 54278                                        CD4+T
# 66209                              CD4+CD25+Foxp3+
# 71137                                     CD3+CD4+
# 77722                                     CD4+CD8-
# 77855                                   CD4+Foxp3+
# 84450                                 CD4+CD25high
# 90325                                    CD25+CD4+
# 98198                              CD4+CD25+FoxP3+
# 102586                                      CD4+8+
# 126543                                      CD4+8-
# 128745                                 CD4+CD45RO+
# 136560                                 CD4+CD45RA+
# 136968                                CD4+CD28null
# 140567                                  CD4+FoxP3+
# 146239                                  CD4+CD25hi
# 171614                                  CD4+/CD25+
# 176879                                   CD4+CD28-
# 181022                                   CD3+/CD4+
# 182547                             CD4+CD25+FOXP3+
# 191189                                   CD25-CD4+
# 196574                                  CD4+CD62L+
# 208331                                  CD4+Foxp3-
# 210551                                   CD4+:CD8+
# 224741                                   CD4+CCR5+
# 229998                              CD4+CD45RBhigh
#                             ...
# 4036849                                   CD4+Tax-
# 4038809                              CD4+Foxp3gfp+
# 4039165                            CD4+Foxp3+cells
# 4042128                                   CD4+IL13
# 4042210                              CD11ahighCD4+
# 4043106                                    NK:CD4+
# 4049400                                  CD4+8+3lo
# 4050349                           CD4+CD8-Vbeta3hi
# 4051114                                CD4+CD45RB+
# 4051309                                CD4+CD43low
# 4051472                                   CD4+CAB+
# 4052114                         CD25+CD45RBlowCD4+
# 4052588                         CD4+CD44lowCD5high
# 4054116                       CD4+CD25+-expressing
# 4054649                              IL-1R1-/-CD4+
# 4055228                            CD4+CCR7+CD62L+
# 4057367                                CD4+CD25dim
# 4058839                        CD4+CD45RO/RBbright
# 4059230                           Thy1.1+CD4+CD25+
# 4067168                           IFN-gamma-/-CD4+
# 4069045              CD4+CD25+CD45RO+IL-7Ralphalow
# 4070768    CD4+/CD8+/NK1.1+/Mac-1+/Gr1+/CD3+/B220+
# 4071099                          CD4+CD44loCD62Lhi
# 4072486                            CD62L+CD25-CD4+
# 4073602                      CD4+CD127+CD25neg-int
# 4074469                        CD4+CD25highCTLA-4+
# 4078177                       CD4+CD62L+Foxp3.GFP-
# 4078754                             CD4+CD127low/-
# 4081757              TCRalphabeta+CD4+CD25-CD107a+
# 4086237                         CD4+CXCR5+PD-1high
# Length: 1092, dtype: object

# %% [markdown]
# ## Clustering

# %%
# Pull list of cell type phrases by frequency (only the most frequent phrases will be analyzed)
cts = df.groupby('text').size().sort_values(ascending=False).rename('count').reset_index()
cts.head()
# Out:
#            text  count
# 0       T cells  45886
# 1          Th17  41559
# 2           Th1  32949
# 3           Th2  27526
# 4  CD4+ T cells  21958

# %%
def get_vecs(df, model, use_spacy=False):
    mtxt, mvec = [], []
    
    if use_spacy:
        import spacy
        nlp = spacy.load('en_core_sci_md')
        
    # Map index -> vocab word
    lkp = pd.Series(np.arange(len(model.vocab)), index=model.vocab).to_dict()
    
    # Build list of 200 dimension vectors with corresponding text
    for i, r in tqdm.tqdm_notebook(df.iterrows(), total=len(df)):
        ws = [str(t) for t in nlp.tokenizer(r['text'])] if use_spacy else r['text'].split()
        
        # Fetch vectors for present tokens 
        wsidx = [i for i in range(len(ws)) if ws[i] in lkp]
        wslbl = str(list(np.array(ws)[wsidx])) 
        vecs = [model.vectors[lkp[ws[i]]] for i in wsidx]
        
        # Ignore cell types having no tokens with embedding vectors
        if len(vecs) == 0:
            continue
            
        # Sum embeddings across present tokens
        mtxt.append((wslbl,) + tuple(r.values))
        mvec.append(np.stack(vecs).sum(axis=0))
    df = pd.DataFrame(mvec, index=pd.MultiIndex.from_tuples(mtxt))
    df.index.names = ['label', 'text', 'count']
    return df

dfv = get_vecs(cts, model, use_spacy=False)
#dfv = get_vecs(cts, model, use_spacy=True)
# Out:
# HBox(children=(IntProgress(value=0, max=30728), HTML(value='')))

# %%
dfv.head(3)
# Out:
#                                    0         1         2         3    \
# label          text    count
# ['T', 'cells'] T cells 45886  0.046443 -0.034749  0.092937  0.029665
# ['Th17']       Th17    41559 -0.045065  0.091974 -0.057747  0.006647
# ['Th1']        Th1     32949  0.017503  0.097283 -0.099464  0.020219
#
#                                    4         5         6         7    \
# label          text    count
# ['T', 'cells'] T cells 45886  0.149286  0.250088 -0.059849  0.199854
# ['Th17']       Th17    41559  0.047733  0.160625 -0.024835  0.052163
# ['Th1']        Th1     32949  0.023538  0.168440 -0.023904  0.108156
#
#                                    8         9    ...       190       191  \
# label          text    count                      ...
# ['T', 'cells'] T cells 45886 -0.153880 -0.060050  ... -0.312609 -0.006381
# ['Th17']       Th17    41559 -0.105156 -0.054238  ... -0.054173 -0.057372
# ['Th1']        Th1     32949 -0.061502 -0.017315  ... -0.023351 -0.059457
#
#                                    192       193       194       195  \
# label          text    count
# ['T', 'cells'] T cells 45886  0.022755  0.311247  0.055689  0.199118
# ['Th17']       Th17    41559  0.037496  0.106478  0.063646  0.040446
# ['Th1']        Th1     32949  0.026301  0.050174  0.059468 -0.019950
#
#                                    196       197       198       199
# label          text    count
# ['T', 'cells'] T cells 45886 -0.170190  0.194637  0.117738 -0.028728
# ['Th17']       Th17    41559  0.001464  0.100441 -0.030139  0.087788
# ['Th1']        Th1     32949 -0.084066  0.107506 -0.032287  0.049623
#
# [3 rows x 200 columns]

# %%
import umap
from numba import NumbaPerformanceWarning
import warnings

with warnings.catch_warnings():
    warnings.filterwarnings("ignore", category=NumbaPerformanceWarning)
    decomp = umap.UMAP(n_components=2, metric='cosine', n_neighbors=15, random_state=1)
    X = dfv.head(10000)
    Y = decomp.fit_transform(X.values)

# %%
from scipy.stats import gaussian_kde
size = np.log10(X.index.get_level_values('count')) 
size = np.clip(20 * (size / size.max()), 6, 20)
kde = gaussian_kde(Y.T)(Y.T)
trace = go.Scatter(
    x = Y[:, 0],
    y = Y[:, 1],
    text = [
        'Text: {}<br>Vocab: {}<br>N: {}'.format(i[1].replace('\n', ''), i[0], i[2]) 
        for i in X.index
    ],
    marker = dict(size=size, line=dict(width=0), color=kde, colorscale='Portland'),
    mode = 'markers'
)
layout = go.Layout(hovermode='closest')
fig = go.Figure(data=[trace], layout=layout)
plotly.offline.iplot(fig) 
# When ready: 
# plotly.tools.set_credentials_file(username='eczech', api_key='########')
# py.iplot(fig, filename='word2vec_umap_v2')
# Out:
# <div>
#
#
#             <div id="3d8ef042-7859-4ac9-9455-3ed38c967533" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3d8ef042-7859-4ac9-9455-3ed38c967533")) {
#                     Plotly.newPlot(
#                         '3d8ef042-7859-4ac9-9455-3ed38c967533',
#                         [{"marker": {"color": [0.007827493872698078, 0.003486633126421464, 0.0034754428740558104, 0.0034882216268703465, 0.0023508455385117316, 0.002471004411731863, 0.0013707362772901338, 0.0026847749867017945, 0.0034809618221333855, 0.0032532259099842514, 0.0048062240181934324, 0.0030227045564933303, 0.0009849125318346242, 0.004821579794883168, 0.0035791886352588443, 0.002483188193357934, 0.003471730809297583, 0.003470087010993826, 0.0017556129593266207, 0.003481587301746384, 0.004355183216318148, 0.003467853745609272, 0.0055682147400792845, 0.007385993243246924, 0.0038784708277865144, 0.0033298831813397003, 0.003418946579770247, 0.0017184577146835292, 0.005689979002891523, 0.002237288851711039, 0.00419348752557238, 0.0039870590849331216, 0.0035082509458923394, 0.008998168903424234, 0.0023420612388870255, 0.004156357033151381, 0.009431810314053362, 0.00267226385698159, 0.0023298552072633745, 0.003957882628294699, 0.004726209395147113, 0.0022429694693412295, 0.005318713393442806, 0.0034572595915035773, 0.010434404555919433, 0.0034231102572735224, 0.0034902474314853506, 0.003448897179479704, 0.002595266111803291, 0.0023366113032922717, 0.0020231252449671422, 0.002796034883475399, 0.005545791026106172, 0.0029447225102505327, 0.0025189814856125133, 0.002039877721908061, 0.00418760227558944, 0.002695103018363872, 0.008083844077899771, 0.0005714527845660663, 0.0013549616760880187, 0.0030742284112019813, 0.002618848284691266, 0.003451945575222782, 0.006530519764050496, 0.006729148352578166, 0.0032224759612584654, 0.00547699571625263, 0.0023408033717624913, 0.0005823945129476826, 0.007068111230165449, 0.0026078225501175245, 0.00526699157674857, 0.0030715621759613196, 0.004361720406995548, 0.007541193571567591, 0.0025076328080066886, 0.004306688951635334, 0.0016781150948408617, 0.003466871870876913, 0.0009659809081516531, 0.0027882399562783326, 0.005394941251156653, 0.0030624381593955877, 0.004268504094447954, 0.0022544851380175896, 0.007134150300122823, 0.002985320166151154, 0.003229013297792328, 0.00361675810307285, 0.003318246861122671, 0.009276496652984108, 0.003454367678154747, 0.0030716482538425418, 0.0036592857479917783, 0.00139126493816235, 0.01001992473037002, 0.003676679889912846, 0.008705276456143883, 0.002254055766543187, 0.0020960945074968715, 0.00752669552993535, 0.0020381907376487846, 0.0026983732645913193, 0.003647947196140497, 0.008058091436225129, 0.01043337712771218, 0.0034779765721433026, 0.003642276569905728, 0.0040051990723587805, 0.005199144043110746, 0.0036186419910583995, 0.0070296672005379195, 0.007030217973900798, 0.0005971340013586459, 0.0017875982109700145, 0.0019155713396877706, 0.004247692523376621, 0.004004836028131461, 0.001074617749834776, 0.0022937553861137093, 0.008042342297176033, 0.0034992723767373487, 0.003463084979443342, 0.005554404683372248, 0.004033362176620983, 0.0019032973463629023, 0.007514167809496999, 0.0022322946024169715, 0.0026509760145717763, 0.0030344688839500284, 0.0013351978826544003, 0.003577079840923558, 0.004919256406880518, 0.002074665542332517, 0.005548830231665817, 0.010093303121656757, 0.0039870683324343004, 0.004083755266967068, 0.004760994547933453, 0.005635651053043654, 0.01007047819710986, 0.003855165159166974, 0.00232593301230978, 0.0020476833941214735, 0.0018493442853426498, 0.0023405080702078238, 0.007183189322240219, 0.0016787676888508427, 0.0032955813780150478, 0.006796991964795392, 0.0016422762453912657, 0.003430286313694489, 0.008691402053674767, 0.0023410389654188635, 0.003260903760574743, 0.004386532975965466, 0.005836904696477653, 0.004200396110159774, 0.005524245589873481, 0.005232273831275203, 0.0012588808133506097, 0.01060531889103042, 0.0110729630417712, 0.006804784467171093, 0.003381520327290605, 0.011024775486254357, 0.0034555633926418856, 0.004472407497367475, 0.0026055499119816846, 0.008510636551776949, 0.004643918183330409, 0.0028382745079736484, 0.004889660861981453, 0.007358605057984006, 0.005636309593261678, 0.004027674227518992, 0 ...

# %% [markdown]
# ### Notable T Cell Noun Phrases
#
# - myelin-reactive encephalitogenic CD4+ (T helper [Th]) cells
# - circulating autoreactive T cells
# - unprimed rat T-cell
# - OVA-specific CD4+ and CD8+ congenically labeled Thy1.1+ T cells
# - hepatic and splenic CD69+CD8+ T cells
# - double-positive (DP) T cells
# - patient-derived T-cells
# - naïve CD8+ T (CD8+CD45RA+CCR7highCD45RO−CD56-CD57−) cells
# - HBV-specific CD8 T cells
# - DO11.10 T cells
# - dividing T cells
# - CD4+2D2-IEL-THIGH cells
# - polyclonal T cells
# - quiescent T cells
# - Antigen-specific T cells
# - infiltrating T-cells
# - normal CD4+ T cells
# - Primary T cells
# - Hector T cells  (Hector is a kind of mouse line)
# - purified CD4+ T cells

# %% [markdown]
# # Graveyard

# %%
# def get_vectors(model, words):
#     lkp = pd.Series(np.arange(len(model.vocab)), index=model.vocab)
#     idx = lkp.loc[words]
#     if idx.isnull().any():
#         raise ValueError('Terms "{}" not found'.format(idx[idx.isnull()].index.values))
#     return model.vectors[idx.values]
#
# def get_augmented_vectors(model, words, combos):
#     vec = get_vectors(model, words)
#     aug = []
#     for c in combos:
#         idx = np.where(np.isin(model.vocab, c))[0]
#         if len(idx) != 2:
#             raise ValueError('Combination "{}" not found'.format(c))
#         aug.append(model.vectors[idx].sum(axis=0))
#     vec = np.concatenate((vec, np.stack(aug, axis=0)))
#     return vec
#
# twd = [
#     'CD4', 'CD4-', 'CD4+', 'CD8', 'CD8-', 'CD8+', 'CD3', 'CD3-', 'CD3+', 'CD25', 'CD25+', 'CD25-',
#     'CD19', 'CD19+', 'CD20', 'CD20+', 'CD27', 'CD27+', 'CD38', 'CD38+', 'CD24', 'CD24+', 'CD10', 'CD10+',
#     'unactivated', 'HIV-specific', 'TIM-1+', 'activated', 'T-bet+', 'CD4+CD28-',
#     'CD3+CD4+', 'CD4+CD8-', 'CD4+CD25-'
# ]
# tcb = [('CD3+', 'CD4+'), ('CD4+', 'CD8-'), ('CD4+', 'CD25-')]
# #tvc = get_vectors(model, twd)
# tvc = get_augmented_vectors(model, twd, tcb)
# tvc.shape, len(twd), len(tcb)

# from sklearn.metrics.pairwise import cosine_similarity
# cols = twd + ['{} + {}'.format(*c) for c in tcb]
# sns.clustermap(pd.DataFrame(cosine_similarity(tvc), index=cols, columns=cols), cmap='Spectral')
