# %%
import os
import os.path as osp
import pandas as pd
import numpy as np
import collections
from snorkel import SnorkelSession
from tcre import supervision
from tcre.env import *
from tcre.supervision import *
session = SnorkelSession()
classes = get_candidate_classes()

REL_INDCK, REL_SECCK, REL_INDTF = 'indck', 'secck', 'indtf'
REL_ABBRS = collections.OrderedDict([
    (REL_INDCK, REL_CLASS_INDUCING_CYTOKINE),
    (REL_SECCK, REL_CLASS_SECRETED_CYTOKINE),
    (REL_INDTF, REL_CLASS_INDUCING_TRANSCRIPTION_FACTOR),
])

# %%
from snorkel.models import Candidate
c = session.query(classes.inducing_cytokine.subclass).first()
c.get_cids(), c.cytokine_cid, c.immune_cell_type_cid
# Out:
# (('CK692CB9564F9067B0:CK6004F9DA69B8AB01',
#   'CT954E3C2D0B390922:CTE9F6070561C95355'),
#  'CK692CB9564F9067B0:CK6004F9DA69B8AB01',
#  'CT954E3C2D0B390922:CTE9F6070561C95355')

# %%
import re
from snorkel.lf_helpers import (
    get_tagged_text,
    get_left_tokens,
    get_right_tokens,
    get_between_tokens,
    get_text_splits,
    rule_regex_search_tagged_text,
    rule_regex_search_btw_AB,
    rule_regex_search_btw_BA,
    rule_regex_search_before_A,
    rule_regex_search_before_B,
)

# %% [markdown]
# ### Text Pattern Functions

# %%
TERMS = get_terms_map()

def subst_pattern(pattern, terms=None):
    for k, v in {**TERMS, **(terms or {})}.items():
        pattern = pattern.replace('{{' + k + '}}', v)
    return pattern

def regex_pattern(pattern, terms=None):
    return regex_search(None, pattern, terms=terms, pattern_only=True)
    
def regex_search(c, pattern, terms=None, pattern_only=False):
    # Add possible "cell" token after each cell type reference
    pattern = pattern.replace('{{B}}', '{{B}}( cell| type cell|-type cell)?')
    
    # Apply generic replacements in pattern
    pattern = subst_pattern(pattern, terms=terms)
    
    if pattern_only:
        return pattern
    return rule_regex_search_tagged_text(c, pattern, 1)

TERMS
# Out:
# {'r_diff_n': '(differentiation|formation|generation|polarization|development|induction)',
#  'r_diff_v': '(differentiate|form|generate|polarize|develop|differentiates|forms|generates|polarizes|develops)',
#  'r_diff_p': '(differentiated|formed|generated|polarized|developed)',
#  'r_diff_g': '(differentiating|forming|generating|polarizing|developing)',
#  'r_push_n': '(inducer|driver|director|regulator|controller|promoter|mediator|mediater)',
#  'r_push_v': '(induce|drive|direct|regulate|control|promote|mediate|induces|drives|directs|regulates|controls|promotes|mediates)',
#  'r_push_p': '(induced|drove|driven|directed|regulated|controlled|promoted|mediated)',
#  'r_push_g': '(inducing|driving|directing|regulating|controlling|promoting|mediating)',
#  'r_prod_n': '(producer|production|generator|generation|creator|creation)',
#  'r_prod_v': '(produce|generate|create|produces|generates|creates)',
#  'r_prod_p': '(produced|generated|created)',
#  'r_prod_g': '(producing|generating|creating)',
#  'r_secr_n': '(secretor|secretion|expressor|expression|producer|production|releaser|release)',
#  'r_secr_v': '(secrete|express|produce|release|secretes|expresses|produces|releases)',
#  'r_secr_p': '(secreted|expressed|produced|released)',
#  'r_secr_g': '(secreting|expressing|producing|releasing)',
#  'r_oppose_n': '(inhibitor|suppressor|suppresor|repressor|represor|antagonizer|impairer)',
#  'r_oppose_v': '(inhibit|suppress|suppres|repress|repres|antagonize|impair|inhibits|suppress|suppreses|repress|represes|antagonizes|impairs)',
#  'r_oppose_p': '(inhibited|suppressed|suppresed|repressed|represed|antagonized|impaired)',
#  'r_oppose_g': '(inhibiting|suppressing|suppresing|repressing|represing|antagonizing|impairing)',
#  'n_do': "(cannot|can't|will not|won't|are not|aren't|does not|doesn't|do not|don't|have not|haven't|would not|wouldn't|should not|shouldn't|never)",
#  'n_break': '(;|however|whereas|yet|otherwise|although|nonetheless|despite|spite of)',
#  'n_action': '(stimulation|costimulation|expansion|proliferation|migration)',
#  'wc_sm': '[^;]{0,30}',
#  'wc_md': '[^;]{0,50}',
#  'wc_lg': '[^;]{0,150}',
#  'wc_xl': '[^;]{0,250}'}

# %%
# LF_REGEX[REL_CLASS_INDUCING_CYTOKINE]['positive'][23]

# %%
def add_lf(fn, name=None):
    if name is not None:
        fn.__name__ = name
    # Register function in global namespace
    globals()[fn.__name__] = fn
        
def get_fn(ptn, sign):
    sub_ptn = regex_search(c, ptn[0], terms=ptn[1] if len(ptn)>1 else None, pattern_only=True)
    def fn(c):
        return sign * regex_search(c, ptn[0], terms=ptn[1] if len(ptn)>1 else None)
    return fn, sub_ptn

def get_agg_fn(ptns, sign, agg):
    fns = [get_fn(ptn, sign)[0] for ptn in ptns]
    def fn(c):
        return agg([f(c) for f in fns])
    return fn

# Set to true to roll all text pattern functions into a single function 
# (since there can be > 30 of them)
use_single_text_pattern_fn = True
if use_single_text_pattern_fn:
    for rcls in LF_REGEX:
        cmap = {v: k for k, v in REL_ABBRS.items()}
        for sign in LF_REGEX[rcls]:
            val = {'positive': 1, 'negative': -1}[sign]
            ptns = LF_REGEX[rcls][sign]
            if len(ptns) == 0:
                continue
            agg = max if val == 1 else min
            add_lf(get_agg_fn(ptns, val, agg), 'LF_{}_txtptn_{}_all'.format(cmap[rcls], sign[:3]))
else:
    for rcls in LF_REGEX:
        cmap = {v: k for k, v in REL_ABBRS.items()}
        for sign in LF_REGEX[rcls]:
            for i, ptn in enumerate(LF_REGEX[rcls][sign]):
                val = {'positive': 1, 'negative': -1}[sign]
                fn_name = 'LF_{}_txtptn_{}_{}'.format(cmap[rcls], sign[:3], i + 1)
                fn, sub_ptn = get_fn(ptn, val)
                print(fn_name, ':\n\t', ptn[0], '\n\t', sub_ptn)
                add_lf(fn, fn_name)

# %%
# text = 'The current {{A}}-(pos) cells'
# pattern = regex_pattern(r'{{A}}(\+|-)?(positive|negative|\(pos\)|neg|hi|lo)')
# print(pattern)
# m = re.search(pattern, text, flags=re.I)
# m is not None, m

# %% [markdown]
# ### Heuristic Functions

# %%
# Universal function to check for references that are over a certain number of words away, 
# making them unlikely to have any kind of relationship
def is_ref_too_far(c, max_words=25, allow_positive=False):
    n = len(list(get_between_tokens(c)))
    alt = 1 if allow_positive else 0
    return -1 if n > max_words else alt

for abbr in REL_ABBRS:
    add_lf(lambda c: is_ref_too_far(c), 'LF_' + abbr + '_heur_distref')
    for dist_wrd in [5, 10, 15, 20, 25, 32, 50]:
        add_lf(
            lambda c: is_ref_too_far(c, dist_wrd, allow_positive=True), 
            'LF_' + abbr + '_heur_distref_' + str(dist_wrd)
        )

def get_kwds(term_prefixes):
    return set([ 
        kw
        for prefix in term_prefixes
        for k, v in TERMS.items() if k.startswith(prefix)
        for kw in re.findall('\w+', v)
    ])

INDCK_KWS = get_kwds(['r_diff'])
SECCK_KWS = get_kwds(['r_secr'])
INDTF_KWS = get_kwds(['r_diff'])
INDCK_KWS = INDCK_KWS.difference(SECCK_KWS)
SECCK_KWS = SECCK_KWS.difference(INDCK_KWS)

             
def has_kwds(c, kwds, window=5):
    words = list(get_left_tokens(c, window=window)) + list(get_between_tokens(c)) + list(get_right_tokens(c, window=window))
    return len(kwds.intersection(words)) > 0

def LF_indck_heur_kwds(c):
    f1, f2 = has_kwds(c, INDCK_KWS), has_kwds(c, SECCK_KWS)
    if f1 and not f2:
        return 1
    if f2 and not f1:
        return -1
    return 0

def LF_secck_heur_kwds(c):
    return -1 * LF_indck_heur_kwds(c)

def LF_indtf_heur_kwds(c):
    return 1 if has_kwds(c, INDTF_KWS) else -1
        
def LF_indck_heur_closer_ck_to_ct(c):
    return -1*has_closer_reference(c, right=True)

def LF_indck_heur_closer_ct_to_ck(c):
    return -1*has_closer_reference(c, right=False)

def LF_indck_heur_closer_ref(c):
    return min(LF_indck_heur_closer_ck_to_ct(c), LF_indck_heur_closer_ct_to_ck(c))

def LF_secck_heur_closer_ck_to_ct(c):
    return -1*has_closer_reference(c, right=True)

def LF_secck_heur_closer_ct_to_ck(c):
    return -1*has_closer_reference(c, right=False)

def LF_secck_heur_closer_ref(c):
    return min(LF_secck_heur_closer_ck_to_ct(c), LF_secck_heur_closer_ct_to_ck(c))

def LF_indtf_heur_closer_tf_to_ct(c):
    return -1*has_closer_reference(c, right=True)

def LF_indtf_heur_closer_ct_to_tf(c):
    return -1*has_closer_reference(c, right=False)

def LF_indtf_heur_closer_ref(c):
    return min(LF_indtf_heur_closer_tf_to_ct(c), LF_indtf_heur_closer_ct_to_tf(c))

def _valid_cand(**kwargs):
    return lambda c: -1 if supervision.is_invalid_candidate(c, **kwargs) else 0

def _cmplx_cand(**kwargs):
    return lambda c: -1 if supervision.is_complex_candidate(c, **kwargs) else 0

for abbr in REL_ABBRS:
    add_lf(_valid_cand(fig_kw_ct_thresh=1, punc_ct_thresh=5, newline_ct_thresh=3, char_ct_thresh=2000), 'LF_' + abbr + '_heur_valid_cand_01')
    add_lf(_valid_cand(fig_kw_ct_thresh=2, punc_ct_thresh=8, newline_ct_thresh=8, char_ct_thresh=2000), 'LF_' + abbr + '_heur_valid_cand_02')
    add_lf(_valid_cand(fig_kw_ct_thresh=4, punc_ct_thresh=12, newline_ct_thresh=10, char_ct_thresh=2000), 'LF_' + abbr + '_heur_valid_cand_03')
    add_lf(_cmplx_cand(entity_ct_thresh=3, char_ct_thresh=500), 'LF_' + abbr + '_heur_complex_cand_01')
    add_lf(_cmplx_cand(entity_ct_thresh=5, char_ct_thresh=800), 'LF_' + abbr + '_heur_complex_cand_02')

# %% [markdown]
# ### Distant Supervision Functions

# %%
df_ix = pd.read_csv(osp.join(SUPERVISION_DATA_DIR, 'immunexpresso', 'data.csv'))

# Filter to records with known cell/cytokine mappings for internal IDS
df_ix = df_ix[df_ix['cell_ref_id'].notnull() & df_ix['cytokine_ref_id'].notnull()]

# Also filter to records with >= 8 publications for stronger relationships
df_ix = df_ix[df_ix['num_papers'] >= 8]
print(df_ix.info())
df_ix = df_ix.set_index(['cell_ref_id', 'cytokine_ref_id']).sort_index()

def is_known_ix_relation(c, actor, category):
    # Actor = 'cytokine' implies induction relationship where category in ['Positive', 'Negative', 'Unknown']
    # Actor = 'cell' implies secreation relationship and category is always 'Positive'
    
    # Split ids saved as "<matched id>:<preferred id>" to do lookup on preferred id
    ct_id, ck_id = c.immune_cell_type_cid, c.cytokine_cid
    ct_id, ck_id = ct_id.split(':')[1], ck_id.split(':')[1]
    if (ct_id, ck_id) in df_ix.index:
        df = df_ix.loc[(ct_id, ck_id)]
        df = df[(df['actor'] == actor) & (df['category'] == category)]
        return len(df) > 0
    return None

def LF_indck_dsup_imexpresso(c):
    if c.type != classes.inducing_cytokine.field:
        return 0
    ind1 = is_known_ix_relation(c, 'cytokine', 'Positive')
    if ind1 is None:
        return 0
    ind2 = is_known_ix_relation(c, 'cytokine', 'Negative')
    ind3 = is_known_ix_relation(c, 'cell', 'Positive')
    if ind1:
        if not ind2 and not ind3:
            return 1
    else:
        if ind2 or ind3:
            return -1
    return 0

def LF_secck_dsup_imexpresso(c):
    if c.type != classes.secreted_cytokine.field:
        return 0
    ind1 = is_known_ix_relation(c, 'cell', 'Positive')
    if ind1 is None:
        return 0
    ind2 = is_known_ix_relation(c, 'cytokine', 'Positive')
    ind3 = is_known_ix_relation(c, 'cytokine', 'Negative')
    if ind1:
        if not ind2 and not ind3:
            return 1
    else:
        if ind2 or ind3:
            return -1
    return 0
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67 entries, 13 to 206
# Data columns (total 10 columns):
# actor              67 non-null object
# category           67 non-null object
# cell_id            67 non-null object
# cell_label         67 non-null object
# cytokine_id        67 non-null object
# cytokine_label     67 non-null object
# num_papers         67 non-null int64
# score              67 non-null float64
# cell_ref_id        67 non-null object
# cytokine_ref_id    67 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 5.8+ KB
# None

# %%
#df_ix.head()
#df_ix[df_ix['cell_label'] == 'T-helper 9 cell']

# %%
#dft = df_ix[(df_ix['actor'] == 'cytokine') & (df_ix['category'] == 'Positive')].sort_values('num_papers', ascending=False)
dft = df_ix[(df_ix['actor'] == 'cell') & (df_ix['category'] == 'Positive')].sort_values('num_papers', ascending=False)
#dft[dft['cell_label'] == 'T-helper 1 cell'].head(10)
dft[dft['cell_label'] == 'T-helper 2 cell'].head(10)
# Out:
#                                       actor  category     cell_id  \
# cell_ref_id        cytokine_ref_id
# CTE7B12DC660323A0E CK6FE135B3F86FB707  cell  Positive  CL_0000546
#                    CK128EC732B281BF60  cell  Positive  CL_0000546
#                    CKC5CC1A269C01EC48  cell  Positive  CL_0000546
#                    CK3B4A795DF4150CF4  cell  Positive  CL_0000546
#                    CK7026891CEAA3C8F9  cell  Positive  CL_0000546
#
#                                             cell_label cytokine_id  \
# cell_ref_id        cytokine_ref_id
# CTE7B12DC660323A0E CK6FE135B3F86FB707  T-helper 2 cell     CID_131
#                    CK128EC732B281BF60  T-helper 2 cell      CID_83
#                    CKC5CC1A269C01EC48  T-helper 2 cell      CID_93
#                    CK3B4A795DF4150CF4  T-helper 2 cell     CID_128
#                    CK7026891CEAA3C8F9  T-helper 2 cell     CID_132
#
#                                       cytokine_label  num_papers  score
# cell_ref_id        cytokine_ref_id
# CTE7B12DC660323A0E CK6FE135B3F86FB707            IL4          59  15.88
#                    CK128EC732B281BF60           IFNG          12   0.99
#                    CKC5CC1A269C01EC48           IL10          11   2.39
#                    CK3B4A795DF4150CF4           IL33           8  14.52
#                    CK7026891CEAA3C8F9            IL5           8   7.20

# %% [markdown]
# ### Supervised Classifier Functions

# %%
# df_sup_pred = pd.read_csv(osp.join(RESULTS_DATA_DIR, 'training-dev', 'run1', 'predictions.csv'))
# df_sup_pred.info()

# %%
# OFFTARGET_SPLITS = collections.defaultdict(lambda: [])

# def get_base_sup_fn(task, cfg):
#     preds = df_sup_pred.pipe(lambda df: df[(df['cfg'] == cfg) & (df['task'] == task)]).set_index('id')['y_pred'].to_dict()
#     def fn(c):
#         if c.type != task and c.type not in COMP_CLASSES:
#             raise ValueError(f'Expected type {task} but got candidate {c} with type {c.type}')
#         # If the type of the candidate does not match that expected, then
#         # fetch the sibling candidate which should be of the correct type
#         # (this allows for example, the function to fetch SCK labels
#         # to accept an ICK candidate, convert to SCK, and then return that label instead)
#         if c.type != task:
#             sc = get_cand_sibling(c, strict=True)
#             if sc.type != task:
#                 raise ValueError(f'Sibling candidate {sc} of type {sc.type} does not match task {task} (original candidate = {c})')
#             # If the sibling ends up being in a split for which no predictions were made (e.g. INFER)
#             # record the id and abstain
#             if sc.id not in preds:
#                 OFFTARGET_SPLITS[task].append(sc.id)
#                 return 0
#             c = sc
#         if c.id not in preds:
#             raise ValueError(f'Failed to find prediction for candidate {c.id} for task {task} and model cfg {cfg}')
#         return 1 if preds[c.id] > .5 else -1
#     return fn

# for k, v in REL_ABBRS.items():
#     for cfg in df_sup_pred['cfg'].unique():
#         fn = get_base_sup_fn(classes[v].field, cfg)
#         add_lf(fn, f'LF_{k}_sup_cfg_{cfg:02d}')

# %%
# c = session.query(classes.inducing_transcription_factor.subclass).first()
# LF_indtf_sup_cfg_00(c)

# %% [markdown]
# ### Composite Functions

# %%
def _global_lfs():
    return {
        k:v for k, v in globals().items() 
        if callable(v) and k.startswith('LF_')
    }

def get_lfs(filter_fn=None): 
    lfs = _global_lfs()
    if filter_fn is None:
        filter_fn = lambda n: True
    res = collections.OrderedDict([
        (k, lfs[k]) for k in sorted(lfs.keys()) 
        if filter_fn(k)
    ])
    return res

fns_indck_comp_pos = get_lfs(lambda k: k.startswith('LF_indck_txtptn_pos'))
fns_secck_comp_pos = get_lfs(lambda k: k.startswith('LF_secck_txtptn_pos'))
fns_indtf_comp_pos = get_lfs(lambda k: k.startswith('LF_indtf_txtptn_pos'))

def summarize_fns(name, fns):
    print('{}: Num functions found = {}, Names:\n{}'.format(
        name, len(fns), '\n'.join(list(fns.keys()))
    ))
summarize_fns('fns_indck_comp_pos', fns_indck_comp_pos)
summarize_fns('fns_secck_comp_pos', fns_secck_comp_pos)
summarize_fns('fns_indtf_comp_pos', fns_indtf_comp_pos)

def LF_indck_comp_neg_sec(c):
    # Create function that returns -1 for inducing cytokines anytime a positive hit is found on secretion
    # * should return -1 or 0
    return min(-1*max([f(c) for f in fns_secck_comp_pos.values()]), 0)

def LF_secck_comp_neg_ind(c):
    # Create function that returns -1 for inducing cytokines anytime a positive hit is found on secretion
    # * should return -1 or 0
    return min(-1*max([f(c) for f in fns_indck_comp_pos.values()]), 0)

fns_indck_comp_neg = get_lfs(lambda k: k.startswith('LF_indck_txtptn_neg') or \
                             k.startswith('LF_indck_heur_distref') or \
                             k.startswith('LF_indck_heur_closer_ct_to_ck') or \
                             k.startswith('LF_indck_comp_neg_sec') or \
                             k.startswith('LF_indck_heur_complex_cand_02') or \
                             k.startswith('LF_indck_heur_valid_cand_03'))
fns_secck_comp_neg = get_lfs(lambda k: k.startswith('LF_secck_txtptn_neg') or \
                             k.startswith('LF_secck_heur_distref') or \
                             k.startswith('LF_secck_heur_closer_ct_to_ck') or \
                             k.startswith('LF_secck_comp_neg_ind') or \
                             k.startswith('LF_secck_heur_complex_cand_02') or \
                             k.startswith('LF_secck_heur_valid_cand_03'))
fns_indtf_comp_neg = get_lfs(lambda k: k.startswith('LF_indtf_txtptn_neg') or \
                             k.startswith('LF_indtf_heur_distref') or \
                             k.startswith('LF_indtf_heur_closer_ct_to_tf') or \
                             k.startswith('LF_indtf_heur_complex_cand_02') or \
                             k.startswith('LF_indtf_heur_valid_cand_03'))
summarize_fns('fns_indck_comp_neg', fns_indck_comp_neg)
summarize_fns('fns_secck_comp_neg', fns_secck_comp_neg)
summarize_fns('fns_indtf_comp_neg', fns_indtf_comp_neg)

def apply_composite_xor_indck(c):
    is_secck = max([f(c) for f in fns_secck_comp_pos.values()]) > 0
    is_indck = max([f(c) for f in fns_indck_comp_pos.values()]) > 0
    not_secck = min([f(c) for f in fns_secck_comp_neg.values()]) < 0
    not_indck = min([f(c) for f in fns_indck_comp_neg.values()]) < 0
    # Look first for single strong positive prediction
    if is_secck and is_indck:
        return 0
    if is_indck and not is_secck:
        return 1
    if not is_indck and is_secck:
        return -1
    # If neither have positive prediction, look for strong negative prediction
    if not_secck == not_indck:
        return 0
    if not_indck and not not_secck:
        return -1
    return 1

def LF_indck_comp_xor(c):
    return apply_composite_xor_indck(c)

def LF_secck_comp_xor(c):
    return -1*apply_composite_xor_indck(c)

def LF_indtf_comp_xor(c):
    is_indtf = max([f(c) for f in fns_indtf_comp_pos.values()]) > 0
    not_indtf = min([f(c) for f in fns_indtf_comp_neg.values()]) < 0
    # Take non-conflicting positive or negative classifications and make 0 otherwise
    if is_indtf and not not_indtf:
        return 1
    if not_indtf and not is_indtf:
        return -1
    return 0

# Distant supervision composites
def LF_indck_comp_imexpresso_nonneg(c):
    skip = min([f(c) for f in fns_indck_comp_neg.values()]) < 0
    return LF_indck_dsup_imexpresso(c) if not skip else 0

def LF_secck_comp_imexpresso_nonneg(c):
    skip = min([f(c) for f in fns_secck_comp_neg.values()]) < 0
    return LF_secck_dsup_imexpresso(c) if not skip else 0

# Direct supervision composites
# fns_indck_sup = get_lfs(lambda k: k.startswith('LF_indck_sup_cfg_'))
# fns_secck_sup = get_lfs(lambda k: k.startswith('LF_secck_sup_cfg_'))
# fns_indtf_sup = get_lfs(lambda k: k.startswith('LF_indtf_sup_cfg_'))
# summarize_fns('fns_indck_sup', fns_indck_sup)
# summarize_fns('fns_secck_sup', fns_secck_sup)
# summarize_fns('fns_indtf_sup', fns_indtf_sup)

# def LF_indck_sup_comp(c):
#     # If there is any strong indication of a negative, use it instead
#     not_indck = min([f(c) for f in fns_indck_comp_neg.values()]) < 0
#     if not_indck:
#         return -1
    
#     # Return false if any supervised model predicts true for secreted cytokines
#     is_secck = max([f(c) for f in fns_secck_sup.values()]) > 0
#     if is_secck:
#         return -1

#     # Otherwise, return true if any model predicts true
#     is_indck = max([f(c) for f in fns_indck_sup.values()]) > 0
#     return 1 if is_indck else -1

# def LF_secck_sup_comp(c):
#     # If there is any strong indication of a negative, use it instead
#     not_secck = min([f(c) for f in fns_secck_comp_neg.values()]) < 0
#     if not_secck:
#         return -1
    
#     # Return false if any supervised model predicts true for inducing cytokines
#     is_indck = max([f(c) for f in fns_indck_sup.values()]) > 0
#     if is_indck:
#         return -1
    
#     # Otherwise, return true if any model predicts true
#     is_secck = max([f(c) for f in fns_secck_sup.values()]) > 0
#     return 1 if is_secck else -1

# def LF_indtf_sup_comp(c):
#     # Return true if any model predicts true
#     is_indtf = max([f(c) for f in fns_indtf_sup.values()]) > 0
#     return 1 if is_indtf else -1
# Out:
# fns_indck_comp_pos: Num functions found = 1, Names:
# LF_indck_txtptn_pos_all
# fns_secck_comp_pos: Num functions found = 1, Names:
# LF_secck_txtptn_pos_all
# fns_indtf_comp_pos: Num functions found = 1, Names:
# LF_indtf_txtptn_pos_all
# fns_indck_comp_neg: Num functions found = 13, Names:
# LF_indck_comp_neg_sec
# LF_indck_heur_closer_ct_to_ck
# LF_indck_heur_complex_cand_02
# LF_indck_heur_distref
# LF_indck_heur_distref_10
# LF_indck_heur_distref_15
# LF_indck_heur_distref_20
# LF_indck_heur_distref_25
# LF_indck_heur_distref_32
# LF_indck_heur_distref_5
# LF_indck_heur_distref_50
# LF_indck_heur_valid_cand_03
# LF_indck_txtptn_neg_all
# fns_secck_comp_neg: Num functions found = 13, Names:
# LF_secck_comp_neg_ind
# LF_secck_heur_closer_ct_to_ck
# LF_secck_heur_complex_cand_02
# LF_secck_heur_distref
# LF_secck_heur_distref_10
# LF_secck_heur_distref_15
# LF_secck_heur_distref_20
# LF_secck_heur_distref_25
# LF_secck_heur_distref_32
# LF_secck_heur_distref_5
# LF_secck_heur_distref_50
# LF_secck_heur_valid_cand_03
# LF_secck_txtptn_neg_all
# fns_indtf_comp_neg: Num functions found = 12, Names:
# LF_indtf_heur_closer_ct_to_tf
# LF_indtf_heur_complex_cand_02
# LF_indtf_heur_distref
# LF_indtf_heur_distref_10
# LF_indtf_heur_distref_15
# LF_indtf_heur_distref_20
# LF_indtf_heur_distref_25
# LF_indtf_heur_distref_32
# LF_indtf_heur_distref_5
# LF_indtf_heur_distref_50
# LF_indtf_heur_valid_cand_03
# LF_indtf_txtptn_neg_all

# %%
LFs = collections.OrderedDict()
LFs[REL_CLASS_INDUCING_CYTOKINE] = get_lfs(lambda k: k.startswith('LF_indck')).values()
LFs[REL_CLASS_SECRETED_CYTOKINE] = get_lfs(lambda k: k.startswith('LF_secck')).values()
LFs[REL_CLASS_INDUCING_TRANSCRIPTION_FACTOR] = get_lfs(lambda k: k.startswith('LF_indtf')).values()
for k in LFs:
    print('{} labeling functions:'.format(k))
    for f in LFs[k]:
        print(f.__name__)
    print()
# Out:
# InducingCytokine labeling functions:
# LF_indck_comp_imexpresso_nonneg
# LF_indck_comp_neg_sec
# LF_indck_comp_xor
# LF_indck_dsup_imexpresso
# LF_indck_heur_closer_ck_to_ct
# LF_indck_heur_closer_ct_to_ck
# LF_indck_heur_closer_ref
# LF_indck_heur_complex_cand_01
# LF_indck_heur_complex_cand_02
# LF_indck_heur_distref
# LF_indck_heur_distref_10
# LF_indck_heur_distref_15
# LF_indck_heur_distref_20
# LF_indck_heur_distref_25
# LF_indck_heur_distref_32
# LF_indck_heur_distref_5
# LF_indck_heur_distref_50
# LF_indck_heur_kwds
# LF_indck_heur_valid_cand_01
# LF_indck_heur_valid_cand_02
# LF_indck_heur_valid_cand_03
# LF_indck_txtptn_neg_all
# LF_indck_txtptn_pos_all
#
# SecretedCytokine labeling functions:
# LF_secck_comp_imexpresso_nonneg
# LF_secck_comp_neg_ind
# LF_secck_comp_xor
# LF_secck_dsup_imexpresso
# LF_secck_heur_closer_ck_to_ct
# LF_secck_heur_closer_ct_to_ck
# LF_secck_heur_closer_ref
# LF_secck_heur_complex_cand_01
# LF_secck_heur_complex_cand_02
# LF_secck_heur_distref
# LF_secck_heur_distref_10
# LF_secck_heur_distref_15
# LF_secck_heur_distref_20
# LF_secck_heur_distref_25
# LF_secck_heur_distref_32
# LF_secck_heur_distref_5
# LF_secck_heur_distref_50
# LF_secck_heur_kwds
# LF_secck_heur_valid_cand_01
# LF_secck_heur_valid_cand_02
# LF_secck_heur_valid_cand_03
# LF_secck_txtptn_neg_all
# LF_secck_txtptn_pos_all
#
# InducingTranscriptionFactor labeling functions:
# LF_indtf_comp_xor
# LF_indtf_heur_closer_ct_to_tf
# LF_indtf_heur_closer_ref
# LF_indtf_heur_closer_tf_to_ct
# LF_indtf_heur_complex_cand_01
# LF_indtf_heur_complex_cand_02
# LF_indtf_heur_distref
# LF_indtf_heur_distref_10
# LF_indtf_heur_distref_15
# LF_indtf_heur_distref_20
# LF_indtf_heur_distref_25
# LF_indtf_heur_distref_32
# LF_indtf_heur_distref_5
# LF_indtf_heur_distref_50
# LF_indtf_heur_kwds
# LF_indtf_heur_valid_cand_01
# LF_indtf_heur_valid_cand_02
# LF_indtf_heur_valid_cand_03
# LF_indtf_txtptn_neg_all
# LF_indtf_txtptn_pos_all

# %% [markdown]
# #### LF Testing

# %%
# c = session.query(candidate_class).filter(candidate_class.id == 32753).all()[0]
# c.cytokine_cid, c.immune_cell_type_cid

# %%
#df_ix.loc[('CTC3A8C3CBC245616A', 'CKB4EB2D2CC8BBB93D')]

# %%
from snorkel.viewer import SentenceNgramViewer
from snorkel.annotations import load_gold_labels

#candidate_class = classes.inducing_cytokine
#candidate_class = classes.secreted_cytokine
candidate_class = classes.inducing_transcription_factor
# Load all dev labels for this relation class
L_dev, I_cand = supervision.get_gold_labels(
    session, candidate_class,
    split=SPLIT_DEV, return_candidate_index=True
)

# %%
# labeled, gold = [], []
# for i, v in enumerate(L_dev):
#     c = session.query(Candidate).filter(Candidate.id == I_cand[i]).one()
#     if LF_secck_heur_valid_cand_02(c) == -1:
#         labeled.append(c)
#         if v > 0:
#             gold.append(c)

# print("Number labeled =", len(labeled), ", num gold =", len(gold))
# # - ID in hover state is sentence id (c.get_parent().id)
# # - Cell type label will be blue if candidate is NOT in "gold" set and red otherwise
# SentenceNgramViewer(labeled, session, gold=gold, height=1000)

# %%
from tcre.query import DocToCand
sent_id = 325453
df_doc_cand = DocToCand.all(session, classes)
cand_ids = df_doc_cand.set_index(['cand_type', 'sentence_id']).sort_index().loc[(candidate_class.field, sent_id)]['cand_id']
c = session.query(Candidate).filter(Candidate.id == int(cand_ids.values[0])).one()
c
# Out:
# InducingTranscriptionFactor(Span("b'T-bet'", sentence=325453, chars=[314,318], words=[62,62]), Span("b'Th1'", sentence=325453, chars=[47,49], words=[8,8]))

# %%
LF_secck_heur_valid_cand_01(c)
# Out:
# -1

# %%
c.get_parent().text
# Out:
# 'However, when determining the fold increase of Th1,\nTh2, Th17 and Treg cell numbers (OVA-OVA/OVA-PBS) we discovered that the GATA-3\nexpressing Th2 cells were increased up to 22 times more compared to any of the\n\nB) Fold change of the total number of lung cells expressing the four\ndifferent transcription factors (T-bet, GATA-3, RORγ and Foxp3) in\nmice to OVA compared to PBS.'

# %%
#pd.Series([c.transcription_factor.get_span() for c in cands]).value_counts()

# %% [markdown]
# ## Apply Labeling to Candidates

# %%
for c in classes.values():
    for split in [SPLIT_DEV, SPLIT_VAL, SPLIT_TEST, SPLIT_TRAIN, SPLIT_INFER]:
        n = session.query(c.subclass).filter(c.subclass.split == split).count()
        print('Candidate counts: {} (split {}) -> {}'.format(c.name, split, n))
# Out:
# Candidate counts: InducingCytokine (split 1) -> 950
# Candidate counts: InducingCytokine (split 3) -> 203
# Candidate counts: InducingCytokine (split 2) -> 271
# Candidate counts: InducingCytokine (split 0) -> 10000
# Candidate counts: InducingCytokine (split 9) -> 80415
# Candidate counts: SecretedCytokine (split 1) -> 952
# Candidate counts: SecretedCytokine (split 3) -> 205
# Candidate counts: SecretedCytokine (split 2) -> 274
# Candidate counts: SecretedCytokine (split 0) -> 10000
# Candidate counts: SecretedCytokine (split 9) -> 80408
# Candidate counts: InducingTranscriptionFactor (split 1) -> 612
# Candidate counts: InducingTranscriptionFactor (split 3) -> 209
# Candidate counts: InducingTranscriptionFactor (split 2) -> 281
# Candidate counts: InducingTranscriptionFactor (split 0) -> 10000
# Candidate counts: InducingTranscriptionFactor (split 9) -> 25433

# %%
# To remove all labels:
from snorkel.models import Label, LabelKey
session.query(Label).delete()
session.query(LabelKey).delete()
session.commit()

# %%
for c in [Label, LabelKey]:
    print(c.__name__, session.query(c).count())
# Out:
# Label 0
# LabelKey 0

# %%
from snorkel.models import Candidate
from snorkel.annotations import LabelAnnotator
from snorkel.annotations import load_gold_labels

def run_labeling(candidate_class, lfs, split, replace_key_set=False, has_gold_labels=False):
    cids_query = get_cids_query(session, candidate_class, split)
    y = None
    if has_gold_labels:
        y = supervision.get_gold_labels(
            session, candidate_class, 
            split=split
        ).values
    
    print('Running labeling for class {}, split {}'.format(candidate_class.name, split))
    labeler = LabelAnnotator(lfs=lfs)
    X = labeler.apply(
        split=split, cids_query=cids_query, clear=False,
        replace_key_set=replace_key_set, key_group=candidate_class.index
    )
    stats = X.lf_stats(session, y)
    
    return X, y, stats, labeler

res_label = collections.defaultdict(dict)
for c in classes:
    if c not in LFs:
        continue
#     for split in [SPLIT_DEV]:
    for i, split in enumerate([SPLIT_DEV, SPLIT_VAL, SPLIT_TEST]):
#     for split in [SPLIT_TRAIN]:
        res_label[c][split] = run_labeling(
            classes[c], LFs[c], split, 
            replace_key_set=i == 0,
            has_gold_labels=split in [SPLIT_DEV, SPLIT_VAL, SPLIT_TEST]
        )
# Out:
#   0%|          | 2/950 [00:00<01:12, 13.04it/s]
# Running labeling for class InducingCytokine, split 1
# Running UDF...
# 100%|██████████| 950/950 [00:40<00:00, 22.17it/s]
# /lab/repos/snorkel/snorkel/annotations.py:137: RuntimeWarning: invalid value encountered in true_divide
#   ac = (tp+tn) / (tp+tn+fp+fn)
#   1%|▏         | 3/203 [00:00<00:06, 28.75it/s]
# Running labeling for class InducingCytokine, split 3
# Running UDF...
# 100%|██████████| 203/203 [00:09<00:00, 20.98it/s]
#   1%|▏         | 4/271 [00:00<00:09, 28.54it/s]
# Running labeling for class InducingCytokine, split 2
# Running UDF...
# 100%|██████████| 271/271 [00:12<00:00, 24.92it/s]
#   0%|          | 4/952 [00:00<00:35, 26.68it/s]
# Running labeling for class SecretedCytokine, split 1
# Running UDF...
# 100%|██████████| 952/952 [00:41<00:00, 23.10it/s]
#   2%|▏         | 4/205 [00:00<00:07, 28.12it/s]
# Running labeling for class SecretedCytokine, split 3
# Running UDF...
# 100%|██████████| 205/205 [00:09<00:00, 20.62it/s]
#   1%|          | 3/274 [00:00<00:09, 29.90it/s]
# Running labeling for class SecretedCytokine, split 2
# Running UDF...
# 100%|██████████| 274/274 [00:12<00:00, 24.52it/s]
#   1%|          | 5/612 [00:00<00:12, 47.54it/s]
# Running labeling for class InducingTranscriptionFactor, split 1
# Running UDF...
# 100%|██████████| 612/612 [00:16<00:00, 38.25it/s]
#   2%|▏         | 5/209 [00:00<00:04, 41.43it/s]
# Running labeling for class InducingTranscriptionFactor, split 3
# Running UDF...
# 100%|██████████| 209/209 [00:06<00:00, 34.10it/s]
#   2%|▏         | 5/281 [00:00<00:06, 41.18it/s]
# Running labeling for class InducingTranscriptionFactor, split 2
# Running UDF...
# 100%|██████████| 281/281 [00:07<00:00, 35.83it/s]

# %%
# [(k, len(set(v))) for k, v in OFFTARGET_SPLITS.items()]

# %%
def add_f1(df, eps=1e-8):
    if 'Empirical Acc.' in df:
        precision = df['TP'] / (df['TP'] + df['FP'])
        recall = df['TP'] / (df['TP'] + df['FN'])
        df['Empirical F1'] = (2 * precision * recall) / (precision + recall + eps)
    return df

# %%
from IPython.display import display
for c in res_label:
    for split in res_label[c]:
        if split not in [SPLIT_DEV, SPLIT_TRAIN]:
            continue
        print('Stats {} (split {}):'.format(c, split))
        display(add_f1(res_label[c][split][2]))
# Out:
# Stats InducingCytokine (split 1):
#                                   j  Coverage  Overlaps  Conflicts  TP   FP  \
# LF_indck_comp_imexpresso_nonneg   0  0.000000  0.000000   0.000000   0    0
# LF_indck_comp_neg_sec             1  0.115789  0.115789   0.004211   0    0
# LF_indck_comp_xor                 2  0.249474  0.249474   0.137895  63   67
# LF_indck_dsup_imexpresso          3  0.000000  0.000000   0.000000   0    0
# LF_indck_heur_closer_ck_to_ct     4  0.346316  0.346316   0.101053   0    0
# LF_indck_heur_closer_ct_to_ck     5  0.258947  0.258947   0.061053   0    0
# LF_indck_heur_closer_ref          6  0.425263  0.425263   0.125263   0    0
# LF_indck_heur_complex_cand_01     7  0.948421  0.948421   0.302105   0    0
# LF_indck_heur_complex_cand_02     8  0.725263  0.725263   0.237895   0    0
# LF_indck_heur_distref             9  0.253684  0.253684   0.031579   0    0
# LF_indck_heur_distref_10         10  1.000000  1.000000   0.316842   0    0
# LF_indck_heur_distref_15         11  1.000000  1.000000   0.316842   0    0
# LF_indck_heur_distref_20         12  1.000000  1.000000   0.316842   0    0
# LF_indck_heur_distref_25         13  1.000000  1.000000   0.316842   0    0
# LF_indck_heur_distref_32         14  1.000000  1.000000   0.316842   0    0
# LF_indck_heur_distref_5          15  1.000000  1.000000   0.316842   0    0
# LF_indck_heur_distref_50         16  1.000000  1.000000   0.316842   0    0
# LF_indck_heur_kwds               17  0.491579  0.491579   0.277895  72  186
# LF_indck_heur_valid_cand_01      18  0.101053  0.101053   0.021053   0    0
# LF_indck_heur_valid_cand_02      19  0.054737  0.054737   0.015789   0    0
# LF_indck_heur_valid_cand_03      20  0.032632  0.032632   0.003158   0    0
# LF_indck_txtptn_neg_all          21  0.065263  0.065263   0.029474   0    0
# LF_indck_txtptn_pos_all          22  0.140000  0.140000   0.140000  65   68
#
#                                   FN   TN  Empirical Acc.  Empirical F1
# LF_indck_comp_imexpresso_nonneg    0    0             NaN           NaN
# LF_indck_comp_neg_sec              5  105        0.954545           NaN
# LF_indck_comp_xor                  3  104        0.704641      0.642857
# LF_indck_dsup_imexpresso           0    0             NaN           NaN
# LF_indck_heur_closer_ck_to_ct     34  295        0.896657           NaN
# LF_indck_heur_closer_ct_to_ck      9  237        0.963415           NaN
# LF_indck_heur_closer_ref          41  363        0.898515           NaN
# LF_indck_heur_complex_cand_01    133  768        0.852386           NaN
# LF_indck_heur_complex_cand_02     97  592        0.859216           NaN
# LF_indck_heur_distref              6  235        0.975104           NaN
# LF_indck_heur_distref_10         137  813        0.855789           NaN
# LF_indck_heur_distref_15         137  813        0.855789           NaN
# LF_indck_heur_distref_20         137  813        0.855789           NaN
# LF_indck_heur_distref_25         137  813        0.855789           NaN
# LF_indck_heur_distref_32         137  813        0.855789           NaN
# LF_indck_heur_distref_5          137  813        0.855789           NaN
# LF_indck_heur_distref_50         137  813        0.855789           NaN
# LF_indck_heur_kwds                 8  201        0.584582      0.426035
# LF_indck_heur_valid_cand_01        3   93        0.968750           NaN
# LF_indck_heur_valid_cand_02        1   51        0.980769           NaN
# LF_indck_heur_valid_cand_03        0   31        1.000000           NaN
# LF_indck_txtptn_neg_all            7   55        0.887097           NaN
# LF_indck_txtptn_pos_all            0    0        0.488722      0.656566
# Stats SecretedCytokine (split 1):
#                                   j  Coverage  Overlaps  Conflicts  TP   FP  \
# LF_secck_comp_imexpresso_nonneg   0  0.000000  0.000000   0.000000   0    0
# LF_secck_comp_neg_ind             1  0.141807  0.141807   0.008403   0    0
# LF_secck_comp_xor                 2  0.251050  0.251050   0.117647  63   44
# LF_secck_dsup_imexpresso          3  0.000000  0.000000   0.000000   0    0
# LF_secck_heur_closer_ck_to_ct     4  0.346639  0.346639   0.064076   0    0
# LF_secck_heur_closer_ct_to_ck     5  0.256303  0.256303   0.047269   0    0
# LF_secck_heur_closer_ref          6  0.423319  0.423319   0.087185   0    0
# LF_secck_heur_complex_cand_01     7  0.947479  0.947479   0.238445   0    0
# LF_secck_heur_complex_cand_02     8  0.722689  0.722689   0.168067   0    0
# LF_secck_heur_distref             9  0.246849  0.246849   0.042017   0    0
# LF_secck_heur_distref_10         10  1.000000  1.000000   0.255252   0    0
# LF_secck_heur_distref_15         11  1.000000  1.000000   0.255252   0    0
# LF_secck_heur_distref_20         12  1.000000  1.000000   0.255252   0    0
# LF_secck_heur_distref_25         13  1.000000  1.000000   0.255252   0    0
# LF_secck_heur_distref_32         14  1.000000  1.000000   0.255252   0    0
# LF_secck_heur_distref_5          15  1.000000  1.000000   0.255252   0    0
# LF_secck_heur_distref_50         16  1.000000  1.000000   0.255252   0    0
# LF_secck_heur_kwds               17  0.491597  0.491597   0.218487  75  132
# LF_secck_heur_valid_cand_01      18  0.095588  0.095588   0.027311   0    0
# LF_secck_heur_valid_cand_02      19  0.050420  0.050420   0.012605   0    0
# LF_secck_heur_valid_cand_03      20  0.028361  0.028361   0.009454   0    0
# LF_secck_txtptn_neg_all          21  0.058824  0.058824   0.009454   0    0
# LF_secck_txtptn_pos_all          22  0.115546  0.115546   0.115546  63   47
#
#                                   FN   TN  Empirical Acc.  Empirical F1
# LF_secck_comp_imexpresso_nonneg    0    0             NaN           NaN
# LF_secck_comp_neg_ind              0  135        1.000000           NaN
# LF_secck_comp_xor                  0  132        0.815900      0.741176
# LF_secck_dsup_imexpresso           0    0             NaN           NaN
# LF_secck_heur_closer_ck_to_ct     14  316        0.957576           NaN
# LF_secck_heur_closer_ct_to_ck      3  241        0.987705           NaN
# LF_secck_heur_closer_ref          17  386        0.957816           NaN
# LF_secck_heur_complex_cand_01    100  802        0.889135           NaN
# LF_secck_heur_complex_cand_02     67  621        0.902616           NaN
# LF_secck_heur_distref              3  232        0.987234           NaN
# LF_secck_heur_distref_10         112  840        0.882353           NaN
# LF_secck_heur_distref_15         112  840        0.882353           NaN
# LF_secck_heur_distref_20         112  840        0.882353           NaN
# LF_secck_heur_distref_25         112  840        0.882353           NaN
# LF_secck_heur_distref_32         112  840        0.882353           NaN
# LF_secck_heur_distref_5          112  840        0.882353           NaN
# LF_secck_heur_distref_50         112  840        0.882353           NaN
# LF_secck_heur_kwds                 3  258        0.711538      0.526316
# LF_secck_heur_valid_cand_01        8   83        0.912088           NaN
# LF_secck_heur_valid_cand_02        1   47        0.979167           NaN
# LF_secck_heur_valid_cand_03        1   26        0.962963           NaN
# LF_secck_txtptn_neg_all            3   53        0.946429           NaN
# LF_secck_txtptn_pos_all            0    0        0.572727      0.728324
# Stats InducingTranscriptionFactor (split 1):
#                                 j  Coverage  Overlaps  Conflicts  TP   FP  \
# LF_indtf_comp_xor               0  0.818627  0.818627   0.295752   0    0
# LF_indtf_heur_closer_ct_to_tf   1  0.307190  0.307190   0.151961   0    0
# LF_indtf_heur_closer_ref        2  0.385621  0.385621   0.178105   0    0
# LF_indtf_heur_closer_tf_to_ct   3  0.209150  0.209150   0.093137   0    0
# LF_indtf_heur_complex_cand_01   4  0.926471  0.926471   0.442810   0    0
# LF_indtf_heur_complex_cand_02   5  0.700980  0.700980   0.330065   0    0
# LF_indtf_heur_distref           6  0.218954  0.218954   0.137255   0    0
# LF_indtf_heur_distref_10        7  1.000000  1.000000   0.477124   0    0
# LF_indtf_heur_distref_15        8  1.000000  1.000000   0.477124   0    0
# LF_indtf_heur_distref_20        9  1.000000  1.000000   0.477124   0    0
# LF_indtf_heur_distref_25       10  1.000000  1.000000   0.477124   0    0
# LF_indtf_heur_distref_32       11  1.000000  1.000000   0.477124   0    0
# LF_indtf_heur_distref_5        12  1.000000  1.000000   0.477124   0    0
# LF_indtf_heur_distref_50       13  1.000000  1.000000   0.477124   0    0
# LF_indtf_heur_kwds             14  1.000000  1.000000   0.477124  73  191
# LF_indtf_heur_valid_cand_01    15  0.142157  0.142157   0.055556   0    0
# LF_indtf_heur_valid_cand_02    16  0.039216  0.039216   0.014706   0    0
# LF_indtf_heur_valid_cand_03    17  0.022876  0.022876   0.008170   0    0
# LF_indtf_txtptn_neg_all        18  0.071895  0.071895   0.040850   0    0
# LF_indtf_txtptn_pos_all        19  0.181373  0.181373   0.181373  60   51
#
#                                 FN   TN  Empirical Acc.  Empirical F1
# LF_indtf_comp_xor               50  451        0.900200           NaN
# LF_indtf_heur_closer_ct_to_tf    1  187        0.994681           NaN
# LF_indtf_heur_closer_ref         8  228        0.966102           NaN
# LF_indtf_heur_closer_tf_to_ct    7  121        0.945312           NaN
# LF_indtf_heur_complex_cand_01   91  476        0.839506           NaN
# LF_indtf_heur_complex_cand_02   57  372        0.867133           NaN
# LF_indtf_heur_distref            2  132        0.985075           NaN
# LF_indtf_heur_distref_10       110  502        0.820261           NaN
# LF_indtf_heur_distref_15       110  502        0.820261           NaN
# LF_indtf_heur_distref_20       110  502        0.820261           NaN
# LF_indtf_heur_distref_25       110  502        0.820261           NaN
# LF_indtf_heur_distref_32       110  502        0.820261           NaN
# LF_indtf_heur_distref_5        110  502        0.820261           NaN
# LF_indtf_heur_distref_50       110  502        0.820261           NaN
# LF_indtf_heur_kwds              37  311        0.627451      0.390374
# LF_indtf_heur_valid_cand_01      6   81        0.931034           NaN
# LF_indtf_heur_valid_cand_02      1   23        0.958333           NaN
# LF_indtf_heur_valid_cand_03      0   14        1.000000           NaN
# LF_indtf_txtptn_neg_all          5   39        0.886364           NaN
# LF_indtf_txtptn_pos_all          0    0        0.540541      0.701754

# %%
# Current LF stats (no supervised models)
from IPython.display import display
for c in res_label:
    for split in res_label[c]:
        print('Stats {} (split {}):'.format(c, split))
        display(add_f1(res_label[c][split][2]))
# Out:
# Stats InducingCytokine (split 1):
#                                   j  Coverage  Overlaps  Conflicts  TP   FP  \
# LF_indck_comp_imexpresso_nonneg   0  0.101040  0.101040   0.049034   9    3
# LF_indck_comp_neg_sec             1  0.121842  0.121842   0.005944   0    0
# LF_indck_comp_xor                 2  0.300149  0.300149   0.092125  73   48
# LF_indck_dsup_imexpresso          3  0.188707  0.188707   0.074294  14    7
# LF_indck_heur_closer_ck_to_ct     4  0.301634  0.301634   0.124814   0    0
# LF_indck_heur_closer_ct_to_ck     5  0.251114  0.251114   0.078752   0    0
# LF_indck_heur_closer_ref          6  0.396731  0.396731   0.151560   0    0
# LF_indck_heur_distref             7  0.230312  0.194651   0.032689   0    0
# LF_indck_heur_kwds                8  0.548291  0.419019   0.205052  84  153
# LF_indck_txtptn_neg_all           9  0.063893  0.050520   0.037147   0    0
# LF_indck_txtptn_pos_all          10  0.182764  0.182764   0.090639  74   49
#
#                                  FN   TN  Empirical Acc.  Empirical F1
# LF_indck_comp_imexpresso_nonneg  14   42        0.750000      0.514286
# LF_indck_comp_neg_sec             2   80        0.975610           NaN
# LF_indck_comp_xor                 1   80        0.757426      0.748718
# LF_indck_dsup_imexpresso         15   91        0.826772      0.560000
# LF_indck_heur_closer_ck_to_ct    27  176        0.866995           NaN
# LF_indck_heur_closer_ct_to_ck     7  162        0.958580           NaN
# LF_indck_heur_closer_ref         32  235        0.880150           NaN
# LF_indck_heur_distref             5  150        0.967742           NaN
# LF_indck_heur_kwds                0  132        0.585366      0.523364
# LF_indck_txtptn_neg_all           5   38        0.883721           NaN
# LF_indck_txtptn_pos_all           0    0        0.601626      0.751269
# Stats InducingCytokine (split 0):
#                                   j  Coverage  Overlaps  Conflicts
# LF_indck_comp_imexpresso_nonneg   0  0.106729  0.106729   0.021847
# LF_indck_comp_neg_sec             1  0.145922  0.145922   0.008776
# LF_indck_comp_xor                 2  0.184068  0.184068   0.017572
# LF_indck_dsup_imexpresso          3  0.204189  0.204189   0.043242
# LF_indck_heur_closer_ck_to_ct     4  0.222378  0.222378   0.052696
# LF_indck_heur_closer_ct_to_ck     5  0.158953  0.158953   0.040899
# LF_indck_heur_closer_ref          6  0.298894  0.298894   0.076270
# LF_indck_heur_distref             7  0.204887  0.173812   0.055471
# LF_indck_heur_kwds                8  0.486785  0.331573   0.127754
# LF_indck_txtptn_neg_all           9  0.059006  0.043900   0.018394
# LF_indck_txtptn_pos_all          10  0.036686  0.036686   0.010194
# Stats SecretedCytokine (split 1):
#                                   j  Coverage  Overlaps  Conflicts  TP  FP  \
# LF_secck_comp_imexpresso_nonneg   0  0.105498  0.105498   0.035661  22  43
# LF_secck_comp_neg_ind             1  0.182764  0.182764   0.025260   0   0
# LF_secck_comp_xor                 2  0.300149  0.300149   0.046062  52  29
# LF_secck_dsup_imexpresso          3  0.181278  0.181278   0.092125  23  78
# LF_secck_heur_closer_ck_to_ct     4  0.301634  0.301634   0.053492   0   0
# LF_secck_heur_closer_ct_to_ck     5  0.251114  0.251114   0.043091   0   0
# LF_secck_heur_closer_ref          6  0.396731  0.396731   0.083210   0   0
# LF_secck_heur_distref             7  0.230312  0.193165   0.044577   0   0
# LF_secck_heur_kwds                8  0.548291  0.419019   0.126300  61  71
# LF_secck_txtptn_neg_all           9  0.060921  0.047548   0.013373   0   0
# LF_secck_txtptn_pos_all          10  0.121842  0.121842   0.025260  52  30
#
#                                  FN   TN  Empirical Acc.  Empirical F1
# LF_secck_comp_imexpresso_nonneg   0    6        0.394366      0.505747
# LF_secck_comp_neg_ind             0  123        1.000000           NaN
# LF_secck_comp_xor                 0  121        0.856436      0.781955
# LF_secck_dsup_imexpresso          0   21        0.360656      0.370968
# LF_secck_heur_closer_ck_to_ct    11  192        0.945813           NaN
# LF_secck_heur_closer_ct_to_ck     0  169        1.000000           NaN
# LF_secck_heur_closer_ref         11  256        0.958801           NaN
# LF_secck_heur_distref             2  153        0.987097           NaN
# LF_secck_heur_kwds                3  234        0.799458      0.622449
# LF_secck_txtptn_neg_all           1   40        0.975610           NaN
# LF_secck_txtptn_pos_all           0    0        0.634146      0.776119
# Stats SecretedCytokine (split 0):
#                                   j  Coverage  Overlaps  Conflicts
# LF_secck_comp_imexpresso_nonneg   0  0.133658  0.133658   0.029283
# LF_secck_comp_neg_ind             1  0.035856  0.035856   0.002926
# LF_secck_comp_xor                 2  0.179611  0.178272   0.037237
# LF_secck_dsup_imexpresso          3  0.193583  0.193583   0.078616
# LF_secck_heur_closer_ck_to_ct     4  0.220722  0.220722   0.070909
# LF_secck_heur_closer_ct_to_ck     5  0.158778  0.158778   0.052280
# LF_secck_heur_closer_ref          6  0.297443  0.297443   0.099903
# LF_secck_heur_distref             7  0.205185  0.171925   0.059843
# LF_secck_heur_kwds                8  0.481196  0.324706   0.121273
# LF_secck_txtptn_neg_all           9  0.055330  0.039566   0.018835
# LF_secck_txtptn_pos_all          10  0.142539  0.142539   0.035547
# Stats InducingTranscriptionFactor (split 1):
#                                j  Coverage  Overlaps  Conflicts  TP   FP  FN  \
# LF_indtf_comp_xor              0  0.568293  0.568293   0.241463  45   14   7
# LF_indtf_heur_closer_ct_to_tf  1  0.370732  0.370732   0.180488   0    0   4
# LF_indtf_heur_closer_ref       2  0.446341  0.446341   0.212195   0    0  10
# LF_indtf_heur_closer_tf_to_ct  3  0.263415  0.263415   0.131707   0    0   6
# LF_indtf_heur_distref          4  0.226829  0.226829   0.158537   0    0   3
# LF_indtf_heur_kwds             5  1.000000  0.660976   0.295122  63  122  23
# LF_indtf_txtptn_neg_all        6  0.075610  0.075610   0.043902   0    0   7
# LF_indtf_txtptn_pos_all        7  0.190244  0.190244   0.080488  50   28   0
#
#                                 TN  Empirical Acc.  Empirical F1
# LF_indtf_comp_xor              167        0.909871      0.810811
# LF_indtf_heur_closer_ct_to_tf  148        0.973684           NaN
# LF_indtf_heur_closer_ref       173        0.945355           NaN
# LF_indtf_heur_closer_tf_to_ct  102        0.944444           NaN
# LF_indtf_heur_distref           90        0.967742           NaN
# LF_indtf_heur_kwds             202        0.646341      0.464945
# LF_indtf_txtptn_neg_all         24        0.774194           NaN
# LF_indtf_txtptn_pos_all          0        0.641026      0.781250
# Stats InducingTranscriptionFactor (split 0):
#                                j  Coverage  Overlaps  Conflicts
# LF_indtf_comp_xor              0  0.403907  0.403907   0.139407
# LF_indtf_heur_closer_ct_to_tf  1  0.131271  0.131271   0.052909
# LF_indtf_heur_closer_ref       2  0.219771  0.219771   0.089109
# LF_indtf_heur_closer_tf_to_ct  3  0.130966  0.130966   0.050168
# LF_indtf_heur_distref          4  0.170691  0.170691   0.071879
# LF_indtf_heur_kwds             5  1.000000  0.471392   0.174129
# LF_indtf_txtptn_neg_all        6  0.044207  0.044207   0.018753
# LF_indtf_txtptn_pos_all        7  0.155506  0.155506   0.063830

# %% [markdown]
# ## Train Generative Model

# %%
res_label.keys()
# Out:
# dict_keys(['InducingCytokine', 'SecretedCytokine', 'InducingTranscriptionFactor'])

# %%
from snorkel.learning.structure import DependencySelector
from snorkel.learning import GenerativeModel

res_train = {}
for c in res_label:
    print('Running generative model training for class {}'.format(c))
    ds = DependencySelector()
    split = 0
    X = res_label[c][split][0]
    deps = ds.select(X, threshold=0.1)
    gen_model = GenerativeModel(lf_propensity=True)
    gen_model.train(
        X, deps=deps, decay=0.95, 
        step_size=0.1/X.shape[0], reg_param=0.0
    )
    marginals = gen_model.marginals(X)
    res_train[c] = gen_model, X, marginals, deps
# Out:
# Running generative model training for class InducingCytokine
# Inferred cardinality: 2
# Running generative model training for class SecretedCytokine
# Inferred cardinality: 2
# Running generative model training for class InducingTranscriptionFactor
# Inferred cardinality: 2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
for c in res_train:
    plt.hist(res_train[c][2], bins=36, label=c, alpha=.3)
    plt.legend()

# %%
# from IPython.display import display
# for c in res_train:
#     print(c)
#     display(res_train[c][0].learned_lf_stats())

# %%
from snorkel.annotations import save_marginals

# Fetch the candidates for each class into a SINGLE list and do
# the same for the marginal arrays since the `save_marginals` function
# deletes all records (with no arguments for filters to avoid this) each time,
# making it impossible to call separately for each set of candidates
candidates, marginals = [], []
for c in res_train:
    X, y = res_train[c][1], res_train[c][2]
    candidates.extend([X.get_candidate(session, i) for i in range(X.shape[0])])
    marginals.append(y)
marginals = np.concatenate(marginals)
assert len(candidates) == len(marginals)
save_marginals(session, candidates, marginals)
# Out:
# Saved 120166 marginals

# %%
from snorkel.models import Marginal, Candidate

# Determine the candidate types for all saved marginals
cids = [m.candidate_id for m in session.query(Marginal).all()]
pd.DataFrame(
    session.query(Candidate.id, Candidate.type).filter(Candidate.id.in_(cids)),
    columns=['id', 'type']
).groupby('type').size()
# Out:
# type
# inducing_cytokine                48656
# inducing_transcription_factor    22983
# secreted_cytokine                48527
# dtype: int64

# %%
# With supervised models as LFs:
res_lf_stats = {}
for c in classes:
    print(c)
    candidate_class = classes[c]
    L_dev = res_label[c][1][0]
    L_gold_dev = res_label[c][1][1]
    gen_model_train = res_train[c][0]
    gen_model_train.error_analysis(session, L_dev, L_gold_dev)
    res_lf_stats[c] = L_dev.lf_stats(session, L_gold_dev, gen_model_train.learned_lf_stats()['Accuracy'])
    display(res_lf_stats[c])
# Out:
# InducingCytokine
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.256
# Neg. class accuracy: 0.844
# Precision            0.288
# Recall               0.256
# F1                   0.271
# ----------------------------------------
# TP: 34 | FP: 84 | TN: 456 | FN: 99
# ========================================
#                                   j  Coverage  Overlaps  Conflicts  TP   FP  \
# LF_indck_comp_imexpresso_nonneg   0  0.101040  0.101040   0.074294   9    3
# LF_indck_comp_neg_sec             1  0.121842  0.121842   0.046062   0    0
# LF_indck_comp_xor                 2  0.300149  0.300149   0.210996  73   48
# LF_indck_dsup_imexpresso          3  0.188707  0.188707   0.120357  14    7
# LF_indck_heur_closer_ck_to_ct     4  0.301634  0.301634   0.175334   0    0
# LF_indck_heur_closer_ct_to_ck     5  0.251114  0.251114   0.120357   0    0
# LF_indck_heur_closer_ref          6  0.396731  0.396731   0.219911   0    0
# LF_indck_heur_distref             7  0.230312  0.230312   0.068351   0    0
# LF_indck_heur_kwds                8  0.548291  0.548291   0.390788  84  153
# LF_indck_sup_cfg_00               9  1.000000  1.000000   0.549777  39  153
# LF_indck_sup_cfg_01              10  1.000000  1.000000   0.549777  23  153
# LF_indck_sup_comp                11  1.000000  1.000000   0.549777  32   67
# LF_indck_txtptn_neg_all          12  0.063893  0.063893   0.050520   0    0
# LF_indck_txtptn_pos_all          13  0.182764  0.182764   0.169391  74   49
#
#                                   FN   TN  Empirical Acc.  Learned Acc.
# LF_indck_comp_imexpresso_nonneg   14   42        0.750000      0.695971
# LF_indck_comp_neg_sec              2   80        0.975610      0.743682
# LF_indck_comp_xor                  1   80        0.757426      0.763710
# LF_indck_dsup_imexpresso          15   91        0.826772      0.744153
# LF_indck_heur_closer_ck_to_ct     27  176        0.866995      0.818841
# LF_indck_heur_closer_ct_to_ck      7  162        0.958580      0.795411
# LF_indck_heur_closer_ref          32  235        0.880150      0.845927
# LF_indck_heur_distref              5  150        0.967742      0.821440
# LF_indck_heur_kwds                 0  132        0.585366      0.665235
# LF_indck_sup_cfg_00               94  387        0.632987      0.918495
# LF_indck_sup_cfg_01              110  387        0.609212      0.920729
# LF_indck_sup_comp                101  473        0.750371      0.964815
# LF_indck_txtptn_neg_all            5   38        0.883721      0.719323
# LF_indck_txtptn_pos_all            0    0        0.601626      0.670367
# SecretedCytokine
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.543
# Neg. class accuracy: 0.878
# Precision            0.379
# Recall               0.543
# F1                   0.447
# ----------------------------------------
# TP: 44 | FP: 72 | TN: 520 | FN: 37
# ========================================
#                                   j  Coverage  Overlaps  Conflicts  TP   FP  \
# LF_secck_comp_imexpresso_nonneg   0  0.105498  0.105498   0.095097  22   43
# LF_secck_comp_neg_ind             1  0.182764  0.182764   0.068351   0    0
# LF_secck_comp_xor                 2  0.300149  0.300149   0.160475  52   29
# LF_secck_dsup_imexpresso          3  0.181278  0.181278   0.154532  23   78
# LF_secck_heur_closer_ck_to_ct     4  0.301634  0.301634   0.108470   0    0
# LF_secck_heur_closer_ct_to_ck     5  0.251114  0.251114   0.095097   0    0
# LF_secck_heur_closer_ref          6  0.396731  0.396731   0.163447   0    0
# LF_secck_heur_distref             7  0.230312  0.230312   0.081724   0    0
# LF_secck_heur_kwds                8  0.548291  0.548291   0.273403  61   71
# LF_secck_sup_cfg_00               9  1.000000  1.000000   0.479941  43  124
# LF_secck_sup_cfg_01              10  1.000000  1.000000   0.479941  37  107
# LF_secck_sup_comp                11  1.000000  1.000000   0.479941  35   50
# LF_secck_txtptn_neg_all          12  0.060921  0.060921   0.029718   0    0
# LF_secck_txtptn_pos_all          13  0.121842  0.121842   0.096582  52   30
#
#                                  FN   TN  Empirical Acc.  Learned Acc.
# LF_secck_comp_imexpresso_nonneg   0    6        0.394366      0.601316
# LF_secck_comp_neg_ind             0  123        1.000000      0.736272
# LF_secck_comp_xor                 0  121        0.856436      0.617426
# LF_secck_dsup_imexpresso          0   21        0.360656      0.569989
# LF_secck_heur_closer_ck_to_ct    11  192        0.945813      0.830714
# LF_secck_heur_closer_ct_to_ck     0  169        1.000000      0.799529
# LF_secck_heur_closer_ref         11  256        0.958801      0.852176
# LF_secck_heur_distref             2  153        0.987097      0.839836
# LF_secck_heur_kwds                3  234        0.799458      0.670879
# LF_secck_sup_cfg_00              38  468        0.759287      0.948304
# LF_secck_sup_cfg_01              44  485        0.775632      0.937606
# LF_secck_sup_comp                46  542        0.857355      0.971170
# LF_secck_txtptn_neg_all           1   40        0.975610      0.731888
# LF_secck_txtptn_pos_all           0    0        0.634146      0.629785
# InducingTranscriptionFactor
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.465
# Neg. class accuracy: 0.725
# Precision            0.31
# Recall               0.465
# F1                   0.372
# ----------------------------------------
# TP: 40 | FP: 89 | TN: 235 | FN: 46
# ========================================
#                                 j  Coverage  Overlaps  Conflicts  TP   FP  FN  \
# LF_indtf_comp_xor               0  0.568293  0.568293   0.402439  45   14   7
# LF_indtf_heur_closer_ct_to_tf   1  0.370732  0.370732   0.243902   0    0   4
# LF_indtf_heur_closer_ref        2  0.446341  0.446341   0.295122   0    0  10
# LF_indtf_heur_closer_tf_to_ct   3  0.263415  0.263415   0.187805   0    0   6
# LF_indtf_heur_distref           4  0.226829  0.226829   0.187805   0    0   3
# LF_indtf_heur_kwds              5  1.000000  1.000000   0.643902  63  122  23
# LF_indtf_sup_cfg_00             6  1.000000  1.000000   0.643902  32   72  54
# LF_indtf_sup_cfg_01             7  1.000000  1.000000   0.643902  32   88  54
# LF_indtf_sup_comp               8  1.000000  1.000000   0.643902  41  111  45
# LF_indtf_txtptn_neg_all         9  0.075610  0.075610   0.063415   0    0   7
# LF_indtf_txtptn_pos_all        10  0.190244  0.190244   0.160976  50   28   0
#
#                                 TN  Empirical Acc.  Learned Acc.
# LF_indtf_comp_xor              167        0.909871      0.783275
# LF_indtf_heur_closer_ct_to_tf  148        0.973684      0.787033
# LF_indtf_heur_closer_ref       173        0.945355      0.808228
# LF_indtf_heur_closer_tf_to_ct  102        0.944444      0.788857
# LF_indtf_heur_distref           90        0.967742      0.809507
# LF_indtf_heur_kwds             202        0.646341      0.709048
# LF_indtf_sup_cfg_00            252        0.692683      0.919394
# LF_indtf_sup_cfg_01            236        0.653659      0.946345
# LF_indtf_sup_comp              213        0.619512      0.963466
# LF_indtf_txtptn_neg_all         24        0.774194      0.592377
# LF_indtf_txtptn_pos_all          0        0.641026      0.616486

# %%
# Without supervised models as LFs
res_lf_stats = {}
for c in classes:
    print(c)
    candidate_class = classes[c]
    L_dev = res_label[c][1][0]
    L_gold_dev = res_label[c][1][1]
    gen_model_train = res_train[c][0]
    gen_model_train.error_analysis(session, L_dev, L_gold_dev)
    res_lf_stats[c] = L_dev.lf_stats(session, L_gold_dev, gen_model_train.learned_lf_stats()['Accuracy'])
    display(res_lf_stats[c])
# Out:
# InducingCytokine
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.677
# Neg. class accuracy: 0.822
# Precision            0.484
# Recall               0.677
# F1                   0.564
# ----------------------------------------
# TP: 90 | FP: 96 | TN: 444 | FN: 43
# ========================================
#                                   j  Coverage  Overlaps  Conflicts  TP   FP  \
# LF_indck_comp_imexpresso_nonneg   0  0.101040  0.101040   0.049034   9    3
# LF_indck_comp_neg_sec             1  0.121842  0.121842   0.005944   0    0
# LF_indck_comp_xor                 2  0.300149  0.300149   0.092125  73   48
# LF_indck_dsup_imexpresso          3  0.188707  0.188707   0.074294  14    7
# LF_indck_heur_closer_ck_to_ct     4  0.301634  0.301634   0.124814   0    0
# LF_indck_heur_closer_ct_to_ck     5  0.251114  0.251114   0.078752   0    0
# LF_indck_heur_closer_ref          6  0.396731  0.396731   0.151560   0    0
# LF_indck_heur_distref             7  0.230312  0.194651   0.032689   0    0
# LF_indck_heur_kwds                8  0.548291  0.419019   0.205052  84  153
# LF_indck_txtptn_neg_all           9  0.063893  0.050520   0.037147   0    0
# LF_indck_txtptn_pos_all          10  0.182764  0.182764   0.090639  74   49
#
#                                  FN   TN  Empirical Acc.  Learned Acc.
# LF_indck_comp_imexpresso_nonneg  14   42        0.750000      0.697630
# LF_indck_comp_neg_sec             2   80        0.975610      0.722380
# LF_indck_comp_xor                 1   80        0.757426      0.722781
# LF_indck_dsup_imexpresso         15   91        0.826772      0.701599
# LF_indck_heur_closer_ck_to_ct    27  176        0.866995      0.781080
# LF_indck_heur_closer_ct_to_ck     7  162        0.958580      0.744350
# LF_indck_heur_closer_ref         32  235        0.880150      0.790706
# LF_indck_heur_distref             5  150        0.967742      0.732959
# LF_indck_heur_kwds                0  132        0.585366      0.733658
# LF_indck_txtptn_neg_all           5   38        0.883721      0.688672
# LF_indck_txtptn_pos_all           0    0        0.601626      0.746622
# SecretedCytokine
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.901
# Neg. class accuracy: 0.856
# Precision            0.462
# Recall               0.901
# F1                   0.611
# ----------------------------------------
# TP: 73 | FP: 85 | TN: 507 | FN: 8
# ========================================
#                                   j  Coverage  Overlaps  Conflicts  TP  FP  \
# LF_secck_comp_imexpresso_nonneg   0  0.105498  0.105498   0.035661  22  43
# LF_secck_comp_neg_ind             1  0.182764  0.182764   0.025260   0   0
# LF_secck_comp_xor                 2  0.300149  0.300149   0.046062  52  29
# LF_secck_dsup_imexpresso          3  0.181278  0.181278   0.092125  23  78
# LF_secck_heur_closer_ck_to_ct     4  0.301634  0.301634   0.053492   0   0
# LF_secck_heur_closer_ct_to_ck     5  0.251114  0.251114   0.043091   0   0
# LF_secck_heur_closer_ref          6  0.396731  0.396731   0.083210   0   0
# LF_secck_heur_distref             7  0.230312  0.193165   0.044577   0   0
# LF_secck_heur_kwds                8  0.548291  0.419019   0.126300  61  71
# LF_secck_txtptn_neg_all           9  0.060921  0.047548   0.013373   0   0
# LF_secck_txtptn_pos_all          10  0.121842  0.121842   0.025260  52  30
#
#                                  FN   TN  Empirical Acc.  Learned Acc.
# LF_secck_comp_imexpresso_nonneg   0    6        0.394366      0.666115
# LF_secck_comp_neg_ind             0  123        1.000000      0.741459
# LF_secck_comp_xor                 0  121        0.856436      0.727455
# LF_secck_dsup_imexpresso          0   21        0.360656      0.640053
# LF_secck_heur_closer_ck_to_ct    11  192        0.945813      0.759190
# LF_secck_heur_closer_ct_to_ck     0  169        1.000000      0.729439
# LF_secck_heur_closer_ref         11  256        0.958801      0.786630
# LF_secck_heur_distref             2  153        0.987097      0.739450
# LF_secck_heur_kwds                3  234        0.799458      0.758285
# LF_secck_txtptn_neg_all           1   40        0.975610      0.687551
# LF_secck_txtptn_pos_all           0    0        0.634146      0.726395
# InducingTranscriptionFactor
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.698
# Neg. class accuracy: 0.799
# Precision            0.48
# Recall               0.698
# F1                   0.569
# ----------------------------------------
# TP: 60 | FP: 65 | TN: 259 | FN: 26
# ========================================
#                                j  Coverage  Overlaps  Conflicts  TP   FP  FN  \
# LF_indtf_comp_xor              0  0.568293  0.568293   0.241463  45   14   7
# LF_indtf_heur_closer_ct_to_tf  1  0.370732  0.370732   0.180488   0    0   4
# LF_indtf_heur_closer_ref       2  0.446341  0.446341   0.212195   0    0  10
# LF_indtf_heur_closer_tf_to_ct  3  0.263415  0.263415   0.131707   0    0   6
# LF_indtf_heur_distref          4  0.226829  0.226829   0.158537   0    0   3
# LF_indtf_heur_kwds             5  1.000000  0.660976   0.295122  63  122  23
# LF_indtf_txtptn_neg_all        6  0.075610  0.075610   0.043902   0    0   7
# LF_indtf_txtptn_pos_all        7  0.190244  0.190244   0.080488  50   28   0
#
#                                 TN  Empirical Acc.  Learned Acc.
# LF_indtf_comp_xor              167        0.909871      0.789554
# LF_indtf_heur_closer_ct_to_tf  148        0.973684      0.710209
# LF_indtf_heur_closer_ref       173        0.945355      0.749887
# LF_indtf_heur_closer_tf_to_ct  102        0.944444      0.689634
# LF_indtf_heur_distref           90        0.967742      0.687139
# LF_indtf_heur_kwds             202        0.646341      0.924540
# LF_indtf_txtptn_neg_all         24        0.774194      0.608416
# LF_indtf_txtptn_pos_all          0        0.641026      0.699603

# %% [markdown]
# ### Check Top Predictions

# %%
pcs = session.query(classes.inducing_cytokine.subclass).filter(classes.inducing_cytokine.subclass.split == SPLIT_TRAIN).all()
pcs = {c.id: c for c in pcs}
len(pcs)
# Out:
# 48656

# %%
dfpcs = pd.DataFrame([dict(id=c.id, pred=c.marginals[0].probability) for c in pcs.values()])
dfpcs = dfpcs.sort_values('pred', ascending=False).head(25)

# %%
def get_rec(r):
    c = pcs[r['id']]
    return dict(id=r['id'], pred=r['pred'], s1=c.get_contexts()[0].get_span(), s2=c.get_contexts()[1].get_span(), sent=c.get_parent().text)
pd.set_option('display.max_colwidth', 200)
pd.DataFrame([get_rec(r) for _, r in dfpcs.iterrows()])
# Out:
#           id      pred                   s1    s2  \
# 0   251888.0  0.999931                IL-12   Th1
# 1    43321.0  0.999931                IL-12   Th1
# 2   255380.0  0.999931                IL-12   Th1
# 3   159145.0  0.999931                IL-12   Th1
# 4     1756.0  0.999931                IL-12   Th1
# 5    94022.0  0.999931                IL-12   Th1
# 6   182560.0  0.999931                IL-12   Th1
# 7   140490.0  0.999931                IL-12   Th1
# 8     5758.0  0.999931  interleukin (IL)-12   Th1
# 9    96699.0  0.999888                IL-12   Th1
# 10  210231.0  0.999888                IL-12   Th1
# 11  249287.0  0.999888                IL-12   Th1
# 12  149781.0  0.999888                IL-12   Th1
# 13   86097.0  0.999816                IL-12   Th1
# 14  247294.0  0.999816                 IL-6  Treg
# 15  234502.0  0.999816                IL-12   Th1
# 16  243682.0  0.999816  interleukin (IL)-12   Th1
# 17    2889.0  0.999816                 IL-6  TREG
# 18  153384.0  0.999816                IL-12   Th1
# 19  218863.0  0.999816                IL-12   Th1
# 20   52947.0  0.999816                IL-12   Th1
# 21  252443.0  0.999816                IL-12   Th1
# 22  243161.0  0.999816                 IL-6  Treg
# 23   95677.0  0.999816                IL-12   Th1
# 24  167445.0  0.999816                 IL-6  Treg
#
#                                                                                                                                                                                                        sent
# 0                                                                            In C57BL/6 mice, IL-12 is produced by T. muris infection and IL-12 and IL-18 promote IFN-γ-producing Th1 cell differentiation.
# 1                                               . STAT1 was activated by autocrine IFN-γ whereas; STAT4 is mainly activated by IL-12 both of which are important for in vitro differentiation of Th1 cells.
# 2                                                                                     IFN-γ-regulated IL-12 signalling drives Th1 differentiation, whereas CXCR3 contributes to the migration of Th1 cells.
# 3                                                                In the absence of IL-12, IL-18-mediated effects on T cells may extend beyond Th1 differentiation to include Th2 cytokine production []. \n
# 4                                                               IL-12 is another important regulator of Th1 cell differentiation, and it is also the primary immunoregulatory factor secreted by Th1 cells.
# 5                      T-bet promotes the expression of IFN-γ and IL-12Rb2, which, together with IL-12Rb1, form a functional IL-12 receptor complex to further stimulate IFN-γ-induced Th1 differentiation.
# 6                                                                                  For example, IL-12 and IL-18 are important for differentiation of Th1 cells but also play a key role in innate immunity.
# 7   B10.S mice are genetically resistant to EAE; lymphocytes from B10.S mice did not generate IFN-γ in response to MBP, unless the cells were cultured in vitro in the presence of IL-12 [], a cytokine ...
# 8   T Helper Type 2 Cell Differentiation Occurs in the Presence of Interleukin 12 Receptor β2 Chain Expression and Signaling\n\nThe differentiation of CD4+ T cells into T helper type 1 (Th1) cells is ...
# 9   Whereas signaling of IL-12Rβ1β2 complex by IL-12 induces STAT4-dependent IFN-γ secretion with consequent Th1 differentiation , signaling of IL-4Rα by IL-4 induces STAT6-dependent IL-4 secretion wi...
# 10                                                   CS can directly target monocytes/macrophages to inhibit IL-12 production, which subsequently redirects T cell polarization from Th1 to Th2 cells [, ].
# 11  Although both IL-12 and IL-18 are major factors in IFN-γ production by Th1 cells, IL-12 is a differentiation factor that induces the development of Th1 cells—in contrast, IL-18 is a proinflammator...
# 12                         The excessive generation of IFN-γ-producing T cells (Th1) driven by IL-12 produced by antigen-presenting cells was described to be responsible for the initiation of disease [].
# 13                                                                              Together with IL-12, IFN-α polarizes the T cell towards a cell mediated Th1 response characterized by DTH and CTL activity.
# 14  Depending on other environmental conditions, such as the presence of specific antigens, T cell receptor (TCR) binding, and the amount of IL-2, IL-6, IL-21 and IL-23, naive CD4 T cells differentiat...
# 15                             The inhibition of IL-10 by IL-4 appears necessary for the induction of Th1 cell differentiation because the ability of IL-4 to induce IL-12 was lost in IL-10–deficient DCs.
# 16  Compromised Th1 differentiation in ICSBP−/− mice could not be attributed to hyporesponsiveness of CD4+ T cells to interleukin (IL)-12; however, the ability of uninfected and infected ICSBP-deficie...
# 17                                                  The developmental crossroads may be regulated by IL-6 or other innate cytokines as rIL-6-exposed Foxp3+ TREG cells can upregulate IL-17A in vitro [97].
# 18                                                                                                                The IL-12 receptor is present in its functional form in Th0 and Th1 but not Th2 cells [].
# 19                                                                                                                             As discussed previously, IL-12 promotes increased CD4+ Th1 cell numbers.\n\n
# 20                                                                    IL-12 activates STAT4, which is a critical regulator of inflammation and T helper type I (Th1) lineage development in murine systems.
# 21                                   No effort was made in these studies to analyze the role of IL-12 in the induction of the Th1 effectors and the authors postulated that the protective effects of anti–
# 22                                                                                  Similar to Tfh cell induction, the Tfh-like Treg are induced by IL-21 and IL-6 and produce IL-21 with STAT3 expression.
# 23   NF-κB promotes Th1 cell differentiation by regulating TCR signaling as well as functioning in innate immune cells to mediate induction of cytokines, such as IL-12, which promote Th1 differentiation.
# 24                                                                                                      IL-6 has counter-regulatory effects in modulating Treg and Th17 differentiation from naive T cells.
