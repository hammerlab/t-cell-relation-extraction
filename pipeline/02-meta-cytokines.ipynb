# %%
import os.path as osp
import pandas as pd
import numpy as np
# %run env.py
# %run src/lib.py
# %run src/meta.py
# %matplotlib inline

# %%
greeks = pd.DataFrame(get_greek_alphabet(), columns=['letter', 'name', 'trans'])
greeks = greeks[greeks['name'].isin(['alpha', 'beta', 'delta', 'gamma', 'kappa', 'epsilon', 'omega'])]
greeks
# Out:
#    letter     name trans
# 0       α    alpha     a
# 1       β     beta     b
# 2       γ    gamma     g
# 3       δ    delta     d
# 4       ε  epsilon     e
# 9       κ    kappa     k
# 23      ω    omega     o

# %% [markdown]
# ### Load from Cameron (Textbook)

# %%
SRC = 'cameron'
dfr = pd.read_csv(osp.join(META_DATA_DIR, 'raw', 'cytokines.cameron.csv'), sep='\t')
dfr.head()
# Out:
#      name                       synonym amino chromosome_acids    mwt  \
# 0   IL-1α               hematopoietin-1   271             2q14  30606
# 1   IL-1β                     catabolin   269             2q14  20747
# 2  IL-1RA      IL-1 receptor antagonist   177           2q14.2  20055
# 3   IL-18  interferon-γ inducing factor   193    11q22.2-q22.3  22326
# 4    IL-2          T cell growth factor   153         4q26-q27  17628
#
#      receptor_form           receptor_location
# 0  CD121a, CDw121b              2q12, 2q12-q22
# 1  CD121a, CDw121b               2q12,2q12-q22
# 2           CD121a                        2q12
# 3       IL-18Rα, β                        2q12
# 4    CD25, 122,132  10p15-p14, 22q13.1, Xq13.1

# %%
dft = (
    pd.concat([
        dfr[['name', 'name']].set_axis(['sym', 'lbl'], axis=1, inplace=False),
        dfr.set_index('name')['synonym'].str.split(',', expand=True).stack().str.strip()
            .reset_index().set_axis(['lbl', 'i', 'sym'], axis=1, inplace=False)
            .filter(items=['sym', 'lbl'])
    ])
    .assign(spid=SPECIES_HUMAN_ID, src=SRC)
)
dft.head()
# Out:
#       sym     lbl  spid      src
# 0   IL-1α   IL-1α     1  cameron
# 1   IL-1β   IL-1β     1  cameron
# 2  IL-1RA  IL-1RA     1  cameron
# 3   IL-18   IL-18     1  cameron
# 4    IL-2    IL-2     1  cameron

# %%
def transform(df, mask, fn):
    df = df.loc[mask.values].copy()
    df['sym'] = df['sym'].apply(fn)
    return df
df = dft.append(transform(dft, dft['sym'].str.match(r'IL-[^ ]+$|TNF-|IFN-|TGF-'), lambda v: v.replace('-', '')))
df['sym'] = df['sym'].str.strip()
df['lbl'] = df['lbl'].str.strip()
df['extid'] = None
df = df[df['sym'].str.len() > 0]
df.head()
# Out:
#       sym     lbl  spid      src extid
# 0   IL-1α   IL-1α     1  cameron  None
# 1   IL-1β   IL-1β     1  cameron  None
# 2  IL-1RA  IL-1RA     1  cameron  None
# 3   IL-18   IL-18     1  cameron  None
# 4    IL-2    IL-2     1  cameron  None

# %%
df['sym'].unique()
# Out:
# array(['IL-1α', 'IL-1β', 'IL-1RA', 'IL-18', 'IL-2', 'IL-4', 'IL-7',
#        'IL-9', 'IL-13', 'IL-15', 'IL-3', 'IL-5', 'GM-CSF', 'IL-6',
#        'IL-11', 'G-CSF', 'IL-12', 'LIF', 'OSM', 'IL-10', 'IL-20', 'IL-14',
#        'IL-16', 'IL-17', 'IFN-α', 'IFN-β', 'IFN-γ', 'CD154', 'LT-β',
#        'TNF-α', 'TNF-β', '4-1BBL', 'APRIL', 'CD70', 'CD153', 'CD178',
#        'GITRL', 'LIGHT', 'OX40L', 'TALL-1', 'TRAIL', 'TWEAK', 'TRANCE',
#        'TGF-β', 'TGF-β2', 'TGF-β3', 'hematopoietin-1', 'catabolin',
#        'IL-1 receptor antagonist', 'interferon-γ inducing factor',
#        'T cell growth factor', 'BSF-1', 'T cell growth factor P40',
#        'P600', 'multipotential CSF', 'MCGF', 'BCDF-1', 'CSF-2', 'IFN-β2',
#        'BSF-2', 'AGIF', 'CSF-3', 'NK cell stimulatory factor',
#        'leukemia inhibitory factor', 'oncostatin M', 'CSIF', 'HMW-BCGF',
#        'LCF', 'CTLA-8', 'CD40L', 'TRAP', 'cachectin', 'LT-α', 'TALL-2',
#        'CD27L', 'CD30L', 'FasL', 'Apo2L', 'Apo3L', 'OPGL', 'TGF-β1',
#        'IL1α', 'IL1β', 'IL1RA', 'IL18', 'IL2', 'IL4', 'IL7', 'IL9',
#        'IL13', 'IL15', 'IL3', 'IL5', 'IL6', 'IL11', 'IL12', 'IL10',
#        'IL20', 'IL14', 'IL16', 'IL17', 'IFNα', 'IFNβ', 'IFNγ', 'TNFα',
#        'TNFβ', 'TGFβ', 'TGFβ2', 'TGFβ3', 'IFNβ2', 'TGFβ1'], dtype=object)

# %%
df_cameron = df.copy()

# %% [markdown]
# #### Load mygene

# %%
SRC = 'mygene'
df = pd.concat([
    mygene_query('interleukin'),
    mygene_query('chemokine')
])
# Out:
# Original result info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 8 columns):
# _id             736 non-null object
# _score          736 non-null float64
# alias           686 non-null object
# ensembl         34 non-null object
# ensembl.gene    683 non-null object
# name            736 non-null object
# symbol          736 non-null object
# taxid           736 non-null int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 46.1+ KB
# None
# Score histogram:
# Original result info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 8 columns):
# _id             257 non-null object
# _score          257 non-null float64
# alias           232 non-null object
# ensembl         20 non-null object
# ensembl.gene    227 non-null object
# name            257 non-null object
# symbol          257 non-null object
# taxid           257 non-null int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 16.1+ KB
# None
# Score histogram:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172 entries, 0 to 76
# Data columns (total 7 columns):
# extid           172 non-null object
# alias           164 non-null object
# ensembl         10 non-null object
# ensembl.gene    157 non-null object
# name            172 non-null object
# symbol          172 non-null object
# taxid           172 non-null int64
# dtypes: int64(1), object(6)
# memory usage: 10.8+ KB

# %%
df = df[(~df['name'].str.contains('receptor'))]
df = df[df['name'].str.contains('interleukin') | df['name'].str.contains('chemokine')]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102 entries, 0 to 76
# Data columns (total 7 columns):
# extid           102 non-null object
# alias           98 non-null object
# ensembl         10 non-null object
# ensembl.gene    87 non-null object
# name            102 non-null object
# symbol          102 non-null object
# taxid           102 non-null int64
# dtypes: int64(1), object(6)
# memory usage: 6.4+ KB

# %%
def label_fn(v):
    # Prefer hyphonated labels (e.g. IL-2) for compatibility with other sources
    if not v.startswith('IL'):
        return v
    if 'IL-' in v:
        return v
    return 'IL-' + v[2:]
df = mygene_prep(df, label_fn=label_fn)
df = df.assign(spid=SPECIES_HUMAN_ID, src=SRC)
df = df.drop_duplicates(subset=['sym', 'lbl'])
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 747 entries, 0 to 775
# Data columns (total 5 columns):
# sym      747 non-null object
# lbl      747 non-null object
# extid    747 non-null object
# spid     747 non-null int64
# src      747 non-null object
# dtypes: int64(1), object(4)
# memory usage: 35.0+ KB
# None
#                sym     lbl  extid  spid     src
# 0           IL-17D  IL-17D  53342     1  mygene
# 1  interleukin 17D  IL-17D  53342     1  mygene
# 2            IL17D  IL-17D  53342     1  mygene
# 4             IL-7    IL-7   3574     1  mygene
# 5    interleukin 7    IL-7   3574     1  mygene

# %%
# Check for (and remove) any excessively vague symbols
df['sym'].unique()
# Out:
# array(['IL-17D', 'interleukin 17D', 'IL17D', 'IL-7', 'interleukin 7',
#        'IL7', 'IL-18', 'interleukin 18', 'IL18', 'IGIF', 'IL-1g', 'IL1F4',
#        'IL-2', 'interleukin 2', 'IL2', 'TCGF', 'lymphokine', 'IL-32',
#        'interleukin 32', 'IL32', 'IL-32alpha', 'IL-32beta', 'IL-32delta',
#        'IL-32gamma', 'NK4', 'TAIF', 'TAIFa', 'TAIFb', 'TAIFc', 'TAIFd',
#        'IL-12A', 'interleukin 12A', 'IL12A', 'CLMF', 'NFSK', 'NKSF1',
#        'P35', 'IL-31', 'interleukin 31', 'IL31', 'IL-22',
#        'interleukin 22', 'IL22', 'IL-21', 'IL-D110', 'IL-TIF', 'ILTIF',
#        'TIFIL-23', 'TIFa', 'zcyto18', 'IL-24', 'interleukin 24', 'IL24',
#        'C49A', 'FISP', 'IL10B', 'MDA7', 'MOB5', 'ST16', 'IL-17C',
#        'interleukin 17C', 'IL17C', 'CX2', 'IL-17B', 'interleukin 17B',
#        'IL17B', 'IL-20', 'NIRF', 'ZCYTO7', 'IL-9', 'interleukin 9', 'IL9',
#        'HP40', 'P40', 'IL-17F', 'interleukin 17F', 'IL17F', 'CANDF6',
#        'ML-1', 'ML1', 'IL-34', 'interleukin 34', 'IL34', 'C16orf77',
#        'IL-15', 'interleukin 15', 'IL15', 'IL-11', 'interleukin 11',
#        'IL11', 'AGIF', 'IL-19', 'interleukin 19', 'IL19', 'IL-10C',
#        'MDA1', 'NG.1', 'ZMDA1', 'IL-5', 'interleukin 5', 'IL5', 'EDF',
#        'TRF', 'IL-6', 'interleukin 6', 'IL6', 'BSF-2', 'BSF2', 'CDF',
#        'HGF', 'HSF', 'IFN-beta-2', 'IFNB2', 'IL-10', 'interleukin 10',
#        'IL10', 'CSIF', 'GVHDS', 'IL10A', 'TGIF', 'IL-25',
#        'interleukin 25', 'IL25', 'IL17E', 'IL-26', 'interleukin 26',
#        'IL26', 'AK155', 'IL-3', 'interleukin 3', 'IL3', 'MCGF',
#        'MULTI-CSF', 'IL-17A', 'interleukin 17A', 'IL17A', 'CTLA-8',
#        'CTLA8', 'IL-17', 'IL17', 'interleukin 20', 'IL20', 'IL10D',
#        'ZCYTO10', 'IL-27', 'interleukin 27', 'IL27', 'IL-27A', 'IL27A',
#        'IL27p28', 'IL30', 'p28', 'IL-16', 'interleukin 16', 'IL16', 'LCF',
#        'NIL16', 'PRIL16', 'prIL-16', 'IL-33', 'interleukin 33', 'IL33',
#        'C9orf26', 'DVS27', 'IL1F11', 'NF-HEV', 'NFEHEV', 'IL-13',
#        'interleukin 13', 'IL13', 'P600', 'IL-12B', 'interleukin 12B',
#        'IL12B', 'CLMF2', 'IMD28', 'IMD29', 'NKSF', 'NKSF2', 'IL-4',
#        'interleukin 4', 'IL4', 'BCGF-1', 'BCGF1', 'BSF-1', 'BSF1',
#        'IL-37', 'interleukin 37', 'IL37', 'FIL1', 'FIL1(ZETA)', 'FIL1Z',
#        'IL-1F7', 'IL-1H', 'IL-1H4', 'IL-1RP1', 'IL1F7', 'IL1H4', 'IL1RP1',
#        'interleukin 21', 'IL21', 'CVID11', 'Za11', 'IL-1B',
#        'interleukin 1 beta', 'IL1B', 'IL-1', 'IL1-BETA', 'IL1F2',
#        'IL-36A', 'interleukin 36 alpha', 'IL36A', 'FIL1(EPSILON)',
#        'FIL1E', 'IL-1F6', 'IL1(EPSILON)', 'IL1F6', 'IL-1A',
#        'interleukin 1 alpha', 'IL1A', 'IL1', 'IL1-ALPHA', 'IL1F1',
#        'IL-36G', 'interleukin 36 gamma', 'IL36G', 'IL-1F9', 'IL-1H1',
#        'IL-1RP2', 'IL1E', 'IL1F9', 'IL1H1', 'IL1RP2', 'IL-36B',
#        'interleukin 36 beta', 'IL36B', 'FIL1-(ETA)', 'FIL1H',
#        'FILI-(ETA)', 'IL-1F8', 'IL-1H2', 'IL1-ETA', 'IL1F8', 'IL1H2',
#        'IL-23A', 'interleukin 23 subunit alpha', 'IL23A', 'IL-23',
#        'IL23P19', 'P19', 'SGRF', 'IL-6ST',
#        'interleukin 6 signal transducer', 'IL6ST', 'CD130', 'CDW130',
#        'GP130', 'IL-6RB', 'IL-4I1', 'interleukin 4 induced 1', 'IL4I1',
#        'FIG1', 'LAAO', 'LAO', 'IL-18BP', 'interleukin 18 binding protein',
#        'IL18BP', 'IL18BPa', 'IL-F3',
#        'interleukin enhancer binding factor 3', 'ILF3', 'CBTF', 'DRBF',
#        'DRBP76', 'MMP4', 'MPHOSPH4', 'MPP4', 'MPP4110', 'NF-AT-90',
#        'NF110', 'NF110b', 'NF90', 'NF90a', 'NF90b', 'NF90c', 'NF90ctv',
#        'NFAR', 'NFAR-1', 'NFAR-2', 'NFAR110', 'NFAR2', 'NFAR90', 'TCP110',
#        'TCP80', 'IL-F2', 'interleukin enhancer binding factor 2', 'ILF2',
#        'NF45', 'PRO3063', 'LIF', 'LIF interleukin 6 family cytokine',
#        'DIA', 'HILDA', 'MLPLI', 'NFIL3',
#        'nuclear factor, interleukin 3 regulated', 'E4BP4', 'IL3BP1',
#        'NF-IL3A', 'NFIL3A', 'IL-1F10', 'interleukin 1 family member 10',
#        'IL1F10', 'FIL1-theta', 'FKSG75', 'IL-1HY2', 'IL-38', 'IL1-theta',
#        'IL1HY2', 'LOC107983991',
#        'nuclear factor interleukin-3-regulated protein-like', 'CKLF',
#        'chemokine like factor', 'C32', 'CKLF1', 'CKLF2', 'CKLF3', 'CKLF4',
#        'HSPC224', 'UCK-1', 'FP248',
#        'Putative chemokine-related protein FP248', 'CCL25',
#        'C-C motif chemokine ligand 25', 'Ckb15', 'SCYA25', 'TECK',
#        'CCL13', 'C-C motif chemokine ligand 13', 'CKb10', 'MCP-4',
#        'NCC-1', 'NCC1', 'SCYA13', 'SCYL1', 'CCL2',
#        'C-C motif chemokine ligand 2', 'GDCF-2', 'HC11', 'HSMCR30',
#        'MCAF', 'MCP-1', 'MCP1', 'SCYA2', 'SMC-CF', 'CCL23',
#        'C-C motif chemokine ligand 23', 'CK-BETA-8', 'CKb8', 'Ckb-8',
#        'Ckb-8-1', 'MIP-3', 'MIP3', 'MPIF-1', 'SCYA23', 'hmrp-2a', 'TAFA1',
#        'TAFA chemokine like family member 1', 'FAM19A1', 'TAFA-1',
#        'CCL24', 'C-C motif chemokine ligand 24', 'Ckb-6', 'MPIF-2',
#        'MPIF2', 'SCYA24', 'TAFA2', 'TAFA chemokine like family member 2',
#        'FAM19A2', 'TAFA-2', 'XCL2', 'X-C motif chemokine ligand 2',
#        'SCM-1b', 'SCM1B', 'SCYC2', 'XCL1', 'X-C motif chemokine ligand 1',
#        'ATAC', 'LPTN', 'LTN', 'SCM-1', 'SCM-1a', 'SCM1', 'SCM1A', 'SCYC1',
#        'CCL27', 'C-C motif chemokine ligand 27', 'ALP', 'CTACK', 'CTAK',
#        'ESKINE', 'ILC', 'PESKY', 'SCYA27', 'CCL28',
#        'C-C motif chemokine ligand 28', 'CCK1', 'MEC', 'SCYA28', 'CCL20',
#        'C-C motif chemokine ligand 20', 'CKb4', 'Exodus', 'LARC',
#        'MIP-3-alpha', 'MIP-3a', 'MIP3A', 'SCYA20', 'ST38', 'CCL16',
#        'C-C motif chemokine ligand 16', 'CKb12', 'HCC-4', 'ILINCK',
#        'LCC-1', 'LEC', 'LMC', 'Mtn-1', 'NCC-4', 'NCC4', 'SCYA16', 'SCYL4',
#        'CCL15', 'C-C motif chemokine ligand 15', 'HCC-2', 'HMRP-2B',
#        'LKN-1', 'LKN1', 'MIP-1 delta', 'MIP-1D', 'MIP-5', 'MRP-2B',
#        'NCC-3', 'NCC3', 'SCYA15', 'SCYL3', 'SY15', 'CCL26',
#        'C-C motif chemokine ligand 26', 'IMAC', 'MIP-4a', 'MIP-4alpha',
#        'SCYA26', 'TSC-1', 'CCL14', 'C-C motif chemokine ligand 14',
#        'CC-1', 'CC-3', 'CKB1', 'HCC-1', 'HCC-1(1-74)', 'HCC-1/HCC-3',
#        'HCC-3', 'MCIF', 'NCC-2', 'NCC2', 'SCYA14', 'SCYL2', 'SY14',
#        'CCL11', 'C-C motif chemokine ligand 11', 'SCYA11', 'CCL5',
#        'C-C motif chemokine ligand 5', 'D17S136E', 'RANTES', 'SCYA5',
#        'SIS-delta', 'SISd', 'TCP228', 'eoCP', 'CCL22',
#        'C-C motif chemokine ligand 22', 'A-152E5.1', 'ABCD-1', 'DC/B-CK',
#        'MDC', 'SCYA22', 'STCP-1', 'CCL18',
#        'C-C motif chemokine ligand 18', 'AMAC-1', 'AMAC1', 'CKb7',
#        'DC-CK1', 'DCCK1', 'MIP-4', 'PARC', 'SCYA18', 'TAFA5',
#        'TAFA chemokine like family member 5', 'FAM19A5', 'QLLK5208',
#        'TAFA-5', 'UNQ5208', 'CCL17', 'C-C motif chemokine ligand 17',
#        'A-152E5.3', 'ABCD-2', 'SCYA17', 'TARC', 'TAFA4',
#        'TAFA chemokine like family member 4', 'FAM19A4', 'TAFA-4',
#        'TAFA3', 'TAFA chemokine like family member 3', 'FAM19A3',
#        'TAFA-3', 'CCL19', 'C-C motif chemokine ligand 19', 'CKb11', 'ELC',
#        'MIP-3b', 'MIP3B', 'SCYA19', 'CCL8',
#        'C-C motif chemokine ligand 8', 'HC14', 'MCP-2', 'MCP2', 'SCYA10',
#        'SCYA8', 'CCL7', 'C-C motif chemokine ligand 7', 'FIC', 'MARC',
#        'MCP-3', 'MCP3', 'NC28', 'SCYA6', 'SCYA7', 'CCL3',
#        'C-C motif chemokine ligand 3', 'G0S19-1', 'LD78ALPHA',
#        'MIP-1-alpha', 'MIP1A', 'SCYA3', 'CCL1',
#        'C-C motif chemokine ligand 1', 'I-309', 'P500', 'SCYA1', 'SISe',
#        'TCA3', 'CCL21', 'C-C motif chemokine ligand 21', '6Ckine', 'CKb9',
#        'ECL', 'SCYA21', 'SLC', 'TCA4', 'CCL4',
#        'C-C motif chemokine ligand 4', 'ACT2', 'AT744.1', 'G-26', 'HC21',
#        'LAG-1', 'LAG1', 'MIP-1-beta', 'MIP1B', 'MIP1B1', 'SCYA4',
#        'CXCL13', 'C-X-C motif chemokine ligand 13', 'ANGIE', 'ANGIE2',
#        'BCA-1', 'BCA1', 'BLC', 'BLR1L', 'SCYB13', 'CXCL8',
#        'C-X-C motif chemokine ligand 8', 'GCP-1', 'GCP1', 'IL8', 'LECT',
#        'LUCT', 'LYNAP', 'MDNCF', 'MONAP', 'NAF', 'NAP-1', 'NAP1', 'CXCL1',
#        'C-X-C motif chemokine ligand 1', 'FSP', 'GRO1', 'GROa', 'MGSA',
#        'MGSA-a', 'NAP-3', 'SCYB1', 'CXCL6',
#        'C-X-C motif chemokine ligand 6', 'CKA-3', 'GCP-2', 'GCP2',
#        'SCYB6', 'CXCL11', 'C-X-C motif chemokine ligand 11', 'H174',
#        'I-TAC', 'IP-9', 'IP9', 'SCYB11', 'SCYB9B', 'b-R1', 'CXCL3',
#        'C-X-C motif chemokine ligand 3', 'CINC-2b', 'GRO3', 'GROg',
#        'MIP-2b', 'MIP2B', 'SCYB3', 'CXCL9',
#        'C-X-C motif chemokine ligand 9', 'CMK', 'Humig', 'MIG', 'SCYB9',
#        'crg-10', 'CXCL10', 'C-X-C motif chemokine ligand 10', 'C7',
#        'IFI10', 'INP10', 'IP-10', 'SCYB10', 'crg-2', 'gIP-10', 'mob-1',
#        'CXCL2', 'C-X-C motif chemokine ligand 2', 'CINC-2a', 'GRO2',
#        'GROb', 'MGSA-b', 'MIP-2a', 'MIP2', 'MIP2A', 'SCYB2', 'CXCL12',
#        'C-X-C motif chemokine ligand 12', 'IRH', 'PBSF', 'SCYB12', 'SDF1',
#        'TLSF', 'TPAR1', 'CXCL17', 'C-X-C motif chemokine ligand 17',
#        'DMC', 'Dcip1', 'UNQ473', 'VCC-1', 'VCC1', 'CXCL5',
#        'C-X-C motif chemokine ligand 5', 'ENA-78', 'SCYB5', 'CXCL14',
#        'C-X-C motif chemokine ligand 14', 'BMAC', 'BRAK', 'KEC', 'KS1',
#        'MIP-2g', 'MIP2G', 'NJAC', 'SCYB14', 'CXCL16',
#        'C-X-C motif chemokine ligand 16', 'CXCLG16', 'SR-PSOX', 'SRPSOX',
#        'CX3CL1', 'C-X3-C motif chemokine ligand 1', 'ABCD-3', 'C3Xkine',
#        'CXC3', 'CXC3C', 'NTN', 'NTT', 'SCYD1', 'fractalkine',
#        'neurotactin', 'CCL3L1', 'C-C motif chemokine ligand 3 like 1',
#        '464.2', 'D17S1718', 'G0S19-2', 'LD78', 'LD78-beta(1-70)',
#        'LD78BETA', 'MIP1AP', 'SCYA3L', 'SCYA3L1', 'CCL3L3',
#        'C-C motif chemokine ligand 3 like 3', 'CCL4L2',
#        'C-C motif chemokine ligand 4 like 2', 'AT744.2', 'CCL4L',
#        'SCYA4L', 'SCYQ4L2', 'UMLILO',
#        'upstream master lncRNA of the inflammatory chemokine locus',
#        'CCL4L1', 'C-C motif chemokine ligand 4 like 1', 'SCYA4L1',
#        'SCYA4L2'], dtype=object)

# %%
df[df['sym'].str.match('lymphokine')]
# Out:
#            sym   lbl extid  spid     src
# 20  lymphokine  IL-2  3558     1  mygene

# %%
dfs = df[~df['sym'].str.match('lymphokine')]
len(dfs), len(df)
# Out:
# (746, 747)

# %%
df_mygene = dfs.copy()

# %%
df_mygene[df_mygene['lbl'] == 'IL-2']
# Out:
#               sym   lbl extid  spid     src
# 15           IL-2  IL-2  3558     1  mygene
# 16  interleukin 2  IL-2  3558     1  mygene
# 17            IL2  IL-2  3558     1  mygene
# 19           TCGF  IL-2  3558     1  mygene

# %% [markdown]
# ### Load from CytokineRegistry

# %%
# Download from https://www.immport.org/docs/CytokineRegistry.November_2015.xls
SRC = 'ckr'
df = pd.read_excel(osp.join(DATA_DIR, 'meta', 'cytokine_registry', 'CytokineRegistry.November_2015.xls'))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 30 columns):
# UNIQUE ID                                    275 non-null object
# REFERENCE NAME                               275 non-null object
# HGNC ID                                      250 non-null object
# EntrezGene official name (Human)             255 non-null object
# EntrezGeneID (Human)                         255 non-null float64
# EntrezGene Symbol (Human)                    255 non-null object
# EntrezGene Aliases (Human)                   252 non-null object
# EntrezGene Additional Names (Human)          242 non-null object
# MGI ID                                       231 non-null object
# EntrezGeneofficial name (Mouse)              230 non-null object
# EntrezGeneID (Mouse)                         231 non-null float64
# EntrezGene Symbol (Mouse)                    231 non-null object
# EntrezGene Aliases (Mouse)                   221 non-null object
# EntrezGene Additional Names (Mouse)          224 non-null object
# UniProtDB ID (Human)                         247 non-null object
# UniProt protein name (Human)                 246 non-null object
# UniProt protein alternative names (Human)    245 non-null object
# UniProtID (Mouse)                            224 non-null object
# UniProt protein name (Mouse)                 207 non-null object
# UniProt protein alternative names (Mouse)    202 non-null object
# MeSH ID                                      103 non-null object
# MeSH Name                                    103 non-null object
# Typographical variations                     88 non-null object
# Shen-Orr ID                                  135 non-null float64
# IX Synonyms                                  135 non-null object
# Protein Ontology ID                          255 non-null object
# Protein Ontology name                        255 non-null object
# Protein Ontology synonyms                    251 non-null object
# Protein Ontology URL                         255 non-null object
# OMIM ID                                      245 non-null object
# dtypes: float64(3), object(27)
# memory usage: 64.5+ KB

# %%
sym_cols = [
    'EntrezGene Aliases (Human)',
    'EntrezGene Symbol (Human)',
    'UniProt protein name (Human)',
    'UniProt protein alternative names (Human)',
    'MeSH Name',
    'Typographical variations',
    'IX Synonyms',
    'Protein Ontology name',
    'Protein Ontology synonyms'
]

def relabel(t):
    
    # Translate greeks
    # - platelet-derived growth factor alpha -> platelet-derived growth factorα)
    # - interferon-alpha 10 -> interferon-α
    for r in greeks.itertuples():
        if ' ' + r.name in t:
            t = t.replace(' ' + r.name, r.letter)
        if '-' + r.name in t:
            t = t.replace(r.name, r.letter)
    
    # These rows have no information beyond reference name so ignore them
    if t == 'Suppressor Factors, Immunologic':
        return None
    if t == 'Macrophage Migration-Inhibitory Factors':
        return None
    
    # Replace patterns in names affecting multiple rows
    if 'Transforming Growth Factor' in t:
        t = t.replace('Transforming Growth Factor', 'TGF')
    elif 'Chemokine ' in t:
        t = t.replace('Chemokine ', '')
    elif 'Interleukin-' in t:
        t = t.replace('Interleukin-', 'IL-')
    elif 'interleukin-' in t:
        t = t.replace('interleukin-', 'IL-')
    elif 'Interferon-' in t:
        t = t.replace('Interferon-', 'IFN-')
    elif 'interferon-' in t:
        t = t.replace('interferon-', 'IFN-')
    elif 'Lymphotoxin-' in t:
        t = t.replace('Lymphotoxin-', 'LT-')
    elif 'Tumor necrosis factor ligand superfamily member ' in t:
        t = t.replace('Tumor necrosis factor ligand superfamily member ', 'TNFSF')
    elif 'platelet-derived growth factor' in t:
        t = t.replace('platelet-derived growth factor', 'PDGF')
    elif 'CKLF-like MARVEL transmembrane domain containing ' in t:
        t = t.replace('CKLF-like MARVEL transmembrane domain containing ', 'CKLFH')
    elif 'Fibroblast Growth Factor-' in t:
        t = t.replace('Fibroblast Growth Factor-', 'FGF')
    
    # Handle single cases
    m = {
        'B-Cell Activating Factor': 'BAFF',
        'B-Cell Stimulating Factor 3': 'BSF-3',
        'CD40 ligand': 'CD40LG',
        'CD70 molecule': 'CD70',
        'Chemokine-like Factor': 'CKLF',
        'Epidermal growth factor': 'EGF',
        'Erythropoietin': 'EPO',
        'Granulocyte Colony-Stimulating Factor': 'G-CSF',
        'Granulocyte-Macrophage Colony-Stimulating Factor': 'GM-CSF',
        'Growth Differentiation Factor 15': 'GDF15',
        'Hepatocyte Growth Factor': 'HGF',
        'IL-12 Subunit p35': 'IL-12A',
        'IL-12 Subunit p40': 'IL-12B',
        'IL-23 Subunit p19': 'IL-23A', 
        'IL-23 Subunit p40': 'IL-23p40',
        'Interferon Type I': 'IFN-1',
        'Interleukin 1 Receptor Antagonist Protein': 'IL-1RA',
        'Leukemia Inhibitory Factor': 'LIF', 
        'Leukocyte Cell Derived Chemotaxin 1': 'LECT1',
        'Leukocyte Cell Derived Chemotaxin 2': 'LECT2',
        'Leukocyte Migration-Inhibitory Factors': 'LMIF',
        'Macrophage Colony-Stimulating Factor 1': 'CSF1',
        'Macrophage Inflammatory Proteins': 'MIP',
        'Macrophage stimulating factor': 'MST1',
        'Macrophage Migration-Inhibitory Factor': 'MIF',
        'Macrophage-Activating Factors': 'MAF',
        'Monocyte Chemoattractant Proteins': 'MCP',
        'Oncostatin M': 'OSM',
        'Osteopontin': 'SPP1',
        'Platelet-Derived Growth Factor': 'PGDF',
        'Resistin': 'RETN',
        'Stem Cell Factor': 'SCF',
        'Thrombopoietin': 'THPO',
        'Transfer Factor': 'TF',
        'Tumor Necrosis Factor-α': 'TNF-α',
        'Tumor Necrosis Factors': 'TNF',
        'XCL-1': 'XCL1',
        'XCL-2': 'XCL2',
        'platelet factor 4 variant 1': 'CXCL4L1'
    }
    if t in m:
        return m[t]
    
    # 
    if t.startswith('IFN'):
        return t.replace(' ', '')
    
    return t

def pivot_df(df):
    res = []
    for i, r in df.iterrows():
        rec = {}
        rec['extid'] = r['UNIQUE ID']
        rec['lbl'] = relabel(r['REFERENCE NAME'])
        
        # Add record where lbl == sym
        row = dict(rec)
        row['sym'] = rec['lbl']
        res.append(row)
        
        # Add individual aliases
        for c in sym_cols:
            for v in (r[c].split(';') if not pd.isnull(r[c]) else []):
                row = dict(rec)
                row['sym'] = v
                res.append(row)
    return pd.DataFrame(res).assign(spid=SPECIES_HUMAN_ID, src=SRC)
       
# As reference name is ultimately used for the "lbl" field, it must be unique
# to ensure that grouping pivoted rows (per-"sym") can be regrouped to original row
assert df['REFERENCE NAME'].value_counts().max()
dfp = pivot_df(df)
dfp = dfp[dfp['lbl'].notnull()]
dfp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8502 entries, 0 to 8509
# Data columns (total 5 columns):
# extid    8502 non-null object
# lbl      8502 non-null object
# sym      8502 non-null object
# spid     8502 non-null int64
# src      8502 non-null object
# dtypes: int64(1), object(4)
# memory usage: 398.5+ KB

# %%
np.sort(dfp['lbl'].unique())
# Out:
# array(['Apo3', 'BAFF', 'BCMA', 'BSF-3', 'CCL1', 'CCL11', 'CCL12', 'CCL13',
#        'CCL14', 'CCL15', 'CCL16', 'CCL17', 'CCL18', 'CCL19', 'CCL2',
#        'CCL20', 'CCL21', 'CCL22', 'CCL23', 'CCL24', 'CCL25', 'CCL26',
#        'CCL27', 'CCL3', 'CCL3L1', 'CCL3L2', 'CCL3L3', 'CCL4', 'CCL4L1',
#        'CCL4L2', 'CCL5', 'CCL6', 'CCL7', 'CCL8', 'CCL9', 'CCR1', 'CCR10',
#        'CCR2', 'CCR3', 'CCR4', 'CCR5', 'CCR6', 'CCR7', 'CCR8', 'CCR9',
#        'CD114', 'CD115', 'CD116', 'CD117', 'CD118', 'CD120a', 'CD120b',
#        'CD121a', 'CD122', 'CD123', 'CD124', 'CD126', 'CD127', 'CD130',
#        'CD131', 'CD132', 'CD212', 'CD213a1', 'CD213a2', 'CD25', 'CD27',
#        'CD30', 'CD4', 'CD40', 'CD40LG', 'CD70', 'CDw119', 'CDw121b',
#        'CDw125', 'CDw136', 'CDw137', 'CDw217', 'CKLF', 'CKLFH1', 'CKLFH6',
#        'CKLFH7', 'CNTFR', 'CSF1', 'CX3CL1', 'CX3CR1', 'CXCL1', 'CXCL10',
#        'CXCL11', 'CXCL12', 'CXCL13', 'CXCL14', 'CXCL15', 'CXCL16',
#        'CXCL17', 'CXCL2', 'CXCL3', 'CXCL4', 'CXCL4L1', 'CXCL5', 'CXCL6',
#        'CXCL7', 'CXCL8', 'CXCL9', 'CXCR1', 'CXCR2', 'CXCR3', 'CXCR4',
#        'CXCR5', 'CXCR6', 'CXCR7', 'EGF', 'EGFR', 'EPO', 'EpoR', 'FASLG',
#        'FGF1', 'FGF2', 'FLT3LG', 'Fas', 'Flt-3', 'G-CSF', 'GDF15', 'GITR',
#        'GM-CSF', 'HGF', 'HVEM', 'IFN-1', 'IFN-α', 'IFN-α1', 'IFN-α10',
#        'IFN-α13', 'IFN-α14', 'IFN-α16', 'IFN-α17', 'IFN-α2', 'IFN-α21',
#        'IFN-α4', 'IFN-α5', 'IFN-α6', 'IFN-α7', 'IFN-α8', 'IFN-β', 'IFN-γ',
#        'IFN-ε', 'IFN-κ', 'IFN-ω', 'IFNAR1', 'IFNAR2', 'IFNGR2', 'IFNLR1',
#        'IL-1', 'IL-1 theta', 'IL-10', 'IL-11', 'IL-12', 'IL-12A',
#        'IL-12B', 'IL-13', 'IL-14', 'IL-15', 'IL-15Ra', 'IL-16', 'IL-17',
#        'IL-17a', 'IL-17b', 'IL-17c', 'IL-17d', 'IL-17f', 'IL-18',
#        'IL-18R1', 'IL-19', 'IL-1RA', 'IL-1α', 'IL-1β', 'IL-1δ', 'IL-1ε',
#        'IL-2', 'IL-20', 'IL-20Ra', 'IL-20Rb', 'IL-21', 'IL-22', 'IL-23',
#        'IL-23A', 'IL-23p40', 'IL-24', 'IL-25', 'IL-26', 'IL-27α',
#        'IL-27β', 'IL-28a', 'IL-28b', 'IL-29', 'IL-3', 'IL-31', 'IL-32',
#        'IL-33', 'IL-34', 'IL-35', 'IL-4', 'IL-5', 'IL-6', 'IL-7', 'IL-9',
#        'IL-9R', 'IL10RA', 'IL10RB', 'IL11RA', 'IL12RB2', 'IL21R',
#        'IL22RA1', 'IL22RA2', 'IL23R', 'LECT1', 'LECT2', 'LIF', 'LMIF',
#        'LT-α', 'LT-β', 'LTbR', 'MAF', 'MCP', 'MET', 'MIF', 'MIP', 'MPL',
#        'MST1', 'OPG', 'OSM', 'OSMR', 'OX40', 'PDGFRA', 'PDGFRB', 'PDGFα',
#        'PDGFβ', 'PGDF', 'RANK', 'RETN', 'SCF', 'SPP1', 'TACI', 'TDGF2',
#        'TDGF3', 'TF', 'TGF', 'TGFBR1', 'TGFBR2', 'TGFBR3', 'TGFα', 'TGFβ',
#        'TGFβ1', 'TGFβ2', 'TGFβ3', 'THPO', 'TNF', 'TNF-α', 'TNFSF10',
#        'TNFSF11', 'TNFSF12', 'TNFSF13', 'TNFSF14', 'TNFSF15', 'TNFSF18',
#        'TNFSF4', 'TNFSF8', 'TNFSF9', 'TRAILR1', 'TRAILR2', 'TRAILR3',
#        'TRAILR4', 'XCL1', 'XCL2', 'XCR1'], dtype=object)

# %%
dfp.head()
# Out:
#    extid   lbl    sym  spid  src
# 0  CID_1  BAFF   BAFF     1  ckr
# 1  CID_1  BAFF    DTL     1  ckr
# 2  CID_1  BAFF   BAFF     1  ckr
# 3  CID_1  BAFF   BLYS     1  ckr
# 4  CID_1  BAFF  CD257     1  ckr

# %%
df_ckr = dfp.copy()

# %% [markdown]
# ### Load from Manual Entries

# %%
SRC = 'manual'
df = pd.read_csv(osp.join(META_DATA_DIR, 'raw', 'cytokines.manual.csv'), sep=',')
df = df.assign(src=SRC, extid=None)
df.head()
# Out:
#      sym    lbl  spid     src extid
# 0  IL-23  IL-23     1  manual  None
# 1   IL23  IL-23     1  manual  None
# 2  IL-35  IL-35     1  manual  None
# 3   IL35  IL-35     1  manual  None
# 4  IL-32  IL-32     1  manual  None

# %%
df_manual = df.copy()

# %% [markdown]
# #### Generate Programmatic Transformations

# %%
# Function to add greek symbol variations
def expand_greeks(sym):
    syms = [sym]
    for r in greeks.itertuples():
        if r.letter in sym:
            syms.append(sym.replace(r.letter, r.name)) # IFN-γ -> IFN-gamma
            syms.append(sym.replace(r.letter, r.trans)) # IFN-γ -> IFN-g
            break
        if r.name in sym:
            syms.append(sym.replace(r.name, r.letter)) # IFN-gamma -> IFN-γ
            syms.append(sym.replace(r.name, r.trans)) # IFN-gamma -> IFN-g
            break
    return syms

# %%
SRC = 'transform'

# Add symbols to resolve references like "interleukin (IL)-4" or "interferon (IFN)-γ"
# as well as ensure that every IL-\d or IL\d+ is present

df = pd.concat([df_cameron, df_mygene, df_ckr, df_manual], sort=True).drop_duplicates()
dfr = []
for prefix, name in [
    ('IL', 'interleukin'), 
    ('IFN', 'interferon'),
    ('TNF', 'tumor necrosis factor'),
    ('TGF', 'transforming growth factor'),
    ('LT', 'lymphotoxin')
]:
    dfp = df[df['sym'].str.startswith(prefix)]
    # Get unique IL numbers, IFN types (alpha, beta, gamma), etc.
    suffixes = dfp['lbl'].str.replace(prefix + '[-]?', '').unique()
    for suffix in suffixes:
        lbl = prefix + '-' + suffix
        syms = [
            prefix + '-' + suffix, # IL-2
            prefix + suffix, # IL2
            '('+ prefix + ')' + suffix, # (IL)2
            '('+ prefix + ') ' + suffix, # (IL) 2
            '('+ prefix + ')-' + suffix, # (IL)-2
            name + ' ' + suffix, # interleukin 2
            name + '-' + suffix, # interleukin-2
            name + ' (' + prefix + ')-' + suffix, # interleukin (IL)-2
        ]
        # Add variations for greek letters
        syms = [v for sym in syms for v in expand_greeks(sym)]
        for sym in syms:
            dfr.append((sym, lbl))
df = pd.DataFrame(dfr, columns=['sym', 'lbl'])
df = df.assign(src=SRC, extid=None, spid=SPECIES_HUMAN_ID)
df_transform = df.copy()
df_transform.head()
# Out:
#          sym    lbl        src extid  spid
# 0      IL-1α  IL-1α  transform  None     1
# 1  IL-1alpha  IL-1α  transform  None     1
# 2      IL-1a  IL-1α  transform  None     1
# 3       IL1α  IL-1α  transform  None     1
# 4   IL1alpha  IL-1α  transform  None     1

# %% [markdown]
# #### Merge

# %%
df = merge([df_cameron, df_mygene, df_ckr, df_manual, df_transform], ID_TYP_CK).drop_duplicates()
df = add_preferred_ids(df, src_priority={'ckr': 3, 'manual': 2, 'transform': 1})
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8913 entries, 118 to 3472
# Data columns (total 7 columns):
# id        8913 non-null object
# src       8913 non-null object
# sym       8913 non-null object
# lbl       8913 non-null object
# spid      8913 non-null int64
# extid     6423 non-null object
# prefid    8913 non-null object
# dtypes: int64(1), object(6)
# memory usage: 557.1+ KB
# None
#                      id      src     sym     lbl  spid extid  \
# 118  CK16DB62C0EE32FCFC   manual   4-1BB   4-1BB     1  None
# 119  CKD6A1F8500CF5BB6C   manual  TNFSF9   4-1BB     1  None
# 31   CK66480A09B13AD79D  cameron  4-1BBL  4-1BBL     1  None
# 32   CK3C8B23133684A426  cameron   APRIL   APRIL     1  None
# 35   CKA1A67F50E3346A8F  cameron  TALL-2   APRIL     1  None
#
#                  prefid
# 118  CK16DB62C0EE32FCFC
# 119  CK16DB62C0EE32FCFC
# 31   CK66480A09B13AD79D
# 32   CKA6E60F616C682FA7
# 35   CKA6E60F616C682FA7

# %%
rm_sym = df[df['sym'].str.len() < MIN_CK_SYM_LEN]['sym'].unique()
print('Removing {} records with excessively short symbols: {}'.format(len(rm_sym), rm_sym))
df = df[~df['sym'].isin(rm_sym)]
df.info()
# Out:
# Removing 15 records with excessively short symbols: ['' 'Je' 'Sl' 'C7' 'c7' 'EP' 'FL' 'SF' 'sf' 'LT' 'lt' 'Op' 'TF' 'ML' 'MK']
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8623 entries, 118 to 3472
# Data columns (total 7 columns):
# id        8623 non-null object
# src       8623 non-null object
# sym       8623 non-null object
# lbl       8623 non-null object
# spid      8623 non-null int64
# extid     6133 non-null object
# prefid    8623 non-null object
# dtypes: int64(1), object(6)
# memory usage: 538.9+ KB

# %%
np.sort(df['lbl'].unique())
# Out:
# array(['4-1BB', '4-1BBL', 'APRIL', 'Apo3', 'BAFF', 'BCMA', 'BSF-3',
#        'CCL1', 'CCL11', 'CCL12', 'CCL13', 'CCL14', 'CCL15', 'CCL16',
#        'CCL17', 'CCL18', 'CCL19', 'CCL2', 'CCL20', 'CCL21', 'CCL22',
#        'CCL23', 'CCL24', 'CCL25', 'CCL26', 'CCL27', 'CCL28', 'CCL3',
#        'CCL3L1', 'CCL3L2', 'CCL3L3', 'CCL4', 'CCL4L1', 'CCL4L2', 'CCL5',
#        'CCL6', 'CCL7', 'CCL8', 'CCL9', 'CCR1', 'CCR10', 'CCR2', 'CCR3',
#        'CCR4', 'CCR5', 'CCR6', 'CCR7', 'CCR8', 'CCR9', 'CD114', 'CD115',
#        'CD116', 'CD117', 'CD118', 'CD120a', 'CD120b', 'CD121a', 'CD122',
#        'CD123', 'CD124', 'CD126', 'CD127', 'CD130', 'CD131', 'CD132',
#        'CD153', 'CD154', 'CD178', 'CD212', 'CD213a1', 'CD213a2', 'CD25',
#        'CD258', 'CD27', 'CD30', 'CD4', 'CD40', 'CD40LG', 'CD70', 'CDw119',
#        'CDw121b', 'CDw125', 'CDw136', 'CDw137', 'CDw217', 'CKLF',
#        'CKLFH1', 'CKLFH6', 'CKLFH7', 'CNTFR', 'CSF1', 'CSF2', 'CSF3',
#        'CX3CL1', 'CX3CR1', 'CXCL1', 'CXCL10', 'CXCL11', 'CXCL12',
#        'CXCL13', 'CXCL14', 'CXCL15', 'CXCL16', 'CXCL17', 'CXCL2', 'CXCL3',
#        'CXCL4', 'CXCL4L1', 'CXCL5', 'CXCL6', 'CXCL7', 'CXCL8', 'CXCL9',
#        'CXCR1', 'CXCR2', 'CXCR3', 'CXCR4', 'CXCR5', 'CXCR6', 'CXCR7',
#        'EBI3', 'EGF', 'EGFR', 'EPO', 'EpoR', 'FASLG', 'FGF1', 'FGF2',
#        'FLT3LG', 'FP248', 'Fas', 'Flt-3', 'G-CSF', 'GDF15', 'GITR',
#        'GITRL', 'GM-CSF', 'HGF', 'HVEM', 'IFN-1', 'IFN-AR1', 'IFN-AR2',
#        'IFN-CDw119', 'IFN-GR2', 'IFN-IL-18', 'IFN-IL-28A', 'IFN-IL-28B',
#        'IFN-IL-28a', 'IFN-IL-28b', 'IFN-IL-29', 'IFN-IL-6', 'IFN-LR1',
#        'IFN-α', 'IFN-α1', 'IFN-α10', 'IFN-α13', 'IFN-α14', 'IFN-α16',
#        'IFN-α17', 'IFN-α2', 'IFN-α21', 'IFN-α4', 'IFN-α5', 'IFN-α6',
#        'IFN-α7', 'IFN-α8', 'IFN-β', 'IFN-β1', 'IFN-γ', 'IFN-ε', 'IFN-κ',
#        'IFN-ω', 'IFNAR1', 'IFNAR2', 'IFNGR2', 'IFNLR1', 'IL-1',
#        'IL-1 theta', 'IL-10', 'IL-10RA', 'IL-10RB', 'IL-11', 'IL-11RA',
#        'IL-12', 'IL-12A', 'IL-12B', 'IL-12RB2', 'IL-12α', 'IL-13',
#        'IL-14', 'IL-15', 'IL-15Ra', 'IL-16', 'IL-17', 'IL-17A', 'IL-17B',
#        'IL-17C', 'IL-17D', 'IL-17F', 'IL-17a', 'IL-17b', 'IL-17c',
#        'IL-17d', 'IL-17f', 'IL-18', 'IL-18BP', 'IL-18R1', 'IL-19',
#        'IL-1A', 'IL-1B', 'IL-1F10', 'IL-1RA', 'IL-1α', 'IL-1β', 'IL-1δ',
#        'IL-1ε', 'IL-2', 'IL-20', 'IL-20Ra', 'IL-20Rb', 'IL-21', 'IL-21R',
#        'IL-22', 'IL-22RA1', 'IL-22RA2', 'IL-23', 'IL-23A', 'IL-23R',
#        'IL-23p40', 'IL-24', 'IL-25', 'IL-26', 'IL-27', 'IL-27α', 'IL-27β',
#        'IL-28', 'IL-28A', 'IL-28B', 'IL-28a', 'IL-28b', 'IL-29', 'IL-3',
#        'IL-31', 'IL-32', 'IL-33', 'IL-34', 'IL-35', 'IL-36A', 'IL-36B',
#        'IL-36G', 'IL-37', 'IL-4', 'IL-4I1', 'IL-5', 'IL-6', 'IL-6ST',
#        'IL-7', 'IL-9', 'IL-9R', 'IL-CCL16', 'IL-CCL27', 'IL-CD121a',
#        'IL-CD122', 'IL-CD123', 'IL-CD124', 'IL-CD126', 'IL-CD127',
#        'IL-CD130', 'IL-CD131', 'IL-CD132', 'IL-CD212', 'IL-CD213a1',
#        'IL-CD213a2', 'IL-CD25', 'IL-CDw121b', 'IL-CDw125', 'IL-CDw137',
#        'IL-CDw217', 'IL-CXCL8', 'IL-CXCR1', 'IL-CXCR2', 'IL-F2', 'IL-F3',
#        'IL-IFNLR1', 'IL-NF3', 'IL-OSMR', 'IL10RA', 'IL10RB', 'IL11RA',
#        'IL12RB2', 'IL21R', 'IL22RA1', 'IL22RA2', 'IL23R', 'LECT1',
#        'LECT2', 'LIF', 'LIGHT', 'LMIF', 'LOC107983991', 'LT-TNF-β',
#        'LT-TNFSF14', 'LT-XCL1', 'LT-bR', 'LT-α', 'LT-β', 'LTbR', 'MAF',
#        'MCP', 'MET', 'MIF', 'MIP', 'MPL', 'MST1', 'NFIL3', 'OPG', 'OSM',
#        'OSMR', 'OX40', 'OX40L', 'PDGFRA', 'PDGFRB', 'PDGFα', 'PDGFβ',
#        'PGDF', 'RANK', 'RETN', 'SCF', 'SPP1', 'TACI', 'TAFA1', 'TAFA2',
#        'TAFA3', 'TAFA4', 'TAFA5', 'TALL-1', 'TDGF2', 'TDGF3', 'TF', 'TGF',
#        'TGF-', 'TGF-BR1', 'TGF-BR2', 'TGF-BR3', 'TGF-α', 'TGF-β',
#        'TGF-β1', 'TGF-β2', 'TGF-β3', 'TGFBR1', 'TGFBR2', 'TGFBR3', 'TGFα',
#        'TGFβ', 'TGFβ1', 'TGFβ2', 'TGFβ3', 'THPO', 'TNF', 'TNF-',
#        'TNF-4-1BB', 'TNF-APRIL', 'TNF-Apo3', 'TNF-BAFF', 'TNF-BCMA',
#        'TNF-CD120a', 'TNF-CD120b', 'TNF-CD153', 'TNF-CD258', 'TNF-CD27',
#        'TNF-CD30', 'TNF-CD40', 'TNF-CD40LG', 'TNF-CD70', 'TNF-CDw137',
#        'TNF-FASLG', 'TNF-Fas', 'TNF-GITR', 'TNF-HVEM', 'TNF-LT-α',
#        'TNF-LT-β', 'TNF-LTbR', 'TNF-OPG', 'TNF-OX40', 'TNF-OX40L',
#        'TNF-RANK', 'TNF-SF10', 'TNF-SF11', 'TNF-SF12', 'TNF-SF13',
#        'TNF-SF13B', 'TNF-SF14', 'TNF-SF15', 'TNF-SF18', 'TNF-SF4',
#        'TNF-SF8', 'TNF-SF9', 'TNF-TACI', 'TNF-TRAILR1', 'TNF-TRAILR2',
#        'TNF-TRAILR3', 'TNF-TRAILR4', 'TNF-VEGI', 'TNF-α', 'TNF-β',
#        'TNFSF10', 'TNFSF11', 'TNFSF12', 'TNFSF13', 'TNFSF13B', 'TNFSF14',
#        'TNFSF15', 'TNFSF18', 'TNFSF4', 'TNFSF8', 'TNFSF9', 'TRAIL',
#        'TRAILR1', 'TRAILR2', 'TRAILR3', 'TRAILR4', 'TRANCE', 'TWEAK',
#        'UMLILO', 'VEGI', 'XCL1', 'XCL2', 'XCR1'], dtype=object)

# %%
df['src'].value_counts()
# Out:
# ckr          5388
# transform    2256
# mygene        745
# manual        123
# cameron       111
# Name: src, dtype: int64

# %%
df[df['lbl'] == 'IFN-γ']
# Out:
#                       id        src                     sym    lbl  spid  \
# 26    CK128EC732B281BF60    cameron                   IFN-γ  IFN-γ     1
# 26    CK8074B95EB01901B1    cameron                    IFNγ  IFN-γ     1
# 7758  CKEF3883BE9F74024F        ckr                   IFN-γ  IFN-γ     1
# 7759  CK9C64E63947F5A2F9        ckr                     IFG  IFN-γ     1
# 7760  CKB48252402DDAF7FD        ckr                     IFI  IFN-γ     1
# 7762  CKE830713A12B539AF        ckr                   IFNG   IFN-γ     1
# 7763  CK9622A52009298DFE        ckr        Interferon gamma  IFN-γ     1
# 7764  CK45F29FA1D05895F8        ckr               IFN-gamma  IFN-γ     1
# 7765  CK9A90B11FAA82C2AC        ckr       Immune interferon  IFN-γ     1
# 7767  CK978588916C50A3E5        ckr        Interferon-gamma  IFN-γ     1
# 7769  CKBF05FCD56CC2A7E2        ckr               IFN gamma  IFN-γ     1
# 7770  CK1162BE8704C5FF3B        ckr                    IFNG  IFN-γ     1
# 7771  CK49C184255D4775C5        ckr                   IFN-g  IFN-γ     1
# 7773  CKD008C37B052D78B9        ckr            Interferon-g  IFN-γ     1
# 7774  CK684D7985139131DC        ckr            Interferon g  IFN-γ     1
# 7775  CK91D6BD510ADE547F        ckr        interferon gamma  IFN-γ     1
# 7776  CKD56AAF124D22097B        ckr        gamma interferon  IFN-γ     1
# 7777  CK167D10F911D6D678        ckr            g interferon  IFN-γ     1
# 7780  CKB58D677833EB4A91        ckr                    ifng  IFN-γ     1
# 7781  CK3ABA59B20A717F44        ckr                     ifg  IFN-γ     1
# 7782  CKA74DFB5F7FF70B07        ckr               ifn-gamma  IFN-γ     1
# 7783  CK431EFEE92F9E8A5B        ckr       interferon, gamma  IFN-γ     1
# 7784  CK842F9F741C83B628        ckr                   ifn-g  IFN-γ     1
# 7785  CKFEB5879FD15E28C6        ckr        interferon-gamma  IFN-γ     1
# 7786  CKCE1EE63C15FF125E        ckr                     ifi  IFN-γ     1
# 7787  CKE521256BBE2AFBCB        ckr        gamma-interferon  IFN-γ     1
# 7789  CK98B7BE924AFDE9F4        ckr       immune interferon  IFN-γ     1
# 1040  CK1B71668FDDECE3CF  transform                   IFN-γ  IFN-γ     1
# 1041  CKB14BD5778A003DBA  transform               IFN-gamma  IFN-γ     1
# 1042  CKAB0A4DC198C5F1ED  transform                   IFN-g  IFN-γ     1
# 1043  CKF88B95F709297E33  transform                    IFNγ  IFN-γ     1
# 1044  CK28F65925FFAAE009  transform                IFNgamma  IFN-γ     1
# 1045  CK0D10BE8E50A659D4  transform                    IFNg  IFN-γ     1
# 1046  CKAC6AB0DEF89E5113  transform                  (IFN)γ  IFN-γ     1
# 1047  CKF5A331D97EF0549F  transform              (IFN)gamma  IFN-γ     1
# 1048  CK9C1DCC534F34890F  transform                  (IFN)g  IFN-γ     1
# 1049  CK8FAB99D623C11005  transform                 (IFN) γ  IFN-γ     1
# 1050  CKE0B9163A8DAECB0E  transform             (IFN) gamma  IFN-γ     1
# 1051  CK27080E286065B3C6  transform                 (IFN) g  IFN-γ     1
# 1052  CKDC084D8D066CBDAD  transform                 (IFN)-γ  IFN-γ     1
# 1053  CK64A840435F9DBA7B  transform             (IFN)-gamma  IFN-γ     1
# 1054  CKCFA041B4E878C9C0  transform                 (IFN)-g  IFN-γ     1
# 1055  CK30FCB87957F6228C  transform            interferon γ  IFN-γ     1
# 1056  CK47D24BFC95CEBC4D  transform        interferon gamma  IFN-γ     1
# 1057  CKC35DFD6C81BFC5CA  transform            interferon g  IFN-γ     1
# 1058  CKB1327E1355BFD9DD  transform            interferon-γ  IFN-γ     1
# 1059  CK8E78E2514321441A  transform        interferon-gamma  IFN-γ     1
# 1060  CK320F7A36DB4839C9  transform            interferon-g  IFN-γ     1
# 1061  CKD58AE8DCDCFEC12B  transform      interferon (IFN)-γ  IFN-γ     1
# 1062  CK39DF3C229ADCB13F  transform  interferon (IFN)-gamma  IFN-γ     1
# 1063  CK8EB605E5401B4F2F  transform      interferon (IFN)-g  IFN-γ     1
#
#        extid              prefid
# 26      None  CKEF3883BE9F74024F
# 26      None  CKEF3883BE9F74024F
# 7758  CID_83  CKEF3883BE9F74024F
# 7759  CID_83  CKEF3883BE9F74024F
# 7760  CID_83  CKEF3883BE9F74024F
# 7762  CID_83  CKEF3883BE9F74024F
# 7763  CID_83  CKEF3883BE9F74024F
# 7764  CID_83  CKEF3883BE9F74024F
# 7765  CID_83  CKEF3883BE9F74024F
# 7767  CID_83  CKEF3883BE9F74024F
# 7769  CID_83  CKEF3883BE9F74024F
# 7770  CID_83  CKEF3883BE9F74024F
# 7771  CID_83  CKEF3883BE9F74024F
# 7773  CID_83  CKEF3883BE9F74024F
# 7774  CID_83  CKEF3883BE9F74024F
# 7775  CID_83  CKEF3883BE9F74024F
# 7776  CID_83  CKEF3883BE9F74024F
# 7777  CID_83  CKEF3883BE9F74024F
# 7780  CID_83  CKEF3883BE9F74024F
# 7781  CID_83  CKEF3883BE9F74024F
# 7782  CID_83  CKEF3883BE9F74024F
# 7783  CID_83  CKEF3883BE9F74024F
# 7784  CID_83  CKEF3883BE9F74024F
# 7785  CID_83  CKEF3883BE9F74024F
# 7786  CID_83  CKEF3883BE9F74024F
# 7787  CID_83  CKEF3883BE9F74024F
# 7789  CID_83  CKEF3883BE9F74024F
# 1040    None  CKEF3883BE9F74024F
# 1041    None  CKEF3883BE9F74024F
# 1042    None  CKEF3883BE9F74024F
# 1043    None  CKEF3883BE9F74024F
# 1044    None  CKEF3883BE9F74024F
# 1045    None  CKEF3883BE9F74024F
# 1046    None  CKEF3883BE9F74024F
# 1047    None  CKEF3883BE9F74024F
# 1048    None  CKEF3883BE9F74024F
# 1049    None  CKEF3883BE9F74024F
# 1050    None  CKEF3883BE9F74024F
# 1051    None  CKEF3883BE9F74024F
# 1052    None  CKEF3883BE9F74024F
# 1053    None  CKEF3883BE9F74024F
# 1054    None  CKEF3883BE9F74024F
# 1055    None  CKEF3883BE9F74024F
# 1056    None  CKEF3883BE9F74024F
# 1057    None  CKEF3883BE9F74024F
# 1058    None  CKEF3883BE9F74024F
# 1059    None  CKEF3883BE9F74024F
# 1060    None  CKEF3883BE9F74024F
# 1061    None  CKEF3883BE9F74024F
# 1062    None  CKEF3883BE9F74024F
# 1063    None  CKEF3883BE9F74024F

# %% [markdown]
# #### Export

# %%
path = osp.join(META_DATA_DIR, CYTOKINES + '.csv')
df.to_csv(path, index=False)
path
# Out:
# '/lab/repos/t-cell-relation-extraction/pm_subtype_protein_relations/data/meta/cytokines.csv'
