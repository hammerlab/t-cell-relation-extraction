# %%
import os
import os.path as osp
import pandas as pd
import numpy as np
import collections
from snorkel import SnorkelSession
from tcre import supervision
from tcre.env import *
from tcre.supervision import *
session = SnorkelSession()
classes = get_candidate_classes()

# %%
from snorkel.models import Candidate
c = session.query(classes.inducing_cytokine.subclass).first()
c.get_cids(), c.cytokine_cid, c.immune_cell_type_cid
# Out:
# (('CK692CB9564F9067B0:CK6004F9DA69B8AB01',
#   'CT954E3C2D0B390922:CTE9F6070561C95355'),
#  'CK692CB9564F9067B0:CK6004F9DA69B8AB01',
#  'CT954E3C2D0B390922:CTE9F6070561C95355')

# %%
import re
from snorkel.lf_helpers import (
    get_tagged_text,
    get_left_tokens,
    get_right_tokens,
    get_between_tokens,
    get_text_splits,
    rule_regex_search_tagged_text,
    rule_regex_search_btw_AB,
    rule_regex_search_btw_BA,
    rule_regex_search_before_A,
    rule_regex_search_before_B,
)

# %%
#get_tagged_text(c)

# %% [markdown]
# ### Text Pattern Functions

# %%
TERMS = get_terms_map()

def subst_pattern(pattern, terms=None):
    for k, v in {**TERMS, **(terms or {})}.items():
        pattern = pattern.replace('{{' + k + '}}', v)
    return pattern

def regex_pattern(pattern, terms=None):
    return regex_search(None, pattern, terms=terms, pattern_only=True)
    
def regex_search(c, pattern, terms=None, pattern_only=False):
    # Add possible "cell" token after each cell type reference
    pattern = pattern.replace('{{B}}', '{{B}}( cell| type cell|-type cell)?')
    
    # Apply generic replacements in pattern
    pattern = subst_pattern(pattern, terms=terms)
    
    if pattern_only:
        return pattern
    return rule_regex_search_tagged_text(c, pattern, 1)

TERMS
# Out:
# {'r_diff_n': '(differentiation|formation|generation|polarization|development|induction)',
#  'r_diff_v': '(differentiate|form|generate|polarize|develop|differentiates|forms|generates|polarizes|develops)',
#  'r_diff_p': '(differentiated|formed|generated|polarized|developed)',
#  'r_diff_g': '(differentiating|forming|generating|polarizing|developing)',
#  'r_push_n': '(inducer|driver|director|regulator|controller|promoter|mediator|mediater)',
#  'r_push_v': '(induce|drive|direct|regulate|control|promote|mediate|induces|drives|directs|regulates|controls|promotes|mediates)',
#  'r_push_p': '(induced|drove|driven|directed|regulated|controlled|promoted|mediated)',
#  'r_push_g': '(inducing|driving|directing|regulating|controlling|promoting|mediating)',
#  'r_prod_n': '(producer|production|generator|generation|creator|creation)',
#  'r_prod_v': '(produce|generate|create|produces|generates|creates)',
#  'r_prod_p': '(produced|generated|created)',
#  'r_prod_g': '(producing|generating|creating)',
#  'r_secr_n': '(secretor|secretion|expressor|expression|producer|production|releaser|release)',
#  'r_secr_v': '(secrete|express|produce|release|secretes|expresses|produces|releases)',
#  'r_secr_p': '(secreted|expressed|produced|released)',
#  'r_secr_g': '(secreting|expressing|producing|releasing)',
#  'r_oppose_n': '(inhibitor|suppressor|suppresor|repressor|represor|antagonizer|impairer)',
#  'r_oppose_v': '(inhibit|suppress|suppres|repress|repres|antagonize|impair|inhibits|suppress|suppreses|repress|represes|antagonizes|impairs)',
#  'r_oppose_p': '(inhibited|suppressed|suppresed|repressed|represed|antagonized|impaired)',
#  'r_oppose_g': '(inhibiting|suppressing|suppresing|repressing|represing|antagonizing|impairing)',
#  'n_do': "(cannot|can't|will not|won't|are not|aren't|does not|doesn't|do not|don't|have not|haven't|would not|wouldn't|should not|shouldn't|never)",
#  'n_break': '(;|however|whereas|yet|otherwise|although|nonetheless|despite|spite of)',
#  'n_action': '(stimulation|costimulation|expansion|proliferation|migration)',
#  'wc_sm': '[^;]{0,30}',
#  'wc_md': '[^;]{0,50}',
#  'wc_lg': '[^;]{0,150}',
#  'wc_xl': '[^;]{0,250}'}

# %%
# LF_REGEX[REL_CLASS_INDUCING_CYTOKINE]['positive'][23]

# %%
def add_lf(fn, name=None):
    if name is not None:
        fn.__name__ = name
    # Register function in global namespace
    globals()[fn.__name__] = fn
        
def get_fn(ptn, sign):
    sub_ptn = regex_search(c, ptn[0], terms=ptn[1] if len(ptn)>1 else None, pattern_only=True)
    def fn(c):
        return sign * regex_search(c, ptn[0], terms=ptn[1] if len(ptn)>1 else None)
    return fn, sub_ptn

def get_agg_fn(ptns, sign, agg):
    fns = [get_fn(ptn, sign)[0] for ptn in ptns]
    def fn(c):
        return agg([f(c) for f in fns])
    return fn

# Set to true to roll all text pattern functions into a single function 
# (since there can be > 30 of them)
use_single_text_pattern_fn = True
if use_single_text_pattern_fn:
    for rcls in LF_REGEX:
        cmap = {v: k for k, v in REL_ABBRS.items()}
        for sign in LF_REGEX[rcls]:
            val = {'positive': 1, 'negative': -1}[sign]
            ptns = LF_REGEX[rcls][sign]
            if len(ptns) == 0:
                continue
            agg = max if val == 1 else min
            add_lf(get_agg_fn(ptns, val, agg), 'LF_{}_txtptn_{}_all'.format(cmap[rcls], sign[:3]))
else:
    for rcls in LF_REGEX:
        cmap = {v: k for k, v in REL_ABBRS.items()}
        for sign in LF_REGEX[rcls]:
            for i, ptn in enumerate(LF_REGEX[rcls][sign]):
                val = {'positive': 1, 'negative': -1}[sign]
                fn_name = 'LF_{}_txtptn_{}_{}'.format(cmap[rcls], sign[:3], i + 1)
                fn, sub_ptn = get_fn(ptn, val)
                print(fn_name, ':\n\t', ptn[0], '\n\t', sub_ptn)
                add_lf(fn, fn_name)

# %%
# text = 'The current {{A}}-(pos) cells'
# pattern = regex_pattern(r'{{A}}(\+|-)?(positive|negative|\(pos\)|neg|hi|lo)')
# print(pattern)
# m = re.search(pattern, text, flags=re.I)
# m is not None, m

# %% [markdown]
# ### Heuristic Functions

# %%
# Universal function to check for references that are over a certain number of words away, 
# making them unlikely to have any kind of relationship
def is_ref_too_far(c, max_words=25, allow_positive=False):
    n = len(list(get_between_tokens(c)))
    alt = 1 if allow_positive else 0
    return -1 if n > max_words else alt

def _add_dist_fn(abbr, dist_wrd):
    add_lf(
        lambda c: is_ref_too_far(c, dist_wrd, allow_positive=True), 
        'LF_' + abbr + '_heur_distref_' + str(dist_wrd)
    )
    
for abbr in REL_ABBRS:
    add_lf(lambda c: is_ref_too_far(c), 'LF_' + abbr + '_heur_distref')
    for dist_wrd in [5, 10, 15, 20, 25, 32, 50]:
        _add_dist_fn(abbr, dist_wrd)

def get_kwds(term_prefixes):
    return set([ 
        kw
        for prefix in term_prefixes
        for k, v in TERMS.items() if k.startswith(prefix)
        for kw in re.findall('\w+', v)
    ])

INDCK_KWS = get_kwds(['r_diff'])
SECCK_KWS = get_kwds(['r_secr'])
INDTF_KWS = get_kwds(['r_diff'])
INDCK_KWS = INDCK_KWS.difference(SECCK_KWS)
SECCK_KWS = SECCK_KWS.difference(INDCK_KWS)

             
def has_kwds(c, kwds, window=5):
    words = list(get_left_tokens(c, window=window)) + list(get_between_tokens(c)) + list(get_right_tokens(c, window=window))
    return len(kwds.intersection(words)) > 0

def indck_kwds(c, window):
    f1, f2 = has_kwds(c, INDCK_KWS, window=window), has_kwds(c, SECCK_KWS, window=window)
    if f1 and not f2:
        return 1
    if f2 and not f1:
        return -1
    return 0

def LF_indck_heur_kwds_01(c):
    return indck_kwds(c, 5)

def LF_indck_heur_kwds_02(c):
    return indck_kwds(c, 10)

def LF_indck_heur_kwds_03(c):
    return indck_kwds(c, 25)
    
def LF_secck_heur_kwds_01(c):
    return -1 * LF_indck_heur_kwds_01(c)

def LF_secck_heur_kwds_02(c):
    return -1 * LF_indck_heur_kwds_02(c)

def LF_secck_heur_kwds_03(c):
    return -1 * LF_indck_heur_kwds_03(c)

def LF_indtf_heur_kwds_01(c):
    return 1 if has_kwds(c, INDTF_KWS, window=5) else -1

def LF_indtf_heur_kwds_02(c):
    return 1 if has_kwds(c, INDTF_KWS, window=10) else -1

def LF_indtf_heur_kwds_03(c):
    return 1 if has_kwds(c, INDTF_KWS, window=25) else -1
        
def LF_indck_heur_closer_ck_to_ct(c):
    return -1*has_closer_reference(c, right=True)

def LF_indck_heur_closer_ct_to_ck(c):
    return -1*has_closer_reference(c, right=False)

def LF_indck_heur_closer_ref(c):
    return min(LF_indck_heur_closer_ck_to_ct(c), LF_indck_heur_closer_ct_to_ck(c))

def LF_secck_heur_closer_ck_to_ct(c):
    return -1*has_closer_reference(c, right=True)

def LF_secck_heur_closer_ct_to_ck(c):
    return -1*has_closer_reference(c, right=False)

def LF_secck_heur_closer_ref(c):
    return min(LF_secck_heur_closer_ck_to_ct(c), LF_secck_heur_closer_ct_to_ck(c))

def LF_indtf_heur_closer_tf_to_ct(c):
    return -1*has_closer_reference(c, right=True)

def LF_indtf_heur_closer_ct_to_tf(c):
    return -1*has_closer_reference(c, right=False)

def LF_indtf_heur_closer_ref(c):
    return min(LF_indtf_heur_closer_tf_to_ct(c), LF_indtf_heur_closer_ct_to_tf(c))


### Heuristics for identifying off-target sentences 

def _valid_cand(**kwargs):
    return lambda c: -1 if supervision.is_invalid_candidate(c, **kwargs) else 0

def _cmplx_cand(**kwargs):
    return lambda c: -1 if supervision.is_complex_candidate(c, **kwargs) else 0

def _hypot_cand(**kwargs):
    return lambda c: -1 if supervision.is_hypothesis_candidate(c, **kwargs) else 0

def _prexp_cand(**kwargs):
    return lambda c: -1 if supervision.is_expressed_protein(c, **kwargs) else 0

for abbr in REL_ABBRS:
    add_lf(_valid_cand(fig_kw_ct_thresh=1, punc_ct_thresh=5, newline_ct_thresh=3, char_ct_thresh=2000), 'LF_' + abbr + '_heur_valid_cand_01')
    add_lf(_valid_cand(fig_kw_ct_thresh=2, punc_ct_thresh=8, newline_ct_thresh=8, char_ct_thresh=2000), 'LF_' + abbr + '_heur_valid_cand_02')
    add_lf(_valid_cand(fig_kw_ct_thresh=4, punc_ct_thresh=12, newline_ct_thresh=10, char_ct_thresh=2000), 'LF_' + abbr + '_heur_valid_cand_03')
    add_lf(_cmplx_cand(entity_ct_thresh=3, char_ct_thresh=500), 'LF_' + abbr + '_heur_complex_cand_01')
    add_lf(_cmplx_cand(entity_ct_thresh=5, char_ct_thresh=800), 'LF_' + abbr + '_heur_complex_cand_02')
    add_lf(_hypot_cand(prefix_ct_thresh=1, token_ct_thresh=1), 'LF_' + abbr + '_heur_hypothesis_cand_01')
    add_lf(_hypot_cand(prefix_ct_thresh=1, token_ct_thresh=3), 'LF_' + abbr + '_heur_hypothesis_cand_02')
    if abbr != REL_SECCK:
        add_lf(_prexp_cand(), 'LF_' + abbr + '_heur_prexpression_cand_01')
    
### Heuristics for dependency parse tree processing

dep_parser = supervision.DependencyParseTree()

def LF_indck_parse_tree_01(c):
    if c.type != REL_FIELD_INDUCING_CYTOKINE:
        raise ValueError(f'Type {c.type} not supported')
    f1 = dep_parser.is_candidate_relation(c, REL_FIELD_INDUCING_CYTOKINE)
    f2 = dep_parser.is_candidate_relation(c, REL_FIELD_SECRETED_CYTOKINE)
    # Return false if heuristic positive for both related classes
    if f1 and f2:
        return -1
    return 1 if f1 else -1

def LF_secck_parse_tree_01(c):
    if c.type != REL_FIELD_SECRETED_CYTOKINE:
        raise ValueError(f'Type {c.type} not supported')
    f1 = dep_parser.is_candidate_relation(c, REL_FIELD_INDUCING_CYTOKINE)
    f2 = dep_parser.is_candidate_relation(c, REL_FIELD_SECRETED_CYTOKINE)
    # Return false if heuristic positive for both related classes
    if f1 and f2:
        return -1
    return 1 if f2 else -1

def LF_indtf_parse_tree_01(c):
    if c.type != REL_FIELD_INDUCING_TRANSCRIPTION_FACTOR:
        raise ValueError(f'Type {c.type} not supported')
    return 1 if dep_parser.is_candidate_relation(c, REL_FIELD_INDUCING_TRANSCRIPTION_FACTOR) else -1

# %% [markdown]
# ### Distant Supervision Functions

# %%
from tcre.ix import IXDB
ix_data_file = osp.join(SUPERVISION_DATA_DIR, 'immunexpresso', 'data.csv')

def add_ix_lfs(ix, lf_suffix):
    
    def indck_fn(c):
        if c.type != classes.inducing_cytokine.field:
            return 0
        ind1 = ix.is_candidate_relation(c, 'cytokine', 'Positive')
        if ind1 is None:
            return 0
        ind2 = ix.is_candidate_relation(c, 'cytokine', 'Negative')
        ind3 = ix.is_candidate_relation(c, 'cell', 'Positive')
        if ind1:
            if not ind2 and not ind3:
                return 1
        else:
            if ind2 or ind3:
                return -1
        return 0

    def secck_fn(c):
        if c.type != classes.secreted_cytokine.field:
            return 0
        ind1 = ix.is_candidate_relation(c, 'cell', 'Positive')
        if ind1 is None:
            return 0
        ind2 = ix.is_candidate_relation(c, 'cytokine', 'Positive')
        ind3 = ix.is_candidate_relation(c, 'cytokine', 'Negative')
        if ind1:
            if not ind2 and not ind3:
                return 1
        else:
            if ind2 or ind3:
                return -1
        return 0
    
    add_lf(indck_fn, 'LF_indck_dsup_imexpresso_' + lf_suffix)
    add_lf(secck_fn, 'LF_secck_dsup_imexpresso_' + lf_suffix)
    
ixs = {}
for min_papers in [4, 8, 12, 20]:
    ixs[min_papers] = IXDB(ix_data_file, min_papers).initialize()
    add_ix_lfs(ixs[min_papers], f'mp{min_papers:02d}')
ixs[4].df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 157 entries, (CT00B5D38A1594A953, CK25044A239340F089) to (CTFE4015328B70D553, CKF8C95AB8BB638BAC)
# Data columns (total 8 columns):
# actor             157 non-null object
# category          157 non-null object
# cell_id           157 non-null object
# cell_label        157 non-null object
# cytokine_id       157 non-null object
# cytokine_label    157 non-null object
# num_papers        157 non-null int64
# score             157 non-null float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 10.6+ KB

# %%
# df_ix = ixs[4].df
# dft = df_ix[(df_ix['actor'] == 'cell') & (df_ix['category'] == 'Positive')].sort_values('num_papers', ascending=False)
# dft[dft['cell_label'] == 'T-helper 2 cell'].head(10)

# %% [markdown]
# ### Supervised Classifier Functions

# %%
# df_sup_pred = pd.read_csv(osp.join(RESULTS_DATA_DIR, 'training-dev', 'run1', 'predictions.csv'))
# df_sup_pred.info()

# %%
# OFFTARGET_SPLITS = collections.defaultdict(lambda: [])

# def get_base_sup_fn(task, cfg):
#     preds = df_sup_pred.pipe(lambda df: df[(df['cfg'] == cfg) & (df['task'] == task)]).set_index('id')['y_pred'].to_dict()
#     def fn(c):
#         if c.type != task and c.type not in COMP_CLASSES:
#             raise ValueError(f'Expected type {task} but got candidate {c} with type {c.type}')
#         # If the type of the candidate does not match that expected, then
#         # fetch the sibling candidate which should be of the correct type
#         # (this allows for example, the function to fetch SCK labels
#         # to accept an ICK candidate, convert to SCK, and then return that label instead)
#         if c.type != task:
#             sc = get_cand_sibling(c, strict=True)
#             if sc.type != task:
#                 raise ValueError(f'Sibling candidate {sc} of type {sc.type} does not match task {task} (original candidate = {c})')
#             # If the sibling ends up being in a split for which no predictions were made (e.g. INFER)
#             # record the id and abstain
#             if sc.id not in preds:
#                 OFFTARGET_SPLITS[task].append(sc.id)
#                 return 0
#             c = sc
#         if c.id not in preds:
#             raise ValueError(f'Failed to find prediction for candidate {c.id} for task {task} and model cfg {cfg}')
#         return 1 if preds[c.id] > .5 else -1
#     return fn

# for k, v in REL_ABBRS.items():
#     for cfg in df_sup_pred['cfg'].unique():
#         fn = get_base_sup_fn(classes[v].field, cfg)
#         add_lf(fn, f'LF_{k}_sup_cfg_{cfg:02d}')

# %%
# c = session.query(classes.inducing_transcription_factor.subclass).first()
# LF_indtf_sup_cfg_00(c)

# %% [markdown]
# ### Composite Functions

# %%
def _global_lfs():
    return {
        k:v for k, v in globals().items() 
        if callable(v) and k.startswith('LF_')
    }

def get_lfs(filter_fn=None): 
    lfs = _global_lfs()
    if filter_fn is None:
        filter_fn = lambda n: True
    res = collections.OrderedDict([
        (k, lfs[k]) for k in sorted(lfs.keys()) 
        if filter_fn(k)
    ])
    return res

fns_indck_comp_pos = get_lfs(lambda k: k.startswith('LF_indck_txtptn_pos'))
fns_secck_comp_pos = get_lfs(lambda k: k.startswith('LF_secck_txtptn_pos'))
fns_indtf_comp_pos = get_lfs(lambda k: k.startswith('LF_indtf_txtptn_pos'))

def summarize_fns(name, fns):
    print('{}: Num functions found = {}, Names:\n{}'.format(
        name, len(fns), '\n'.join(list(fns.keys()))
    ))
summarize_fns('fns_indck_comp_pos', fns_indck_comp_pos)
summarize_fns('fns_secck_comp_pos', fns_secck_comp_pos)
summarize_fns('fns_indtf_comp_pos', fns_indtf_comp_pos)

def LF_indck_comp_neg_sec(c):
    # Create function that returns -1 for inducing cytokines anytime a positive hit is found on secretion
    # * should return -1 or 0
    return min(-1*max([f(c) for f in fns_secck_comp_pos.values()]), 0)

def LF_secck_comp_neg_ind(c):
    # Create function that returns -1 for inducing cytokines anytime a positive hit is found on secretion
    # * should return -1 or 0
    return min(-1*max([f(c) for f in fns_indck_comp_pos.values()]), 0)

fns_indck_comp_neg = get_lfs(lambda k: k.startswith('LF_indck_txtptn_neg') or \
                             k.startswith('LF_indck_heur_distref') or \
                             k.startswith('LF_indck_heur_closer_ct_to_ck') or \
                             k.startswith('LF_indck_comp_neg_sec') or \
                             k.startswith('LF_indck_heur_complex_cand_02') or \
                             k.startswith('LF_indck_heur_valid_cand_03'))
fns_secck_comp_neg = get_lfs(lambda k: k.startswith('LF_secck_txtptn_neg') or \
                             k.startswith('LF_secck_heur_distref') or \
                             k.startswith('LF_secck_heur_closer_ct_to_ck') or \
                             k.startswith('LF_secck_comp_neg_ind') or \
                             k.startswith('LF_secck_heur_complex_cand_02') or \
                             k.startswith('LF_secck_heur_valid_cand_03'))
fns_indtf_comp_neg = get_lfs(lambda k: k.startswith('LF_indtf_txtptn_neg') or \
                             k.startswith('LF_indtf_heur_distref') or \
                             k.startswith('LF_indtf_heur_closer_ct_to_tf') or \
                             k.startswith('LF_indtf_heur_complex_cand_02') or \
                             k.startswith('LF_indtf_heur_valid_cand_03'))
summarize_fns('fns_indck_comp_neg', fns_indck_comp_neg)
summarize_fns('fns_secck_comp_neg', fns_secck_comp_neg)
summarize_fns('fns_indtf_comp_neg', fns_indtf_comp_neg)

def apply_composite_xor_indck(c):
    is_secck = max([f(c) for f in fns_secck_comp_pos.values()]) > 0
    is_indck = max([f(c) for f in fns_indck_comp_pos.values()]) > 0
    not_secck = min([f(c) for f in fns_secck_comp_neg.values()]) < 0
    not_indck = min([f(c) for f in fns_indck_comp_neg.values()]) < 0
    # Look first for single strong positive prediction
    if is_secck and is_indck:
        return 0
    if is_indck and not is_secck:
        return 1
    if not is_indck and is_secck:
        return -1
    # If neither have positive prediction, look for strong negative prediction
    if not_secck == not_indck:
        return 0
    if not_indck and not not_secck:
        return -1
    return 1

def LF_indck_comp_xor(c):
    return apply_composite_xor_indck(c)

def LF_secck_comp_xor(c):
    return -1*apply_composite_xor_indck(c)

def LF_indtf_comp_xor(c):
    is_indtf = max([f(c) for f in fns_indtf_comp_pos.values()]) > 0
    not_indtf = min([f(c) for f in fns_indtf_comp_neg.values()]) < 0
    # Take non-conflicting positive or negative classifications and make 0 otherwise
    if is_indtf and not not_indtf:
        return 1
    if not_indtf and not is_indtf:
        return -1
    return 0

# Distant supervision composites
def LF_indck_comp_imexpresso_nonneg(c):
    skip = min([f(c) for f in fns_indck_comp_neg.values()]) < 0
    return LF_indck_dsup_imexpresso_mp08(c) if not skip else 0

def LF_secck_comp_imexpresso_nonneg(c):
    skip = min([f(c) for f in fns_secck_comp_neg.values()]) < 0
    return LF_secck_dsup_imexpresso_mp08(c) if not skip else 0

# Direct supervision composites
# fns_indck_sup = get_lfs(lambda k: k.startswith('LF_indck_sup_cfg_'))
# fns_secck_sup = get_lfs(lambda k: k.startswith('LF_secck_sup_cfg_'))
# fns_indtf_sup = get_lfs(lambda k: k.startswith('LF_indtf_sup_cfg_'))
# summarize_fns('fns_indck_sup', fns_indck_sup)
# summarize_fns('fns_secck_sup', fns_secck_sup)
# summarize_fns('fns_indtf_sup', fns_indtf_sup)

# def LF_indck_sup_comp(c):
#     # If there is any strong indication of a negative, use it instead
#     not_indck = min([f(c) for f in fns_indck_comp_neg.values()]) < 0
#     if not_indck:
#         return -1
    
#     # Return false if any supervised model predicts true for secreted cytokines
#     is_secck = max([f(c) for f in fns_secck_sup.values()]) > 0
#     if is_secck:
#         return -1

#     # Otherwise, return true if any model predicts true
#     is_indck = max([f(c) for f in fns_indck_sup.values()]) > 0
#     return 1 if is_indck else -1

# def LF_secck_sup_comp(c):
#     # If there is any strong indication of a negative, use it instead
#     not_secck = min([f(c) for f in fns_secck_comp_neg.values()]) < 0
#     if not_secck:
#         return -1
    
#     # Return false if any supervised model predicts true for inducing cytokines
#     is_indck = max([f(c) for f in fns_indck_sup.values()]) > 0
#     if is_indck:
#         return -1
    
#     # Otherwise, return true if any model predicts true
#     is_secck = max([f(c) for f in fns_secck_sup.values()]) > 0
#     return 1 if is_secck else -1

# def LF_indtf_sup_comp(c):
#     # Return true if any model predicts true
#     is_indtf = max([f(c) for f in fns_indtf_sup.values()]) > 0
#     return 1 if is_indtf else -1
# Out:
# fns_indck_comp_pos: Num functions found = 1, Names:
# LF_indck_txtptn_pos_all
# fns_secck_comp_pos: Num functions found = 1, Names:
# LF_secck_txtptn_pos_all
# fns_indtf_comp_pos: Num functions found = 1, Names:
# LF_indtf_txtptn_pos_all
# fns_indck_comp_neg: Num functions found = 13, Names:
# LF_indck_comp_neg_sec
# LF_indck_heur_closer_ct_to_ck
# LF_indck_heur_complex_cand_02
# LF_indck_heur_distref
# LF_indck_heur_distref_10
# LF_indck_heur_distref_15
# LF_indck_heur_distref_20
# LF_indck_heur_distref_25
# LF_indck_heur_distref_32
# LF_indck_heur_distref_5
# LF_indck_heur_distref_50
# LF_indck_heur_valid_cand_03
# LF_indck_txtptn_neg_all
# fns_secck_comp_neg: Num functions found = 13, Names:
# LF_secck_comp_neg_ind
# LF_secck_heur_closer_ct_to_ck
# LF_secck_heur_complex_cand_02
# LF_secck_heur_distref
# LF_secck_heur_distref_10
# LF_secck_heur_distref_15
# LF_secck_heur_distref_20
# LF_secck_heur_distref_25
# LF_secck_heur_distref_32
# LF_secck_heur_distref_5
# LF_secck_heur_distref_50
# LF_secck_heur_valid_cand_03
# LF_secck_txtptn_neg_all
# fns_indtf_comp_neg: Num functions found = 12, Names:
# LF_indtf_heur_closer_ct_to_tf
# LF_indtf_heur_complex_cand_02
# LF_indtf_heur_distref
# LF_indtf_heur_distref_10
# LF_indtf_heur_distref_15
# LF_indtf_heur_distref_20
# LF_indtf_heur_distref_25
# LF_indtf_heur_distref_32
# LF_indtf_heur_distref_5
# LF_indtf_heur_distref_50
# LF_indtf_heur_valid_cand_03
# LF_indtf_txtptn_neg_all

# %%
LFs = collections.OrderedDict()
LFs[REL_CLASS_INDUCING_CYTOKINE] = get_lfs(lambda k: k.startswith('LF_indck')).values()
LFs[REL_CLASS_SECRETED_CYTOKINE] = get_lfs(lambda k: k.startswith('LF_secck')).values()
LFs[REL_CLASS_INDUCING_TRANSCRIPTION_FACTOR] = get_lfs(lambda k: k.startswith('LF_indtf')).values()
for k in LFs:
    print('{} labeling functions:'.format(k))
    for f in LFs[k]:
        print(f.__name__)
    print()
# Out:
# InducingCytokine labeling functions:
# LF_indck_comp_imexpresso_nonneg
# LF_indck_comp_neg_sec
# LF_indck_comp_xor
# LF_indck_dsup_imexpresso_mp04
# LF_indck_dsup_imexpresso_mp08
# LF_indck_dsup_imexpresso_mp12
# LF_indck_dsup_imexpresso_mp20
# LF_indck_heur_closer_ck_to_ct
# LF_indck_heur_closer_ct_to_ck
# LF_indck_heur_closer_ref
# LF_indck_heur_complex_cand_01
# LF_indck_heur_complex_cand_02
# LF_indck_heur_distref
# LF_indck_heur_distref_10
# LF_indck_heur_distref_15
# LF_indck_heur_distref_20
# LF_indck_heur_distref_25
# LF_indck_heur_distref_32
# LF_indck_heur_distref_5
# LF_indck_heur_distref_50
# LF_indck_heur_hypothesis_cand_01
# LF_indck_heur_hypothesis_cand_02
# LF_indck_heur_kwds_01
# LF_indck_heur_kwds_02
# LF_indck_heur_kwds_03
# LF_indck_heur_prexpression_cand_01
# LF_indck_heur_valid_cand_01
# LF_indck_heur_valid_cand_02
# LF_indck_heur_valid_cand_03
# LF_indck_parse_tree_01
# LF_indck_txtptn_neg_all
# LF_indck_txtptn_pos_all
#
# SecretedCytokine labeling functions:
# LF_secck_comp_imexpresso_nonneg
# LF_secck_comp_neg_ind
# LF_secck_comp_xor
# LF_secck_dsup_imexpresso_mp04
# LF_secck_dsup_imexpresso_mp08
# LF_secck_dsup_imexpresso_mp12
# LF_secck_dsup_imexpresso_mp20
# LF_secck_heur_closer_ck_to_ct
# LF_secck_heur_closer_ct_to_ck
# LF_secck_heur_closer_ref
# LF_secck_heur_complex_cand_01
# LF_secck_heur_complex_cand_02
# LF_secck_heur_distref
# LF_secck_heur_distref_10
# LF_secck_heur_distref_15
# LF_secck_heur_distref_20
# LF_secck_heur_distref_25
# LF_secck_heur_distref_32
# LF_secck_heur_distref_5
# LF_secck_heur_distref_50
# LF_secck_heur_hypothesis_cand_01
# LF_secck_heur_hypothesis_cand_02
# LF_secck_heur_kwds_01
# LF_secck_heur_kwds_02
# LF_secck_heur_kwds_03
# LF_secck_heur_valid_cand_01
# LF_secck_heur_valid_cand_02
# LF_secck_heur_valid_cand_03
# LF_secck_parse_tree_01
# LF_secck_txtptn_neg_all
# LF_secck_txtptn_pos_all
#
# InducingTranscriptionFactor labeling functions:
# LF_indtf_comp_xor
# LF_indtf_heur_closer_ct_to_tf
# LF_indtf_heur_closer_ref
# LF_indtf_heur_closer_tf_to_ct
# LF_indtf_heur_complex_cand_01
# LF_indtf_heur_complex_cand_02
# LF_indtf_heur_distref
# LF_indtf_heur_distref_10
# LF_indtf_heur_distref_15
# LF_indtf_heur_distref_20
# LF_indtf_heur_distref_25
# LF_indtf_heur_distref_32
# LF_indtf_heur_distref_5
# LF_indtf_heur_distref_50
# LF_indtf_heur_hypothesis_cand_01
# LF_indtf_heur_hypothesis_cand_02
# LF_indtf_heur_kwds_01
# LF_indtf_heur_kwds_02
# LF_indtf_heur_kwds_03
# LF_indtf_heur_prexpression_cand_01
# LF_indtf_heur_valid_cand_01
# LF_indtf_heur_valid_cand_02
# LF_indtf_heur_valid_cand_03
# LF_indtf_parse_tree_01
# LF_indtf_txtptn_neg_all
# LF_indtf_txtptn_pos_all

# %% [markdown]
# #### LF Testing

# %%
# from snorkel.viewer import SentenceNgramViewer
# from snorkel.annotations import load_gold_labels

# candidate_class = classes.inducing_cytokine
# #candidate_class = classes.secreted_cytokine
# #candidate_class = classes.inducing_transcription_factor
# # Load all dev labels for this relation class
# L_dev = supervision.get_gold_labels(session, candidate_class, split=SPLIT_DEV)

# labeled, gold = [], []
# for cand_id, v in L_dev.items():
#     c = session.query(Candidate).filter(Candidate.id == cand_id).one()
#     if LF_indck_parse_tree_01(c) == 1:
#         labeled.append(c)
#         if v > 0:
#             gold.append(c)

# print("Number labeled =", len(labeled), ", num gold =", len(gold))
# # - ID in hover state is sentence id (c.get_parent().id)
# # - Cell type label will be blue if candidate is NOT in "gold" set and red otherwise
# SentenceNgramViewer(labeled, session, gold=gold, height=1000)

# %%
# from tcre.query import DocToCand
# sent_id = 325453
# df_doc_cand = DocToCand.all(session, classes)
# cand_ids = df_doc_cand.set_index(['cand_type', 'sentence_id']).sort_index().loc[(candidate_class.field, sent_id)]['cand_id']
# c = session.query(Candidate).filter(Candidate.id == int(cand_ids.values[0])).one()
# c

# %% [markdown]
# ## Apply Labeling to Candidates

# %%
for c in classes.values():
    for split in [SPLIT_DEV, SPLIT_VAL, SPLIT_TEST, SPLIT_TRAIN, SPLIT_INFER]:
        n = session.query(c.subclass).filter(c.subclass.split == split).count()
        print('Candidate counts: {} (split {}) -> {}'.format(c.name, split, n))
# Out:
# Candidate counts: InducingCytokine (split 1) -> 950
# Candidate counts: InducingCytokine (split 3) -> 203
# Candidate counts: InducingCytokine (split 2) -> 271
# Candidate counts: InducingCytokine (split 0) -> 10000
# Candidate counts: InducingCytokine (split 9) -> 80415
# Candidate counts: SecretedCytokine (split 1) -> 952
# Candidate counts: SecretedCytokine (split 3) -> 205
# Candidate counts: SecretedCytokine (split 2) -> 274
# Candidate counts: SecretedCytokine (split 0) -> 10000
# Candidate counts: SecretedCytokine (split 9) -> 80408
# Candidate counts: InducingTranscriptionFactor (split 1) -> 612
# Candidate counts: InducingTranscriptionFactor (split 3) -> 209
# Candidate counts: InducingTranscriptionFactor (split 2) -> 281
# Candidate counts: InducingTranscriptionFactor (split 0) -> 10000
# Candidate counts: InducingTranscriptionFactor (split 9) -> 25433

# %%
from tcre import labeling
labeling.clear_labeling_functions()

# %%
res_label = collections.defaultdict(dict)
for c in classes:
    if c not in LFs:
        continue
#     for i, split in enumerate([SPLIT_DEV]):
#     for i, split in enumerate([SPLIT_DEV, SPLIT_VAL, SPLIT_TEST]):
#     for i, split in enumerate([SPLIT_TRAIN]):
    for i, split in enumerate([SPLIT_DEV, SPLIT_VAL, SPLIT_TEST, SPLIT_TRAIN]):
        res_label[c][split] = labeling.apply_labeling_functions(session, classes[c], split, LFs[c])
# Out:
#   0%|          | 2/950 [00:00<01:22, 11.45it/s]
# Running labeling for class InducingCytokine, split 1
# Running UDF...
# 100%|██████████| 950/950 [00:57<00:00, 16.39it/s]
#   1%|▏         | 3/203 [00:00<00:08, 24.04it/s]
# Running labeling for class InducingCytokine, split 3
# Running UDF...
# 100%|██████████| 203/203 [00:13<00:00, 17.72it/s]
#   1%|          | 3/271 [00:00<00:10, 24.86it/s]
# Running labeling for class InducingCytokine, split 2
# Running UDF...
# 100%|██████████| 271/271 [00:17<00:00, 15.30it/s]
#   0%|          | 2/10000 [00:00<12:11, 13.67it/s]
# Running labeling for class InducingCytokine, split 0
# Running UDF...
# 100%|██████████| 10000/10000 [11:00<00:00, 15.14it/s]
#   0%|          | 3/952 [00:00<00:32, 29.30it/s]
# Running labeling for class SecretedCytokine, split 1
# Running UDF...
# 100%|██████████| 952/952 [00:57<00:00, 16.44it/s]
#   1%|▏         | 3/205 [00:00<00:08, 24.24it/s]
# Running labeling for class SecretedCytokine, split 3
# Running UDF...
# 100%|██████████| 205/205 [00:13<00:00, 14.64it/s]
#   1%|          | 3/274 [00:00<00:10, 25.15it/s]
# Running labeling for class SecretedCytokine, split 2
# Running UDF...
# 100%|██████████| 274/274 [00:18<00:00, 17.13it/s]
#   0%|          | 3/10000 [00:00<06:13, 26.78it/s]
# Running labeling for class SecretedCytokine, split 0
# Running UDF...
# 100%|██████████| 10000/10000 [11:02<00:00, 15.10it/s]
#   1%|          | 4/612 [00:00<00:17, 35.70it/s]
# Running labeling for class InducingTranscriptionFactor, split 1
# Running UDF...
# 100%|██████████| 612/612 [00:18<00:00, 32.26it/s]
#   2%|▏         | 4/209 [00:00<00:05, 36.91it/s]
# Running labeling for class InducingTranscriptionFactor, split 3
# Running UDF...
# 100%|██████████| 209/209 [00:07<00:00, 31.74it/s]
#   1%|▏         | 4/281 [00:00<00:07, 36.18it/s]
# Running labeling for class InducingTranscriptionFactor, split 2
# Running UDF...
# 100%|██████████| 281/281 [00:09<00:00, 29.96it/s]
#   0%|          | 4/10000 [00:00<04:25, 37.59it/s]
# Running labeling for class InducingTranscriptionFactor, split 0
# Running UDF...
# 100%|██████████| 10000/10000 [05:38<00:00, 31.80it/s]

# %%
# [(k, len(set(v))) for k, v in OFFTARGET_SPLITS.items()]

# %%
from IPython.display import display
for c in res_label:
    for split in res_label[c]:
        if split not in [SPLIT_DEV, SPLIT_TRAIN]:
            continue
        print('Stats {} (split = {} ({})):'.format(c, SPLIT_MAP[split], split))
        df = res_label[c][split][2]
        subset = ['Coverage'] + (['Empirical Acc.'] if 'Empirical Acc.' in df else [])
        display(df.style.background_gradient(subset=subset))
# Out:
# Stats InducingCytokine (split = dev (1)):
# <style  type="text/css" >
#     #T_cb9228ba_b947_11e9_8894_0242ac110002row0_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row0_col8 {
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row1_col1 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row1_col8 {
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row2_col1 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row2_col8 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row3_col1 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row3_col8 {
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row4_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row4_col8 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row5_col1 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row5_col8 {
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row6_col1 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row6_col8 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row7_col1 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row7_col8 {
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row8_col1 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row8_col8 {
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row9_col1 {
#             background-color:  #94b6d7;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row9_col8 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row10_col1 {
#             background-color:  #03466e;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row10_col8 {
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row11_col1 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row11_col8 {
#             background-color:  #0566a0;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row12_col1 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row12_col8 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row13_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row13_col8 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row14_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row14_col8 {
#             background-color:  #b0c2de;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row15_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row15_col8 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row16_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row16_col8 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row17_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row17_col8 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row18_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row18_col8 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row19_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row19_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row20_col1 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row20_col8 {
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row21_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row21_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row22_col1 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row22_col8 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row23_col1 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row23_col8 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row24_col1 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row24_col8 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row25_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row25_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row26_col1 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row26_col8 {
#             background-color:  #034369;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row27_col1 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row27_col8 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row28_col1 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row28_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row29_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9228ba_b947_11e9_8894_0242ac110002row29_col8 {
#             background-color:  #
# Stats InducingCytokine (split = train (0)):
# <style  type="text/css" >
#     #T_cb9e5022_b947_11e9_8894_0242ac110002row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row1_col1 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row2_col1 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row3_col1 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row4_col1 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row5_col1 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row6_col1 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row7_col1 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row8_col1 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row9_col1 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row10_col1 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row11_col1 {
#             background-color:  #4094c3;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row12_col1 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row13_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row14_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row15_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row16_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row17_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row18_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row19_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row20_col1 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row21_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row22_col1 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row23_col1 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row24_col1 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row25_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row26_col1 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row27_col1 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row28_col1 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row29_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row30_col1 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_cb9e5022_b947_11e9_8894_0242ac110002row31_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }</style><table id="T_cb9e5022_b947_11e9_8894_0242ac110002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >j</th>        <th class="col_heading level0 col1" >Coverage</th>        <th class="col_heading level0 col2" >Overlaps</th>        <th class="col_heading level0 col3" >Conflicts</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cb9e5022_b947_11e9_8894_0242ac110002level0_row0" class="row_heading level0 row0" >LF_indck_comp_imexpresso_nonneg</th>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row0_col1" class="data row0 col1" >0.0117</td>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row0_col2" class="data row0 col2" >0.0117</td>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row0_col3" class="data row0 col3" >0.0116</td>
#             </tr>
#             <tr>
#                         <th id="T_cb9e5022_b947_11e9_8894_0242ac110002level0_row1" class="row_heading level0 row1" >LF_indck_comp_neg_sec</th>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row1_col1" class="data row1 col1" >0.1442</td>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row1_col2" class="data row1 col2" >0.1442</td>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row1_col3" class="data row1 col3" >0.1438</td>
#             </tr>
#             <tr>
#                         <th id="T_cb9e5022_b947_11e9_8894_0242ac110002level0_row2" class="row_heading level0 row2" >LF_indck_comp_xor</th>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row2_col1" class="data row2 col1" >0.167</td>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row2_col2" class="data row2 col2" >0.167</td>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row2_col3" class="data row2 col3" >0.1662</td>
#             </tr>
#             <tr>
#                         <th id="T_cb9e5022_b947_11e9_8894_0242ac110002level0_row3" class="row_heading level0 row3" >LF_indck_dsup_imexpresso_mp04</th>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row3_col1" class="data row3 col1" >0.2039</td>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row3_col2" class="data row3 col2" >0.2039</td>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row3_col3" class="data row3 col3" >0.1935</td>
#             </tr>
#             <tr>
#                         <th id="T_cb9e5022_b947_11e9_8894_0242ac110002level0_row4" class="row_heading level0 row4" >LF_indck_dsup_imexpresso_mp08</th>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row4_col1" class="data row4 col1" >0.1358</td>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row4_col2" class="data row4 col2" >0.1358</td>
#                         <td id="T_cb9e5022_b947_11e9_8894_0242ac110002row4_col3" class="data row4 col3" >0.1271</td>
#             </tr>
#             <tr>
#                         <th id="T_cb9e5022_b947_11e9_8894_0242ac110002level0_row5" cl
# Stats SecretedCytokine (split = dev (1)):
# <style  type="text/css" >
#     #T_cbac4434_b947_11e9_8894_0242ac110002row0_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row0_col8 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row1_col1 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row1_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row2_col1 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row2_col8 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row3_col1 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row3_col8 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row4_col1 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row4_col8 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row5_col1 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row5_col8 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row6_col1 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row6_col8 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row7_col1 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row7_col8 {
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row8_col1 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row8_col8 {
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row9_col1 {
#             background-color:  #94b6d7;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row9_col8 {
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row10_col1 {
#             background-color:  #03466e;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row10_col8 {
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row11_col1 {
#             background-color:  #1077b4;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row11_col8 {
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row12_col1 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row12_col8 {
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row13_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row13_col8 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row14_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row14_col8 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row15_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row15_col8 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row16_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row16_col8 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row17_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row17_col8 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row18_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row18_col8 {
#             background-color:  #197db7;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row19_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row19_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row20_col1 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row20_col8 {
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row21_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row21_col8 {
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row22_col1 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row22_col8 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row23_col1 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row23_col8 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row24_col1 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row24_col8 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row25_col1 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row25_col8 {
#             background-color:  #045788;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row26_col1 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row26_col8 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row27_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row27_col8 {
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row28_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row28_col8 {
#             background-color:  #045b8e;
#             color:  #f1f1f1;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row29_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_cbac4434_b947_11e9_8894_0242ac110002row29_col8 {
#             background-color:  #
# Stats SecretedCytokine (split = train (0)):
# <style  type="text/css" >
#     #T_cbb58fee_b947_11e9_8894_0242ac110002row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row1_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row2_col1 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row3_col1 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row4_col1 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row5_col1 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row6_col1 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row7_col1 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row8_col1 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row9_col1 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row10_col1 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row11_col1 {
#             background-color:  #4094c3;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row12_col1 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row13_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row14_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row15_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row16_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row17_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row18_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row19_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row20_col1 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row21_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row22_col1 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row23_col1 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row24_col1 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row25_col1 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row26_col1 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row27_col1 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row28_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row29_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_cbb58fee_b947_11e9_8894_0242ac110002row30_col1 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }</style><table id="T_cbb58fee_b947_11e9_8894_0242ac110002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >j</th>        <th class="col_heading level0 col1" >Coverage</th>        <th class="col_heading level0 col2" >Overlaps</th>        <th class="col_heading level0 col3" >Conflicts</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cbb58fee_b947_11e9_8894_0242ac110002level0_row0" class="row_heading level0 row0" >LF_secck_comp_imexpresso_nonneg</th>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row0_col1" class="data row0 col1" >0.02</td>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row0_col2" class="data row0 col2" >0.02</td>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row0_col3" class="data row0 col3" >0.0186</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb58fee_b947_11e9_8894_0242ac110002level0_row1" class="row_heading level0 row1" >LF_secck_comp_neg_ind</th>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row1_col1" class="data row1 col1" >0.025</td>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row1_col2" class="data row1 col2" >0.025</td>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row1_col3" class="data row1 col3" >0.025</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb58fee_b947_11e9_8894_0242ac110002level0_row2" class="row_heading level0 row2" >LF_secck_comp_xor</th>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row2_col1" class="data row2 col1" >0.1649</td>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row2_col2" class="data row2 col2" >0.1649</td>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row2_col3" class="data row2 col3" >0.1625</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb58fee_b947_11e9_8894_0242ac110002level0_row3" class="row_heading level0 row3" >LF_secck_dsup_imexpresso_mp04</th>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row3_col1" class="data row3 col1" >0.2184</td>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row3_col2" class="data row3 col2" >0.2184</td>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row3_col3" class="data row3 col3" >0.2133</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb58fee_b947_11e9_8894_0242ac110002level0_row4" class="row_heading level0 row4" >LF_secck_dsup_imexpresso_mp08</th>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row4_col1" class="data row4 col1" >0.128</td>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row4_col2" class="data row4 col2" >0.128</td>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row4_col3" class="data row4 col3" >0.1257</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb58fee_b947_11e9_8894_0242ac110002level0_row5" class="row_heading level0 row5" >LF_secck_dsup_imexpresso_mp12</th>
#                         <td id="T_cbb58fee_b947_11e9_8894_0242ac110002row5_
# Stats InducingTranscriptionFactor (split = dev (1)):
# <style  type="text/css" >
#     #T_cbbde252_b947_11e9_8894_0242ac110002row0_col1 {
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row0_col8 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row1_col1 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row1_col8 {
#             background-color:  #02395a;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row2_col1 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row2_col8 {
#             background-color:  #03446a;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row3_col1 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row3_col8 {
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row4_col1 {
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row4_col8 {
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row5_col1 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row5_col8 {
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row6_col1 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row6_col8 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row7_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row7_col8 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row8_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row8_col8 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row9_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row9_col8 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row10_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row10_col8 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row11_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row11_col8 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row12_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row12_col8 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row13_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row13_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row14_col1 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row14_col8 {
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row15_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row15_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row16_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row16_col8 {
#             background-color:  #75a9cf;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row17_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row17_col8 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row18_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row18_col8 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row19_col1 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row19_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row20_col1 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row20_col8 {
#             background-color:  #03517e;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row21_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row21_col8 {
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row22_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row22_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row23_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row23_col8 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row24_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row24_col8 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row25_col1 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_cbbde252_b947_11e9_8894_0242ac110002row25_col8 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }</style><table id="T_cbbde252_b947_11e9_8894_0242ac110002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >j</th>        <th class="col_heading level0 col1" >Coverage</th>        <th class="col_heading level0 col2" >Overlaps</th>        <th class="col_heading level0 col3" >Conflicts</th>        <th class="col_heading level0 col4" >TP</th>        <th class="col_heading level0 col5" >FP</th>        <th class="col_heading level0 col6" >FN</th>        <th class="col_heading level0 col7" >TN</th>        <th class="col_heading level0 col8" >Empirical Acc.</th>        <th class="col_heading level0 col9" >Empirical F1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cbbde252_b947_11e9_8894_0242ac110002level0_row0" class="row_heading level0 row0" >LF_indtf_comp_xor</th>
#                         <td id="T_cbbde252_b947_11e9_8894_0242ac110002row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_cbbde252_b947_11e9_88
# Stats InducingTranscriptionFactor (split = train (0)):
# <style  type="text/css" >
#     #T_cbc45b82_b947_11e9_8894_0242ac110002row0_col1 {
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row1_col1 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row2_col1 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row3_col1 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row4_col1 {
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row5_col1 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row6_col1 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row7_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row8_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row9_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row10_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row11_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row12_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row13_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row14_col1 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row15_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row16_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row17_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row18_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row19_col1 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row20_col1 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row21_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row22_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row23_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row24_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_cbc45b82_b947_11e9_8894_0242ac110002row25_col1 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }</style><table id="T_cbc45b82_b947_11e9_8894_0242ac110002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >j</th>        <th class="col_heading level0 col1" >Coverage</th>        <th class="col_heading level0 col2" >Overlaps</th>        <th class="col_heading level0 col3" >Conflicts</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cbc45b82_b947_11e9_8894_0242ac110002level0_row0" class="row_heading level0 row0" >LF_indtf_comp_xor</th>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row0_col1" class="data row0 col1" >0.773</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row0_col2" class="data row0 col2" >0.773</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row0_col3" class="data row0 col3" >0.7472</td>
#             </tr>
#             <tr>
#                         <th id="T_cbc45b82_b947_11e9_8894_0242ac110002level0_row1" class="row_heading level0 row1" >LF_indtf_heur_closer_ct_to_tf</th>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row1_col1" class="data row1 col1" >0.1633</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row1_col2" class="data row1 col2" >0.1633</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row1_col3" class="data row1 col3" >0.1525</td>
#             </tr>
#             <tr>
#                         <th id="T_cbc45b82_b947_11e9_8894_0242ac110002level0_row2" class="row_heading level0 row2" >LF_indtf_heur_closer_ref</th>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row2_col1" class="data row2 col1" >0.2569</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row2_col2" class="data row2 col2" >0.2569</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row2_col3" class="data row2 col3" >0.2405</td>
#             </tr>
#             <tr>
#                         <th id="T_cbc45b82_b947_11e9_8894_0242ac110002level0_row3" class="row_heading level0 row3" >LF_indtf_heur_closer_tf_to_ct</th>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row3_col1" class="data row3 col1" >0.1452</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row3_col2" class="data row3 col2" >0.1452</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row3_col3" class="data row3 col3" >0.1343</td>
#             </tr>
#             <tr>
#                         <th id="T_cbc45b82_b947_11e9_8894_0242ac110002level0_row4" class="row_heading level0 row4" >LF_indtf_heur_complex_cand_01</th>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row4_col1" class="data row4 col1" >0.8832</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row4_col2" class="data row4 col2" >0.8832</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row4_col3" class="data row4 col3" >0.8593</td>
#             </tr>
#             <tr>
#                         <th id="T_cbc45b82_b947_11e9_8894_0242ac110002level0_row5" class="row_heading level0 row5" >LF_indtf_heur_complex_cand_02</th>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row5_col1" class="data row5 col1" >0.5269</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row5_col2" class="data row5 col2" >0.5269</td>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row5_col3" class="data row5 col3" >0.5038</td>
#             </tr>
#             <tr>
#                         <th id="T_cbc45b82_b947_11e9_8894_0242ac110002level0_row6" class="row_heading level0 row6" >LF_indtf_heur_distref</th>
#                         <td id="T_cbc45b82_b947_11e9_8894_0242ac110002row6_col0" class="data row

# %% [markdown]
# ## Train Generative Model

# %% [markdown]
# ### Check Top Predictions

# %%
pcs = session.query(classes.inducing_cytokine.subclass).filter(classes.inducing_cytokine.subclass.split == SPLIT_TRAIN).all()
pcs = {c.id: c for c in pcs}
len(pcs)
# Out:
# 48656

# %%
dfpcs = pd.DataFrame([dict(id=c.id, pred=c.marginals[0].probability) for c in pcs.values()])
dfpcs = dfpcs.sort_values('pred', ascending=False).head(25)

# %%
def get_rec(r):
    c = pcs[r['id']]
    return dict(id=r['id'], pred=r['pred'], s1=c.get_contexts()[0].get_span(), s2=c.get_contexts()[1].get_span(), sent=c.get_parent().text)
pd.set_option('display.max_colwidth', 200)
pd.DataFrame([get_rec(r) for _, r in dfpcs.iterrows()])
# Out:
#           id      pred                   s1    s2  \
# 0   251888.0  0.999931                IL-12   Th1
# 1    43321.0  0.999931                IL-12   Th1
# 2   255380.0  0.999931                IL-12   Th1
# 3   159145.0  0.999931                IL-12   Th1
# 4     1756.0  0.999931                IL-12   Th1
# 5    94022.0  0.999931                IL-12   Th1
# 6   182560.0  0.999931                IL-12   Th1
# 7   140490.0  0.999931                IL-12   Th1
# 8     5758.0  0.999931  interleukin (IL)-12   Th1
# 9    96699.0  0.999888                IL-12   Th1
# 10  210231.0  0.999888                IL-12   Th1
# 11  249287.0  0.999888                IL-12   Th1
# 12  149781.0  0.999888                IL-12   Th1
# 13   86097.0  0.999816                IL-12   Th1
# 14  247294.0  0.999816                 IL-6  Treg
# 15  234502.0  0.999816                IL-12   Th1
# 16  243682.0  0.999816  interleukin (IL)-12   Th1
# 17    2889.0  0.999816                 IL-6  TREG
# 18  153384.0  0.999816                IL-12   Th1
# 19  218863.0  0.999816                IL-12   Th1
# 20   52947.0  0.999816                IL-12   Th1
# 21  252443.0  0.999816                IL-12   Th1
# 22  243161.0  0.999816                 IL-6  Treg
# 23   95677.0  0.999816                IL-12   Th1
# 24  167445.0  0.999816                 IL-6  Treg
#
#                                                                                                                                                                                                        sent
# 0                                                                            In C57BL/6 mice, IL-12 is produced by T. muris infection and IL-12 and IL-18 promote IFN-γ-producing Th1 cell differentiation.
# 1                                               . STAT1 was activated by autocrine IFN-γ whereas; STAT4 is mainly activated by IL-12 both of which are important for in vitro differentiation of Th1 cells.
# 2                                                                                     IFN-γ-regulated IL-12 signalling drives Th1 differentiation, whereas CXCR3 contributes to the migration of Th1 cells.
# 3                                                                In the absence of IL-12, IL-18-mediated effects on T cells may extend beyond Th1 differentiation to include Th2 cytokine production []. \n
# 4                                                               IL-12 is another important regulator of Th1 cell differentiation, and it is also the primary immunoregulatory factor secreted by Th1 cells.
# 5                      T-bet promotes the expression of IFN-γ and IL-12Rb2, which, together with IL-12Rb1, form a functional IL-12 receptor complex to further stimulate IFN-γ-induced Th1 differentiation.
# 6                                                                                  For example, IL-12 and IL-18 are important for differentiation of Th1 cells but also play a key role in innate immunity.
# 7   B10.S mice are genetically resistant to EAE; lymphocytes from B10.S mice did not generate IFN-γ in response to MBP, unless the cells were cultured in vitro in the presence of IL-12 [], a cytokine ...
# 8   T Helper Type 2 Cell Differentiation Occurs in the Presence of Interleukin 12 Receptor β2 Chain Expression and Signaling\n\nThe differentiation of CD4+ T cells into T helper type 1 (Th1) cells is ...
# 9   Whereas signaling of IL-12Rβ1β2 complex by IL-12 induces STAT4-dependent IFN-γ secretion with consequent Th1 differentiation , signaling of IL-4Rα by IL-4 induces STAT6-dependent IL-4 secretion wi...
# 10                                                   CS can directly target monocytes/macrophages to inhibit IL-12 production, which subsequently redirects T cell polarization from Th1 to Th2 cells [, ].
# 11  Although both IL-12 and IL-18 are major factors in IFN-γ production by Th1 cells, IL-12 is a differentiation factor that induces the development of Th1 cells—in contrast, IL-18 is a proinflammator...
# 12                         The excessive generation of IFN-γ-producing T cells (Th1) driven by IL-12 produced by antigen-presenting cells was described to be responsible for the initiation of disease [].
# 13                                                                              Together with IL-12, IFN-α polarizes the T cell towards a cell mediated Th1 response characterized by DTH and CTL activity.
# 14  Depending on other environmental conditions, such as the presence of specific antigens, T cell receptor (TCR) binding, and the amount of IL-2, IL-6, IL-21 and IL-23, naive CD4 T cells differentiat...
# 15                             The inhibition of IL-10 by IL-4 appears necessary for the induction of Th1 cell differentiation because the ability of IL-4 to induce IL-12 was lost in IL-10–deficient DCs.
# 16  Compromised Th1 differentiation in ICSBP−/− mice could not be attributed to hyporesponsiveness of CD4+ T cells to interleukin (IL)-12; however, the ability of uninfected and infected ICSBP-deficie...
# 17                                                  The developmental crossroads may be regulated by IL-6 or other innate cytokines as rIL-6-exposed Foxp3+ TREG cells can upregulate IL-17A in vitro [97].
# 18                                                                                                                The IL-12 receptor is present in its functional form in Th0 and Th1 but not Th2 cells [].
# 19                                                                                                                             As discussed previously, IL-12 promotes increased CD4+ Th1 cell numbers.\n\n
# 20                                                                    IL-12 activates STAT4, which is a critical regulator of inflammation and T helper type I (Th1) lineage development in murine systems.
# 21                                   No effort was made in these studies to analyze the role of IL-12 in the induction of the Th1 effectors and the authors postulated that the protective effects of anti–
# 22                                                                                  Similar to Tfh cell induction, the Tfh-like Treg are induced by IL-21 and IL-6 and produce IL-21 with STAT3 expression.
# 23   NF-κB promotes Th1 cell differentiation by regulating TCR signaling as well as functioning in innate immune cells to mediate induction of cytokines, such as IL-12, which promote Th1 differentiation.
# 24                                                                                                      IL-6 has counter-regulatory effects in modulating Treg and Th17 differentiation from naive T cells.
