# %% [markdown]
# ## Cell Type Integration

# %%
import os.path as osp
import pandas as pd
import numpy as np
from tcre import meta
from tcre import lib
from tcre.env import *
from tcre.lib import SPECIES_HUMAN_ID

# %% [markdown]
# ### Load Cell Ontology

# %%
path = osp.join(META_DATA_DIR, 'raw', 'cl.raw.csv')
df = pd.read_csv(path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 632 entries, 0 to 631
# Data columns (total 6 columns):
# desc          632 non-null object
# id            632 non-null object
# label         632 non-null object
# syn           632 non-null object
# syn_typ       632 non-null object
# syn_typ_id    632 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 29.7+ KB

# %%
# Make sure that each group of synonyms has a record with symbol equal to label
assert (df.groupby('label').apply(lambda g: len(g[g['syn'] == g['label']])) == 1).all()

# %%
def search(term, df):
    term = term.lower()
    ids = df[df['syn'].str.lower().apply(lambda v: term in v)]['id'].unique()
    df = df.groupby('label').apply(lambda g: g if g['id'].isin(ids).any() else None)
    return df[df['syn_typ'] == 'label']
        
pd.set_option('display.max_colwidth', 200)
search('gamma', df)
# Out:
#                                                                                                                                                                                                         desc  \
# 13                                                        A type II NK T cell that has been recently activated, secretes interferon-gamma, and has the phenotype CD69-positive and downregulated NK markers.
# 91                               A gamma-delta T cell that has a mature phenotype. These cells can be found in tissues and circulation where they express unique TCR repertoire depending on their location.
# 97   A thymocyte that has a T cell receptor consisting of a gamma chain containing Vgamma2 segment, and a delta chain. This cell type is CD4- negative, CD8-negative and CD24-negative. This cell-type is...
# 98   A thymocyte that has a T cell receptor consisting of a gamma chain containing Vgamma2 segment, and a delta chain. This cell type is CD4- negative, CD8-negative and CD24-negative. This cell-type is...
# 99   A thymocyte that has a T cell receptor consisting of a gamma chain containing Vgamma2 segment, and a delta chain. This cell type is CD4- negative, CD8-negative and CD24-negative. This cell-type is...
# 100                                                                                                                                A Vgamma1.1-positive, Vdelta6.3-positive thymocyte that is CD24-negative.
# 101                                                                                                                                A Vgamma1.1-positive, Vdelta6.3-negative thymocyte that is CD24-negative.
# 140                                                                                                                                                     A gamma-delta T cell that has an immature phenotype.
# 146  A double negative post-natal thymocyte that has a T cell receptor consisting of a gamma chain containing a Vgamma2 segment, and a delta chain. This cell type is CD4- negative, CD8-negative and CD2...
# 147  A double negative thymocyte that has a T cell receptor consisting of a gamma chain containing a Vgamma2 segment, and a delta chain. This cell type is CD4- negative, CD8-negative and CD24-positive ...
# 148  A double negative post-natal thymocyte that has a T cell receptor consisting of a gamma chain containing a Vgamma2 segment, and a delta chain. This cell type is CD4- negative, CD8-negative and CD2...
# 149                                                                                                                                A Vgamma1.1-positive, Vdelta6.3-positive thymocyte that is CD24-positive.
# 150                                                                                                                                A Vgamma1.1-positive, Vdelta6.3-negative thymocyte that is CD24-positive.
# 184                                             A post-natal thymocyte expressing components of the gamma-delta T cell receptor. This cell type is always double-negative (i.e. CD4-negative, CD8-negative).
# 188                                                 A mature gamma-delta T cell that is found in the columnar epithelium of the gastrointestinal tract. These cells participate in mucosal immune responses.
# 192                                                                                                                                           A T cell that expresses a gamma-delta T cell receptor complex.
# 320                                                                           A CD8alpha alpha positive gamma-delta intraepithelial T cell that expresses a TCR encoded in part by the Vgamma5 gene segment.
# 321                                                                  A CD8alpha alpha positive gamma-delta intraepithelial T cell that does not express a TCR partially encoded by the Vgamma5 gene segment.
# 326                                                                                                                 A gamma-delta receptor that expresses Vgamma1.1-Vdelta6.3 chains in the T-cell receptor.
# 327                                                                                            A gamma-delta receptor that expresses Vgamma1.1 but does not express Vdelta6.3 chains in the T-cell receptor.
# 516                                                                                                                    A gamma-delta intraepithelial T cell that has the phenotype CD8-alpha alpha-positive.
# 589                                                                                                                  A mature NK T cell that secretes interferon-gamma and enhances type 1 immune responses.
# 615                                                                                                                     A mature NK T cell that secretes interferon-gamma and enhances Th1 immune responses.
# 619                                                                                                               A gamma-delta intraepithelial T cell that has the phenotype CD4-negative and CD8-negative.
# 623                                                                                                               A circulating gamma-delta T cell that is CD27-positive and capable of producing IFN-gamma.
# 624                                                                                         A circulating gamma-delta T cell that expresses RORgamma(t), is CD27-negative and is capable of IL-17 secretion.
# 625                      A CD25-positive, CD27-positive immature gamma-delta T cell found in the thymus that has an immature phenotype (i.e. CD24-high, CD25-high, CD62L-high, CD44-high, CD2-low, CD5-low).
#
#              id  \
# 13   CL:0000932
# 91   CL:0000800
# 97   CL:0002407
# 98   CL:0002403
# 99   CL:0002409
# 100  CL:0002416
# 101  CL:0002413
# 140  CL:0000799
# 146  CL:0002406
# 147  CL:0002378
# 148  CL:0002408
# 149  CL:0002415
# 150  CL:0002414
# 184  CL:0002405
# 188  CL:0000801
# 192  CL:0000798
# 320  CL:0002513
# 321  CL:0002514
# 326  CL:0002412
# 327  CL:0002411
# 516  CL:0000802
# 589  CL:0000926
# 615  CL:0000929
# 619  CL:0000803
# 623  CL:0002124
# 624  CL:0002125
# 625  CL:0002126
#
#                                                                            label  \
# 13                                  type II NK T cell secreting interferon-gamma
# 91                                                     mature gamma-delta T cell
# 97                                             mature Vgamma2-positive thymocyte
# 98                                       mature Vgamma2-positive fetal thymocyte
# 99                                             mature Vgamma2-negative thymocyte
# 100                      mature Vgamma1.1-positive, Vdelta6.3-positive thymocyte
# 101                      mature Vgamma1.1-positive, Vdelta6.3-negative thymocyte
# 140                                                  immature gamma-delta T cell
# 146                                          immature Vgamma2-positive thymocyte
# 147                                    immature Vgamma2-positive fetal thymocyte
# 148                                          immature Vgamma2-negative thymocyte
# 149                    immature Vgamma1.1-positive, Vdelta6.3-positive thymocyte
# 150                    immature Vgamma1.1-positive, Vdelta6.3-negative thymocyte
# 184                                                        gamma-delta thymocyte
# 188                                           gamma-delta intraepithelial T cell
# 192                                                           gamma-delta T cell
# 320  Vgamma5-positive CD8alpha alpha positive gamma-delta intraepithelial T cell
# 321  Vgamma5-negative CD8alpha alpha positive gamma-delta intraepithelial T cell
# 326                             Vgamma1.1-positive, Vdelta6.3-positive thymocyte
# 327                             Vgamma1.1-positive, Vdelta6.3-negative thymocyte
# 516                 CD8-alpha alpha positive, gamma-delta intraepithelial T cell
# 589                     CD4-positive type I NK T cell secreting interferon-gamma
# 615       CD4-negative, CD8-negative type I NK T cell secreting interferon-gamma
# 619                 CD4-negative CD8-negative gamma-delta intraepithelial T cell
# 623                                             CD27-positive gamma-delta T cell
# 624                                             CD27-negative gamma-delta T cell
# 625                     CD25-positive, CD27-positive immature gamma-delta T cell
#
#                                                                              syn  \
# 13                                  type II NK T cell secreting interferon-gamma
# 91                                                     mature gamma-delta T cell
# 97                                             mature Vgamma2-positive thymocyte
# 98                                       mature Vgamma2-positive fetal thymocyte
# 99                                             mature Vgamma2-negative thymocyte
# 100                      mature Vgamma1.1-positive, Vdelta6.3-positive thymocyte
# 101                      mature Vgamma1.1-positive, Vdelta6.3-negative thymocyte
# 140                                                  immature gamma-delta T cell
# 146                                          immature Vgamma2-positive thymocyte
# 147                                    immature Vgamma2-positive fetal thymocyte
# 148                                          immature Vgamma2-negative thymocyte
# 149                    immature Vgamma1.1-positive, Vdelta6.3-positive thymocyte
# 150                    immature Vgamma1.1-positive, Vdelta6.3-negative thymocyte
# 184                                                        gamma-delta thymocyte
# 188                                           gamma-delta intraepithelial T cell
# 192                                                           gamma-delta T cell
# 320  Vgamma5-positive CD8alpha alpha positive gamma-delta intraepithelial T cell
# 321  Vgamma5-negative CD8alpha alpha positive gamma-delta intraepithelial T cell
# 326                             Vgamma1.1-positive, Vdelta6.3-positive thymocyte
# 327                             Vgamma1.1-positive, Vdelta6.3-negative thymocyte
# 516                 CD8-alpha alpha positive, gamma-delta intraepithelial T cell
# 589                     CD4-positive type I NK T cell secreting interferon-gamma
# 615       CD4-negative, CD8-negative type I NK T cell secreting interferon-gamma
# 619                 CD4-negative CD8-negative gamma-delta intraepithelial T cell
# 623                                             CD27-positive gamma-delta T cell
# 624                                             CD27-negative gamma-delta T cell
# 625                     CD25-positive, CD27-positive immature gamma-delta T cell
#
#     syn_typ  syn_typ_id
# 13    label         5.0
# 91    label         5.0
# 97    label         5.0
# 98    label         5.0
# 99    label         5.0
# 100   label         5.0
# 101   label         5.0
# 140   label         5.0
# 146   label         5.0
# 147   label         5.0
# 148   label         5.0
# 149   label         5.0
# 150   label         5.0
# 184   label         5.0
# 188   label         5.0
# 192   label         5.0
# 320   label         5.0
# 321   label         5.0
# 326   label         5.0
# 327   label         5.0
# 516   label         5.0
# 589   label         5.0
# 615   label         5.0
# 619   label         5.0
# 623   label         5.0
# 624   label         5.0
# 625   label         5.0

# %% [markdown]
# ### Manual Entries

# %%
# Not found:
# - T-helper precursor
# - Tissue resident memory
# - Stem memory
# - Treg17
# - Follicular regulatory
# - Peripheral Treg

# %%
SRC = 'manual'
cell_types = [
    #('TEFF', ['T-eff', 'T-effector', 'eff-T', 'effector-T']),
    ('TN',    'CL:0000898', ['T-naïve', 'naïve-T']),
    ('TMEM',  'CL:0000813', ['T-mem', 'memory-T', 'mem-T']),
    ('TEMRA', 'CL:0001062', ['T-emra', 'emra-T']),
    ('TCM',   'CL:0000904', ['T-cm', 'cm-T', 'central-memory-T']),
    ('TEM',   'CL:0000905', ['T-em', 'em-T', 'effector-memory-T', 'effector-memory-T']),
    ('IEL',   'CL:0002496', ['IELs', 'Intraepithelial-lymphocyte', 'Intraepithelial-lymphocytes']),
    ('DETC',  'CL:0000916', ['DETCs', 'Dendritic-epidermal-T']),
    ('Thymocyte', 'CL:0000893', ['thymocyte', 'thymocytes']),
    ('Th',   'CL:0000912', ['T-Helper', 'Helper-T']),
    ('Tc',   'CL:0000910', ['T-Cytotoxic', 'Cytotoxic-T', 'Cytolitic-T', 'T-Cytolitic', 'CTL', 'CTLs']),
    ('ThP',  None,         ['Th-Precursor', 'Precursor-Th']),
    ('Trm',  None,         ['T-rm', 'T-resident-memory', 'resident-memory-T']),
    ('Tscm', None,         ['T-SCM', 'T-SC', 'stem-memory-T', 'T-stem-memory', 'memory-stem-T', 'T-memory-stem']),
    ('NKT',   'CL:0000814', ['natural-killer-T', 'T-natural-killer', 'INKT', 'TRNKT', 'CNKT', 'NK/T']),
    ('MAIT',  'CL:0000940', ['Mucosal-associated invariant T']),
    ('Treg',  'CL:0000792', ['T-reg', 'T-regs', 'T-regulatory', 'regulatory-T']),
    ('Tsupp', 'CL:0000792', ['Tsuppressor', 'Ts/c', 'Ts/Tc','T-suppressor/cytotoxic'], 'Treg'),
    ('Treg1', 'CL:0000901', ['T-reg1', 'T-reg-1', 'Treg/Th1', 'Treg-Th1', 'Tr-1'], 'Treg'),
    ('Treg17', None,        ['T-reg17', 'T-reg-17', 'Treg/Th17', 'Treg-Th17', 'Tr-17'], 'Treg'),
    ('Tfh',   'CL:0002038', ['T-FH', 'T-follicular-helper', 'follicular-helper-T', 'fhT', 'T-follicular'], 'Th'),
    ('Tfreg', None,         ['Tf-reg', 'T-follicular-regulatory', 'follicular-regulatory-T', 'follicular-Treg', 'fTreg'], 'Treg'),
    ('iTreg', 'CL:0000902', [
        'i-Treg', 'induced-Treg', 'inducible-Treg', 'induced-T-reg', 'inducible-T-reg',
        'induced T-regulatory', 'induced-T-regulatory', 'induced regulatory-T', 'induced-regulatory-T',
        'inducible T-regulatory', 'inducible-T-regulatory', 'inducible regulatory-T', 'inducible-regulatory-T',
        ], 'Treg'),
    ('nTreg', 'CL:0000903', [
        'n-Treg', 'natural-Treg', 'natural-T-reg', 
        'natural T-regulatory', 'natural-T-regulatory', 'natural regulatory-T', 'natural-regulatory-T'
        ], 'Treg'),
    ('pTreg', None, [
        'p-Treg', 'peripheral-Treg', 'peripheral-T-reg', 
        'peripheral T-regulatory', 'peripheral-T-regulatory', 'peripheral regulatory-T', 'peripheral-regulatory-T',
        'peripherally-induced-Treg'
        ], 'Treg'),
    ('γδT', 'CL:0000798', ['Gamma-Delta-T', 'T-Gamma-Delta', 'Gamma/Delta-T', 'γ/δ-T', 'γδ-T', 'gd-T', 'Tgd', 'g/dT', 'Tg/d']),
    ('γδT-Vδ1', ['VDelta1-T', 'Vδ1-T'], 'γδT'),
    ('γδT-Vδ2', ['VDelta2-T', 'Vδ2-T'], 'γδT'),
    ('γδT-Vγ1', ['VGamma1-T', 'Vγ1-T'], 'γδT'),
    ('γδT-Vγ4', ['VGamma4-T', 'Vγ4-T'], 'γδT'),
    ('γδT-Vγ9', ['VGamma9-T', 'Vγ9-T'], 'γδT'),
    ('γδT-Vγ9Vδ2', ['T-VGamma9-Delta2', 'VGamma9-Delta2-T', 'Vγ9Vδ2T'], 'γδT'),
    ('γδT-17', ['γδ17T', 'T-Gamma-Delta17', 'Gamma-Delta17-T'], 'γδT'),
    ('γδT-TCS1', ['TCS1'], 'γδT')
] + [
    ('Tc' + str(i), ['Tc-' + str(i), 'T-cytolitic-' + str(i), 'T cytolitic-' + str(i), 'T-cytotoxic-' + str(i), 'T cytotoxic-' + str(i)], 'Tc') 
    for i in [0, 1, 2, 3, 9, 17, 22]
] + [
    ('Th' + str(i), [
        'Th-' + str(i), 'T-helper-' + str(i), 'T-helper ' + str(i), 'T helper-' + str(i), 'T helper cell-' + str(i),
        'T helper cell (Th)-' + str(i), 'T helper (Th)-' + str(i)
        ], 'Th')
    for i in [0, 1, 2, 3, 9, 17, 22]
] + [
    ('Tfh{}like'.format(i), ['Tfh-{}-like'.format(i), 'Tfh-{}like'.format(i), 'Tfh{}-like'.format(i), 'Tfh{}'.format(i)], 'Tfh') 
    for i in [0, 1, 2, 3, 9, 17, 22]
]

# %%
import unidecode
df = []
for r in cell_types:
    assert len(r) in [2, 3]
    lbl, alias = r[:2]
    parent = None if len(r) == 2 else r[2]
    df.append((lbl, lbl))
    for a1 in alias:
        for a2 in [a1, unidecode.unidecode(a1)]:
            df.append((a2, lbl))
            df.append((a2.replace('-', ' '), lbl))
            df.append((a2.replace('-', ''), lbl))
df = pd.DataFrame(df, columns=['sym', 'lbl']).drop_duplicates()

# Add -cell[s] -lymphocyte[s] to the end of each symbol to cover cases where that
# the spans are not broken into separate tokens (e.g. "follicular regulatory T-cells")
df = pd.concat([df] + [
    df[df['sym'].str.endswith('T')].assign(sym=lambda df: df['sym'] + suffix)
    for suffix in ['-cell', '-cells', '-lymphoctye', '-lymphocytes']
])

df = df.assign(spid=SPECIES_HUMAN_ID, src=SRC, extid=None)
df['id'] = get_ids(df, ID_TYP_CT)
df = df.drop_duplicates()
df = add_preferred_ids(df)
df.head()
# Out:
#                        sym   lbl  spid     src extid                  id  \
# 108                   DETC  DETC     1  manual  None  CT231343DE336492F1
# 109                  DETCs  DETC     1  manual  None  CT4CF1E0FFE26A395F
# 115  Dendritic-epidermal-T  DETC     1  manual  None  CTAD8B4B3EE6ECB6BB
# 116  Dendritic epidermal T  DETC     1  manual  None  CT728A6AA916C71387
# 117    DendriticepidermalT  DETC     1  manual  None  CTE89D7A3B2E8FAACE
#
#                  prefid
# 108  CT231343DE336492F1
# 109  CT231343DE336492F1
# 115  CT231343DE336492F1
# 116  CT231343DE336492F1
# 117  CT231343DE336492F1

# %%
df[df['sym'].str.lower().str.match('.*help.*')].head(15)
# Out:
#                       sym  lbl  spid     src extid                  id  \
# 404   T-follicular-helper  Tfh     1  manual  None  CT521FD23411A69F7B
# 405   T follicular helper  Tfh     1  manual  None  CT5C03730892B0B7E0
# 406     Tfollicularhelper  Tfh     1  manual  None  CT10F75C923DC5D960
# 410   follicular-helper-T  Tfh     1  manual  None  CT8A54A7929F3074FF
# 411   follicular helper T  Tfh     1  manual  None  CT48DDD25612FEC28B
# 412     follicularhelperT  Tfh     1  manual  None  CT92FD47DCB488F926
# 135              T-Helper   Th     1  manual  None  CT58AC91B99EE259CE
# 136              T Helper   Th     1  manual  None  CTCC4CF8EAB76DFC68
# 137               THelper   Th     1  manual  None  CT0107866BBCD97E04
# 141              Helper-T   Th     1  manual  None  CT068AEEF38840649E
# 142              Helper T   Th     1  manual  None  CT7580C71A46994EC5
# 143               HelperT   Th     1  manual  None  CTAF0873D2974B1075
# 1013           T-helper-0  Th0     1  manual  None  CTBD1BDE561333FA0A
# 1014           T helper 0  Th0     1  manual  None  CT550BD2F6E7C9F4A6
# 1015             Thelper0  Th0     1  manual  None  CT2B7FD02233168156
#
#                   prefid
# 404   CTE9F6070561C95355
# 405   CTE9F6070561C95355
# 406   CTE9F6070561C95355
# 410   CTE9F6070561C95355
# 411   CTE9F6070561C95355
# 412   CTE9F6070561C95355
# 135   CTB7DFCED683E6F0A9
# 136   CTB7DFCED683E6F0A9
# 137   CTB7DFCED683E6F0A9
# 141   CTB7DFCED683E6F0A9
# 142   CTB7DFCED683E6F0A9
# 143   CTB7DFCED683E6F0A9
# 1013  CTBDDE0043F47EDCC1
# 1014  CTBDDE0043F47EDCC1
# 1015  CTBDDE0043F47EDCC1

# %% [markdown]
# ### Export

# %%
path = osp.join(META_DATA_DIR, CELL_TYPES + '.csv')
df.to_csv(path, index=False)
path
# Out:
# '/Users/eczech/repos/hammer/t-cell-relation-extraction/pm_subtype_protein_relations/data/meta/cell_types.csv'
