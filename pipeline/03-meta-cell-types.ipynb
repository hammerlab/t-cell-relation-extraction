# %% [markdown]
# ## Cell Type Integration

# %%
import os.path as osp
import pandas as pd
import numpy as np
from tcre import meta
from tcre import lib
from tcre.lib import SPECIES_HUMAN_ID, CELL_TYPES
from tcre.meta import ID_TYP_CT
from tcre.env import *

# %% [markdown]
# ### Load Cell Ontology

# %%
SRC = 'cl'
path = osp.join(META_DATA_DIR, 'raw', 'cl.raw.csv')
df = pd.read_csv(path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 8 columns):
# depth         700 non-null int64
# desc          700 non-null object
# id            700 non-null object
# label         700 non-null object
# root          700 non-null object
# syn           700 non-null object
# syn_typ       700 non-null object
# syn_typ_id    700 non-null int64
# dtypes: int64(2), object(6)
# memory usage: 43.8+ KB

# %%
df.head()
# Out:
#    depth                                               desc          id  \
# 0      4  A type II NK T cell that has been recently act...  CL:0000933
# 1      4  A type II NK T cell that has been recently act...  CL:0000932
# 2      4  An alpha-beta T cell expressing NK call marker...  CL:0000922
# 3      4  A type II NK T cell that has been recently act...  CL:0000933
# 4      4  A type II NK T cell that has been recently act...  CL:0000932
#
#                                           label        root  \
# 0     type II NK T cell secreting interleukin-4  CL:0000084
# 1  type II NK T cell secreting interferon-gamma  CL:0000084
# 2                             type II NK T cell  CL:0000084
# 3     type II NK T cell secreting interleukin-4  CL:0000084
# 4  type II NK T cell secreting interferon-gamma  CL:0000084
#
#                                                  syn syn_typ  syn_typ_id
# 0           type II NKT cell secreting interleukin-4   exact           4
# 1        type II NKT cell secreting interferon-gamma   exact           4
# 2                                   type II NKT cell   exact           4
# 3    type II NK T-lymphocyte secreting interleukin-4   exact           4
# 4  type II NK T-lymphocyte secreting interferon-g...   exact           4

# %%
# Make sure that each group of synonyms has a record with symbol equal to label
assert (df.groupby('label').apply(lambda g: len(g[g['syn'] == g['label']])) == 1).all()

# %%
df_cl_raw = df.copy()

# %%
df = df[['id', 'label', 'syn', 'root', 'depth']].rename(columns={'id': 'extid', 'syn': 'sym', 'label': 'lbl'}).copy()
df = df.drop_duplicates()
df = df.assign(src=SRC, spid=SPECIES_HUMAN_ID, parent=None)
df.head()
# Out:
#         extid                                           lbl  \
# 0  CL:0000933     type II NK T cell secreting interleukin-4
# 1  CL:0000932  type II NK T cell secreting interferon-gamma
# 2  CL:0000922                             type II NK T cell
# 3  CL:0000933     type II NK T cell secreting interleukin-4
# 4  CL:0000932  type II NK T cell secreting interferon-gamma
#
#                                                  sym        root  depth src  \
# 0           type II NKT cell secreting interleukin-4  CL:0000084      4  cl
# 1        type II NKT cell secreting interferon-gamma  CL:0000084      4  cl
# 2                                   type II NKT cell  CL:0000084      4  cl
# 3    type II NK T-lymphocyte secreting interleukin-4  CL:0000084      4  cl
# 4  type II NK T-lymphocyte secreting interferon-g...  CL:0000084      4  cl
#
#    spid parent
# 0     1   None
# 1     1   None
# 2     1   None
# 3     1   None
# 4     1   None

# %%
# Remove trailing cell|lymphocyte qualifer
BAD_SUFFIX_PTNS = [' cell[s]?$', ' lymphocyte[s]?$']
for ptn in BAD_SUFFIX_PTNS:
    for col in ['sym', 'lbl']:
        df[col] = df[col].str.replace(ptn, '')
        assert not df['sym'].str.contains(ptn).any()

# %%
df_cl = df.copy().drop_duplicates()
df_cl['id'] = meta.get_ids(df_cl, ID_TYP_CT)
df_cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 621 entries, 0 to 699
# Data columns (total 9 columns):
# extid     621 non-null object
# lbl       621 non-null object
# sym       621 non-null object
# root      621 non-null object
# depth     621 non-null int64
# src       621 non-null object
# spid      621 non-null int64
# parent    0 non-null object
# id        621 non-null object
# dtypes: int64(2), object(7)
# memory usage: 48.5+ KB

# %% [markdown]
# ### Manual Entries

# %%
SRC = 'manual'

# Not found in CL:
# - Tissue resident memory
# - Stem memory
# - Treg17
# - Follicular regulatory
# - Peripheral Treg
# - iNKT17 (iNKT1, iNKT2 are there)
# - Tc0, Tc3, Tc9, Tc22 (Tc1, Tc2, and Tc17 are there)
# - Th0, Th3 (Th1, Th2, Th9, Th17, and Th22 are there)
# - Tfh* (Tfh0, Tfh1, Tfh2, Tfh17 are all absent)

def search(term, df):
    term = term.lower()
    ids = df[df['syn'].str.lower().apply(lambda v: term in v)]['id'].unique()
    df = df.groupby('label').apply(lambda g: g if g['id'].isin(ids).any() else None)
    return df[df['syn_typ'] == 'label']
        
pd.set_option('display.max_colwidth', 200)
search('th17', df_cl_raw)
# Out:
#      depth  \
# 424    5.0
# 619    4.0
#
#                                                                                                                                        desc  \
# 424  CD4-positive, alpha-beta T cell with the phenotype RORgamma-t-positive, CXCR3-negative, CCR6-positive, and capable of producing IL-17.
# 619                                                 A CD4-positive, alpha-beta T cell that has the phenotype CXCR3-negative, CCR6-negative.
#
#              id  \
# 424  CL:0000899
# 619  CL:0001051
#
#                                                               label  \
# 424                                                T-helper 17 cell
# 619  CD4-positive, CXCR3-negative, CCR6-negative, alpha-beta T cell
#
#            root  \
# 424  CL:0000084
# 619  CL:0000084
#
#                                                                 syn syn_typ  \
# 424                                                T-helper 17 cell   label
# 619  CD4-positive, CXCR3-negative, CCR6-negative, alpha-beta T cell   label
#
#      syn_typ_id
# 424         5.0
# 619         5.0

# %%
# If this gives an error, it is likely that the delimiter was typed incorrectly in one of the sym strings in the raw file
dfm = pd.read_csv(osp.join(META_DATA_DIR, 'raw', CELL_TYPES + '.manual.csv'), sep=',', comment='#', error_bad_lines=True, warn_bad_lines=True)
# Ignore hand-engineered depth feature in favor of distance within ontology
dfm = dfm.drop('lvl', axis=1)
for c in dfm.select_dtypes(include=[object]):
    dfm[c] = dfm[c].apply(lambda v: None if pd.isnull(v) or not v.strip() else v.strip())
dfm.head()
# Out:
#      lbl         cl0   cl1         cl2  \
# 0    IEL  CL:0002496  None  CL:0000084
# 1     TN  CL:0000898  None  CL:0000789
# 2   TMEM  CL:0000813  None  CL:0000789
# 3  TEMRA  CL:0001062  None  CL:0000789
# 4    TCM  CL:0000904  None  CL:0000789
#
#                                                           syms   lkp
# 0  IELs|Intraepithelial-lymphocyte|Intraepithelial-lymphocytes  None
# 1                                              T-naïve|naïve-T  None
# 2                                         T-mem|memory-T|mem-T  None
# 3                                                T-emra|emra-T  None
# 4                                   T-cm|cm-T|central-memory-T  None

# %%
import unidecode

def parse(r):
    df = []
    lbl = r['lbl'].strip()
    syms = r['syms'].split('|')
    extid = r['cl0']
    parid = r['cl1']
    rootid = r['cl2']
    assert not (pd.isnull(extid) and pd.isnull(parid))
    assert not pd.isnull(rootid)
    lkp = {None:None} if pd.isnull(r['lkp']) else dict([v.split('=') for v in r['lkp'].split('|')])
    assert len(lkp) > 0

    def append(sym, lbl, extid):
        df.append((sym, lbl, extid, parid, rootid))
        
    for lk, lv in lkp.items():
        lv = None if lv is None or not lv.strip() else lv.strip()
        lblf = lbl.format(lk) if lk else lbl
        extidf = lv or extid
        append(lblf, lblf, extidf)
        for alias in syms:
            for sym in [alias, unidecode.unidecode(alias)]: 
                symf = sym.format(lk) if lk else sym
                append(symf, lblf, extidf)
                append(symf.replace('-', ' '), lblf, extidf)
                append(symf.replace('-', ''), lblf, extidf)
    return pd.DataFrame(df, columns=['sym', 'lbl', 'extid', 'parent', 'root']).drop_duplicates()

def flatten(df):
    return pd.concat([parse(r) for _, r in df.iterrows()])
    
def enrich(df):
    # Add -cell[s] -lymphocyte[s] to the end of each symbol to cover cases where 
    # the spans are not broken into separate tokens (e.g. "follicular regulatory T-cells")
    df = pd.concat([df] + [
        df[df['sym'].str.endswith('T')].assign(sym=lambda df: df['sym'] + suffix)
        for suffix in ['-cell', '-cells', '-lymphoctye', '-lymphocytes']
    ])
    df = df.assign(spid=SPECIES_HUMAN_ID, src=SRC)
    df['id'] = meta.get_ids(df, ID_TYP_CT)
    df = df.drop_duplicates()
    return df

dfc = enrich(flatten(dfm))
dfc.head()
# Out:
#                           sym  lbl       extid parent        root  spid  \
# 0                         IEL  IEL  CL:0002496   None  CL:0000084     1
# 1                        IELs  IEL  CL:0002496   None  CL:0000084     1
# 7  Intraepithelial-lymphocyte  IEL  CL:0002496   None  CL:0000084     1
# 8  Intraepithelial lymphocyte  IEL  CL:0002496   None  CL:0000084     1
# 9   Intraepitheliallymphocyte  IEL  CL:0002496   None  CL:0000084     1
#
#       src                  id
# 0  manual  CT22416FE03B9D6C99
# 1  manual  CTB660BADB779FAA4E
# 7  manual  CT54F82A76F87DFC87
# 8  manual  CT77F7FFA741C8DF8A
# 9  manual  CT2F2F6025243D7121

# %%
dfc[dfc['sym'].isin(['IEL', 'Th1', 'Th0', 'Th', 'MAIT', 'Tfh1like'])]
# Out:
#          sym   lbl       extid      parent        root  spid     src  \
# 0        IEL   IEL  CL:0002496        None  CL:0000084     1  manual
# 0       MAIT  MAIT  CL:0000940        None  CL:0000789     1  manual
# 0         Th    Th  CL:0000912        None  CL:0000789     1  manual
# 0        Th0   Th0        None  CL:0000912  CL:0000789     1  manual
# 43       Th1   Th1  CL:0000545  CL:0000912  CL:0000789     1  manual
# 32  Tfh1like  Tfh1        None  CL:0002038  CL:0000789     1  manual
#
#                     id
# 0   CT22416FE03B9D6C99
# 0   CT2AA8AAF80CE1BE08
# 0   CTB7DFCED683E6F0A9
# 0   CTBDDE0043F47EDCC1
# 43  CTC3A8C3CBC245616A
# 32  CT1F84133DEE0D3909

# %% [markdown]
# ### Add Depth

# %%
# Create mapping of CL ids to depth
m_depth = df_cl.groupby('extid')['depth'].unique()
assert (m_depth.apply(len) == 1).all()
m_depth = m_depth.apply(lambda v: v[0])
m_depth.head()
# Out:
# extid
# CL:0000084    0
# CL:0000492    4
# CL:0000545    5
# CL:0000546    5
# CL:0000623    0
# Name: depth, dtype: int64

# %%
# Assign depth based on exact CL ID but if a cell type does not exist in CL, assign
# depth as the depth of the closest parent + 2 (i.e. assume it is a somewhat immediate child
# -- +2 was chosen because this is the distance between T helper and ThN types)
# capped at max depth + 1 of existing terms
dfc['depth'] = dfc['extid'].map(m_depth).combine_first((dfc['parent'].map(m_depth) + 2).clip(0, m_depth.max() + 1))
assert dfc['depth'].notnull().all()
dfc['depth'] = dfc['depth'].astype(int)
dfc['depth'].value_counts()
# Out:
# 3    859
# 4    361
# 5    341
# 1     95
# 2     89
# 6     63
# Name: depth, dtype: int64

# %%
dfc[dfc['sym'].isin(['IEL', 'Th1', 'Th0', 'Th', 'MAIT', 'Tfh', 'Tfh1like', 'Tc', 'Tc0', 'Treg', 'nTreg', 'Treg1', 'NKT', 'iNKT1', 'iNKT17'])]
# Out:
#          sym     lbl       extid      parent        root  spid     src  \
# 0        IEL     IEL  CL:0002496        None  CL:0000084     1  manual
# 0        NKT     NKT  CL:0000814        None  CL:0000789     1  manual
# 0      iNKT1   iNKT1  CL:0000929  CL:0000814  CL:0000789     1  manual
# 0     iNKT17  iNKT17        None  CL:0000814  CL:0000789     1  manual
# 0       MAIT    MAIT  CL:0000940        None  CL:0000789     1  manual
# 0       Treg    Treg  CL:0000792        None  CL:0000789     1  manual
# 0      nTreg   nTreg  CL:0000903  CL:0000792  CL:0000789     1  manual
# 0      Treg1   Treg1  CL:0000901  CL:0000792  CL:0000789     1  manual
# 0         Tc      Tc  CL:0000910        None  CL:0000789     1  manual
# 0        Tc0     Tc0        None  CL:0000910  CL:0000789     1  manual
# 0         Th      Th  CL:0000912        None  CL:0000789     1  manual
# 0        Th0     Th0        None  CL:0000912  CL:0000789     1  manual
# 43       Th1     Th1  CL:0000545  CL:0000912  CL:0000789     1  manual
# 0        Tfh     Tfh  CL:0002038  CL:0000912  CL:0000789     1  manual
# 32  Tfh1like    Tfh1        None  CL:0002038  CL:0000789     1  manual
#
#                     id  depth
# 0   CT22416FE03B9D6C99      2
# 0   CT459998F048BE65F2      3
# 0   CTA5FE71C9EE6E21F8      4
# 0   CT52C8DAEA84ED4DBB      5
# 0   CT2AA8AAF80CE1BE08      3
# 0   CTB574584AD019ABB8      3
# 0   CT5D4E277D12A1C208      4
# 0   CT301EB268E263D718      3
# 0   CT231C4EC31B01615E      3
# 0   CT65B6393015C16630      5
# 0   CTB7DFCED683E6F0A9      3
# 0   CTBDDE0043F47EDCC1      5
# 43  CTC3A8C3CBC245616A      5
# 0   CTE9F6070561C95355      5
# 32  CT1F84133DEE0D3909      6

# %%
dfc[dfc['depth'] == 6]['lbl'].unique()
# Out:
# array(['Tfh0', 'Tfh1', 'Tfh2', 'Tfh3', 'Tfh9', 'Tfh17', 'Tfh22'],
#       dtype=object)

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1808 entries, 0 to 142
# Data columns (total 9 columns):
# sym       1808 non-null object
# lbl       1808 non-null object
# extid     813 non-null object
# parent    1348 non-null object
# root      1808 non-null object
# spid      1808 non-null int64
# src       1808 non-null object
# id        1808 non-null object
# depth     1808 non-null int64
# dtypes: int64(2), object(7)
# memory usage: 141.2+ KB

# %%
df_manual = dfc.copy()

# %% [markdown]
# ### Merge

# %%
SRC_PRIORITY = {
    'cl': 50, 
    'manual': 20
}
df = pd.concat([df_cl, df_manual], sort=True)
df = meta.add_source_priority(df, SRC_PRIORITY)
df = meta.add_preferred_ids(df)
assert df['depth'].notnull().all()
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2429 entries, 699 to 0
# Data columns (total 12 columns):
# depth       2429 non-null int64
# extid       1434 non-null object
# id          2429 non-null object
# lbl         2429 non-null object
# parent      1348 non-null object
# root        2429 non-null object
# spid        2429 non-null int64
# src         2429 non-null object
# sym         2429 non-null object
# priority    2429 non-null int64
# prefid      2429 non-null object
# enabled     2429 non-null bool
# dtypes: bool(1), int64(3), object(8)
# memory usage: 230.1+ KB
# None
#      depth       extid                  id  \
# 699      4  CL:0001047  CT312FEE66DC3CC142
# 698      3  CL:0002426  CT5847C8E0924693BF
# 697      2  CL:0000939  CTDEA6CA6446B38258
# 696      2  CL:0000938  CTBC1262C129A2D683
# 695      2  CL:0000938  CT9761754DA14E9898
#
#                                                                      lbl  \
# 699  CD4-positive, CD25-positive, CCR4-positive, alpha-beta regulatory T
# 698                         CD11b-positive, CD27-positive natural killer
# 697                               CD16-positive, CD56-dim natural killer
# 696                            CD16-negative, CD56-bright natural killer
# 695                            CD16-negative, CD56-bright natural killer
#
#     parent        root  spid src  \
# 699   None  CL:0000084     1  cl
# 698   None  CL:0000623     1  cl
# 697   None  CL:0000623     1  cl
# 696   None  CL:0000623     1  cl
# 695   None  CL:0000623     1  cl
#
#                                               sym  priority  \
# 699                                     CCR+ Treg        50
# 698  CD11b-positive, CD27-positive natural killer        50
# 697                                 CD16+CD56+ NK        50
# 696                            CD16-CD56bright NK        50
# 695                 CD16-negative, CD56-bright NK        50
#
#                  prefid  enabled
# 699  CT05DC4A067F2BDFCB     True
# 698  CT5847C8E0924693BF     True
# 697  CTDBB7C729B7F40970     True
# 696  CT2751E190DAECAF00     True
# 695  CT2751E190DAECAF00     True

# %% [markdown]
# ### Filter

# %%
df[df['depth'] == 0]
# Out:
#      depth       extid                  id             lbl parent        root  \
# 461      0  CL:0000623  CT06C688429DDA2C12  natural killer   None  CL:0000623
# 435      0  CL:0000084  CT6C8A6A42A7CACE7E               T   None  CL:0000084
# 428      0  CL:0000084  CT92CA7451180D9E23               T   None  CL:0000084
# 419      0  CL:0000084  CT74A52A16108A2D6C               T   None  CL:0000084
# 125      0  CL:0000623  CTE1644A5D3EFE3209  natural killer   None  CL:0000623
# 48       0  CL:0000623  CT7BE9F97125768633  natural killer   None  CL:0000623
# 41       0  CL:0000623  CT4397F923F488A250  natural killer   None  CL:0000623
#
#      spid src             sym  priority              prefid  enabled
# 461     1  cl              NK        50  CT7BE9F97125768633     True
# 435     1  cl               T        50  CT6C8A6A42A7CACE7E     True
# 428     1  cl          T-cell        50  CT6C8A6A42A7CACE7E     True
# 419     1  cl    T-lymphocyte        50  CT6C8A6A42A7CACE7E     True
# 125     1  cl  large granular        50  CT7BE9F97125768633     True
# 48      1  cl  natural killer        50  CT7BE9F97125768633     True
# 41      1  cl            null        50  CT7BE9F97125768633     True

# %%
# Remove top level records for root cell types (i.e. where the depth is 0) since these will match to too
# many sentences in non-informative contexts
mask = df['depth'] == 0
print('Removing {} records for root nodes'.format(mask.sum()))
df = df[~mask]
df.info()
# Out:
# Removing 7 records for root nodes
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2422 entries, 699 to 0
# Data columns (total 12 columns):
# depth       2422 non-null int64
# extid       1427 non-null object
# id          2422 non-null object
# lbl         2422 non-null object
# parent      1348 non-null object
# root        2422 non-null object
# spid        2422 non-null int64
# src         2422 non-null object
# sym         2422 non-null object
# priority    2422 non-null int64
# prefid      2422 non-null object
# enabled     2422 non-null bool
# dtypes: bool(1), int64(3), object(8)
# memory usage: 229.4+ KB

# %%
# Apply static blacklist
df = meta.apply_symbol_filters(df, lib.get_entity_meta_filters(CELL_TYPES))
df.info()
# Out:
# Removing 1 symbols in pre-defined filters: ['DP']
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2421 entries, 699 to 0
# Data columns (total 12 columns):
# depth       2421 non-null int64
# extid       1426 non-null object
# id          2421 non-null object
# lbl         2421 non-null object
# parent      1348 non-null object
# root        2421 non-null object
# spid        2421 non-null int64
# src         2421 non-null object
# sym         2421 non-null object
# priority    2421 non-null int64
# prefid      2421 non-null object
# enabled     2421 non-null bool
# dtypes: bool(1), int64(3), object(8)
# memory usage: 229.3+ KB

# %%
# Ensure that no labels/symbols are empty or null
for c in ['lbl', 'sym']:
    assert len(df[df[c].str.strip().str.len() == 0]) == 0
    assert df[c].notnull().all()
# Ensure that all ids are either null or non-empty
for c in ['extid', 'parent', 'root']:
    assert df[c].apply(lambda v: pd.isnull(v) or (isinstance(v, str) and len(v) > 0)).all()

# %% [markdown]
# ### Summarize

# %%
df['src'].value_counts()
# Out:
# manual    1808
# cl         613
# Name: src, dtype: int64

# %%
df.groupby(['src', 'enabled']).size().unstack().fillna(0)
# Out:
# enabled  False  True
# src
# cl           1    612
# manual      46   1762

# %%
df[df['sym'].str.contains(' lymphocyte') & (df['src'] == 'cl') & (df['sym'].str.contains('Th'))]
# Out:
# Empty DataFrame
# Columns: [depth, extid, id, lbl, parent, root, spid, src, sym, priority, prefid, enabled]
# Index: []

# %%
df[df['sym'].str.lower().str.contains('dp$')]
# Out:
# Empty DataFrame
# Columns: [depth, extid, id, lbl, parent, root, spid, src, sym, priority, prefid, enabled]
# Index: []

# %%
df.head()
# Out:
#      depth       extid                  id  \
# 699      4  CL:0001047  CT312FEE66DC3CC142
# 698      3  CL:0002426  CT5847C8E0924693BF
# 697      2  CL:0000939  CTDEA6CA6446B38258
# 696      2  CL:0000938  CTBC1262C129A2D683
# 695      2  CL:0000938  CT9761754DA14E9898
#
#                                                                      lbl  \
# 699  CD4-positive, CD25-positive, CCR4-positive, alpha-beta regulatory T
# 698                         CD11b-positive, CD27-positive natural killer
# 697                               CD16-positive, CD56-dim natural killer
# 696                            CD16-negative, CD56-bright natural killer
# 695                            CD16-negative, CD56-bright natural killer
#
#     parent        root  spid src  \
# 699   None  CL:0000084     1  cl
# 698   None  CL:0000623     1  cl
# 697   None  CL:0000623     1  cl
# 696   None  CL:0000623     1  cl
# 695   None  CL:0000623     1  cl
#
#                                               sym  priority  \
# 699                                     CCR+ Treg        50
# 698  CD11b-positive, CD27-positive natural killer        50
# 697                                 CD16+CD56+ NK        50
# 696                            CD16-CD56bright NK        50
# 695                 CD16-negative, CD56-bright NK        50
#
#                  prefid  enabled
# 699  CT05DC4A067F2BDFCB     True
# 698  CT5847C8E0924693BF     True
# 697  CTDBB7C729B7F40970     True
# 696  CT2751E190DAECAF00     True
# 695  CT2751E190DAECAF00     True

# %% [markdown]
# ### Export

# %%
assert df['id'].value_counts().max() == 1

# %%
path = osp.join(META_DATA_DIR, CELL_TYPES + '.csv')
df.to_csv(path, index=False)
path
# Out:
# '/lab/repos/t-cell-relation-extraction/data/meta/cell_types.csv'
