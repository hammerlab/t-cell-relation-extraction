# %% [markdown]
# ## Cell Type Integration

# %%
import os.path as osp
import pandas as pd
import numpy as np
from tcre import meta
from tcre import lib
from tcre.lib import SPECIES_HUMAN_ID, CELL_TYPES
from tcre.meta import ID_TYP_CT
from tcre.env import *

# %% [markdown]
# ### Load Cell Ontology

# %%
SRC = 'cl'
path = osp.join(META_DATA_DIR, 'raw', 'cl.raw.csv')
df = pd.read_csv(path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 7 columns):
# desc          700 non-null object
# id            700 non-null object
# label         700 non-null object
# root          700 non-null object
# syn           700 non-null object
# syn_typ       700 non-null object
# syn_typ_id    700 non-null int64
# dtypes: int64(1), object(6)
# memory usage: 38.4+ KB

# %%
# Make sure that each group of synonyms has a record with symbol equal to label
assert (df.groupby('label').apply(lambda g: len(g[g['syn'] == g['label']])) == 1).all()

# %%
df_cl_raw = df.copy()

# %%
df = df[['id', 'label', 'syn', 'root']].rename(columns={'id': 'extid', 'syn': 'sym', 'label': 'lbl'}).copy()
df = df.assign(src=SRC, spid=SPECIES_HUMAN_ID, parent=None, lvl=None)
df['id'] = meta.get_ids(df, ID_TYP_CT)
df.head()
# Out:
#         extid                                           lbl  \
# 0  CL:0000933     type II NK T cell secreting interleukin-4
# 1  CL:0000932  type II NK T cell secreting interferon-gamma
# 2  CL:0000922                             type II NK T cell
# 3  CL:0000933     type II NK T cell secreting interleukin-4
# 4  CL:0000932  type II NK T cell secreting interferon-gamma
#
#                                                  sym        root src  spid  \
# 0           type II NKT cell secreting interleukin-4  CL:0000084  cl     1
# 1        type II NKT cell secreting interferon-gamma  CL:0000084  cl     1
# 2                                   type II NKT cell  CL:0000084  cl     1
# 3    type II NK T-lymphocyte secreting interleukin-4  CL:0000084  cl     1
# 4  type II NK T-lymphocyte secreting interferon-g...  CL:0000084  cl     1
#
#   parent   lvl                  id
# 0   None  None  CT2A162A51CA50D3E2
# 1   None  None  CT9D60C0282C217F30
# 2   None  None  CT1033047CAD81DC57
# 3   None  None  CT1AECB450297C08F0
# 4   None  None  CT452EC16F00882078

# %%
def get_substitutions(df):
    return pd.concat([
        df[df['sym'].str.match('.*' + ptn + '.*')].assign(sym=lambda df: df['sym'].str.replace(ptn, ''))
        for ptn in ['T.cell[s]?', '.cell[s]?', 'T.lymphocyte[s]?', '.lymphocyte[s]?']
    ])
df = pd.concat([df.assign(sub=False), get_substitutions(df).assign(sub=True)])
len(df)
# Out:
# 1729

# %%
df['sub'].value_counts()
# Out:
# True     1029
# False     700
# Name: sub, dtype: int64

# %%
# Check substitutions for a single case
df[df['sym'].str.contains('Th17')]
# Out:
#           extid                                                lbl  \
# 42   CL:0001051  CD4-positive, CXCR3-negative, CCR6-negative, a...
# 365  CL:0000899                                   T-helper 17 cell
# 366  CL:0000899                                   T-helper 17 cell
# 367  CL:0000899                                   T-helper 17 cell
# 368  CL:0000899                                   T-helper 17 cell
# 369  CL:0000899                                   T-helper 17 cell
# 370  CL:0000899                                   T-helper 17 cell
# 42   CL:0001051  CD4-positive, CXCR3-negative, CCR6-negative, a...
# 367  CL:0000899                                   T-helper 17 cell
# 369  CL:0000899                                   T-helper 17 cell
# 370  CL:0000899                                   T-helper 17 cell
# 42   CL:0001051  CD4-positive, CXCR3-negative, CCR6-negative, a...
# 365  CL:0000899                                   T-helper 17 cell
# 367  CL:0000899                                   T-helper 17 cell
# 369  CL:0000899                                   T-helper 17 cell
# 370  CL:0000899                                   T-helper 17 cell
# 366  CL:0000899                                   T-helper 17 cell
# 368  CL:0000899                                   T-helper 17 cell
# 366  CL:0000899                                   T-helper 17 cell
# 368  CL:0000899                                   T-helper 17 cell
#
#                           sym        root src  spid parent   lvl  \
# 42   non-Th1/Th17 CD4+ T cell  CL:0000084  cl     1   None  None
# 365                 Th17 cell  CL:0000084  cl     1   None  None
# 366         Th17 T-lymphocyte  CL:0000084  cl     1   None  None
# 367               Th17 T-cell  CL:0000084  cl     1   None  None
# 368         Th17 T lymphocyte  CL:0000084  cl     1   None  None
# 369               Th17 T cell  CL:0000084  cl     1   None  None
# 370          Th17 CD4+ T cell  CL:0000084  cl     1   None  None
# 42         non-Th1/Th17 CD4+   CL:0000084  cl     1   None  None
# 367                     Th17   CL:0000084  cl     1   None  None
# 369                     Th17   CL:0000084  cl     1   None  None
# 370                Th17 CD4+   CL:0000084  cl     1   None  None
# 42        non-Th1/Th17 CD4+ T  CL:0000084  cl     1   None  None
# 365                      Th17  CL:0000084  cl     1   None  None
# 367                    Th17 T  CL:0000084  cl     1   None  None
# 369                    Th17 T  CL:0000084  cl     1   None  None
# 370               Th17 CD4+ T  CL:0000084  cl     1   None  None
# 366                     Th17   CL:0000084  cl     1   None  None
# 368                     Th17   CL:0000084  cl     1   None  None
# 366                    Th17 T  CL:0000084  cl     1   None  None
# 368                    Th17 T  CL:0000084  cl     1   None  None
#
#                      id    sub
# 42   CTFA121F1DA4774659  False
# 365  CTEB678404BA18C220  False
# 366  CTE54915A0B3E4C31A  False
# 367  CT0C1ECB7486EF204C  False
# 368  CT18731E81B15685DF  False
# 369  CT7FF0459CEF1226F1  False
# 370  CT3DCDDD9C2EDA45AD  False
# 42   CTFA121F1DA4774659   True
# 367  CT0C1ECB7486EF204C   True
# 369  CT7FF0459CEF1226F1   True
# 370  CT3DCDDD9C2EDA45AD   True
# 42   CTFA121F1DA4774659   True
# 365  CTEB678404BA18C220   True
# 367  CT0C1ECB7486EF204C   True
# 369  CT7FF0459CEF1226F1   True
# 370  CT3DCDDD9C2EDA45AD   True
# 366  CTE54915A0B3E4C31A   True
# 368  CT18731E81B15685DF   True
# 366  CTE54915A0B3E4C31A   True
# 368  CT18731E81B15685DF   True

# %%
df_cl = df.drop('sub', axis=1).copy()
df_cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1729 entries, 0 to 666
# Data columns (total 9 columns):
# extid     1729 non-null object
# lbl       1729 non-null object
# sym       1729 non-null object
# root      1729 non-null object
# src       1729 non-null object
# spid      1729 non-null int64
# parent    0 non-null object
# lvl       0 non-null object
# id        1729 non-null object
# dtypes: int64(1), object(8)
# memory usage: 135.1+ KB

# %% [markdown]
# ### Manual Entries

# %%
SRC = 'manual'

# Not found in CL:
# - Tissue resident memory
# - Stem memory
# - Treg17
# - Follicular regulatory
# - Peripheral Treg
# - iNKT17 (iNKT1, iNKT2 are there)
# - Tc0, Tc3, Tc9, Tc22 (Tc1, Tc2, and Tc17 are there)
# - Th0, Th3 (Th1, Th2, Th9, Th17, and Th22 are there)
# - Tfh* (Tfh0, Tfh1, Tfh2, Tfh17 are all absent)

def search(term, df):
    term = term.lower()
    ids = df[df['syn'].str.lower().apply(lambda v: term in v)]['id'].unique()
    df = df.groupby('label').apply(lambda g: g if g['id'].isin(ids).any() else None)
    return df[df['syn_typ'] == 'label']
        
pd.set_option('display.max_colwidth', 200)
search('th17', df_cl_raw)
# Out:
#                                                                                                                                        desc  \
# 424  CD4-positive, alpha-beta T cell with the phenotype RORgamma-t-positive, CXCR3-negative, CCR6-positive, and capable of producing IL-17.
# 619                                                 A CD4-positive, alpha-beta T cell that has the phenotype CXCR3-negative, CCR6-negative.
#
#              id  \
# 424  CL:0000899
# 619  CL:0001051
#
#                                                               label  \
# 424                                                T-helper 17 cell
# 619  CD4-positive, CXCR3-negative, CCR6-negative, alpha-beta T cell
#
#            root  \
# 424  CL:0000084
# 619  CL:0000084
#
#                                                                 syn syn_typ  \
# 424                                                T-helper 17 cell   label
# 619  CD4-positive, CXCR3-negative, CCR6-negative, alpha-beta T cell   label
#
#      syn_typ_id
# 424         5.0
# 619         5.0

# %%
dfm = pd.read_csv(osp.join(META_DATA_DIR, 'raw', lib.CELL_TYPES + '.manual.csv'), sep=',', comment='#', error_bad_lines=False, warn_bad_lines=False)
for c in dfm.select_dtypes(include=[object]):
    dfm[c] = dfm[c].apply(lambda v: None if pd.isnull(v) or not v.strip() else v.strip())
dfm.head()
# Out:
#      lbl  lvl         cl0   cl1         cl2  \
# 0    IEL    1  CL:0002496  None  CL:0000084
# 1     TN    2  CL:0000898  None  CL:0000789
# 2   TMEM    2  CL:0000813  None  CL:0000789
# 3  TEMRA    2  CL:0001062  None  CL:0000789
# 4    TCM    2  CL:0000904  None  CL:0000789
#
#                                                           syms   lkp
# 0  IELs|Intraepithelial-lymphocyte|Intraepithelial-lymphocytes  None
# 1                                              T-naïve|naïve-T  None
# 2                                         T-mem|memory-T|mem-T  None
# 3                                                T-emra|emra-T  None
# 4                                   T-cm|cm-T|central-memory-T  None

# %%
import unidecode

def parse(r):
    df = []
    lbl, lvl = r['lbl'].strip(), int(r['lvl'])
    syms = r['syms'].split('|')
    extid = r['cl0']
    parid = r['cl1']
    rootid = r['cl2']
    assert not (pd.isnull(extid) and pd.isnull(parid))
    assert not pd.isnull(rootid)
    lkp = {None:None} if pd.isnull(r['lkp']) else dict([v.split('=') for v in r['lkp'].split('|')])
    assert len(lkp) > 0

    def append(sym, lbl, extid):
        df.append((sym, lbl, lvl, extid, parid, rootid))
        
    for lk, lv in lkp.items():
        lv = None if lv is None or not lv.strip() else lv.strip()
        lblf = lbl.format(lk) if lk else lbl
        extidf = lv or extid
        append(lblf, lblf, extidf)
        for alias in syms:
            for sym in [alias, unidecode.unidecode(alias)]: 
                symf = sym.format(lk) if lk else sym
                append(symf, lblf, extidf)
                append(symf.replace('-', ' '), lblf, extidf)
                append(symf.replace('-', ''), lblf, extidf)
    return pd.DataFrame(df, columns=['sym', 'lbl', 'lvl', 'extid', 'parent', 'root']).drop_duplicates()

def flatten(df):
    return pd.concat([parse(r) for _, r in df.iterrows()])
    
def enrich(df):
    # Add -cell[s] -lymphocyte[s] to the end of each symbol to cover cases where 
    # the spans are not broken into separate tokens (e.g. "follicular regulatory T-cells")
    df = pd.concat([df] + [
        df[df['sym'].str.endswith('T')].assign(sym=lambda df: df['sym'] + suffix)
        for suffix in ['-cell', '-cells', '-lymphoctye', '-lymphocytes']
    ])
    df = df.assign(spid=SPECIES_HUMAN_ID, src=SRC)
    df['id'] = meta.get_ids(df, ID_TYP_CT)
    df = df.drop_duplicates()
    return df

dfc = enrich(flatten(dfm))
dfc.head()
# Out:
#                           sym  lbl  lvl       extid parent        root  spid  \
# 0                         IEL  IEL    1  CL:0002496   None  CL:0000084     1
# 1                        IELs  IEL    1  CL:0002496   None  CL:0000084     1
# 7  Intraepithelial-lymphocyte  IEL    1  CL:0002496   None  CL:0000084     1
# 8  Intraepithelial lymphocyte  IEL    1  CL:0002496   None  CL:0000084     1
# 9   Intraepitheliallymphocyte  IEL    1  CL:0002496   None  CL:0000084     1
#
#       src                  id
# 0  manual  CT22416FE03B9D6C99
# 1  manual  CTB660BADB779FAA4E
# 7  manual  CT54F82A76F87DFC87
# 8  manual  CT77F7FFA741C8DF8A
# 9  manual  CT2F2F6025243D7121

# %%
dfc[dfc['sym'].isin(['IEL', 'Th1', 'Th0', 'Th', 'MAIT', 'Tfh1like'])]
# Out:
#          sym   lbl  lvl       extid      parent        root  spid     src  \
# 0        IEL   IEL    1  CL:0002496        None  CL:0000084     1  manual
# 0       MAIT  MAIT    2  CL:0000940        None  CL:0000789     1  manual
# 0         Th    Th    2  CL:0000912        None  CL:0000789     1  manual
# 0        Th0   Th0    3        None  CL:0000912  CL:0000789     1  manual
# 43       Th1   Th1    3  CL:0000545  CL:0000912  CL:0000789     1  manual
# 32  Tfh1like  Tfh1    3        None  CL:0002038  CL:0000789     1  manual
#
#                     id
# 0   CT22416FE03B9D6C99
# 0   CT2AA8AAF80CE1BE08
# 0   CTB7DFCED683E6F0A9
# 0   CTBDDE0043F47EDCC1
# 43  CTC3A8C3CBC245616A
# 32  CT1F84133DEE0D3909

# %%
df_manual = dfc.copy()

# %% [markdown]
# ### Merge

# %%
SRC_PRIORITY = {
    'cl': 50, 
    'manual': 20
}
df = pd.concat([df_cl, df_manual], sort=True)
df = meta.add_source_priority(df, SRC_PRIORITY)
df = meta.add_preferred_ids(df)
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3463 entries, 428 to 0
# Data columns (total 12 columns):
# extid       2476 non-null object
# id          3463 non-null object
# lbl         3463 non-null object
# lvl         1734 non-null object
# parent      1274 non-null object
# root        3463 non-null object
# spid        3463 non-null int64
# src         3463 non-null object
# sym         3463 non-null object
# priority    3463 non-null int64
# prefid      3463 non-null object
# enabled     3463 non-null bool
# dtypes: bool(1), int64(2), object(9)
# memory usage: 328.0+ KB
# None
#           extid                  id  \
# 428  CL:0000084  CTA3F4025CC0433FA5
# 441  CL:0000084  CT32F14A7EC04D490E
# 419  CL:0000084  CTB4B2FBD42F25E349
# 435  CL:0000084  CTBE11EE67EE985EA9
# 699  CL:0001047  CT15C28CADCF080753
#
#                                                                           lbl  \
# 428                                                                    T cell
# 441                                                                    T cell
# 419                                                                    T cell
# 435                                                                    T cell
# 699  CD4-positive, CD25-positive, CCR4-positive, alpha-beta regulatory T cell
#
#       lvl parent        root  spid src        sym  priority  \
# 428  None   None  CL:0000084     1  cl                   50
# 441  None   None  CL:0000084     1  cl                   50
# 419  None   None  CL:0000084     1  cl                   50
# 435  None   None  CL:0000084     1  cl                   50
# 699  None   None  CL:0000084     1  cl  CCR+ Treg        50
#
#                  prefid  enabled
# 428  CT32F14A7EC04D490E     True
# 441  CT32F14A7EC04D490E    False
# 419  CT32F14A7EC04D490E    False
# 435  CT32F14A7EC04D490E    False
# 699  CT5229C817BCB2D95C     True

# %% [markdown]
# ### Filter

# %%
df[df['extid'] == 'CL:0000084']
# Out:
#           extid                  id     lbl   lvl parent        root  spid  \
# 428  CL:0000084  CTA3F4025CC0433FA5  T cell  None   None  CL:0000084     1
# 441  CL:0000084  CT32F14A7EC04D490E  T cell  None   None  CL:0000084     1
# 419  CL:0000084  CTB4B2FBD42F25E349  T cell  None   None  CL:0000084     1
# 435  CL:0000084  CTBE11EE67EE985EA9  T cell  None   None  CL:0000084     1
# 428  CL:0000084  CTA3F4025CC0433FA5  T cell  None   None  CL:0000084     1
# 441  CL:0000084  CT32F14A7EC04D490E  T cell  None   None  CL:0000084     1
# 419  CL:0000084  CTB4B2FBD42F25E349  T cell  None   None  CL:0000084     1
# 435  CL:0000084  CTBE11EE67EE985EA9  T cell  None   None  CL:0000084     1
# 441  CL:0000084  CT32F14A7EC04D490E  T cell  None   None  CL:0000084     1
# 435  CL:0000084  CTBE11EE67EE985EA9  T cell  None   None  CL:0000084     1
# 428  CL:0000084  CTA3F4025CC0433FA5  T cell  None   None  CL:0000084     1
# 419  CL:0000084  CTB4B2FBD42F25E349  T cell  None   None  CL:0000084     1
#
#     src           sym  priority              prefid  enabled
# 428  cl                      50  CT32F14A7EC04D490E     True
# 441  cl                      50  CT32F14A7EC04D490E    False
# 419  cl                      50  CT32F14A7EC04D490E    False
# 435  cl                      50  CT32F14A7EC04D490E    False
# 428  cl             T        50  CT32F14A7EC04D490E     True
# 441  cl             T        50  CT32F14A7EC04D490E    False
# 419  cl             T        50  CT32F14A7EC04D490E    False
# 435  cl             T        50  CT32F14A7EC04D490E    False
# 441  cl        T cell        50  CT32F14A7EC04D490E     True
# 435  cl  T lymphocyte        50  CT32F14A7EC04D490E     True
# 428  cl        T-cell        50  CT32F14A7EC04D490E     True
# 419  cl  T-lymphocyte        50  CT32F14A7EC04D490E     True

# %%
# Remove top level "T cell" records
mask = df['extid'] == 'CL:0000084'
print('Removing {} records for root record "T Cell"'.format(mask.sum()))
df = df[~mask]
df.info()
# Out:
# Removing 12 records for root record "T Cell"
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3451 entries, 699 to 0
# Data columns (total 12 columns):
# extid       2464 non-null object
# id          3451 non-null object
# lbl         3451 non-null object
# lvl         1734 non-null object
# parent      1274 non-null object
# root        3451 non-null object
# spid        3451 non-null int64
# src         3451 non-null object
# sym         3451 non-null object
# priority    3451 non-null int64
# prefid      3451 non-null object
# enabled     3451 non-null bool
# dtypes: bool(1), int64(2), object(9)
# memory usage: 326.9+ KB

# %%
# Ensure that no labels/symbols are empty or null
for c in ['lbl', 'sym']:
    assert len(df[df[c].str.strip().str.len() == 0]) == 0
    assert df[c].notnull().all()
# Ensure that all ids are either null or non-empty
for c in ['extid', 'parent', 'root']:
    assert df[c].apply(lambda v: pd.isnull(v) or (isinstance(v, str) and len(v) > 0)).all()

# %% [markdown]
# ### Summarize

# %%
df['src'].value_counts()
# Out:
# manual    1734
# cl        1717
# Name: src, dtype: int64

# %%
df.groupby(['src', 'enabled']).size().unstack().fillna(0)
# Out:
# enabled  False  True
# src
# cl         564   1153
# manual      41   1693

# %%
df[df['sym'].str.lower().str.contains('nkt')]
# Out:
#           extid                  id  \
# 657  CL:0000924  CT948ADF339CF9FFA6
# 657  CL:0000924  CT948ADF339CF9FFA6
# 656  CL:0000929  CT0C96066BBF0089A3
# 655  CL:0000930  CTC0D0F70B61D9EF80
# 656  CL:0000929  CT0C96066BBF0089A3
# 655  CL:0000930  CTC0D0F70B61D9EF80
# 631  CL:0000923  CT563AF057F140E448
# 631  CL:0000923  CT563AF057F140E448
# 630  CL:0000926  CT9EB26456E45D8922
# 629  CL:0000927  CT543C63B59817A4AB
# 630  CL:0000926  CT9EB26456E45D8922
# 629  CL:0000927  CT543C63B59817A4AB
# 25   CL:0000814  CT56A2C76DD4C4EFFF
# 25   CL:0000814  CT1D47F3A2C576B1D0
# 25   CL:0000814  CT11F87A7B646F7396
# 25   CL:0000814  CT48B2D91A0354B781
# 25   CL:0000814  CT171033E507829E29
# 13   CL:0000814  CT47667978DACC1BA7
# 13   CL:0000814  CTA16E7CCA1F9C00C9
# 13   CL:0000814  CTCD9D7185A3AF7224
# 13   CL:0000814  CT682887E9599C7CD3
# 13   CL:0000814  CT873DCF609995B494
# 0    CL:0000814  CT459998F048BE65F2
# 0    CL:0000814  CT99F0E2D70292850E
# 0    CL:0000814  CTE21248E2FB30FE45
# 0    CL:0000814  CT4CE472C1E7E28924
# 0    CL:0000814  CTD3930D60EDBC7C11
# 447  CL:0000923  CT882C6AE400C06198
# 446  CL:0000924  CTD768A1EF2645A1FF
# 445  CL:0002042  CT021F5C27B1FE694D
# 444  CL:0002040  CT48F69E82A5FF7BEB
# 19   CL:0000814  CTAB99EA6A1C47FED8
# 19   CL:0000814  CT596C18B83176969C
# 19   CL:0000814  CT974C71AAC6580F13
# 19   CL:0000814  CTFCF630A6607DCD6C
# 19   CL:0000814  CT321ACAC757F9DC75
# 330  CL:0000928  CTA2F927421BCB791B
# 330  CL:0000928  CTA2F927421BCB791B
# 325  CL:0000925  CT446A75AA3453710E
# 325  CL:0000925  CT446A75AA3453710E
# 298  CL:0000931  CT591ADA1D2B6A17E5
# 298  CL:0000931  CT591ADA1D2B6A17E5
# 168  CL:0000914  CT20B2B566F4916142
# 168  CL:0000914  CT20B2B566F4916142
# 113  CL:0000814  CT4BC27E5AC6CABE78
# 113  CL:0000814  CT4BC27E5AC6CABE78
# 17   CL:0000921  CT6A22D838AC926851
# 17   CL:0000921  CT6A22D838AC926851
# 2    CL:0000922  CT1033047CAD81DC57
# 2    CL:0000922  CT1033047CAD81DC57
# 1    CL:0000932  CT9D60C0282C217F30
# 0    CL:0000933  CT2A162A51CA50D3E2
# 1    CL:0000932  CT9D60C0282C217F30
# 0    CL:0000933  CT2A162A51CA50D3E2
#
#                                                                         lbl  \
# 657                             CD4-negative, CD8-negative type I NK T cell
# 657                             CD4-negative, CD8-negative type I NK T cell
# 656  CD4-negative, CD8-negative type I NK T cell secreting interferon-gamma
# 655     CD4-negative, CD8-negative type I NK T cell secreting interleukin-4
# 656  CD4-negative, CD8-negative type I NK T cell secreting interferon-gamma
# 655     CD4-negative, CD8-negative type I NK T cell secreting interleukin-4
# 631                                           CD4-positive type I NK T cell
# 631                                           CD4-positive type I NK T cell
# 630                CD4-positive type I NK T cell secreting interferon-gamma
# 629                   CD4-positive type I NK T cell secreting interleukin-4
# 630                CD4-positive type I NK T cell secreting interferon-gamma
# 629                   CD4-positive type I NK T cell secreting interleukin-4
# 25                                                                      NKT
# 25                                                                      NKT
# 25                                                                      NKT
# 25                                                                      NKT
# 25                                                                      NKT
# 13                                                                      NKT
# 13                                                                      NKT
# 13                                                                      NKT
# 13                                                                      NKT
# 13                                                                      NKT
# 0                                                                       NKT
# 0                                                                       NKT
# 0                                                                       NKT
# 0                                                                       NKT
# 0                                                                       NKT
# 447                                           CD4-positive type I NK T cell
# 446                             CD4-negative, CD8-negative type I NK T cell
# 445                                             immature NK T cell stage IV
# 444                                             immature NK T cell stage II
# 19                                                                      NKT
# 19                                                                      NKT
# 19                                                                      NKT
# 19                                                                      NKT
# 19                                                                      NKT
# 330                   activated CD4-negative, CD8-negative type I NK T cell
# 330                   activated CD4-negative, CD8-negative type I NK T cell
# 325                                 activated CD4-positive type I NK T cell
# 325                                 activated CD4-positive type I NK T cell
# 298                                             activated type II NK T cell
# 298                                             activated type II NK T cell
# 168                                                      immature NK T cell
# 168                                                      immature NK T cell
# 113                                                        mature NK T cell
# 113                                                        mature NK T cell
# 17                                                         type I NK T cell
# 17                                                         type I NK T cell
# 2                                                         type II NK T cell
# 2                                                         type II NK T cell
# 1                              type II NK T cell secreting interferon-gamma
# 0                                 type II NK T cell secreting interleukin-4
# 1                              type II NK T cell secreting interferon-gamma
# 0                                 type II NK T cell secreting interleukin-4
#
#       lvl parent        root  spid     src  \
# 657  None   None  CL:0000084     1      cl
# 657  None   None  CL:0000084     1      cl
# 656  None   None  CL:0000084     1      cl
# 655  None   None  CL:0000084     1      cl
# 656  None   None  CL:0000084     1      cl
# 655  None   None  CL:0000084     1      cl
# 631  None   None  CL:0000084     1      cl
# 631  None   None  CL:0000084     1      cl
# 630  None   None  CL:0000084     1      cl
# 629  None   None  CL:0000084     1      cl
# 630  None   None  CL:0000084     1      cl
# 629  None   None  CL:0000084     1      cl
# 25      2   None  CL:0000789     1  manual
# 25      2   None  CL:0000789     1  manual
# 25      2   None  CL:0000789     1  manual
# 25      2   None  CL:0000789     1  manual
# 25      2   None  CL:0000789     1  manual
# 13      2   None  CL:0000789     1  manual
# 13      2   None  CL:0000789     1  manual
# 13      2   None  CL:0000789     1  manual
# 13      2   None  CL:0000789     1  manual
# 13      2   None  CL:0000789     1  manual
# 0       2   None  CL:0000789     1  manual
# 0       2   None  CL:0000789     1  manual
# 0       2   None  CL:0000789     1  manual
# 0       2   None  CL:0000789     1  manual
# 0       2   None  CL:0000789     1  manual
# 447  None   None  CL:0000084     1      cl
# 446  None   None  CL:0000084     1      cl
# 445  None   None  CL:0000084     1      cl
# 444  None   None  CL:0000084     1      cl
# 19      2   None  CL:0000789     1  manual
# 19      2   None  CL:0000789     1  manual
# 19      2   None  CL:0000789     1  manual
# 19      2   None  CL:0000789     1  manual
# 19      2   None  CL:0000789     1  manual
# 330  None   None  CL:0000084     1      cl
# 330  None   None  CL:0000084     1      cl
# 325  None   None  CL:0000084     1      cl
# 325  None   None  CL:0000084     1      cl
# 298  None   None  CL:0000084     1      cl
# 298  None   None  CL:0000084     1      cl
# 168  None   None  CL:0000084     1      cl
# 168  None   None  CL:0000084     1      cl
# 113  None   None  CL:0000084     1      cl
# 113  None   None  CL:0000084     1      cl
# 17   None   None  CL:0000084     1      cl
# 17   None   None  CL:0000084     1      cl
# 2    None   None  CL:0000084     1      cl
# 2    None   None  CL:0000084     1      cl
# 1    None   None  CL:0000084     1      cl
# 0    None   None  CL:0000084     1      cl
# 1    None   None  CL:0000084     1      cl
# 0    None   None  CL:0000084     1      cl
#
#                                                                        sym  \
# 657                                  CD4-negative, CD8-negative type I NKT
# 657                             CD4-negative, CD8-negative type I NKT cell
# 656  CD4-negative, CD8-negative type I NKT cell secreting interferon-gamma
# 655     CD4-negative, CD8-negative type I NKT cell secreting interleukin-4
# 656       CD4-negative, CD8-negative type I NKT secreting interferon-gamma
# 655          CD4-negative, CD8-negative type I NKT secreting interleukin-4
# 631                                                CD4-positive type I NKT
# 631                                           CD4-positive type I NKT cell
# 630                CD4-positive type I NKT cell secreting interferon-gamma
# 629                   CD4-positive type I NKT cell secreting interleukin-4
# 630                     CD4-positive type I NKT secreting interferon-gamma
# 629                        CD4-positive type I NKT secreting interleukin-4
# 25                                                                    CNKT
# 25                                                               CNKT-cell
# 25                                                              CNKT-cells
# 25                                                         CNKT-lymphoctye
# 25                                                        CNKT-lymphocytes
# 13                                                                    INKT
# 13                                                               INKT-cell
# 13                                                              INKT-cells
# 13                                                         INKT-lymphoctye
# 13                                                        INKT-lymphocytes
# 0                                                                      NKT
# 0                                                                 NKT-cell
# 0                                                                NKT-cells
# 0                                                           NKT-lymphoctye
# 0                                                          NKT-lymphocytes
# 447                                                              NKT.4+.SP
# 446                                                              NKT.4-.Sp
# 445                                                      NKT.44+.NK1.1-.Th
# 444                                                       NKT.44-NK1.1-.Th
# 19                                                                   TRNKT
# 19                                                              TRNKT-cell
# 19                                                             TRNKT-cells
# 19                                                        TRNKT-lymphoctye
# 19                                                       TRNKT-lymphocytes
# 330                        activated CD4-negative, CD8-negative type I NKT
# 330                   activated CD4-negative, CD8-negative type I NKT cell
# 325                                      activated CD4-positive type I NKT
# 325                                 activated CD4-positive type I NKT cell
# 298                                                  activated type II NKT
# 298                                             activated type II NKT cell
# 168                                                           immature NKT
# 168                                                      immature NKT cell
# 113                                                             mature NKT
# 113                                                        mature NKT cell
# 17                                                              type I NKT
# 17                                                         type I NKT cell
# 2                                                              type II NKT
# 2                                                         type II NKT cell
# 1                              type II NKT cell secreting interferon-gamma
# 0                                 type II NKT cell secreting interleukin-4
# 1                                   type II NKT secreting interferon-gamma
# 0                                      type II NKT secreting interleukin-4
#
#      priority              prefid  enabled
# 657        50  CT07F1F2C6A0F264DF     True
# 657        50  CT07F1F2C6A0F264DF     True
# 656        50  CT0A759254BC64362B     True
# 655        50  CT2C066E491AC47785     True
# 656        50  CT0A759254BC64362B     True
# 655        50  CT2C066E491AC47785     True
# 631        50  CTF06FF20730C1639C     True
# 631        50  CTF06FF20730C1639C     True
# 630        50  CT6571984FFC9FAA3A     True
# 629        50  CT502941FC937D8B88     True
# 630        50  CT6571984FFC9FAA3A     True
# 629        50  CT502941FC937D8B88     True
# 25         20  CT459998F048BE65F2     True
# 25         20  CT459998F048BE65F2     True
# 25         20  CT459998F048BE65F2     True
# 25         20  CT459998F048BE65F2     True
# 25         20  CT459998F048BE65F2     True
# 13         20  CT459998F048BE65F2     True
# 13         20  CT459998F048BE65F2     True
# 13         20  CT459998F048BE65F2     True
# 13         20  CT459998F048BE65F2     True
# 13         20  CT459998F048BE65F2     True
# 0          20  CT459998F048BE65F2     True
# 0          20  CT459998F048BE65F2     True
# 0          20  CT459998F048BE65F2     True
# 0          20  CT459998F048BE65F2     True
# 0          20  CT459998F048BE65F2     True
# 447        50  CTF06FF20730C1639C     True
# 446        50  CT07F1F2C6A0F264DF     True
# 445        50  CT7E2713F1605B3F31     True
# 444        50  CTC2A890BC0E62852E     True
# 19         20  CT459998F048BE65F2     True
# 19         20  CT459998F048BE65F2     True
# 19         20  CT459998F048BE65F2     True
# 19         20  CT459998F048BE65F2     True
# 19         20  CT459998F048BE65F2     True
# 330        50  CTB2F0202ACD2112D6     True
# 330        50  CTB2F0202ACD2112D6     True
# 325        50  CT2B2D1AF814E72E7A     True
# 325        50  CT2B2D1AF814E72E7A     True
# 298        50  CT182B03FA7D07DB04     True
# 298        50  CT182B03FA7D07DB04     True
# 168        50  CT86EDBDACAA75DB56     True
# 168        50  CT86EDBDACAA75DB56     True
# 113        50  CT0FAA0FA285151490     True
# 113        50  CT0FAA0FA285151490     True
# 17         50  CT2B55F4AAD139E266     True
# 17         50  CT2B55F4AAD139E266     True
# 2          50  CT7D62B89F77A31B8B     True
# 2          50  CT7D62B89F77A31B8B     True
# 1          50  CT48949C42721FA73F     True
# 0          50  CTD6C165A232241D19     True
# 1          50  CT48949C42721FA73F     True
# 0          50  CTD6C165A232241D19     True

# %% [markdown]
# ### Export

# %%
path = osp.join(META_DATA_DIR, CELL_TYPES + '.csv')
df.to_csv(path, index=False)
path
# Out:
# '/lab/repos/t-cell-relation-extraction/data/meta/cell_types.csv'
