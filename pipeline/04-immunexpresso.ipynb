# %%
from urllib.parse import urlencode, quote_plus
import os.path as osp
import requests
import pandas as pd
import numpy as np
import tqdm
from tcre.env import *
from tcre import lib
TEMP_FILE = osp.join(SUPERVISION_DATA_DIR, 'immunexpresso', 'import.csv')
DATA_FILE = osp.join(SUPERVISION_DATA_DIR, 'immunexpresso', 'data.csv')

# %% [markdown]
# ### Import

# %% [markdown]
# #### Collect Cell Types

# %%
def query(terms):
    url_format = 'http://immuneexpresso.org/immport-immunexpresso/search/ix_lexicon/synonym-search-trim?rows=2000&bf=product(frequency,preferred)&q={}&_=1555322107128'
    #query = urlencode({'q': '"' + term + '"'}, quote_via=quote_plus)
    query = urlencode({'q': terms}, quote_via=quote_plus)
    url = url_format.format(query)
    r = requests.get(url)
    df = pd.DataFrame(r.json()['response']['docs'])
    return df

# %%
query('"effector T"')
# Out:
#    frequency    id                                               name  \
# 0      29222  4109                                    effector T cell
# 1          1  8835                             innate effector T cell
# 2          1  4053  CD8-positive, alpha-beta cytokine secreting ef...
#
#    preferred        score                                            synonym  \
# 0          1  1608.145600                                    effector T cell
# 1          1     1.710521                             innate effector T cell
# 2          1     1.296634  CD8-positive, alpha-beta cytokine secreting ef...
#
#       term_id  type
# 0  CL_0000911  CELL
# 1  CL_0002127  CELL
# 2  CL_0000908  CELL

# %%
queries = [
    '"T cell" OR (T AND cell)',
    '"T-helper"',
    '"gamma delta"',
    '"Treg"',
    '"cytotoxic T"',
    '"regulatory T"',
    '"natural killer T"',
    '"NKT"',
    '"TFH"',
    '"memory T"',
    '"effector T"',
    '"effector memory"',
    '"central memory"',
]
df = pd.concat([query(q) for q in queries])\
    .drop_duplicates(subset=['name', 'preferred', 'synonym', 'term_id', 'type'])
df.head()
# Out:
#    frequency    id                             name  preferred       score  \
# 0     379437   301                           T cell          1  16194.7140
# 1      88514  9779                    mature T cell          1   3778.1338
# 2      65426  2399                alpha-beta T cell          1   2792.9727
# 3      63953  2431         mature alpha-beta T cell          1   2730.1199
# 4      59986  1779  CD4-positive, alpha-beta T cell          1   2560.8486
#
#                            synonym     term_id  type
# 0                           T cell  CL_0000084  CELL
# 1                    mature T cell  CL_0002419  CELL
# 2                alpha-beta T cell  CL_0000789  CELL
# 3         mature alpha-beta T cell  CL_0000791  CELL
# 4  CD4-positive, alpha-beta T cell  CL_0000624  CELL

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 2
# Data columns (total 8 columns):
# frequency    195 non-null int64
# id           195 non-null object
# name         195 non-null object
# preferred    195 non-null int64
# score        195 non-null float64
# synonym      195 non-null object
# term_id      195 non-null object
# type         195 non-null object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 13.7+ KB

# %%
df['synonym'].unique()
# Out:
# array(['T cell', 'mature T cell', 'alpha-beta T cell',
#        'mature alpha-beta T cell', 'CD4-positive, alpha-beta T cell',
#        'CD8-positive, alpha-beta T cell', 'effector T cell',
#        'cytotoxic T cell', 'regulatory T cell',
#        'CD4-positive, CD25-positive, alpha-beta regulatory T cell',
#        'helper T cell', 'CD8-positive, alpha-beta cytotoxic T cell',
#        'immature T cell', 'CD4-positive helper T cell', 'naive T cell',
#        'memory T cell', 'gamma-delta T cell',
#        'CD4-positive, alpha-beta intraepithelial T cell',
#        'mature NK T cell', 'alpha-beta intraepithelial T cell',
#        'Anaplastic large cell lymphoma, T cell and Null cell type',
#        'naive thymus-derived CD4-positive, alpha-beta T cell',
#        'CD8-positive, alpha-beta memory T cell',
#        'T follicular helper cell',
#        'CD8-positive, alpha-beta regulatory T cell',
#        'CD4-positive, alpha-beta memory T cell',
#        'mature gamma-delta T cell', 'gamma-delta intraepithelial T cell',
#        'dendritic epidermal T cell',
#        'CD8-alpha-beta-positive, alpha-beta intraepithelial T cell',
#        'CD2-positive, CD5-positive, CD44-positive alpha-beta intraepithelial T cell',
#        'CD8-alpha alpha positive, gamma-delta intraepithelial T cell',
#        'CD4-negative CD8-negative gamma-delta intraepithelial T cell',
#        'CD4-positive, alpha-beta cytotoxic T cell',
#        'CD8-positive, CD28-negative, alpha-beta regulatory T cell',
#        'type II NK T cell',
#        'effector memory CD8-positive, alpha-beta T cell',
#        'type I NK T cell',
#        'effector memory CD4-positive, alpha-beta T cell',
#        'type II NK T cell secreting interleukin-4',
#        'central memory CD8 positive, alpha-beta T cell',
#        'CD8-alpha-alpha-positive, alpha-beta intraepithelial T cell',
#        'central memory CD4-positive, alpha-beta T cell',
#        'CD8-positive, CD25-positive, alpha-beta regulatory T cell',
#        'CD8-positive, CXCR3-positive, alpha-beta regulatory T cell',
#        'naive regulatory T cell', 'memory regulatory T cell',
#        'immature NK T cell', 'CD4-positive type I NK T cell',
#        'immature alpha-beta T cell', 'immature gamma-delta T cell',
#        'mucosal invariant T cell', 'CD27-positive gamma-delta T cell',
#        'CD27-negative gamma-delta T cell', 'innate effector T cell',
#        'hairy T cell leukemia', 'human T cell leukemia', 'T cell CLL',
#        'T cell lymphoma', 'cutaneous T cell lymphoma',
#        'peripheral T cell lymphoma', 'acute T cell leukemia',
#        'T cell prolymphocytic leukemia', 't cell activation protein-3',
#        't cell growth factor', 't cell growth factor-2',
#        't cell replacing factor', 't cell activating factor',
#        't cell growth factor-3', 't cell antigen 41bb',
#        't cell activation protein-2',
#        'ifn-inducible t cell a chemoattractant',
#        't cell chemotactic factor', 't cell antigen gp-39', 'Th1 T cell',
#        'Th2 T cell', 'plasmacytoid T cell',
#        'immature single-positive T cell', 'DN2 immature T cell',
#        'DN3 immature T cell', 'DN4 immature T cell',
#        'CD4(+) immature T cell', 'CD8(+) immature T cell',
#        'progenitor T cell', 'Th17 T cell', 'Tr1 T cell',
#        'induced regulatory T cell', 'natural regulatory T cell',
#        'Tc1 T cell', 'Tc2 T cell', 'Th22 T cell', 'Th9 T cell',
#        'IL17(+)CD8(+) T cell', 'Vg1.1-positive, Vd6.3-negative T cell',
#        'Vg1.1+Vd6.3+ T cell', 'immature Vg1.1+Vd6.3+ T cell',
#        'mature Vg1.1+Vd6.3+ T cell', 'double negative T cell',
#        'intraepithelial T cell',
#        'activated CD4-positive, alpha-beta T cell',
#        'activated CD8-positive, alpha-beta T cell',
#        'enteropathy associated T cell lymphoma',
#        'jka-3-induced upon t cell activation',
#        'glioblastoma-derived t cell suppressor factor',
#        't cell directed cc chemokine',
#        'stimulated t cell chemotactic protein-1',
#        'cutaneous t cell attracting chemokine',
#        't cell specific protein p228', 't cell activation antigen cd-27',
#        't cell growth inhibitory factor',
#        't cell activation protein p600', 'DN1 thymic progenitor T cell',
#        'cd4(-)cd8(-) alpha-beta iel t cell',
#        'CD25(+)CD27(+) immature gamma-delta T cell',
#        'mature Vg1.1-positive, Vd6.3-negative T cell',
#        'immature Vg1.1-positive, Vd6.3-negative T cell',
#        'activated CD4-positive type I NK T cell',
#        'type II NK T cell secreting interferon-gamma',
#        'naive thymus-derived CD8-positive, alpha-beta T cell',
#        'CD8-positive, alpha-beta cytokine secreting effector T cell',
#        'CD4-negative, CD8-negative type I NK T cell',
#        'activated type II NK T cell', 'immature NK T cell stage I',
#        'immature NK T cell stage II', 'immature NK T cell stage III',
#        'immature NK T cell stage IV',
#        'immature dendritic epithelial T cell precursor',
#        'mature dendritic epithelial T cell precursor',
#        'il 10-related t cell derived inducible factor',
#        'activated CD4-CD8- type I NK T cell',
#        'CD4-positive type I NK T cell secreting interferon-gamma',
#        'CD4-positive type I NK T cell secreting interleukin-4',
#        'CD4-negative, CD8-negative type I NK T cell secreting interferon-gamma',
#        'CD4-negative, CD8-negative type I NK T cell secreting interleukin-4',
#        'Vgamma5-positive CD8alpha alpha positive gamma-delta intraepithelial T cell',
#        'Vgamma5-negative CD8alpha alpha positive gamma-delta intraepithelial T cell',
#        'T mast cell', 'T-helper 2 cell', 'T-helper 1 cell',
#        'T-helper 17 cell', 'T-helper 9 cell', 'T-helper 22 cell',
#        'T-helper cell', 'CD4-positive T-helper cell',
#        'follicular T-helper cell', 'gamma delta T cell',
#        'immature gamma delta T-cell', 'mature gamma delta T-cell',
#        'CD27+ gamma delta T-cell', 'CD27- gamma delta T-cell',
#        'gamma delta thymocyte', 'CD8+ gamma delta intraepithelial T-cell',
#        'CD25+CD27+ immature gamma delta T-cell', 'Treg', 'CD8a Treg',
#        'adaptive Treg', 'natural Treg', 'CD8+CD25+ Treg',
#        'CD8+CD28- Treg', 'CD8+CXCR3+ Treg',
#        'cytotoxic t lymphocyte associated antigen-8',
#        'secondary cytotoxic t cell-inducing factor',
#        'cytotoxic t cell differentiation factor',
#        'T cytotoxic T cell type 1', 'T cytotoxic T cell type 2',
#        'T cytotoxic T cell type 17', 'cytotoxic t-lymphocyte inducer',
#        'type 1 regulatory T cell ', 'natural killer T cell', 'NKT.4+.SP',
#        'NKT.4-.Sp', 'mature NKT cell', 'immature NKT cell',
#        'NKT cells, type I', 'NKT cells, type II',
#        'activated type 2 NKT cell', 'immature NKT cell stage 1',
#        'immature NKT cell stage 2', 'immature NKT cell stage 3',
#        'immature NKT cell stage 4',
#        'activated CD4-positive type I NKT cell',
#        'CD4-positive type I NKT cell secreting interferon-gamma',
#        'CD4-positive type I NKT cell secreting interleukin-4',
#        'activated CD4-CD8- type I NKT cell',
#        'CD4-CD8- type I NKT cell secreting interferon-gamma',
#        'CD4-CD8- type I NKT cell secreting interleukin-4',
#        'type II NKT cell secreting interferon gamma',
#        'type II NKT cell secreting interleukin 4', 'Tfh',
#        'CD4(+) central memory T cell', 'CD4(+) effector memory T cell',
#        'CD8(+) central memory T cell',
#        'effector CD8+ alpha beta memory T cell',
#        'CD8(+) effector memory T-cell'], dtype=object)

# %%
df['type'].value_counts()
# Out:
# CELL        160
# CYTOKINE     25
# DISEASE      10
# Name: type, dtype: int64

# %% [markdown]
# #### Collect Relation Data

# %%
REQ_FMT="""<request type='data'>
<knowledgeSpace id='interactions'>
<filters>
<cell expand='true'>{}</cell>
<add_functions>true</add_functions>
</filters>
<paging start='0' limit='1000000' />
<sort by='numPapers' dir='desc'/>
</knowledgeSpace>
</request>
"""

# Example response (from post to http://immuneexpresso.org/immport-immunexpresso/rest/RESTServlet):
# {'status': {'statusCode': 1},
#  'totalNumElements': 299,
#  'start': 0,
#  'limit': 10,
#  'dataElements': [{'score': '0.08',
#    'numPapers': 88,
#    'enrichmentScore': '5.01',
#    'actor': 'cell',
#    'cellOntologyNodeId': 'CL_0000545',
#    'cellOntologyNodeLabel': 'T-helper 1 cell',
#    'cytokineOntologyNodeId': 'CID_83',
#    'cytokineOntologyNodeLabel': 'IFNG',
#    'verbCategory': 'Positive',
#    'functions': []}, 
#     ... ]
# }

def parse(res):
    df = []
    if 'dataElements' not in res:
        return pd.DataFrame(df)
    for e in res['dataElements']:
        df.append(dict(
            cell_id = e['cellOntologyNodeId'],
            cell_label = e['cellOntologyNodeLabel'],
            cytokine_id = e['cytokineOntologyNodeId'],
            cytokine_label = e['cytokineOntologyNodeLabel'],
            category = e['verbCategory'],
            score = e['enrichmentScore'],
            num_papers = e['numPapers'],
            actor = e['actor']
        ))
    return pd.DataFrame(df)

def get_ix_data(cell_type_ids, max_failures=5):
    dfs = []
    n_fail = 0
    url = 'http://immuneexpresso.org/immport-immunexpresso/rest/RESTServlet'
    for cid in tqdm.tqdm_notebook(cell_type_ids):
        try:
            request = REQ_FMT.format(cid)
            res = requests.post(url, data={'request': request})
            df = parse(res.json())
            if len(df) > 0:
                dfs.append(df)
        except:
            n_fail += 1
            print('Failure occurred for cell type id "{}" (ignoring)')
            if n_fail >= max_failures:
                print('Num failures exceeds max ({})'.format(max_failures))
                raise
    return pd.concat(dfs)

#dfr = get_ix_data(['CL_0000084'])
cell_type_ids = df[df['type'] == 'CELL']['term_id'].unique()
dfi = get_ix_data(cell_type_ids)
dfi = dfi.drop_duplicates()
dfi.head()
# Out:
# HBox(children=(IntProgress(value=0, max=108), HTML(value='')))
#       actor  category     cell_id                       cell_label  \
# 0      cell  Positive  CL_0000084                           T cell
# 1      cell  Positive  CL_0000084                           T cell
# 2      cell  Positive  CL_0000625  CD8-positive, alpha-beta T cell
# 3  cytokine  Positive  CL_0000084                           T cell
# 4  cytokine   Unknown  CL_0000084                           T cell
#
#   cytokine_id cytokine_label  num_papers score
# 0      CID_83           IFNG         809  4.28
# 1     CID_110            IL2         701   5.3
# 2      CID_83           IFNG         338  8.88
# 3     CID_110            IL2         313  1.58
# 4     CID_110            IL2         260  4.52

# %%
dfi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6246 entries, 0 to 9
# Data columns (total 8 columns):
# actor             6246 non-null object
# category          6246 non-null object
# cell_id           6246 non-null object
# cell_label        6246 non-null object
# cytokine_id       6246 non-null object
# cytokine_label    6246 non-null object
# num_papers        6246 non-null int64
# score             6246 non-null object
# dtypes: int64(1), object(7)
# memory usage: 439.2+ KB

# %%
# Save results in the event of restart 
dfi.to_csv(TEMP_FILE, index=False)
TEMP_FILE
# Out:
# '/lab/repos/t-cell-relation-extraction/data/supervision/immunexpresso/import.csv'

# %% [markdown]
# ### Matching
#
# Match cell types and cytokines to those in this project:

# %% [markdown]
# #### Load Project Meta Data

# %%
dfr = pd.read_csv(TEMP_FILE).drop_duplicates()
for c in ['cell_ref_id', 'cytokine_ref_id']:
    if c in dfr:
        dfr = dfr.drop(c, axis=1)
# Save record count to ensure that none are lost after transformation
n_init = len(dfr)
dfr.head()
# Out:
#       actor  category     cell_id                       cell_label  \
# 0      cell  Positive  CL_0000084                           T cell
# 1      cell  Positive  CL_0000084                           T cell
# 2      cell  Positive  CL_0000625  CD8-positive, alpha-beta T cell
# 3  cytokine  Positive  CL_0000084                           T cell
# 4  cytokine   Unknown  CL_0000084                           T cell
#
#   cytokine_id cytokine_label  num_papers  score
# 0      CID_83           IFNG         809   4.28
# 1     CID_110            IL2         701   5.30
# 2      CID_83           IFNG         338   8.88
# 3     CID_110            IL2         313   1.58
# 4     CID_110            IL2         260   4.52

# %%
df_ct = lib.get_entity_meta_data(lib.CELL_TYPES)
df_ct.head()
# Out:
#    depth       extid                  id  \
# 0      4  CL:0001047  CT312FEE66DC3CC142
# 1      3  CL:0002426  CT5847C8E0924693BF
# 2      2  CL:0000939  CTDEA6CA6446B38258
# 3      2  CL:0000938  CTBC1262C129A2D683
# 4      2  CL:0000938  CT9761754DA14E9898
#
#                                                  lbl parent        root  spid  \
# 0  CD4-positive, CD25-positive, CCR4-positive, al...    NaN  CL:0000084     1
# 1       CD11b-positive, CD27-positive natural killer    NaN  CL:0000623     1
# 2             CD16-positive, CD56-dim natural killer    NaN  CL:0000623     1
# 3          CD16-negative, CD56-bright natural killer    NaN  CL:0000623     1
# 4          CD16-negative, CD56-bright natural killer    NaN  CL:0000623     1
#
#   src                                           sym  priority  \
# 0  cl                                     CCR+ Treg        50
# 1  cl  CD11b-positive, CD27-positive natural killer        50
# 2  cl                                 CD16+CD56+ NK        50
# 3  cl                            CD16-CD56bright NK        50
# 4  cl                 CD16-negative, CD56-bright NK        50
#
#                prefid  enabled
# 0  CT05DC4A067F2BDFCB     True
# 1  CT5847C8E0924693BF     True
# 2  CTDBB7C729B7F40970     True
# 3  CT2751E190DAECAF00     True
# 4  CT2751E190DAECAF00     True

# %%
df_ct['lbl'].unique()[:50]
# Out:
# array(['CD4-positive, CD25-positive, CCR4-positive, alpha-beta regulatory T',
#        'CD11b-positive, CD27-positive natural killer',
#        'CD16-positive, CD56-dim natural killer',
#        'CD16-negative, CD56-bright natural killer',
#        'CD2-positive, CD5-positive, CD44-positive alpha-beta intraepithelial T',
#        'CD24-positive, CD4 single-positive thymocyte',
#        'CD24-positive, CD8 single-positive thymocyte',
#        'CD25-positive, CD27-positive immature gamma-delta T',
#        'CD27-high, CD11b-high natural killer',
#        'CD27-high, CD11b-low natural killer',
#        'CD27-low, CD11b-high natural killer',
#        'CD27-low, CD11b-low immature natural killer',
#        'CD27-negative gamma-delta T', 'CD27-positive gamma-delta T',
#        'mature T',
#        'CD4-intermediate, CD8-positive double-positive thymocyte',
#        'CD4-negative CD8-negative gamma-delta intraepithelial T',
#        'CD4-negative, CD8-negative type I NK T',
#        'CD4-negative, CD8-negative type I NK T cell secreting interferon-gamma',
#        'CD4-negative, CD8-negative type I NK T cell secreting interleukin-4',
#        'CD4-negative, CD8-negative, alpha-beta intraepithelial T',
#        'CD4-positive helper T', 'CD4-positive type I NK T',
#        'CD4-positive type I NK T cell secreting interferon-gamma',
#        'CD4-positive type I NK T cell secreting interleukin-4',
#        'CD4-positive, CD25-positive, alpha-beta regulatory T',
#        'CD4-positive, CD8-intermediate double-positive thymocyte',
#        'CD4-positive, CXCR3-negative, CCR6-negative, alpha-beta T',
#        'CD4-positive, alpha-beta T',
#        'CD4-positive, alpha-beta cytotoxic T',
#        'CD4-positive, alpha-beta thymocyte',
#        'CD4-positive, alpha-beta intraepithelial T',
#        'CD4-positive, alpha-beta memory T',
#        'CD56-negative, CD161-positive immature natural killer',
#        'CD56-positive, CD161-positive immature natural killer',
#        'CD69-positive double-positive thymocyte',
#        'CD69-positive, CD4-positive single-positive thymocyte',
#        'CD69-positive, CD8-positive single-positive thymocyte',
#        'CD8-positive, alpha-beta regulatory T',
#        'CD8-positive, CD25-positive, alpha-beta regulatory T',
#        'CD8-positive, CD28-negative, alpha-beta regulatory T',
#        'CD8-positive, CXCR3-positive, alpha-beta regulatory T',
#        'CD8-alpha alpha positive, gamma-delta intraepithelial T',
#        'CD8-alpha-alpha-positive, alpha-beta intraepithelial T',
#        'CD8-alpha-beta-positive, alpha-beta intraepithelial T',
#        'CD8-positive, CXCR3-negative, CCR6-negative, alpha-beta T',
#        'CD8-positive, alpha-beta T',
#        'CD8-positive, alpha-beta cytokine secreting effector T',
#        'CD8-positive, alpha-beta cytotoxic T',
#        'CD8-positive, alpha-beta thymocyte'], dtype=object)

# %%
df_ck = lib.get_entity_meta_data(lib.CYTOKINES)
df_ck.head()
# Out:
#                    id  src         sym     lbl  spid    extid  priority  \
# 0  CKC13858A2B1F14B6A  ckr        FGF2    FGF2     1   CID_61        50
# 1  CKE1C384AC6D4F253C  ckr     G0S19-3  CCL3L2     1    CID_4        50
# 2  CK02F6DA228C64A2DE  ckr       IL 27  IL-27α     1  CID_120        50
# 3  CKFB6F75446966C774  ckr   LD78gamma  CCL3L2     1    CID_4        50
# 4  CK4FE9053AF4462C6F  ckr     SCYA3L2  CCL3L2     1    CID_4        50
#
#                prefid  enabled
# 0  CKC4486E15652210FC     True
# 1  CKA949C45055283102     True
# 2  CKC78D5F9D7031D9FD     True
# 3  CKA949C45055283102     True
# 4  CKA949C45055283102     True

# %%
df_ck['lbl'].unique()
# Out:
# array(['FGF2', 'CCL3L2', 'IL-27α', 'TGFα', 'CXCL8', 'IFN-1', 'IFN-AR1',
#        'IFN-AR2', 'IFN-CDw119', 'IFN-GR2', 'IFN-IL-18', 'IFN-IL-28A',
#        'IFN-IL-28B', 'IFN-IL-28a', 'IFN-IL-28b', 'IFN-IL-29', 'IFN-IL-6',
#        'IFN-LR1', 'IFN-α', 'IFN-α1', 'IFN-α10', 'IFN-α13', 'IFN-α14',
#        'IFN-α16', 'IFN-α17', 'IFN-α2', 'IFN-α21', 'IFN-α4', 'IFN-α5',
#        'IFN-α6', 'IFN-α7', 'IFN-α8', 'IFN-β', 'IFN-β1', 'IFN-ε', 'IFN-γ',
#        'IFN-κ', 'IFN-ω', 'IL-1', 'IL-1 theta', 'IL-10', 'IL-10RA',
#        'IL-10RB', 'IL-11', 'IL-11RA', 'IL-12', 'IL-12A', 'IL-12B',
#        'IL-12RB2', 'IL-12α', 'IL-13', 'IL-14', 'IL-15', 'IL-15Ra',
#        'IL-16', 'IL-17', 'IL-17A', 'IL-17B', 'IL-17C', 'IL-17D', 'IL-17F',
#        'IL-17a', 'IL-17b', 'IL-17c', 'IL-17d', 'IL-17f', 'IL-18',
#        'IL-18BP', 'IL-18R1', 'IL-19', 'IL-1A', 'IL-1B', 'IL-1F10',
#        'IL-1RA', 'IL-1α', 'IL-1β', 'IL-1δ', 'IL-1ε', 'IL-2', 'IL-20',
#        'IL-20Ra', 'IL-20Rb', 'IL-21', 'IL-21R', 'IL-22', 'IL-22RA1',
#        'IL-22RA2', 'IL-23', 'IL-23A', 'IL-23R', 'IL-23p40', 'IL-24',
#        'IL-25', 'IL-26', 'IL-27', 'IL-27β', 'IL-28', 'IL-28A', 'IL-28B',
#        'IL-28a', 'IL-28b', 'IL-29', 'IL-3', 'IL-31', 'IL-32', 'IL-33',
#        'IL-34', 'IL-35', 'IL-36A', 'IL-36B', 'IL-36G', 'IL-37', 'IL-4',
#        'IL-4I1', 'IL-5', 'IL-6', 'IL-6ST', 'IL-7', 'IL-9', 'IL-9R',
#        'IL-CCL16', 'IL-CCL27', 'IL-CD121a', 'IL-CD122', 'IL-CD123',
#        'IL-CD124', 'IL-CD126', 'IL-CD127', 'IL-CD130', 'IL-CD131',
#        'IL-CD132', 'IL-CD212', 'IL-CD213a1', 'IL-CD213a2', 'IL-CD25',
#        'IL-CDw121b', 'IL-CDw125', 'IL-CDw137', 'IL-CDw217', 'IL-CXCL8',
#        'IL-CXCR1', 'IL-CXCR2', 'IL-F2', 'IL-F3', 'IL-IFNLR1', 'IL-NF3',
#        'IL-OSMR', 'LT-TNF-β', 'LT-TNFSF14', 'LT-XCL1', 'LT-α', 'LT-β',
#        'LT-bR', 'TGF-', 'TGF-BR1', 'TGF-BR2', 'TGF-BR3', 'TGF-α', 'TGF-β',
#        'TGF-β1', 'TGF-β2', 'TGF-β3', 'TNF-', 'TNF-4-1BB', 'TNF-APRIL',
#        'TNF-Apo3', 'TNF-BAFF', 'TNF-BCMA', 'TNF-CD120a', 'TNF-CD120b',
#        'TNF-CD153', 'TNF-CD258', 'TNF-CD27', 'TNF-CD30', 'TNF-CD40',
#        'TNF-CD40LG', 'TNF-CD70', 'TNF-CDw137', 'TNF-FASLG', 'TNF-Fas',
#        'TNF-GITR', 'TNF-HVEM', 'TNF-LT-α', 'TNF-LT-β', 'TNF-LTbR',
#        'TNF-OPG', 'TNF-OX40', 'TNF-OX40L', 'TNF-RANK', 'TNF-SF10',
#        'TNF-SF11', 'TNF-SF12', 'TNF-SF13', 'TNF-SF13B', 'TNF-SF14',
#        'TNF-SF15', 'TNF-SF18', 'TNF-SF4', 'TNF-SF8', 'TNF-SF9',
#        'TNF-TACI', 'TNF-TRAILR1', 'TNF-TRAILR2', 'TNF-TRAILR3',
#        'TNF-TRAILR4', 'TNF-VEGI', 'TNF-α', 'TNF-β', 'FGF1', 'CXCL7',
#        'CXCL10', 'CXCL12', 'CXCL17', 'SPP1', 'CDw137', 'TNFSF9', 'CCL3L3',
#        'CD124', 'CCL21', 'TNFSF13', 'CCL22', 'CCL17', 'TGFBR2', 'TGFBR1',
#        'CX3CL1', 'CXCR7', 'CCL4', 'OX40', 'RETN', 'IFNGR2', 'GITR',
#        'TNFSF18', 'CCL27', 'Fas', 'FASLG', 'CCL18', 'CXCL13', 'Apo3',
#        'TRAILR1', 'TNFSF10', 'TNFSF12', 'TGFβ3', 'CCL4L2', 'XCL1', 'HVEM',
#        'MET', 'IFNAR1', 'CD131', 'PDGFRA', 'TRAILR3', 'CD70', 'TRAIL',
#        'TWEAK', 'BAFF', 'BCMA', 'CD40', 'BSF-3', 'TGFBR3', 'CXCR5',
#        'CCR7', 'CXCL14', 'CCR6', 'CXCR6', 'LECT1', 'TGFβ2', 'CX3CR1',
#        'PDGFRB', 'CXCL11', 'CCL20', 'CCL19', 'XCL2', 'CXCR1', 'CCR1',
#        'CCR10', 'CCR2', 'CCR3', 'CCR4', 'CCR5', 'CCR8', 'CCR9', 'CCL1',
#        'CCL11', 'CCL12', 'CCL13', 'CCL14', 'CCL15', 'CCL16', 'CCL2',
#        'CCL23', 'CCL24', 'CCL25', 'CCL26', 'CCL3', 'CCL6', 'CCL7', 'CCL8',
#        'CCL9', 'CCL28', 'CCL3L1', 'CCL4L1', 'CCL5', 'CD115', 'CD117',
#        'MPL', 'CXCR2', 'CXCR3', 'CXCR4', 'CXCL1', 'CXCL15', 'CXCL16',
#        'CXCL2', 'CXCL3', 'CXCL4', 'CXCL4L1', 'CXCL5', 'CXCL6', 'CXCL9',
#        'THPO', 'G-CSF', 'CKLF', 'CDw217', 'XCR1', 'CD114', 'CD116',
#        'CD118', 'CDw119', 'CD120a', 'CD120b', 'CD121a', 'CDw121b',
#        'CD122', 'CD123', 'CDw125', 'CD126', 'CD127', 'CD130', 'CD132',
#        'TNFSF4', 'Flt-3', 'CDw136', 'TNFSF8', 'CD40LG', 'LTbR', 'IL10RA',
#        'CD212', 'CD213a1', 'CD213a2', 'TNFSF11', 'TNFSF14', 'TRAILR2',
#        'TRAILR4', 'RANK', 'TACI', 'CD27', 'CD30', 'IL21R', 'IL10RB',
#        'TGFβ1', 'CKLFH1', 'CKLFH6', 'CKLFH7', 'CNTFR', 'TDGF2', 'TDGF3',
#        'IL22RA2', 'IFNLR1', 'IL22RA1', 'IL11RA', 'GM-CSF', 'CSF1',
#        'LECT2', 'LIF', 'MST1', 'MIF', 'HGF', 'NFIL3', 'EPO', 'EGF',
#        'EGFR', 'EpoR', 'TAFA1', 'TAFA2', 'TAFA3', 'TAFA4', 'TAFA5',
#        'FLT3LG', 'FP248', 'SCF', 'GDF15', 'PDGFβ', 'CD25', 'IFNAR2',
#        'IL12RB2', 'IL23R', 'OSMR', 'LMIF', 'LOC107983991', 'MAF', 'MCP',
#        'MIP', 'OPG', 'OSM', 'PGDF', 'PDGFα', 'TGF', 'TGFβ', 'TNFSF15',
#        'TNF', 'TF', 'UMLILO'], dtype=object)

# %% [markdown]
# #### Match Cell Types

# %%
# Map immuneXpresso cell type labels to internal labels
m_ct = {
    'CD4-positive helper T cell': 'Th',
    'naive T cell': 'TN',
    'naive thymus-derived CD4-positive, alpha-beta T cell': 'TN',
    'regulatory T cell': 'Treg',
    'CD4-positive, CD25-positive, alpha-beta regulatory T cell': 'Treg',
    'CD8-positive, CD28-negative, alpha-beta regulatory T cell': 'Treg',
    'CD8-positive, CXCR3-positive, alpha-beta regulatory T cell': 'Treg',
    'induced T-regulatory cell': 'iTreg',
    'natural T-regulatory cell': 'nTreg',
    'CD8-positive, alpha-beta regulatory T cell': 'Treg',
    'CD4-positive, alpha-beta cytotoxic T cell': 'Tc',
    'CD8-positive, alpha-beta cytotoxic T cell': 'Tc',
    'cytotoxic T cell': 'Tc',
    'effector T cell': 'effector T',
    'mature T cell': 'mature T',
    'pro-T cell': 'DN2 immature T',
    'early T lineage precursor': 'ThP',
    'CD4-positive, alpha-beta intraepithelial T cell': 'IEL',
    'CD8-alpha-beta-positive, alpha-beta intraepithelial T cell': 'IEL',
    'intraepithelial lymphocyte': 'IEL',
    'CD4-positive, alpha-beta memory T cell': 'TMEM',
    'CD8-positive, alpha-beta memory T cell': 'TMEM',
    'memory T cell': 'TMEM',
    'T follicular helper cell': 'Tfh',
    'T-helper 1 cell': 'Th1',
    'T-helper 17 cell': 'Th17',
    'T-helper 2 cell': 'Th2',
    'T-helper 22 cell': 'Th22',
    'T-helper 9 cell': 'Th9',
    'Tc1 cell': 'Tc1',
    'Tc17 cell': 'Tc17',
    'Tr1 cell': 'Treg1',
    'dendritic epidermal T cell': 'DETC',
    'CD8-positive, alpha-beta thymocyte': 'Thymocyte',
    'DN4 thymocyte': 'Thymocyte',
    'fetal thymocyte': 'Thymocyte',
    'double negative thymocyte': 'Thymocyte',
    'double-positive, alpha-beta thymocyte': 'Thymocyte',
    'mature CD4 single-positive thymocyte': 'Thymocyte',
    'thymocyte': 'Thymocyte',
    'effector T cell': 'TEFF',
    'effector memory CD4-positive, alpha-beta T cell': 'TEM',
    'effector memory CD8-positive, alpha-beta T cell': 'TEM',
    'gamma-delta T cell': 'γδT',
    'helper T cell': 'Th',
    'mature NK T cell': 'NKT'
}

# %%
df_ct.head()
# Out:
#    depth       extid                  id  \
# 0      4  CL:0001047  CT312FEE66DC3CC142
# 1      3  CL:0002426  CT5847C8E0924693BF
# 2      2  CL:0000939  CTDEA6CA6446B38258
# 3      2  CL:0000938  CTBC1262C129A2D683
# 4      2  CL:0000938  CT9761754DA14E9898
#
#                                                  lbl parent        root  spid  \
# 0  CD4-positive, CD25-positive, CCR4-positive, al...    NaN  CL:0000084     1
# 1       CD11b-positive, CD27-positive natural killer    NaN  CL:0000623     1
# 2             CD16-positive, CD56-dim natural killer    NaN  CL:0000623     1
# 3          CD16-negative, CD56-bright natural killer    NaN  CL:0000623     1
# 4          CD16-negative, CD56-bright natural killer    NaN  CL:0000623     1
#
#   src                                           sym  priority  \
# 0  cl                                     CCR+ Treg        50
# 1  cl  CD11b-positive, CD27-positive natural killer        50
# 2  cl                                 CD16+CD56+ NK        50
# 3  cl                            CD16-CD56bright NK        50
# 4  cl                 CD16-negative, CD56-bright NK        50
#
#                prefid  enabled
# 0  CT05DC4A067F2BDFCB     True
# 1  CT5847C8E0924693BF     True
# 2  CTDBB7C729B7F40970     True
# 3  CT2751E190DAECAF00     True
# 4  CT2751E190DAECAF00     True

# %%
#np.sort(dfr['cell_label'].unique())

# %%
#np.sort(df_ct['lbl'].unique())

# %%
assert df_ct['sym'].is_unique
m_prefid = df_ct.set_index('sym')['prefid'].to_dict()
# Map iX cell type name to some known symbol and then map that symbol to the preferred id
dfr['cell_ref_id'] = dfr['cell_label'].map(m_ct).map(m_prefid)
dfr[dfr['cell_ref_id'].notnull()].head()
# Out:
#        actor  category     cell_id  \
# 13      cell  Positive  CL_0000545
# 21  cytokine  Positive  CL_0000792
# 22      cell  Positive  CL_0000546
# 26      cell  Positive  CL_0000792
# 27  cytokine  Positive  CL_0000545
#
#                                            cell_label cytokine_id  \
# 13                                    T-helper 1 cell      CID_83
# 21  CD4-positive, CD25-positive, alpha-beta regula...     CID_110
# 22                                    T-helper 2 cell     CID_131
# 26  CD4-positive, CD25-positive, alpha-beta regula...      CID_93
# 27                                    T-helper 1 cell      CID_95
#
#    cytokine_label  num_papers  score         cell_ref_id     cytokine_ref_id
# 13           IFNG          88   5.01  CT4EC75AEE8E7F5A03  CKEF3883BE9F74024F
# 21            IL2          60   3.12  CT3FE60C3FE8E2D0E6  CKA3BA887803CF8CE7
# 22            IL4          59  15.88  CT3CFB613D270E6C62  CKF0F9E60D7241467D
# 26           IL10          57   7.93  CT3FE60C3FE8E2D0E6  CK8F843985B9BF76B8
# 27           IL12          56  11.77  CT4EC75AEE8E7F5A03  CKDE858D3F63FD2E03

# %%
dfr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1245 entries, 0 to 6045
# Data columns (total 10 columns):
# actor              1245 non-null object
# category           1245 non-null object
# cell_id            1245 non-null object
# cell_label         1245 non-null object
# cytokine_id        1245 non-null object
# cytokine_label     1245 non-null object
# num_papers         1245 non-null int64
# score              1245 non-null float64
# cell_ref_id        685 non-null object
# cytokine_ref_id    1245 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 107.0+ KB

# %%
dfr[dfr['cell_ref_id'].isnull()]['cell_label'].unique()
# Out:
# array(['T cell', 'CD8-positive, alpha-beta T cell',
#        'CD4-positive, alpha-beta T cell', 'effector T cell',
#        'plasmacytoid dendritic cell',
#        'thymic plasmacytoid dendritic cell',
#        'CD11c-low plasmacytoid dendritic cell'], dtype=object)

# %% [markdown]
# #### Match Cytokines

# %%
# cts = df_ck.groupby(['src', 'sym'])['lbl'].nunique()
# cts[cts > 1]

# %%
#df_ck[df_ck['sym'] == 'IFN-L2']
#df_ck[df_ck['sym'] == 'LT-α']
#df_ck[df_ck['sym'] == 'Monocyte-CSF']
df_ck[df_ck['sym'] == 'IL-1RN']
#df_ck[df_ck['lbl'] == 'CXCL7']
# Out:
#                       id  src     sym     lbl  spid   extid  priority  \
# 2916  CKE72725973F3BAC8F  ckr  IL-1RN  IL-1RA     1  CID_86        50
#
#                   prefid  enabled
# 2916  CK5898940A9125FE21     True

# %%
m_ck = {'Monocyte-CSF': 'CSF1'}
dfr_ck = dfr['cytokine_label'].unique()
prj_ck = df_ck['lbl'].unique()
prj_ck_m = df_ck.groupby('sym')['lbl'].min().to_dict()
prj_ck_m = {k.upper():v for k, v in prj_ck_m.items()}

unmapped_cytokines = []
for ck in dfr_ck:
    if ck in m_ck:
        continue
    sym = ck
    if ck.startswith('IL'):
        sym = 'IL-' + ck[2:]
    if sym in prj_ck:
        m_ck[ck] = sym
    elif sym in prj_ck_m:
        m_ck[ck] = prj_ck_m[sym]
    else:
        unmapped_cytokines.append(ck)

assert len(unmapped_cytokines) == 0, 'Found the following unmapped cytokines:\n{}'.format(sorted(unmapped_cytokines))

# %%
#np.sort(dfr['cytokine_label'].unique())
#np.sort(df_ck['lbl'].unique())
#u'\N{GREEK SMALL LETTER GAMMA}'
#df_ck[df_ck['lbl'] == 'IFN-α']
#df_ck[df_ck['lbl'] == 'IFN-γ']

# %%
assert df_ck['sym'].is_unique
# Map iX cytokine name to some known symbol and then map that symbol to the preferred id
m_prefid = df_ck.set_index('sym')['prefid'].to_dict()
dfr['cytokine_ref_id'] = dfr['cytokine_label'].map(m_ck).map(m_prefid)
assert dfr['cytokine_ref_id'].notnull().all()
dfr.head()
# Out:
#       actor  category     cell_id                       cell_label  \
# 0      cell  Positive  CL_0000084                           T cell
# 1      cell  Positive  CL_0000084                           T cell
# 2      cell  Positive  CL_0000625  CD8-positive, alpha-beta T cell
# 3  cytokine  Positive  CL_0000084                           T cell
# 4  cytokine   Unknown  CL_0000084                           T cell
#
#   cytokine_id cytokine_label  num_papers  score cell_ref_id  \
# 0      CID_83           IFNG         809   4.28         NaN
# 1     CID_110            IL2         701   5.30         NaN
# 2      CID_83           IFNG         338   8.88         NaN
# 3     CID_110            IL2         313   1.58         NaN
# 4     CID_110            IL2         260   4.52         NaN
#
#       cytokine_ref_id
# 0  CKEF3883BE9F74024F
# 1  CKA3BA887803CF8CE7
# 2  CKEF3883BE9F74024F
# 3  CKA3BA887803CF8CE7
# 4  CKA3BA887803CF8CE7

# %%
dfr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1245 entries, 0 to 6045
# Data columns (total 10 columns):
# actor              1245 non-null object
# category           1245 non-null object
# cell_id            1245 non-null object
# cell_label         1245 non-null object
# cytokine_id        1245 non-null object
# cytokine_label     1245 non-null object
# num_papers         1245 non-null int64
# score              1245 non-null float64
# cell_ref_id        685 non-null object
# cytokine_ref_id    1245 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 107.0+ KB

# %% [markdown]
# ## EDA

# %%
dfr['actor'].value_counts()
# Out:
# cytokine    1054
# cell         191
# Name: actor, dtype: int64

# %%
dfr.groupby(['actor', 'category']).size()
# Out:
# actor     category
# cell      Positive    191
# cytokine  Negative    271
#           Positive    422
#           Unknown     361
# dtype: int64

# %%
dft = dfr[(dfr['actor'] == 'cytokine') & (dfr['category'] == 'Positive')].sort_values('num_papers', ascending=False)
#dft = dfr[(dfr['category'] == 'Positive')].sort_values('num_papers', ascending=False)
dft[dft['cell_label'] == 'T-helper 2 cell'].head(15)
# Out:
#          actor  category     cell_id       cell_label cytokine_id  \
# 58    cytokine  Positive  CL_0000546  T-helper 2 cell     CID_131
# 153   cytokine  Positive  CL_0000546  T-helper 2 cell     CID_128
# 184   cytokine  Positive  CL_0000546  T-helper 2 cell      CID_93
# 277   cytokine  Positive  CL_0000546  T-helper 2 cell      CID_83
# 310   cytokine  Positive  CL_0000546  T-helper 2 cell     CID_118
# 387   cytokine  Positive  CL_0000546  T-helper 2 cell     CID_108
# 495   cytokine  Positive  CL_0000546  T-helper 2 cell     CID_133
# 456   cytokine  Positive  CL_0000546  T-helper 2 cell      CID_20
# 406   cytokine  Positive  CL_0000546  T-helper 2 cell      CID_95
# 413   cytokine  Positive  CL_0000546  T-helper 2 cell     CID_162
# 637   cytokine  Positive  CL_0000546  T-helper 2 cell      CID_89
# 649   cytokine  Positive  CL_0000546  T-helper 2 cell      CID_87
# 1055  cytokine  Positive  CL_0000546  T-helper 2 cell      CID_98
# 963   cytokine  Positive  CL_0000546  T-helper 2 cell     CID_135
# 973   cytokine  Positive  CL_0000546  T-helper 2 cell     CID_110
#
#      cytokine_label  num_papers  score         cell_ref_id     cytokine_ref_id
# 58              IL4          31   5.47  CT3CFB613D270E6C62  CKF0F9E60D7241467D
# 153            IL33          11  13.53  CT3CFB613D270E6C62  CK621B34672BE37D14
# 184            IL10           9   1.47  CT3CFB613D270E6C62  CK8F843985B9BF76B8
# 277            IFNG           5   0.33  CT3CFB613D270E6C62  CKEF3883BE9F74024F
# 310            IL25           5  30.31  CT3CFB613D270E6C62  CK52B8D587BB3E5BB9
# 387            IL18           4   3.91  CT3CFB613D270E6C62  CK3F77E7B46E9E491A
# 495             IL6           3   0.44  CT3CFB613D270E6C62  CKF8C95AB8BB638BAC
# 456            CCL2           3   1.15  CT3CFB613D270E6C62  CK73ED9A7EF785943D
# 406            IL12           3   0.91  CT3CFB613D270E6C62  CKDE858D3F63FD2E03
# 413            TGFB           3   0.48  CT3CFB613D270E6C62  CKFD4CA0B2B4BC3AE4
# 637            IL1B           2   0.56  CT3CFB613D270E6C62  CK1E538D2D92F213B3
# 649             IL1           2   0.53  CT3CFB613D270E6C62  CKE05E12A50F6849A0
# 1055           IL13           1   1.14  CT3CFB613D270E6C62  CK9CECD914AC9D8D66
# 963             IL9           1   4.92  CT3CFB613D270E6C62  CK25044A239340F089
# 973             IL2           1   0.08  CT3CFB613D270E6C62  CKA3BA887803CF8CE7

# %% [markdown]
# ## Export

# %%
assert len(dfr) == n_init
dfr.to_csv(DATA_FILE, index=False)
DATA_FILE
# Out:
# '/lab/repos/t-cell-relation-extraction/data/supervision/immunexpresso/data.csv'
