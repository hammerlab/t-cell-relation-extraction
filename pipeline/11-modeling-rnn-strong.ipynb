# %%
# %matplotlib inline
import os
import tqdm
import os.path as osp
import pandas as pd
import numpy as np
import itertools
import glob
import json 
import plotnine as pn
import matplotlib.pyplot as plt
import collections
from tcre.env import *
from tcre.supervision import get_candidate_classes, SPLIT_DEV, SPLIT_VAL, SPLIT_TEST, SPLIT_MAP
from tcre.exec.v1 import optim
from tcre.modeling import features
from tcre.modeling import sampling
from snorkel.learning.utils import LabelBalancer
from snorkel import SnorkelSession
from snorkel.models import Candidate
import logging
session = SnorkelSession()
# %run ../src/tcre/logging.py
classes = get_candidate_classes()
# Out:
# /opt/conda/envs/nlp/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
#output_dir = osp.join(RESULTS_DATA_DIR, 'modeling-rnn-strong', 'run1')
#output_dir = osp.join(RESULTS_DATA_DIR, 'modeling-rnn-strong', 'run2')
output_dir = osp.join(RESULTS_DATA_DIR, 'modeling-rnn-strong', 'run3')
output_dir
# Out:
# '/lab/data/results/modeling-rnn-dev/run3'

# %%
tasks = [classes[c].field for c in classes]
tasks
# Out:
# ['inducing_cytokine', 'secreted_cytokine', 'inducing_transcription_factor']

# %% [markdown]
# ### Initialize Optimizers

# %%
from skopt.space import Categorical
from skopt.space import Space

space = Space([
    Categorical(['doub_01'], name='marker_list'),
    Categorical([True, False], name='use_secondary'),
    Categorical([True], name='use_swaps'),
    Categorical([True], name='use_positions'),
    Categorical(['w2v_frozen', 'w2v_trained'], name='wrd_embedding_type'),
    Categorical(['XL', 'XXL', 'XXXL', 'XXXXL'], name='model_size'),
    Categorical([0.0, .0001, .001, .005], name='weight_decay'),
    Categorical([.005, .01, .05], name='learning_rate'),
    Categorical([0.0, 0.25, 0.5, 0.75], name='dropout'),
    Categorical(['LSTM'], name='cell_type'),
    Categorical([False], name='bidirectional')
])

# %%
n_space = np.prod([len(dim.categories) for dim in space])
print('Number of combinations in parameter space:', n_space)
# Out:
# Number of combinations in parameter space: 768

# %%
space.rvs()[0]
# Out:
# ['doub_01',
#  False,
#  True,
#  True,
#  'w2v_trained',
#  'XL',
#  0.001,
#  0.005,
#  0.5,
#  'LSTM',
#  False]

# %%
from skopt import forest_minimize, dummy_minimize

optimizers = {
    task: optim.TaskParameterOptimizer(
        task, space, output_dir, minimizer=dummy_minimize, client_args=dict(cli={'batch_size': 512})
    ) for task in tasks
}

# %%
optimizers[tasks[0]].client.exceptions
# Out:
# ['log_level',
#  'seed',
#  'vocab_limit',
#  'use_lower',
#  'save_keys',
#  'log_iter_interval',
#  'log_epoch_interval',
#  'balance',
#  'batch_size',
#  'simulation_strategy',
#  'swap_list']

# %% [markdown]
# ### Create Splits for Tasks

# %%
cands = session.query(Candidate).filter(Candidate.split.in_([SPLIT_DEV, SPLIT_VAL, SPLIT_TEST])).all()
len(cands)
# Out:
# 3957

# %%
# DB splits -> modeling splits 
TARGET_MAP = {'dev': 'train', 'val': 'val', 'test': 'test'}
df_cand, df_dist = sampling.get_modeling_splits(session, target_split_map=TARGET_MAP)

# Duplicate val candidates for prediction
df_cand = pd.concat([
    df_cand, df_cand[df_cand['split'] == 'val'].assign(split='predict')
])

# Write splits to file
for task, g in df_cand.groupby('task'):
    splits = g.groupby('split')['id'].unique()
    splits_file = optimizers[task].write_splits(splits)
    print(f'Splits for task {task} written to "{splits_file}"')
df_dist
# Out:
# Splits for task inducing_cytokine written to "/lab/data/results/modeling-rnn-dev/run3/inducing_cytokine/splits/splits.json"
# Splits for task inducing_transcription_factor written to "/lab/data/results/modeling-rnn-dev/run3/inducing_transcription_factor/splits/splits.json"
# Splits for task secreted_cytokine written to "/lab/data/results/modeling-rnn-dev/run3/secreted_cytokine/splits/splits.json"
# statistic                           percent       count
# label                                     0     1     0    1
# task                          split
# inducing_cytokine             test     50.0  50.0    25   25
#                               train    50.0  50.0   137  137
#                               val      50.0  50.0    14   14
# inducing_transcription_factor test     50.0  50.0    57   57
#                               train    50.0  50.0   110  110
#                               val      50.0  50.0    35   35
# secreted_cytokine             test     50.0  50.0    50   50
#                               train    50.0  50.0   112  112
#                               val      50.0  50.0    36   36

# %%
df_cand.groupby(['task', 'split']).size().unstack()
# Out:
# split                          predict  test  train  val
# task
# inducing_cytokine                   28    50    274   28
# inducing_transcription_factor       70   114    220   70
# secreted_cytokine                   72   100    224   72

# %% [markdown]
# ### Run Search

# %%
# Show an example command to be run 
print(optimizers[tasks[0]].get_cmd(space.rvs()[0]))
# Out:
# python /lab/repos/t-cell-relation-extraction/src/tcre/exec/v1/cli.py --relation-class=inducing_cytokine --device="cuda:1" --output-dir=/lab/data/results/gridsearch-dev/run3/inducing_cytokine/data --batch-size=512 train --splits-file=/lab/data/results/gridsearch-dev/run3/inducing_cytokine/splits/splits.json --use-checkpoints=False --save-keys="history" --marker-list=doub_01 --use-secondary=False --use-swaps=True --use-positions=True --wrd-embedding-type=w2v_trained --model-size=XL --weight-decay=0.0001 --learning-rate=0.05 --dropout=0.5 --cell-type=LSTM --bidirectional=False > /lab/data/results/gridsearch-dev/run3/inducing_cytokine/log/log.txt 2>&1

# %%
# For 3 tasks at about about 30s per iteration, show common time estimations:
time_per_iter_sec = 30
n_iter = np.array([10, 100, 250, 500, 1000])
for n in n_iter:
    time = n * time_per_iter_sec * len(tasks) / 3600
    print(f'Iterations = {n} --> Time = {time} (hrs)')
# Out:
# Iterations = 10 --> Time = 0.25 (hrs)
# Iterations = 100 --> Time = 2.5 (hrs)
# Iterations = 250 --> Time = 6.25 (hrs)
# Iterations = 500 --> Time = 12.5 (hrs)
# Iterations = 1000 --> Time = 25.0 (hrs)

# %%
results = {}

for task in tasks:
    optimizer = optimizers[task]
    logging.info(f'Running optimization for task {task}')
    # kappa=3.090 -> 99.8% confidence interval (favors exploration when higher than default 1.96)
    #res, scores, callbacks = optimizer.run(n_iterations=250, progress_interval=1, checkpoint_interval=10, n_random_starts=10, acq_func='LCB', kappa=3.090)
    res, scores, callbacks = optimizer.run(n_iterations=64, progress_interval=1, checkpoint_interval=10)
    
    # Save scores for non-objective (i.e. validation) after converting to long form
    scores = pd.DataFrame(scores)
    scores.columns = pd.MultiIndex.from_tuples([c for c in scores])
    scores = scores.rename_axis('iteration', axis=0).rename_axis(('metric', 'type'), axis=1)
    scores = scores.stack().stack().rename('value').reset_index()
    scores_file = osp.join(optimizer.output_dir, 'scores.feather')
    scores.to_feather(scores_file)
    logging.info(f'Saved scores to {scores_file}')
    
    # Checkpoint final result since it is not saved at every step
    callbacks['saver'].i = -1
    callbacks['saver'](res)
    logging.info(f'Saved final result')
    
    results[task] = res, scores, callbacks
# Out:
# 2019-08-05 15:36:40,854:INFO:root: Running optimization for task inducing_cytokine
# 2019-08-05 15:36:40,855:INFO:tcre.exec.v1.optim: Beginning parameter search with max iterations 64
# 2019-08-05 15:36:56,642:INFO:tcre.exec.v1.optim: Completed iteration 1 of 64 (score = -0.7096774193548381)
# 2019-08-05 15:37:13,900:INFO:tcre.exec.v1.optim: Completed iteration 2 of 64 (score = -0.684210526315789)
# 2019-08-05 15:37:31,856:INFO:tcre.exec.v1.optim: Completed iteration 3 of 64 (score = -0.6666666666666661)
# 2019-08-05 15:37:47,602:INFO:tcre.exec.v1.optim: Completed iteration 4 of 64 (score = -0.5454545454545451)
# 2019-08-05 15:38:03,915:INFO:tcre.exec.v1.optim: Completed iteration 5 of 64 (score = -0.625)
# 2019-08-05 15:38:19,043:INFO:tcre.exec.v1.optim: Completed iteration 6 of 64 (score = -0.685714285714285)
# 2019-08-05 15:38:34,807:INFO:tcre.exec.v1.optim: Completed iteration 7 of 64 (score = -0.6829268292682921)
# 2019-08-05 15:38:51,112:INFO:tcre.exec.v1.optim: Completed iteration 8 of 64 (score = -0.6000000000000001)
# 2019-08-05 15:39:07,701:INFO:tcre.exec.v1.optim: Completed iteration 9 of 64 (score = -0.6000000000000001)
# 2019-08-05 15:39:24,516:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/inducing_cytokine/checkpoints/checkpoint.pkl
# 2019-08-05 15:39:24,546:INFO:tcre.exec.v1.optim: Completed iteration 10 of 64 (score = -0.6666666666666661)
# 2019-08-05 15:39:41,250:INFO:tcre.exec.v1.optim: Completed iteration 11 of 64 (score = -0.65)
# 2019-08-05 15:39:56,970:INFO:tcre.exec.v1.optim: Completed iteration 12 of 64 (score = -0.6875)
# 2019-08-05 15:40:11,971:INFO:tcre.exec.v1.optim: Completed iteration 13 of 64 (score = -0.8125000000000001)
# 2019-08-05 15:45:49,085:INFO:tcre.exec.v1.optim: Completed iteration 14 of 64 (score = -0.764705882352941)
# 2019-08-05 15:46:04,788:INFO:tcre.exec.v1.optim: Completed iteration 15 of 64 (score = -0.6000000000000001)
# 2019-08-05 15:46:21,203:INFO:tcre.exec.v1.optim: Completed iteration 16 of 64 (score = -0.7222222222222221)
# 2019-08-05 15:46:36,722:INFO:tcre.exec.v1.optim: Completed iteration 17 of 64 (score = -0.628571428571428)
# 2019-08-05 15:46:52,675:INFO:tcre.exec.v1.optim: Completed iteration 18 of 64 (score = -0.764705882352941)
# 2019-08-05 15:47:08,727:INFO:tcre.exec.v1.optim: Completed iteration 19 of 64 (score = -0.7058823529411761)
# 2019-08-05 15:47:24,336:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/inducing_cytokine/checkpoints/checkpoint.pkl
# 2019-08-05 15:47:24,384:INFO:tcre.exec.v1.optim: Completed iteration 20 of 64 (score = -0.74074074074074)
# 2019-08-05 15:47:39,603:INFO:tcre.exec.v1.optim: Completed iteration 21 of 64 (score = -0.756756756756756)
# 2019-08-05 15:51:14,872:INFO:tcre.exec.v1.optim: Completed iteration 22 of 64 (score = -0.74074074074074)
# 2019-08-05 15:51:31,423:INFO:tcre.exec.v1.optim: Completed iteration 23 of 64 (score = -0.75)
# 2019-08-05 15:51:46,609:INFO:tcre.exec.v1.optim: Completed iteration 24 of 64 (score = -0.758620689655172)
# 2019-08-05 15:52:02,016:INFO:tcre.exec.v1.optim: Completed iteration 25 of 64 (score = -0.75)
# 2019-08-05 15:52:18,705:INFO:tcre.exec.v1.optim: Completed iteration 26 of 64 (score = -0.689655172413793)
# 2019-08-05 15:52:34,184:INFO:tcre.exec.v1.optim: Completed iteration 27 of 64 (score = -0.7096774193548381)
# 2019-08-05 15:52:49,880:INFO:tcre.exec.v1.optim: Completed iteration 28 of 64 (score = -0.628571428571428)
# 2019-08-05 15:53:05,719:INFO:tcre.exec.v1.optim: Completed iteration 29 of 64 (score = -0.533333333333333)
# 2019-08-05 15:53:21,243:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/inducing_cytokine/checkpoints/checkpoint.pkl
# 2019-08-05 15:53:21,302:INFO:tcre.exec.v1.optim: Completed iteration 30 of 64 (score = -0.5882352941176471)
# 2019-08-05 15:53:37,549:INFO:tcre.exec.v1.optim: Completed iteration 31 of 64 (score = -0.7096774193548381)
# 2019-08-05 15:53:53,915:INFO:tcre.exec.v1.optim: Completed iteration 32 of 64 (score = -0.7428571428571431)
# 2019-08-05 15:54:09,531:INFO:tcre.exec.v1.optim: Completed iteration 33 of 64 (score = -0.74074074074074)
# 2019-08-05 15:54:25,211:INFO:tcre.exec.v1.optim: Completed iteration 34 of 64 (score = -0.7222222222222221)
# 2019-08-05 15:54:42,195:INFO:tcre.exec.v1.optim: Completed iteration 35 of 64 (score = -0.7368421052631571)
# 2019-08-05 15:54:57,564:INFO:tcre.exec.v1.optim: Completed iteration 36 of 64 (score = -0.648648648648648)
# 2019-08-05 15:55:14,079:INFO:tcre.exec.v1.optim: Completed iteration 37 of 64 (score = -0.648648648648648)
# 2019-08-05 15:55:28,712:INFO:tcre.exec.v1.optim: Completed iteration 38 of 64 (score = -0.5714285714285711)
# 2019-08-05 15:55:45,855:INFO:tcre.exec.v1.optim: Completed iteration 39 of 64 (score = -0.7333333333333331)
# 2019-08-05 15:56:01,715:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/inducing_cytokine/checkpoints/checkpoint.pkl
# 2019-08-05 15:56:01,781:INFO:tcre.exec.v1.optim: Completed iteration 40 of 64 (score = -0.7058823529411761)
# 2019-08-05 15:56:17,503:INFO:tcre.exec.v1.optim: Completed iteration 41 of 64 (score = -0.5945945945945941)
# 2019-08-05 15:56:32,689:INFO:tcre.exec.v1.optim: Completed iteration 42 of 64 (score = -0.6829268292682921)
# 2019-08-05 15:56:48,024:INFO:tcre.exec.v1.optim: Completed iteration 43 of 64 (score = -0.7428571428571431)
# 2019-08-05 15:57:04,355:INFO:tcre.exec.v1.optim: Completed iteration 44 of 64 (score = -0.689655172413793)
# 2019-08-05 15:57:20,048:INFO:tcre.exec.v1.optim: Completed iteration 45 of 64 (score = -0.6829268292682921)
# 2019-08-05 15:57:37,496:INFO:tcre.exec.v1.optim: Completed iteration 46 of 64 (score = -0.6875)
# 2019-08-05 15:57:53,934:INFO:tcre.exec.v1.optim: Completed iteration 47 of 64 (score = -0.642857142857142)
# 2019-08-05 15:58:09,840:INFO:tcre.exec.v1.optim: Completed iteration 48 of 64 (score = -0.758620689655172)
# 2019-08-05 15:58:25,587:INFO:tcre.exec.v1.optim: Completed iteration 49 of 64 (score = -0.764705882352941)
# 2019-08-05 15:58:42,415:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/inducing_cytokine/checkpoints/checkpoint.pkl
# 2019-08-05 15:58:42,492:INFO:tcre.exec.v1.optim: Completed iteration 50 of 64 (score = -0.6451612903225801)
# 2019-08-05 15:58:56,934:INFO:tcre.exec.v1.optim: Completed iteration 51 of 64 (score = -0.6060606060606061)
# 2019-08-05 15:59:12,662:INFO:tcre.exec.v1.optim: Completed iteration 52 of 64 (score = -0.6666666666666661)
# 2019-08-05 15:59:28,418:INFO:tcre.exec.v1.optim: Completed iteration 53 of 64 (score = -0.7000000000000001)
# 2019-08-05 15:59:43,561:INFO:tcre.exec.v1.optim: Completed iteration 54 of 64 (score = -0.7428571428571431)
# 2019-08-05 15:59:58,241:INFO:tcre.exec.v1.optim: Completed iteration 55 of 64 (score = -0.5454545454545451)
# 2019-08-05 16:00:13,500:INFO:tcre.exec.v1.optim: Completed iteration 56 of 64 (score = -0.7741935483870961)
# 2019-08-05 16:00:29,164:INFO:tcre.exec.v1.optim: Completed iteration 57 of 64 (score = -0.7096774193548381)
# 2019-08-05 16:00:47,008:INFO:tcre.exec.v1.optim: Completed iteration 58 of 64 (score = -0.74074074074074)
# 2019-08-05 16:01:02,006:INFO:tcre.exec.v1.optim: Completed iteration 59 of 64 (score = -0.7000000000000001)
# 2019-08-05 16:01:17,169:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/inducing_cytokine/checkpoints/checkpoint.pkl
# 2019-08-05 16:01:17,248:INFO:tcre.exec.v1.optim: Completed iteration 60 of 64 (score = -0.65)
# 2019-08-05 16:01:33,728:INFO:tcre.exec.v1.optim: Completed iteration 61 of 64 (score = -0.7058823529411761)
# 2019-08-05 16:01:49,629:INFO:tcre.exec.v1.optim: Completed iteration 62 of 64 (score = -0.685714285714285)
# 2019-08-05 16:02:05,474:INFO:tcre.exec.v1.optim: Completed iteration 63 of 64 (score = -0.7428571428571431)
# 2019-08-05 16:02:20,313:INFO:tcre.exec.v1.optim: Completed iteration 64 of 64 (score = -0.6829268292682921)
# 2019-08-05 16:02:20,473:INFO:root: Saved scores to /lab/data/results/gridsearch-dev/run3/inducing_cytokine/scores.feather
# 2019-08-05 16:02:20,474:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/inducing_cytokine/checkpoints/checkpoint.pkl
# 2019-08-05 16:02:20,569:INFO:root: Saved final result
# 2019-08-05 16:02:20,570:INFO:root: Running optimization for task secreted_cytokine
# 2019-08-05 16:02:20,571:INFO:tcre.exec.v1.optim: Beginning parameter search with max iterations 64
# 2019-08-05 16:02:37,052:INFO:tcre.exec.v1.optim: Completed iteration 1 of 64 (score = -0.7272727272727271)
# 2019-08-05 16:02:53,467:INFO:tcre.exec.v1.optim: Completed iteration 2 of 64 (score = -0.7272727272727271)
# 2019-08-05 16:03:11,670:INFO:tcre.exec.v1.optim: Completed iteration 3 of 64 (score = -0.775)
# 2019-08-05 16:03:30,006:INFO:tcre.exec.v1.optim: Completed iteration 4 of 64 (score = -0.75)
# 2019-08-05 16:03:47,488:INFO:tcre.exec.v1.optim: Completed iteration 5 of 64 (score = -0.75)
# 2019-08-05 16:04:05,293:INFO:tcre.exec.v1.optim: Completed iteration 6 of 64 (score = -0.7222222222222221)
# 2019-08-05 16:04:23,223:INFO:tcre.exec.v1.optim: Completed iteration 7 of 64 (score = -0.712643678160919)
# 2019-08-05 16:04:42,902:INFO:tcre.exec.v1.optim: Completed iteration 8 of 64 (score = -0.753246753246753)
# 2019-08-05 16:04:59,478:INFO:tcre.exec.v1.optim: Completed iteration 9 of 64 (score = -0.753623188405797)
# 2019-08-05 16:05:17,642:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/secreted_cytokine/checkpoints/checkpoint.pkl
# 2019-08-05 16:05:17,668:INFO:tcre.exec.v1.optim: Completed iteration 10 of 64 (score = -0.769230769230769)
# 2019-08-05 16:05:33,464:INFO:tcre.exec.v1.optim: Completed iteration 11 of 64 (score = -0.756756756756756)
# 2019-08-05 16:05:50,107:INFO:tcre.exec.v1.optim: Completed iteration 12 of 64 (score = -0.676056338028169)
# 2019-08-05 16:06:06,389:INFO:tcre.exec.v1.optim: Completed iteration 13 of 64 (score = -0.7070707070707071)
# 2019-08-05 16:06:22,790:INFO:tcre.exec.v1.optim: Completed iteration 14 of 64 (score = -0.7446808510638291)
# 2019-08-05 16:06:39,967:INFO:tcre.exec.v1.optim: Completed iteration 15 of 64 (score = -0.6875)
# 2019-08-05 16:06:57,721:INFO:tcre.exec.v1.optim: Completed iteration 16 of 64 (score = -0.7733333333333331)
# 2019-08-05 16:07:16,516:INFO:tcre.exec.v1.optim: Completed iteration 17 of 64 (score = -0.756756756756756)
# 2019-08-05 16:07:34,847:INFO:tcre.exec.v1.optim: Completed iteration 18 of 64 (score = -0.7246376811594201)
# 2019-08-05 16:07:54,578:INFO:tcre.exec.v1.optim: Completed iteration 19 of 64 (score = -0.6575342465753421)
# 2019-08-05 16:08:11,999:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/secreted_cytokine/checkpoints/checkpoint.pkl
# 2019-08-05 16:08:12,041:INFO:tcre.exec.v1.optim: Completed iteration 20 of 64 (score = -0.75)
# 2019-08-05 16:08:30,299:INFO:tcre.exec.v1.optim: Completed iteration 21 of 64 (score = -0.7250000000000001)
# 2019-08-05 16:08:47,108:INFO:tcre.exec.v1.optim: Completed iteration 22 of 64 (score = -0.704225352112676)
# 2019-08-05 16:09:08,021:INFO:tcre.exec.v1.optim: Completed iteration 23 of 64 (score = -0.696969696969697)
# 2019-08-05 16:09:24,584:INFO:tcre.exec.v1.optim: Completed iteration 24 of 64 (score = -0.696969696969697)
# 2019-08-05 16:09:41,090:INFO:tcre.exec.v1.optim: Completed iteration 25 of 64 (score = -0.7368421052631581)
# 2019-08-05 16:09:58,944:INFO:tcre.exec.v1.optim: Completed iteration 26 of 64 (score = -0.75)
# 2019-08-05 16:10:17,671:INFO:tcre.exec.v1.optim: Completed iteration 27 of 64 (score = -0.718749999999999)
# 2019-08-05 16:10:33,835:INFO:tcre.exec.v1.optim: Completed iteration 28 of 64 (score = -0.75)
# 2019-08-05 16:10:52,043:INFO:tcre.exec.v1.optim: Completed iteration 29 of 64 (score = -0.7222222222222221)
# 2019-08-05 16:11:09,700:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/secreted_cytokine/checkpoints/checkpoint.pkl
# 2019-08-05 16:11:09,762:INFO:tcre.exec.v1.optim: Completed iteration 30 of 64 (score = -0.756756756756756)
# 2019-08-05 16:11:26,423:INFO:tcre.exec.v1.optim: Completed iteration 31 of 64 (score = -0.704225352112676)
# 2019-08-05 16:11:43,631:INFO:tcre.exec.v1.optim: Completed iteration 32 of 64 (score = -0.657142857142857)
# 2019-08-05 16:12:01,062:INFO:tcre.exec.v1.optim: Completed iteration 33 of 64 (score = -0.753623188405797)
# 2019-08-05 16:12:18,491:INFO:tcre.exec.v1.optim: Completed iteration 34 of 64 (score = -0.7058823529411761)
# 2019-08-05 16:12:37,627:INFO:tcre.exec.v1.optim: Completed iteration 35 of 64 (score = -0.753623188405797)
# 2019-08-05 16:12:54,444:INFO:tcre.exec.v1.optim: Completed iteration 36 of 64 (score = -0.75)
# 2019-08-05 16:13:10,209:INFO:tcre.exec.v1.optim: Completed iteration 37 of 64 (score = -0.7671232876712321)
# 2019-08-05 16:13:28,271:INFO:tcre.exec.v1.optim: Completed iteration 38 of 64 (score = -0.7058823529411761)
# 2019-08-05 16:13:46,200:INFO:tcre.exec.v1.optim: Completed iteration 39 of 64 (score = -0.7837837837837831)
# 2019-08-05 16:14:02,680:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/secreted_cytokine/checkpoints/checkpoint.pkl
# 2019-08-05 16:14:02,733:INFO:tcre.exec.v1.optim: Completed iteration 40 of 64 (score = -0.732394366197183)
# 2019-08-05 16:14:18,941:INFO:tcre.exec.v1.optim: Completed iteration 41 of 64 (score = -0.7435897435897431)
# 2019-08-05 16:14:38,772:INFO:tcre.exec.v1.optim: Completed iteration 42 of 64 (score = -0.7272727272727271)
# 2019-08-05 16:14:56,787:INFO:tcre.exec.v1.optim: Completed iteration 43 of 64 (score = -0.757575757575757)
# 2019-08-05 16:15:14,078:INFO:tcre.exec.v1.optim: Completed iteration 44 of 64 (score = -0.7199999999999991)
# 2019-08-05 16:15:31,776:INFO:tcre.exec.v1.optim: Completed iteration 45 of 64 (score = -0.7671232876712321)
# 2019-08-05 16:15:52,684:INFO:tcre.exec.v1.optim: Completed iteration 46 of 64 (score = -0.6753246753246751)
# 2019-08-05 16:16:11,345:INFO:tcre.exec.v1.optim: Completed iteration 47 of 64 (score = -0.7352941176470581)
# 2019-08-05 16:16:29,681:INFO:tcre.exec.v1.optim: Completed iteration 48 of 64 (score = -0.6944444444444441)
# 2019-08-05 16:16:46,064:INFO:tcre.exec.v1.optim: Completed iteration 49 of 64 (score = -0.73972602739726)
# 2019-08-05 16:17:02,559:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/secreted_cytokine/checkpoints/checkpoint.pkl
# 2019-08-05 16:17:02,637:INFO:tcre.exec.v1.optim: Completed iteration 50 of 64 (score = -0.729729729729729)
# 2019-08-05 16:17:20,772:INFO:tcre.exec.v1.optim: Completed iteration 51 of 64 (score = -0.6944444444444441)
# 2019-08-05 16:17:37,632:INFO:tcre.exec.v1.optim: Completed iteration 52 of 64 (score = -0.647887323943662)
# 2019-08-05 16:17:53,111:INFO:tcre.exec.v1.optim: Completed iteration 53 of 64 (score = -0.75)
# 2019-08-05 16:18:10,104:INFO:tcre.exec.v1.optim: Completed iteration 54 of 64 (score = -0.6575342465753421)
# 2019-08-05 16:18:27,800:INFO:tcre.exec.v1.optim: Completed iteration 55 of 64 (score = -0.6666666666666661)
# 2019-08-05 16:18:44,215:INFO:tcre.exec.v1.optim: Completed iteration 56 of 64 (score = -0.738095238095238)
# 2019-08-05 16:19:03,004:INFO:tcre.exec.v1.optim: Completed iteration 57 of 64 (score = -0.788732394366197)
# 2019-08-05 16:19:23,985:INFO:tcre.exec.v1.optim: Completed iteration 58 of 64 (score = -0.795180722891566)
# 2019-08-05 16:19:39,489:INFO:tcre.exec.v1.optim: Completed iteration 59 of 64 (score = -0.7222222222222221)
# 2019-08-05 16:19:57,369:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/secreted_cytokine/checkpoints/checkpoint.pkl
# 2019-08-05 16:19:57,458:INFO:tcre.exec.v1.optim: Completed iteration 60 of 64 (score = -0.6746987951807231)
# 2019-08-05 16:20:16,049:INFO:tcre.exec.v1.optim: Completed iteration 61 of 64 (score = -0.7096774193548381)
# 2019-08-05 16:20:32,575:INFO:tcre.exec.v1.optim: Completed iteration 62 of 64 (score = -0.6756756756756751)
# 2019-08-05 16:20:48,735:INFO:tcre.exec.v1.optim: Completed iteration 63 of 64 (score = -0.6756756756756751)
# 2019-08-05 16:21:06,947:INFO:tcre.exec.v1.optim: Completed iteration 64 of 64 (score = -0.676470588235294)
# 2019-08-05 16:21:07,032:INFO:root: Saved scores to /lab/data/results/gridsearch-dev/run3/secreted_cytokine/scores.feather
# 2019-08-05 16:21:07,033:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/secreted_cytokine/checkpoints/checkpoint.pkl
# 2019-08-05 16:21:07,127:INFO:root: Saved final result
# 2019-08-05 16:21:07,128:INFO:root: Running optimization for task inducing_transcription_factor
# 2019-08-05 16:21:07,129:INFO:tcre.exec.v1.optim: Beginning parameter search with max iterations 64
# 2019-08-05 16:21:23,634:INFO:tcre.exec.v1.optim: Completed iteration 1 of 64 (score = -0.7294117647058821)
# 2019-08-05 16:21:41,371:INFO:tcre.exec.v1.optim: Completed iteration 2 of 64 (score = -0.7391304347826081)
# 2019-08-05 16:21:57,946:INFO:tcre.exec.v1.optim: Completed iteration 3 of 64 (score = -0.6888888888888881)
# 2019-08-05 16:22:16,936:INFO:tcre.exec.v1.optim: Completed iteration 4 of 64 (score = -0.658227848101265)
# 2019-08-05 16:22:35,562:INFO:tcre.exec.v1.optim: Completed iteration 5 of 64 (score = -0.6756756756756751)
# 2019-08-05 16:22:51,320:INFO:tcre.exec.v1.optim: Completed iteration 6 of 64 (score = -0.659793814432989)
# 2019-08-05 16:23:07,521:INFO:tcre.exec.v1.optim: Completed iteration 7 of 64 (score = -0.703296703296703)
# 2019-08-05 16:23:24,668:INFO:tcre.exec.v1.optim: Completed iteration 8 of 64 (score = -0.704545454545454)
# 2019-08-05 16:23:40,209:INFO:tcre.exec.v1.optim: Completed iteration 9 of 64 (score = -0.635294117647058)
# 2019-08-05 16:23:57,423:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/inducing_transcription_factor/checkpoints/checkpoint.pkl
# 2019-08-05 16:23:57,454:INFO:tcre.exec.v1.optim: Completed iteration 10 of 64 (score = -0.6753246753246751)
# 2019-08-05 16:24:13,816:INFO:tcre.exec.v1.optim: Completed iteration 11 of 64 (score = -0.69047619047619)
# 2019-08-05 16:24:29,925:INFO:tcre.exec.v1.optim: Completed iteration 12 of 64 (score = -0.7341772151898731)
# 2019-08-05 16:24:45,618:INFO:tcre.exec.v1.optim: Completed iteration 13 of 64 (score = -0.6976744186046511)
# 2019-08-05 16:25:02,027:INFO:tcre.exec.v1.optim: Completed iteration 14 of 64 (score = -0.744186046511627)
# 2019-08-05 16:25:17,343:INFO:tcre.exec.v1.optim: Completed iteration 15 of 64 (score = -0.630434782608695)
# 2019-08-05 16:25:35,679:INFO:tcre.exec.v1.optim: Completed iteration 16 of 64 (score = -0.704545454545454)
# 2019-08-05 16:25:50,905:INFO:tcre.exec.v1.optim: Completed iteration 17 of 64 (score = -0.703296703296703)
# 2019-08-05 16:26:06,619:INFO:tcre.exec.v1.optim: Completed iteration 18 of 64 (score = -0.689655172413793)
# 2019-08-05 16:26:22,780:INFO:tcre.exec.v1.optim: Completed iteration 19 of 64 (score = -0.738095238095238)
# 2019-08-05 16:26:43,983:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/inducing_transcription_factor/checkpoints/checkpoint.pkl
# 2019-08-05 16:26:44,032:INFO:tcre.exec.v1.optim: Completed iteration 20 of 64 (score = -0.7142857142857141)
# 2019-08-05 16:27:00,439:INFO:tcre.exec.v1.optim: Completed iteration 21 of 64 (score = -0.6947368421052631)
# 2019-08-05 16:27:16,751:INFO:tcre.exec.v1.optim: Completed iteration 22 of 64 (score = -0.683544303797468)
# 2019-08-05 16:27:32,358:INFO:tcre.exec.v1.optim: Completed iteration 23 of 64 (score = -0.7272727272727271)
# 2019-08-05 16:27:48,098:INFO:tcre.exec.v1.optim: Completed iteration 24 of 64 (score = -0.6818181818181811)
# 2019-08-05 16:28:04,474:INFO:tcre.exec.v1.optim: Completed iteration 25 of 64 (score = -0.698795180722891)
# 2019-08-05 16:28:21,769:INFO:tcre.exec.v1.optim: Completed iteration 26 of 64 (score = -0.6666666666666661)
# 2019-08-05 16:28:38,413:INFO:tcre.exec.v1.optim: Completed iteration 27 of 64 (score = -0.6666666666666661)
# 2019-08-05 16:28:53,955:INFO:tcre.exec.v1.optim: Completed iteration 28 of 64 (score = -0.69047619047619)
# 2019-08-05 16:29:10,197:INFO:tcre.exec.v1.optim: Completed iteration 29 of 64 (score = -0.611111111111111)
# 2019-08-05 16:29:25,757:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/inducing_transcription_factor/checkpoints/checkpoint.pkl
# 2019-08-05 16:29:25,811:INFO:tcre.exec.v1.optim: Completed iteration 30 of 64 (score = -0.6966292134831461)
# 2019-08-05 16:29:43,113:INFO:tcre.exec.v1.optim: Completed iteration 31 of 64 (score = -0.6756756756756751)
# 2019-08-05 16:29:59,391:INFO:tcre.exec.v1.optim: Completed iteration 32 of 64 (score = -0.716049382716049)
# 2019-08-05 16:30:17,193:INFO:tcre.exec.v1.optim: Completed iteration 33 of 64 (score = -0.710526315789473)
# 2019-08-05 16:30:33,841:INFO:tcre.exec.v1.optim: Completed iteration 34 of 64 (score = -0.695652173913043)
# 2019-08-05 16:30:51,996:INFO:tcre.exec.v1.optim: Completed iteration 35 of 64 (score = -0.70886075949367)
# 2019-08-05 16:31:07,479:INFO:tcre.exec.v1.optim: Completed iteration 36 of 64 (score = -0.703296703296703)
# 2019-08-05 16:31:23,151:INFO:tcre.exec.v1.optim: Completed iteration 37 of 64 (score = -0.72289156626506)
# 2019-08-05 16:31:42,373:INFO:tcre.exec.v1.optim: Completed iteration 38 of 64 (score = -0.64)
# 2019-08-05 16:31:59,145:INFO:tcre.exec.v1.optim: Completed iteration 39 of 64 (score = -0.6666666666666661)
# 2019-08-05 16:32:15,909:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/inducing_transcription_factor/checkpoints/checkpoint.pkl
# 2019-08-05 16:32:15,974:INFO:tcre.exec.v1.optim: Completed iteration 40 of 64 (score = -0.673684210526315)
# 2019-08-05 16:32:31,390:INFO:tcre.exec.v1.optim: Completed iteration 41 of 64 (score = -0.689655172413793)
# 2019-08-05 16:32:47,195:INFO:tcre.exec.v1.optim: Completed iteration 42 of 64 (score = -0.703296703296703)
# 2019-08-05 16:33:03,446:INFO:tcre.exec.v1.optim: Completed iteration 43 of 64 (score = -0.7142857142857141)
# 2019-08-05 16:33:19,916:INFO:tcre.exec.v1.optim: Completed iteration 44 of 64 (score = -0.6753246753246751)
# 2019-08-05 16:33:35,435:INFO:tcre.exec.v1.optim: Completed iteration 45 of 64 (score = -0.703296703296703)
# 2019-08-05 16:33:51,572:INFO:tcre.exec.v1.optim: Completed iteration 46 of 64 (score = -0.7027027027027021)
# 2019-08-05 16:34:09,132:INFO:tcre.exec.v1.optim: Completed iteration 47 of 64 (score = -0.683544303797468)
# 2019-08-05 16:34:26,753:INFO:tcre.exec.v1.optim: Completed iteration 48 of 64 (score = -0.7294117647058821)
# 2019-08-05 16:34:43,102:INFO:tcre.exec.v1.optim: Completed iteration 49 of 64 (score = -0.704545454545454)
# 2019-08-05 16:34:58,689:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/inducing_transcription_factor/checkpoints/checkpoint.pkl
# 2019-08-05 16:34:58,771:INFO:tcre.exec.v1.optim: Completed iteration 50 of 64 (score = -0.703296703296703)
# 2019-08-05 16:35:15,091:INFO:tcre.exec.v1.optim: Completed iteration 51 of 64 (score = -0.632911392405063)
# 2019-08-05 16:35:30,756:INFO:tcre.exec.v1.optim: Completed iteration 52 of 64 (score = -0.7250000000000001)
# 2019-08-05 16:35:46,874:INFO:tcre.exec.v1.optim: Completed iteration 53 of 64 (score = -0.6666666666666661)
# 2019-08-05 16:36:03,391:INFO:tcre.exec.v1.optim: Completed iteration 54 of 64 (score = -0.6976744186046511)
# 2019-08-05 16:36:19,092:INFO:tcre.exec.v1.optim: Completed iteration 55 of 64 (score = -0.597402597402597)
# 2019-08-05 16:36:34,722:INFO:tcre.exec.v1.optim: Completed iteration 56 of 64 (score = -0.717391304347826)
# 2019-08-05 16:36:50,765:INFO:tcre.exec.v1.optim: Completed iteration 57 of 64 (score = -0.698795180722891)
# 2019-08-05 16:37:09,473:INFO:tcre.exec.v1.optim: Completed iteration 58 of 64 (score = -0.719101123595505)
# 2019-08-05 16:37:25,335:INFO:tcre.exec.v1.optim: Completed iteration 59 of 64 (score = -0.717391304347826)
# 2019-08-05 16:37:40,751:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/inducing_transcription_factor/checkpoints/checkpoint.pkl
# 2019-08-05 16:37:40,842:INFO:tcre.exec.v1.optim: Completed iteration 60 of 64 (score = -0.6666666666666661)
# 2019-08-05 16:37:58,067:INFO:tcre.exec.v1.optim: Completed iteration 61 of 64 (score = -0.6666666666666661)
# 2019-08-05 16:38:13,979:INFO:tcre.exec.v1.optim: Completed iteration 62 of 64 (score = -0.651685393258427)
# 2019-08-05 16:38:30,618:INFO:tcre.exec.v1.optim: Completed iteration 63 of 64 (score = -0.675)
# 2019-08-05 16:38:46,530:INFO:tcre.exec.v1.optim: Completed iteration 64 of 64 (score = -0.659340659340659)
# 2019-08-05 16:38:46,609:INFO:root: Saved scores to /lab/data/results/gridsearch-dev/run3/inducing_transcription_factor/scores.feather
# 2019-08-05 16:38:46,610:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/gridsearch-dev/run3/inducing_transcription_factor/checkpoints/checkpoint.pkl
# 2019-08-05 16:38:46,685:INFO:root: Saved final result

# %%
print(tasks[0])
res, scores, callbacks = results[tasks[0]]
# Out:
# inducing_cytokine

# %%
times = callbacks['timer'].iter_time
pd.Series(times).describe()
# Out:
# count     64.000000
# mean      24.054052
# std       46.921990
# min       14.442801
# 25%       15.461235
# 50%       15.760679
# 75%       16.448348
# max      337.113783
# dtype: float64

# %%
res.func_vals[:5]
# Out:
# array([-0.70967742, -0.68421053, -0.66666667, -0.54545455, -0.625     ])

# %%
pd.DataFrame(res.x_iters[:5], columns=[dim.name for dim in space])
# Out:
#   marker_list  use_secondary  use_swaps  use_positions wrd_embedding_type  \
# 0     doub_01           True       True           True        w2v_trained
# 1     doub_01          False       True           True        w2v_trained
# 2     doub_01          False       True           True         w2v_frozen
# 3     doub_01          False       True           True        w2v_trained
# 4     doub_01           True       True           True        w2v_trained
#
#   model_size  weight_decay  learning_rate  dropout cell_type  bidirectional
# 0       XXXL         0.000          0.010     0.75      LSTM          False
# 1       XXXL         0.005          0.050     0.25      LSTM          False
# 2      XXXXL         0.005          0.010     0.00      LSTM          False
# 3         XL         0.005          0.005     0.75      LSTM          False
# 4      XXXXL         0.001          0.005     0.00      LSTM          False

# %%
res.models[:5]
# Out:
# []

# %% [markdown]
# ## Analysis

# %%
output_dir
# Out:
# '/lab/data/results/gridsearch-dev/run3'

# %%
# !ls $output_dir
# Out:
# inducing_cytokine	       secreted_cytokine
# inducing_transcription_factor  top_model_configurations.json

# %%
import skopt
# Restore from serialized data

results = {}
for task in tasks:
    optimizer = optimizers[task]
    res = skopt.load(optimizer.get_checkpoints_file())
    
    scores = None
    scores_file = osp.join(optimizer.output_dir, 'scores.feather')
    if osp.exists(scores_file):
        scores = pd.read_feather(scores_file)
    
    results[task] = res, scores, globals().get('times')

# %%
def get_dfx(results):
    df = []
    for k in results:
        res = results[k][0]
        dfx = pd.DataFrame(res.x_iters, columns=[dim.name for dim in space])
        dfx['score'] = -res.func_vals
        dfx['task'] = k
        dfx['iteration'] = np.arange(len(dfx))
        df.append(dfx)
    return pd.concat(df)

# %%
dfx = get_dfx(results)
props = dfx.drop(['score', 'task', 'iteration'], axis=1).columns.tolist()
print(props)
dfx.head()
# Out:
# ['marker_list', 'use_secondary', 'use_swaps', 'use_positions', 'wrd_embedding_type', 'model_size', 'weight_decay', 'learning_rate', 'dropout', 'cell_type', 'bidirectional']
#   marker_list  use_secondary  use_swaps  use_positions wrd_embedding_type  \
# 0     doub_01           True       True           True        w2v_trained
# 1     doub_01          False       True           True        w2v_trained
# 2     doub_01          False       True           True         w2v_frozen
# 3     doub_01          False       True           True        w2v_trained
# 4     doub_01           True       True           True        w2v_trained
#
#   model_size  weight_decay  learning_rate  dropout cell_type  bidirectional  \
# 0       XXXL         0.000          0.010     0.75      LSTM          False
# 1       XXXL         0.005          0.050     0.25      LSTM          False
# 2      XXXXL         0.005          0.010     0.00      LSTM          False
# 3         XL         0.005          0.005     0.75      LSTM          False
# 4      XXXXL         0.001          0.005     0.00      LSTM          False
#
#       score               task  iteration
# 0  0.709677  inducing_cytokine          0
# 1  0.684211  inducing_cytokine          1
# 2  0.666667  inducing_cytokine          2
# 3  0.545455  inducing_cytokine          3
# 4  0.625000  inducing_cytokine          4

# %%
# Show top configs by task
pd.set_option('display.max_rows', 100)
dfx.groupby('task').apply(lambda g: g.sort_values('score', ascending=False).iloc[:8].reset_index(drop=True)).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_44f2594a_b7a0_11e9_a38e_0242ac110002row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row0_col8 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row0_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row0_col13 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row1_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row1_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row1_col8 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row1_col11 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row1_col13 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row2_col6 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row2_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row2_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row2_col11 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row2_col13 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row3_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row3_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row3_col8 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row3_col11 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row3_col13 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row4_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row4_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row4_col8 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row4_col11 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row4_col13 {
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row5_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row5_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row5_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row5_col11 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row5_col13 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row6_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row6_col7 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row6_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row6_col11 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row6_col13 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row7_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row7_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row7_col8 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row7_col11 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row7_col13 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row8_col6 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row8_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row8_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row8_col11 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row8_col13 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row9_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row9_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row9_col8 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row9_col11 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row9_col13 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row10_col6 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row10_col7 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row10_col8 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row10_col11 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row10_col13 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row11_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row11_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row11_col8 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row11_col11 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_44f2594a_b7a0_11e9_a38e_0242ac110002row11_col13 {
#             background-color:  #dddbec

# %% [markdown]
# ### Parameter Regression

# %%
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, message='The default of the `iid` parameter.*')

def get_coefs(est):
    coefs = []
    grps = dfx.groupby(['task'])
    fig, axs = plt.subplots(1, len(grps))
    if len(grps) == 1:
        axs = [axs]
    fig.set_size_inches(18, 4)
    for i, (k, g) in enumerate(grps):
        X = pd.get_dummies(g.drop(['task', 'iteration', 'score'], axis=1).astype(str), prefix_sep=':')
        y = g['score'].values
        est = est.fit(X.values, y)
        y_pred = est.predict(X)
        score = max(r2_score(y, y_pred), 0)
        title = f'{est.__class__.__name__} {k} (R2={score:.2f})'
        pd.DataFrame({'y_true': y, 'y_pred': y_pred}).plot(kind='scatter', x='y_pred', y='y_true', ax=axs[i], title=title)
        coefs.append(
            pd.Series(est.coef_, index=X.columns.to_list()).sort_index()
            .append(pd.Series(dict(task=k, score=score, est=est.__class__.__name__)))
        )
    return est, pd.DataFrame(coefs)

def plot_coefs(est, coefs):
    return (
        pn.ggplot(
            coefs
                .set_index('task').rename_axis('metric', axis='columns').stack().rename('value').reset_index()
                .assign(metric=lambda df: pd.Categorical(df['metric'], ordered=True, categories=df.groupby('metric')['value'].mean().sort_values().index)), 
            pn.aes(x='metric', y='value', fill='task', color='task', group='task')
        ) + 
        pn.geom_point() +
        pn.geom_line() + 
        pn.ggtitle(type(est).__name__) + 
        pn.theme(figure_size=(12, 4), axis_text_x=pn.element_text(rotation=90, hjust=.5))
    )

# %%
from sklearn.linear_model import LassoCV, RidgeCV, ElasticNetCV

# %%
df_coef = pd.concat([
    get_coefs(RidgeCV(normalize=True, cv=5))[1],
    get_coefs(LassoCV(normalize=True, cv=5, random_state=1))[1],
    get_coefs(ElasticNetCV(normalize=True, cv=5, random_state=1))[1]
])

# Add weight for each model as R2 for model / R2 for all models
df_coef = df_coef.groupby('task', group_keys=False).apply(lambda g: g.assign(weight=(g['score'] / g['score'].sum())))
df_coef = df_coef.set_index(['task', 'score', 'est', 'weight'])

df_coef.head()
# Out:
#                                                               bidirectional:False  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244                  0.0
#                               0.753784 LassoCV      0.329994                  0.0
#                               0.750970 ElasticNetCV 0.328762                  0.0
# inducing_transcription_factor 0.350117 RidgeCV      0.320635                  0.0
#                               0.371663 LassoCV      0.340367                  0.0
#
#                                                               cell_type:LSTM  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244             0.0
#                               0.753784 LassoCV      0.329994             0.0
#                               0.750970 ElasticNetCV 0.328762             0.0
# inducing_transcription_factor 0.350117 RidgeCV      0.320635             0.0
#                               0.371663 LassoCV      0.340367             0.0
#
#                                                               dropout:0.0  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244    -0.013845
#                               0.753784 LassoCV      0.329994    -0.009922
#                               0.750970 ElasticNetCV 0.328762    -0.009847
# inducing_transcription_factor 0.350117 RidgeCV      0.320635    -0.002142
#                               0.371663 LassoCV      0.340367    -0.000000
#
#                                                               dropout:0.25  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244      0.004493
#                               0.753784 LassoCV      0.329994      0.000000
#                               0.750970 ElasticNetCV 0.328762      0.000000
# inducing_transcription_factor 0.350117 RidgeCV      0.320635      0.005822
#                               0.371663 LassoCV      0.340367      0.007329
#
#                                                               dropout:0.5  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244     0.010436
#                               0.753784 LassoCV      0.329994     0.004386
#                               0.750970 ElasticNetCV 0.328762     0.004124
# inducing_transcription_factor 0.350117 RidgeCV      0.320635    -0.001953
#                               0.371663 LassoCV      0.340367    -0.000000
#
#                                                               dropout:0.75  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244     -0.004413
#                               0.753784 LassoCV      0.329994     -0.000000
#                               0.750970 ElasticNetCV 0.328762     -0.000000
# inducing_transcription_factor 0.350117 RidgeCV      0.320635     -0.001161
#                               0.371663 LassoCV      0.340367     -0.000000
#
#                                                               learning_rate:0.005  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244            -0.011590
#                               0.753784 LassoCV      0.329994            -0.000000
#                               0.750970 ElasticNetCV 0.328762            -0.000000
# inducing_transcription_factor 0.350117 RidgeCV      0.320635            -0.000334
#                               0.371663 LassoCV      0.340367            -0.000000
#
#                                                               learning_rate:0.01  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244           -0.016396
#                               0.753784 LassoCV      0.329994           -0.000950
#                               0.750970 ElasticNetCV 0.328762           -0.001563
# inducing_transcription_factor 0.350117 RidgeCV      0.320635           -0.004109
#                               0.371663 LassoCV      0.340367           -0.002475
#
#                                                               learning_rate:0.05  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244            0.026408
#                               0.753784 LassoCV      0.329994            0.036167
#                               0.750970 ElasticNetCV 0.328762            0.034881
# inducing_transcription_factor 0.350117 RidgeCV      0.320635            0.003906
#                               0.371663 LassoCV      0.340367            0.004033
#
#                                                               marker_list:doub_01  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244                  0.0
#                               0.753784 LassoCV      0.329994                  0.0
#                               0.750970 ElasticNetCV 0.328762                  0.0
# inducing_transcription_factor 0.350117 RidgeCV      0.320635                  0.0
#                               0.371663 LassoCV      0.340367                  0.0
#
#                                                               ...  \
# task                          score    est          weight    ...
# inducing_cytokine             0.779481 RidgeCV      0.341244  ...
#                               0.753784 LassoCV      0.329994  ...
#                               0.750970 ElasticNetCV 0.328762  ...
# inducing_transcription_factor 0.350117 RidgeCV      0.320635  ...
#                               0.371663 LassoCV      0.340367  ...
#
#                                                               use_positions:True  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244                 0.0
#                               0.753784 LassoCV      0.329994                 0.0
#                               0.750970 ElasticNetCV 0.328762                 0.0
# inducing_transcription_factor 0.350117 RidgeCV      0.320635                 0.0
#                               0.371663 LassoCV      0.340367                 0.0
#
#                                                               use_secondary:False  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244            -0.041002
#                               0.753784 LassoCV      0.329994            -0.082307
#                               0.750970 ElasticNetCV 0.328762            -0.040554
# inducing_transcription_factor 0.350117 RidgeCV      0.320635            -0.006853
#                               0.371663 LassoCV      0.340367            -0.016869
#
#                                                               use_secondary:True  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244            0.041002
#                               0.753784 LassoCV      0.329994            0.000000
#                               0.750970 ElasticNetCV 0.328762            0.040416
# inducing_transcription_factor 0.350117 RidgeCV      0.320635            0.006853
#                               0.371663 LassoCV      0.340367            0.000000
#
#                                                               use_swaps:True  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244             0.0
#                               0.753784 LassoCV      0.329994             0.0
#                               0.750970 ElasticNetCV 0.328762             0.0
# inducing_transcription_factor 0.350117 RidgeCV      0.320635             0.0
#                               0.371663 LassoCV      0.340367             0.0
#
#                                                               weight_decay:0.0  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244         -0.008726
#                               0.753784 LassoCV      0.329994         -0.004784
#                               0.750970 ElasticNetCV 0.328762         -0.004703
# inducing_transcription_factor 0.350117 RidgeCV      0.320635         -0.006955
#                               0.371663 LassoCV      0.340367         -0.010509
#
#                                                               weight_decay:0.0001  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244             0.001588
#                               0.753784 LassoCV      0.329994             0.000000
#                               0.750970 ElasticNetCV 0.328762             0.000000
# inducing_transcription_factor 0.350117 RidgeCV      0.320635            -0.002314
#                               0.371663 LassoCV      0.340367            -0.000000
#
#                                                               weight_decay:0.001  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244            0.007312
#                               0.753784 LassoCV      0.329994            0.000000
#                               0.750970 ElasticNetCV 0.328762            0.000000
# inducing_transcription_factor 0.350117 RidgeCV      0.320635            0.001951
#                               0.371663 LassoCV      0.340367            0.000000
#
#                                                               weight_decay:0.005  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244            0.000306
#                               0.753784 LassoCV      0.329994            0.000000
#                               0.750970 ElasticNetCV 0.328762            0.000000
# inducing_transcription_factor 0.350117 RidgeCV      0.320635            0.006873
#                               0.371663 LassoCV      0.340367            0.008760
#
#                                                               wrd_embedding_type:w2v_frozen  \
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244                       0.003108
#                               0.753784 LassoCV      0.329994                       0.000000
#                               0.750970 ElasticNetCV 0.328762                       0.000000
# inducing_transcription_factor 0.350117 RidgeCV      0.320635                      -0.002551
#                               0.371663 LassoCV      0.340367                      -0.003961
#
#                                                               wrd_embedding_type:w2v_trained
# task                          score    est          weight
# inducing_cytokine             0.779481 RidgeCV      0.341244                       -0.003108
#                               0.753784 LassoCV      0.329994                       -0.000000
#                               0.750970 ElasticNetCV 0.328762                       -0.000000
# inducing_transcription_factor 0.350117 RidgeCV      0.320635                        0.002551
#                               0.371663 LassoCV      0.340367                        0.000000
#
# [5 rows x 24 columns]

# %%
df_coef_lng = df_coef.rename_axis('parameter', axis='columns').stack().rename('value').reset_index()
df_coef_lng['weighted_value'] = df_coef_lng['value'] * df_coef_lng['weight']
df_coef_lng.head()
# Out:
#                 task     score      est    weight            parameter  \
# 0  inducing_cytokine  0.779481  RidgeCV  0.341244  bidirectional:False
# 1  inducing_cytokine  0.779481  RidgeCV  0.341244       cell_type:LSTM
# 2  inducing_cytokine  0.779481  RidgeCV  0.341244          dropout:0.0
# 3  inducing_cytokine  0.779481  RidgeCV  0.341244         dropout:0.25
# 4  inducing_cytokine  0.779481  RidgeCV  0.341244          dropout:0.5
#
#       value  weighted_value
# 0  0.000000        0.000000
# 1  0.000000        0.000000
# 2 -0.013845       -0.004725
# 3  0.004493        0.001533
# 4  0.010436        0.003561

# %%
(
    pn.ggplot(
        df_coef_lng.assign(parameter=lambda df: pd.Categorical(
            df['parameter'], ordered=True, 
            categories=df.groupby('parameter')['weighted_value'].mean().sort_values().index
        )), 
        pn.aes(x='parameter', y='value', fill='task', color='task', group='task')
    ) + 
    pn.geom_point() +
    pn.geom_line() + 
    pn.ggtitle('Parameter Coefficients by Model') + 
    pn.facet_wrap('~ est', ncol=1) +
    pn.theme(figure_size=(12, 8), axis_text_x=pn.element_text(rotation=90, hjust=.5))
)
# Out:
# <ggplot: (-9223363252856996103)>

# %% [markdown]
# ### Score Distributions

# %%
df_score = pd.concat([v[1].assign(task=k) for k, v in results.items()])
df_score.head()
# Out:
#    iteration  type    metric      value               task
# 0          0           epoch   2.000000  inducing_cytokine
# 1          0  test  accuracy   0.560000  inducing_cytokine
# 2          0  test        ct  50.000000  inducing_cytokine
# 3          0  test        f1   0.656250  inducing_cytokine
# 4          0  test      loss   0.781614  inducing_cytokine

# %%
# Label balance
df_lbl = df_cand.assign(label=lambda df: np.where(df['label'] > 0, 1, 0))
pd.concat([
    df_lbl.assign(agg='count').groupby(['task', 'split', 'agg'])['label'].value_counts().unstack([-2, -1]),
    df_lbl.assign(agg='percent').groupby(['task', 'split', 'agg'])['label'].value_counts(normalize=True).unstack([-2, -1]).round(2)
], axis=1)
# Out:
# agg                                   count      percent
# label                                     0    1       0     1
# task                          split
# inducing_cytokine             predict   189   14    0.93  0.07
#                               test      246   25    0.91  0.09
#                               train     813  137    0.86  0.14
#                               val       189   14    0.93  0.07
# inducing_transcription_factor predict   174   35    0.83  0.17
#                               test      224   57    0.80  0.20
#                               train     502  110    0.82  0.18
#                               val       174   35    0.83  0.17
# secreted_cytokine             predict   169   36    0.82  0.18
#                               test      224   50    0.82  0.18
#                               train     840  112    0.88  0.12
#                               val       169   36    0.82  0.18

# %%
(
    df_score
    .pivot_table(index=['task', 'iteration'], columns=['metric', 'type'], values='value')
    .head()[('epoch', '')]
)
# Out:
# task               iteration
# inducing_cytokine  0             2.0
#                    1            20.0
#                    2            13.0
#                    3            10.0
#                    4             1.0
# Name: (epoch, ), dtype: float64

# %%
df_score.head()
# Out:
#    iteration  type    metric      value               task
# 0          0           epoch   2.000000  inducing_cytokine
# 1          0  test  accuracy   0.560000  inducing_cytokine
# 2          0  test        ct  50.000000  inducing_cytokine
# 3          0  test        f1   0.656250  inducing_cytokine
# 4          0  test      loss   0.781614  inducing_cytokine

# %%
df_top_score = (
    df_score
    # Pivot to task and hyperparameter config number (all scores already filtered to best epoch)
    .pivot_table(index=['task', 'iteration'], columns=['metric', 'type'], values='value')
    # Remove models with early top score
    .pipe(lambda df: df[df[('epoch', '')] >= 5])
    # Filter to best model config based on validation score
    .pipe(lambda df: df.groupby('task').apply(lambda g: g.iloc[np.argmax(g[('f1', 'validation')].values)]))
)
df_top_score.head()
# Out:
# metric                        accuracy                          ct           \
# type                              test  training validation   test training
# task
# inducing_cytokine                 0.56  0.762774   0.714286   50.0    274.0
# inducing_transcription_factor     0.50  0.681818   0.657143  114.0    220.0
# secreted_cytokine                 0.49  0.852679   0.763889  100.0    224.0
#
# metric                                   epoch        f1                       \
# type                          validation            test  training validation
# task
# inducing_cytokine                   28.0   7.0  0.666667  0.788274   0.764706
# inducing_transcription_factor       70.0  18.0  0.641509  0.753521   0.739130
# secreted_cytokine                   72.0  26.0  0.598425  0.871595   0.795181
#
# metric                         ... precision@70 precision@80            \
# type                           ...   validation         test  training
# task                           ...
# inducing_cytokine              ...     0.000000     0.000000  1.000000
# inducing_transcription_factor  ...     0.591837     0.534091  0.729167
# secreted_cytokine              ...     0.725000     0.492754  0.833333
#
# metric                                   precision@90                       \
# type                          validation         test  training validation
# task
# inducing_cytokine               0.000000     0.000000  0.000000   0.000000
# inducing_transcription_factor   0.609756     0.528571  0.811475   0.620690
# secreted_cytokine               0.777778     0.586207  0.915254   0.787879
#
# metric                           recall
# type                               test  training validation
# task
# inducing_cytokine              0.880000  0.883212   0.928571
# inducing_transcription_factor  0.894737  0.972727   0.971429
# secreted_cytokine              0.760000  1.000000   0.916667
#
# [3 rows x 34 columns]

# %%
# Scores at best validation F1 iteration
def get_scores_table(metrics):
    df_bal = (
        df_lbl.assign(metric='balance').groupby(['task', 'metric', 'split'])['label'].value_counts(normalize=True)
        .unstack().round(2)[1].unstack([-2, -1])
    )
    return (
        df_top_score
        .round(2)
        .pipe(lambda df: pd.concat([df, df_bal], axis=1, sort=True))
        .style.background_gradient(cmap='Greens', low=.1, high=.3)
    )

# %%
# Scores at best validation F1 iteration
get_scores_table(['ct', 'f1', 'accuracy', 'precision', 'recall'])
# Out:
# <style  type="text/css" >
#     #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col0 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col1 {
#             background-color:  #95d391;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col2 {
#             background-color:  #8ed08b;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col3 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col4 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col5 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col6 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col7 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col8 {
#             background-color:  #b5e1ae;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col9 {
#             background-color:  #b5e1ae;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col10 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col11 {
#             background-color:  #81ca81;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col12 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col13 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col14 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col15 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col16 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col17 {
#             background-color:  #6dc072;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col18 {
#             background-color:  #8ed08b;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col19 {
#             background-color:  #8ed08b;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col20 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col21 {
#             background-color:  #c0e6b9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col22 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col23 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col24 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col25 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col26 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col27 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col28 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col29 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col30 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col31 {
#             background-color:  #278f48;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col32 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col33 {
#             background-color:  #d0edca;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col34 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col35 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col36 {
#             background-color:  #b5e1ae;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row0_col37 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col0 {
#             background-color:  #daf0d4;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col1 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col2 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col3 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col4 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col5 {
#             background-color:  #228a44;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col6 {
#             background-color:  #79c67a;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col7 {
#             background-color:  #7cc87c;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col8 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col9 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col10 {
#             background-color:  #6bc072;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col11 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col12 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col13 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col14 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col15 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col16 {
#             background-color:  #d0edca;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col17 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col18 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col19 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col20 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_fa85f2b6_b7a6_11e9_a38e_0242ac110002row1_col21 {
#             background-color:  #

# %%
# Median scores
p = (
    df_score
    .pipe(lambda df: df[df['metric'].isin(['precision', 'recall', 'f1'])])
    .groupby(['task', 'metric', 'type'])['value'].describe()[['mean', '25%', '50%', '75%']].unstack()['50%'].unstack()[['test', 'validation']]
    .round(3)
    .style.background_gradient(cmap='Greens', low=.3, high=.9)
)

# %%
p
# Out:
# <style  type="text/css" >
#     #T_47f77138_b7a6_11e9_a38e_0242ac110002row0_col0 {
#             background-color:  #4eb264;
#             color:  #000000;
#         }    #T_47f77138_b7a6_11e9_a38e_0242ac110002row0_col1 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_47f77138_b7a6_11e9_a38e_0242ac110002row0_col2 {
#             background-color:  #4eb264;
#             color:  #000000;
#         }    #T_47f77138_b7a6_11e9_a38e_0242ac110002row0_col3 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_47f77138_b7a6_11e9_a38e_0242ac110002row0_col4 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_47f77138_b7a6_11e9_a38e_0242ac110002row0_col5 {
#             background-color:  #70c274;
#             color:  #000000;
#         }    #T_47f77138_b7a6_11e9_a38e_0242ac110002row1_col0 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_47f77138_b7a6_11e9_a38e_0242ac110002row1_col1 {
#             background-color:  #d6efd0;
#             color:  #000000;
#         }    #T_47f77138_b7a6_11e9_a38e_0242ac110002row1_col2 {
#             background-color:  #7ac77b;
#             color:  #000000;
#         }    #T_47f77138_b7a6_11e9_a38e_0242ac110002row1_col3 {
#             background-color:  #d1edcb;
#             color:  #000000;
#         }    #T_47f77138_b7a6_11e9_a38e_0242ac110002row1_col4 {
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }    #T_47f77138_b7a6_11e9_a38e_0242ac110002row1_col5 {
#             background-color:  #4eb264;
#             color:  #000000;
#         }    #T_47f77138_b7a6_11e9_a38e_0242ac110002row2_col0 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_47f77138_b7a6_11e9_a38e_0242ac110002row2_col1 {
#             background-color:  #4eb264;
#             color:  #000000;
#         }    #T_47f77138_b7a6_11e9_a38e_0242ac110002row2_col2 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_47f77138_b7a6_11e9_a38e_0242ac110002row2_col3 {
#             background-color:  #4eb264;
#             color:  #000000;
#         }    #T_47f77138_b7a6_11e9_a38e_0242ac110002row2_col4 {
#             background-color:  #4eb264;
#             color:  #000000;
#         }    #T_47f77138_b7a6_11e9_a38e_0242ac110002row2_col5 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }</style><table id="T_47f77138_b7a6_11e9_a38e_0242ac110002" ><thead>    <tr>        <th class="index_name level0" >type</th>        <th class="col_heading level0 col0" colspan=3>test</th>        <th class="col_heading level0 col3" colspan=3>validation</th>    </tr>    <tr>        <th class="index_name level1" >metric</th>        <th class="col_heading level1 col0" >f1</th>        <th class="col_heading level1 col1" >precision</th>        <th class="col_heading level1 col2" >recall</th>        <th class="col_heading level1 col3" >f1</th>        <th class="col_heading level1 col4" >precision</th>        <th class="col_heading level1 col5" >recall</th>    </tr>    <tr>        <th class="index_name level0" >task</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_47f77138_b7a6_11e9_a38e_0242ac110002level0_row0" class="row_heading level0 row0" >inducing_cytokine</th>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row0_col0" class="data row0 col0" >0.644</td>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row0_col1" class="data row0 col1" >0.528</td>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row0_col2" class="data row0 col2" >0.82</td>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row0_col3" class="data row0 col3" >0.69</td>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row0_col4" class="data row0 col4" >0.591</td>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row0_col5" class="data row0 col5" >0.821</td>
#             </tr>
#             <tr>
#                         <th id="T_47f77138_b7a6_11e9_a38e_0242ac110002level0_row1" class="row_heading level0 row1" >inducing_transcription_factor</th>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row1_col0" class="data row1 col0" >0.639</td>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row1_col1" class="data row1 col1" >0.536</td>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row1_col2" class="data row1 col2" >0.789</td>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row1_col3" class="data row1 col3" >0.696</td>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row1_col4" class="data row1 col4" >0.592</td>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row1_col5" class="data row1 col5" >0.843</td>
#             </tr>
#             <tr>
#                         <th id="T_47f77138_b7a6_11e9_a38e_0242ac110002level0_row2" class="row_heading level0 row2" >secreted_cytokine</th>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row2_col0" class="data row2 col0" >0.639</td>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row2_col1" class="data row2 col1" >0.598</td>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row2_col2" class="data row2 col2" >0.69</td>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row2_col3" class="data row2 col3" >0.727</td>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row2_col4" class="data row2 col4" >0.726</td>
#                         <td id="T_47f77138_b7a6_11e9_a38e_0242ac110002row2_col5" class="data row2 col5" >0.722</td>
#             </tr>
#     </tbody></table>

# %%
(
    pn.ggplot(
        df_score.pipe(lambda df: df[df['metric'].isin(['f1'])]),
        pn.aes(x='type', y='value', fill='type')
    ) + 
    pn.geom_violin() + 
    pn.ylim(.4, 1) +
    pn.labs(y='F1', title='Dev Supervised Model Results', x='Dataset', fill='Dataset') + 
    pn.facet_grid('task ~ metric', scales='free') + 
    pn.theme(figure_size=(3, 7))
)
# Out:
# <ggplot: (8783996680084)>

# %%
(
    pn.ggplot(
        df_score.pipe(lambda df: df[df['metric'].isin(['f1', 'accuracy', 'precision', 'recall'])]),
        pn.aes(x='type', y='value', fill='type')
    ) + 
    pn.geom_violin() + 
    pn.facet_grid('metric ~ task', scales='free') + 
    pn.theme(figure_size=(12, 8))
)
# Out:
# <ggplot: (-9223363252857838192)>

# %%
(
    pn.ggplot(
        df_score.pipe(lambda df: df[df['metric'].isin(['f1'])]),
        pn.aes(x='type', y='value', fill='type')
    ) + 
    pn.geom_violin() + 
    pn.labs(y='F1', title='Labeling Function Model Results', x='Dataset', fill='Dataset') + 
    pn.facet_grid('metric ~ task', scales='free') + 
    pn.theme(figure_size=(12, 3))
)
# Out:
# <ggplot: (-9223363252856977948)>

# %% [markdown]
# ## Export

# %% [markdown]
# Export scores:

# %%
df_exp = df_top_score.stack().stack().rename('value').reset_index().rename(columns={'type': 'split'}).assign(model='rnn-dev')
assert df_exp.groupby(['task', 'metric', 'split']).size().max() == 1
df_exp.head()
# Out:
#                 task split    metric      value    model
# 0  inducing_cytokine           epoch   7.000000  rnn-dev
# 1  inducing_cytokine  test  accuracy   0.560000  rnn-dev
# 2  inducing_cytokine  test        ct  50.000000  rnn-dev
# 3  inducing_cytokine  test        f1   0.666667  rnn-dev
# 4  inducing_cytokine  test      loss   0.775557  rnn-dev

# %%
df_exp[df_exp['metric'] == 'epoch']['value'].value_counts()
# Out:
# 26.0    1
# 18.0    1
# 7.0     1
# Name: value, dtype: int64

# %%
path = osp.join(output_dir, 'scores.csv')
df_exp.to_csv(path, index=False)
path
# Out:
# '/lab/data/results/modeling-rnn-dev/run3/scores.csv'

# %% [markdown]
# Export top model configurations for each task:

# %%
# Show top 3 models
dftm = dfx.groupby('task', group_keys=False)\
    .apply(lambda g: g.sort_values('score', ascending=False).iloc[:3].reset_index(drop=True).assign(rank=lambda df: 1+np.arange(len(df))))\
    .reset_index(drop=True)\
    .rename(columns={dim.name: f'param:{dim.name}' for dim in space})
dftm
# Out:
#   param:marker_list  param:use_secondary  param:use_swaps  \
# 0           doub_01                 True             True
# 1           doub_01                 True             True
# 2           doub_01                 True             True
# 3           doub_01                 True             True
# 4           doub_01                False             True
# 5           doub_01                 True             True
# 6           doub_01                 True             True
# 7           doub_01                 True             True
# 8           doub_01                 True             True
#
#    param:use_positions param:wrd_embedding_type param:model_size  \
# 0                 True              w2v_trained              XXL
# 1                 True               w2v_frozen              XXL
# 2                 True               w2v_frozen              XXL
# 3                 True               w2v_frozen              XXL
# 4                 True              w2v_trained             XXXL
# 5                 True              w2v_trained               XL
# 6                 True              w2v_trained            XXXXL
# 7                 True              w2v_trained             XXXL
# 8                 True               w2v_frozen            XXXXL
#
#    param:weight_decay  param:learning_rate  param:dropout param:cell_type  \
# 0               0.000                0.050           0.50            LSTM
# 1               0.005                0.050           0.50            LSTM
# 2               0.001                0.050           0.75            LSTM
# 3               0.001                0.050           0.75            LSTM
# 4               0.005                0.050           0.25            LSTM
# 5               0.001                0.010           0.25            LSTM
# 6               0.001                0.050           0.50            LSTM
# 7               0.001                0.050           0.00            LSTM
# 8               0.001                0.005           0.75            LSTM
#
#    param:bidirectional     score                           task  iteration  \
# 0                False  0.812500              inducing_cytokine         12
# 1                False  0.774194              inducing_cytokine         55
# 2                False  0.764706              inducing_cytokine         13
# 3                False  0.744186  inducing_transcription_factor         13
# 4                False  0.739130  inducing_transcription_factor          1
# 5                False  0.738095  inducing_transcription_factor         18
# 6                False  0.795181              secreted_cytokine         57
# 7                False  0.788732              secreted_cytokine         56
# 8                False  0.783784              secreted_cytokine         38
#
#    rank
# 0     1
# 1     2
# 2     3
# 3     1
# 4     2
# 5     3
# 6     1
# 7     2
# 8     3

# %%
path = osp.join(output_dir, 'top_model_configurations.json')
dftm.to_json(path)
path
# Out:
# '/lab/data/results/modeling-rnn-dev/run3/top_model_configurations.json'

# %% [markdown]
# ## Debug

# %%
debug_task = tasks[1]
optimizer = optimizers[debug_task]
debug_task
# Out:
# 'secreted_cytokine'

# %%
model_config = dfx.groupby('task').apply(lambda g: g.sort_values('score', ascending=False).iloc[0]).loc[debug_task]
model_config
# Out:
# marker_list                     doub_01
# use_secondary                     False
# use_swaps                          True
# use_positions                      True
# wrd_embedding_type          w2v_trained
# model_size                          XXL
# weight_decay                          0
# learning_rate                      0.01
# dropout                            0.25
# cell_type                          LSTM
# bidirectional                     False
# score                          0.424242
# task                  secreted_cytokine
# iteration                            49
# Name: secreted_cytokine, dtype: object

# %%
#model_config['model_size'] = 'XL'

# %%
# Train on top config
train_args = dict(optimizer.train_args([model_config[dim.name] for dim in space]))
train_args['use_checkpoints'] = True
del train_args['save_keys']
args = dict(cli=optimizer.cli_args(), train=train_args)
cmd = optimizer.format(optimizer.client.cmd(**args))
print(cmd)
optimizer.client.execute(cmd)
# Out:
# python /lab/repos/t-cell-relation-extraction/src/tcre/exec/v1/cli.py --relation-class=secreted_cytokine --device="cuda:1" --output-dir=/lab/data/results/gridsearch-dev/run2/secreted_cytokine/data --batch-size=512 train --splits-file=/lab/data/results/gridsearch-dev/run2/secreted_cytokine/splits/splits.json --use-checkpoints=True --marker-list=doub_01 --use-secondary=False --use-swaps=True --use-positions=True --wrd-embedding-type=w2v_trained --model-size=XXL --weight-decay=0.0 --learning-rate=0.01 --dropout=0.25 --cell-type=LSTM --bidirectional=False > /lab/data/results/gridsearch-dev/run2/secreted_cytokine/log/log.txt 2>&1
# 0

# %%
pd.read_json(osp.join(optimizer.output_dir, 'data', 'history.json'))\
    .set_index(['epoch', 'type'])['f1'].unstack().plot()

# %%
# Predict with trained model
predict_args = dict(splits_file=optimizer.get_splits_file())
args = dict(cli=optimizer.cli_args(), predict=predict_args)
cmd = optimizer.format(optimizer.client.cmd(**args))
print(cmd)
optimizer.client.execute(cmd)
# Out:
# python /lab/repos/t-cell-relation-extraction/src/tcre/exec/v1/cli.py --relation-class=secreted_cytokine --device="cuda:1" --output-dir=/lab/data/results/gridsearch-dev/run2/secreted_cytokine/data --batch-size=512 predict --splits-file=/lab/data/results/gridsearch-dev/run2/secreted_cytokine/splits/splits.json > /lab/data/results/gridsearch-dev/run2/secreted_cytokine/log/log.txt 2>&1
# 0

# %%
from tcre import visualization
import imp
imp.reload(visualization)

df_pred = pd.read_json(osp.join(optimizer.output_dir, 'data', 'predictions.json')).set_index('id')
pred_cands = session.query(Candidate).filter(Candidate.type == debug_task).all()
pred_cands = [c for c in pred_cands if c.id in df_pred.index]
assert len(pred_cands) == len(df_pred)
df_pred = pd.merge(df_pred.reset_index(), visualization.candidate_df(pred_cands), on='id', how='inner')
df_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 0 to 97
# Data columns (total 8 columns):
# id        98 non-null int64
# y_true    98 non-null int64
# y_pred    98 non-null float64
# type      98 non-null object
# split     98 non-null int64
# e1        98 non-null object
# e2        98 non-null object
# text      98 non-null object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 6.9+ KB

# %%
df_pred['y_true'].unique(), (df_pred['y_true'] > .5).value_counts()
# Out:
# (array([0, 1]), False    79
#  True     19
#  Name: y_true, dtype: int64)

# %%
(df_pred['y_pred'] > .5).value_counts()
# Out:
# False    89
# True      9
# Name: y_pred, dtype: int64

# %%
from IPython.display import HTML
pd.set_option('display.max_colwidth', 600)
#HTML(df_pred.sort_values('y_pred', ascending=False).head(25).to_html(escape=False))
HTML(df_pred[df_pred['y_true'] == 1].sort_values('y_pred', ascending=False).head(25).to_html(escape=False))
#HTML(df_pred[df_pred['y_pred'] > .5].sort_values('y_pred', ascending=False).head(25).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>y_true</th>
#       <th>y_pred</th>
#       <th>type</th>
#       <th>split</th>
#       <th>e1</th>
#       <th>e2</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>60</th>
#       <td>291424</td>
#       <td>1</td>
#       <td>0.995636</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IFN-γ</td>
#       <td>γδT</td>
#       <td>We next sought to determine if the production of <div style="color:blue;display:inline" title="CK128EC732B281BF60:CK128EC732B281BF60">IFN-γ</div> by CD161 + <div style="color:red;display:inline" title="CT7DC8DD80306E71A2:CT7DC8DD80306E71A2">γδT</div> cells in response to TCR - independent cytokine stimulation occurred in both the Vδ1 + and Vδ2 + γδT cell subsets .</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>364562</td>
#       <td>1</td>
#       <td>0.990747</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IL-23</td>
#       <td>Th17</td>
#       <td>Th17 cells express the <div style="color:blue;display:inline" title="CK128EF9AC08AC594D:CK9EDC256C75A00BC5">IL-23</div> receptor ( IL-23R ) , and the exquisite pathogenicity of <div style="color:red;display:inline" title="CTBFBDE5121B6748D1:CTBFBDE5121B6748D1">Th17</div> cells may be associated with their capacity to respond to IL-23 (; ; ; ) . \n</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>333888</td>
#       <td>1</td>
#       <td>0.981965</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IL-4</td>
#       <td>Th2</td>
#       <td>For example , the cytokines typically produced by <div style="color:red;display:inline" title="CTE7B12DC660323A0E:CTE7B12DC660323A0E">Th2</div> cells , including <div style="color:blue;display:inline" title="CK6FE135B3F86FB707:CK6FE135B3F86FB707">IL-4</div> , IL-5 and IL-13 , are silenced in Th1 cells through histone modification [ ] .</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>288940</td>
#       <td>1</td>
#       <td>0.634935</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>TNF-α</td>
#       <td>Th1</td>
#       <td>Supporting this hypothesis , we also found that <div style="color:blue;display:inline" title="CKE50C068CBDAC0F8F:CK80A1A727AC173EE7">TNF-α</div> , a cytokine , which can be produced by Th17 and <div style="color:red;display:inline" title="CTC3A8C3CBC245616A:CTC3A8C3CBC245616A">Th1</div> cells , neither influenced the CD44 level of IL-17 + nor IFN-γ+CD4 + T cells .</td>
#     </tr>
#     <tr>
#       <th>94</th>
#       <td>298139</td>
#       <td>1</td>
#       <td>0.527107</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IL-4</td>
#       <td>Th2</td>
#       <td><div style="color:red;display:inline" title="CTE7B12DC660323A0E:CTE7B12DC660323A0E">Th2</div> cells express <div style="color:blue;display:inline" title="CK6FE135B3F86FB707:CK6FE135B3F86FB707">IL-4</div> , IL-5 , and IL-13 , which stimulates mucosal immunity against parasite infections ( – ) .</td>
#     </tr>
#     <tr>
#       <th>90</th>
#       <td>327843</td>
#       <td>1</td>
#       <td>0.200419</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IL-21</td>
#       <td>Th17</td>
#       <td>Another subset that has become increasingly important is <div style="color:red;display:inline" title="CTBFBDE5121B6748D1:CTBFBDE5121B6748D1">Th17</div> cells that produce a variety of cytokines including IL-17A , <div style="color:blue;display:inline" title="CKE72A17870C23A2D1:CK284ADEA6187E1FF3">IL-21</div> and IL-22 .</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>58853</td>
#       <td>1</td>
#       <td>0.192096</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IFN-γ</td>
#       <td>NKT</td>
#       <td>Based on the expression of an invariant TCRα chain ( Vα14-Jα18 in mice , Vα24-Jα18 in humans ) , CD1d - dependent NKT cells can be classified into type I and type II <div style="color:red;display:inline" title="CT459998F048BE65F2:CT459998F048BE65F2">NKT</div> cells , both of which can produce <div style="color:blue;display:inline" title="CK1B71668FDDECE3CF:CK128EC732B281BF60">IFN-γ</div> , the Th1 cytokine , and IL-4 , a Th2 cytokine , and participate in the regulation of innate and adaptive immunity .</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>365585</td>
#       <td>1</td>
#       <td>0.147616</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IL-17</td>
#       <td>Th17</td>
#       <td>The signaling cascade of <div style="color:blue;display:inline" title="CK2741EFAE1F31AD65:CK2741EFAE1F31AD65">IL-17</div> , the signature cytokine of <div style="color:red;display:inline" title="CTBFBDE5121B6748D1:CTBFBDE5121B6748D1">Th17</div> cells , requires a key signaling molecule , Act1 ( also known as TRAF3IP2 or CIKS ) to propagate downstream signaling events in tissue cells , including activation of the transcription factor NF-κB. The absence of Act1 leads to resistance to IL-17-mediated inflammation in mouse models of experimental autoimmune encephalomyelitis ( EAE ) and asthma .</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>347530</td>
#       <td>1</td>
#       <td>0.131577</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IL-13</td>
#       <td>Th2</td>
#       <td>Dominance of Th2 responses ( – ) and <div style="color:red;display:inline" title="CTE7B12DC660323A0E:CTE7B12DC660323A0E">Th2</div> cytokines IL-4 ( – ) , IL-10 ( ) , and <div style="color:blue;display:inline" title="CK713350DF0E9099E8:CK713350DF0E9099E8">IL-13</div> ( ) , can protect against autoimmunity , but their effects are variable . Th2</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>323721</td>
#       <td>1</td>
#       <td>0.126618</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IL-10</td>
#       <td>TH17</td>
#       <td>a Quantitative RT - PCR analysis of gene expression in human IL-10– and <div style="color:blue;display:inline" title="CK3A3EC71E6A0C53F0:CKC5CC1A269C01EC48">IL-10</div> + <div style="color:red;display:inline" title="CTBFBDE5121B6748D1:CTBFBDE5121B6748D1">TH17</div> clones isolated from healthy donors ( two tailed , paired Student ’s t test , mean   ±   s.d .</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>105315</td>
#       <td>1</td>
#       <td>0.064663</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>TNF</td>
#       <td>Th1</td>
#       <td>These cells have a limited capacity to mediate control of Mtb infection , but produce significant amounts of <div style="color:red;display:inline" title="CTC3A8C3CBC245616A:CTC3A8C3CBC245616A">Th1</div> related cytokines like IFN-γ and <div style="color:blue;display:inline" title="CK9F74D00862D05D5F:CK80A1A727AC173EE7">TNF</div> .</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>317312</td>
#       <td>1</td>
#       <td>0.045519</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IL-5</td>
#       <td>Th2</td>
#       <td>Consistent with above results , mice that received Ova - specific Batf KO Tfh cells revealed decreased numbers of total infiltrated cells , eosinophils and lymphocytes ( ) along with decreased expression of <div style="color:red;display:inline" title="CTE7B12DC660323A0E:CTE7B12DC660323A0E">Th2</div> cytokines IL-4 , <div style="color:blue;display:inline" title="CK7026891CEAA3C8F9:CK7026891CEAA3C8F9">IL-5</div> and IL-13 by Ova - restimulated splenocytes ( ) compared with mice that received WT Tfh cells .</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>358115</td>
#       <td>1</td>
#       <td>0.006491</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IFNγ</td>
#       <td>Th17</td>
#       <td>We asked whether STAT4 signaling was critical for the induction of <div style="color:blue;display:inline" title="CK8074B95EB01901B1:CK128EC732B281BF60">IFNγ</div> production by <div style="color:red;display:inline" title="CTBFBDE5121B6748D1:CTBFBDE5121B6748D1">Th17</div> cells upon stimulation with IL-12 and IL-18 .</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>3
