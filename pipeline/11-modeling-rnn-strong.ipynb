# %%
# %matplotlib inline
import os
import tqdm
import os.path as osp
import pandas as pd
import numpy as np
import itertools
import glob
import json 
import plotnine as pn
import matplotlib.pyplot as plt
import collections
from tcre.env import *
from tcre.supervision import get_candidate_classes, SPLIT_DEV, SPLIT_VAL, SPLIT_TEST, SPLIT_MAP
from tcre.exec.v1 import optim
from tcre.modeling import features
from tcre.modeling import sampling
from snorkel.learning.utils import LabelBalancer
from snorkel import SnorkelSession
from snorkel.models import Candidate
import logging
session = SnorkelSession()
# %run ../src/tcre/logging.py
classes = get_candidate_classes()
# Out:
# /opt/conda/envs/nlp/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
#output_dir = osp.join(RESULTS_DATA_DIR, 'modeling-rnn-strong', 'run1')
#output_dir = osp.join(RESULTS_DATA_DIR, 'modeling-rnn-strong', 'run2')
#output_dir = osp.join(RESULTS_DATA_DIR, 'modeling-rnn-strong', 'run3')
output_dir = osp.join(RESULTS_DATA_DIR, 'modeling-rnn-strong', 'run4') # last annotation round
output_dir
# Out:
# '/lab/data/results/modeling-rnn-strong/run4'

# %%
tasks = [classes[c].field for c in classes]
tasks
# Out:
# ['inducing_cytokine', 'secreted_cytokine', 'inducing_transcription_factor']

# %% [markdown]
# ### Initialize Optimizers

# %%
from skopt.space import Categorical
from skopt.space import Space

space = Space([
    Categorical(['doub_01'], name='marker_list'),
    Categorical([True, False], name='use_secondary'),
    Categorical([True], name='use_swaps'),
    Categorical([True], name='use_positions'),
    Categorical(['w2v_frozen', 'w2v_trained'], name='wrd_embedding_type'),
    Categorical(['XL', 'XXL', 'XXXL', 'XXXXL'], name='model_size'),
    Categorical([0.0, .0001, .001, .005], name='weight_decay'),
    Categorical([.005, .01, .05], name='learning_rate'),
    Categorical([0.0, 0.25, 0.5, 0.75], name='dropout'),
    Categorical(['LSTM'], name='cell_type'),
    Categorical([False], name='bidirectional')
])

# %%
n_space = np.prod([len(dim.categories) for dim in space])
print('Number of combinations in parameter space:', n_space)
# Out:
# Number of combinations in parameter space: 768

# %%
space.rvs()[0]
# Out:
# ['doub_01',
#  False,
#  True,
#  True,
#  'w2v_trained',
#  'XXL',
#  0.001,
#  0.01,
#  0.25,
#  'LSTM',
#  False]

# %%
from skopt import forest_minimize, dummy_minimize

optimizers = {
    task: optim.TaskParameterOptimizer(
        task, space, output_dir, minimizer=dummy_minimize, client_args=dict(cli={'batch_size': 512})
    ) for task in tasks
}

# %%
optimizers[tasks[0]].client.exceptions
# Out:
# ['log_level',
#  'seed',
#  'vocab_limit',
#  'use_lower',
#  'save_keys',
#  'log_iter_interval',
#  'log_epoch_interval',
#  'balance',
#  'batch_size',
#  'simulation_strategy',
#  'swap_list']

# %% [markdown]
# ### Create Splits for Tasks

# %%
# DB splits -> modeling splits 
TARGET_MAP = {'dev': 'train', 'val': 'val', 'test': 'test'}
df_cand, df_dist = sampling.get_modeling_splits(session, target_split_map=TARGET_MAP)

# Duplicate val candidates for prediction
df_cand = pd.concat([
    df_cand, df_cand[df_cand['split'] == 'val'].assign(split='predict')
])

# Write splits to file
for task, g in df_cand.groupby('task'):
    splits = g.groupby('split')['id'].unique()
    splits_file = optimizers[task].write_splits(splits)
    print(f'Splits for task {task} written to "{splits_file}"')
df_dist
# Out:
# Splits for task inducing_cytokine written to "/lab/data/results/modeling-rnn-strong/run4/inducing_cytokine/splits/splits.json"
# Splits for task inducing_transcription_factor written to "/lab/data/results/modeling-rnn-strong/run4/inducing_transcription_factor/splits/splits.json"
# Splits for task secreted_cytokine written to "/lab/data/results/modeling-rnn-strong/run4/secreted_cytokine/splits/splits.json"
# statistic                           percent       count
# label                                     0     1     0    1
# task                          split
# inducing_cytokine             test     50.0  50.0    29   29
#                               train    50.0  50.0   145  145
#                               val      50.0  50.0    23   23
# inducing_transcription_factor test     50.0  50.0    58   58
#                               train    50.0  50.0   107  107
#                               val      50.0  50.0    44   44
# secreted_cytokine             test     50.0  50.0    64   64
#                               train    50.0  50.0   131  131
#                               val      50.0  50.0    49   49

# %%
df_cand.groupby(['task', 'split']).size().unstack()
# Out:
# split                          predict  test  train  val
# task
# inducing_cytokine                   46    58    290   46
# inducing_transcription_factor       88   116    214   88
# secreted_cytokine                   98   128    262   98

# %% [markdown]
# ### Run Search

# %%
# Show an example command to be run 
print(optimizers[tasks[0]].get_cmd(space.rvs()[0]))
# Out:
# python /lab/repos/t-cell-relation-extraction/src/tcre/exec/v1/cli.py --relation-class=inducing_cytokine --device="cuda:1" --output-dir=/lab/data/results/modeling-rnn-strong/run4/inducing_cytokine/data --batch-size=512 train --splits-file=/lab/data/results/modeling-rnn-strong/run4/inducing_cytokine/splits/splits.json --use-checkpoints=False --save-keys="history" --marker-list=doub_01 --use-secondary=False --use-swaps=True --use-positions=True --wrd-embedding-type=w2v_trained --model-size=XXXL --weight-decay=0.001 --learning-rate=0.05 --dropout=0.75 --cell-type=LSTM --bidirectional=False > /lab/data/results/modeling-rnn-strong/run4/inducing_cytokine/log/log.txt 2>&1

# %%
# For 3 tasks at about about 30s per iteration, show common time estimations:
time_per_iter_sec = 30
n_iter = np.array([10, 100, 250, 500, 1000])
for n in n_iter:
    time = n * time_per_iter_sec * len(tasks) / 3600
    print(f'Iterations = {n} --> Time = {time} (hrs)')
# Out:
# Iterations = 10 --> Time = 0.25 (hrs)
# Iterations = 100 --> Time = 2.5 (hrs)
# Iterations = 250 --> Time = 6.25 (hrs)
# Iterations = 500 --> Time = 12.5 (hrs)
# Iterations = 1000 --> Time = 25.0 (hrs)

# %%
results = {}

for task in tasks:
    optimizer = optimizers[task]
    logging.info(f'Running optimization for task {task}')
    # kappa=3.090 -> 99.8% confidence interval (favors exploration when higher than default 1.96)
    #res, scores, callbacks = optimizer.run(n_iterations=250, progress_interval=1, checkpoint_interval=10, n_random_starts=10, acq_func='LCB', kappa=3.090)
    res, scores, callbacks = optimizer.run(n_iterations=64, progress_interval=1, checkpoint_interval=10)
    
    # Save scores for non-objective (i.e. validation) after converting to long form
    scores = pd.DataFrame(scores)
    scores.columns = pd.MultiIndex.from_tuples([c for c in scores])
    scores = scores.rename_axis('iteration', axis=0).rename_axis(('metric', 'type'), axis=1)
    scores = scores.stack().stack().rename('value').reset_index()
    scores_file = osp.join(optimizer.output_dir, 'scores.feather')
    scores.to_feather(scores_file)
    logging.info(f'Saved scores to {scores_file}')
    
    # Checkpoint final result since it is not saved at every step
    callbacks['saver'].i = -1
    callbacks['saver'](res)
    logging.info(f'Saved final result')
    
    results[task] = res, scores, callbacks
# Out:
# 2019-09-11 14:44:12,311:INFO:root: Running optimization for task inducing_cytokine
# 2019-09-11 14:44:12,313:INFO:tcre.exec.v1.optim: Beginning parameter search with max iterations 64
# 2019-09-11 14:44:31,218:INFO:tcre.exec.v1.optim: Completed iteration 1 of 64 (score = -0.693877551020408)
# 2019-09-11 14:44:52,089:INFO:tcre.exec.v1.optim: Completed iteration 2 of 64 (score = -0.6551724137931031)
# 2019-09-11 14:45:08,273:INFO:tcre.exec.v1.optim: Completed iteration 3 of 64 (score = -0.5862068965517241)
# 2019-09-11 14:45:26,315:INFO:tcre.exec.v1.optim: Completed iteration 4 of 64 (score = -0.68)
# 2019-09-11 14:45:45,051:INFO:tcre.exec.v1.optim: Completed iteration 5 of 64 (score = -0.711111111111111)
# 2019-09-11 14:46:01,946:INFO:tcre.exec.v1.optim: Completed iteration 6 of 64 (score = -0.678571428571428)
# 2019-09-11 14:46:17,661:INFO:tcre.exec.v1.optim: Completed iteration 7 of 64 (score = -0.6567164179104471)
# 2019-09-11 14:46:34,485:INFO:tcre.exec.v1.optim: Completed iteration 8 of 64 (score = -0.60377358490566)
# 2019-09-11 14:46:50,737:INFO:tcre.exec.v1.optim: Completed iteration 9 of 64 (score = -0.5964912280701751)
# 2019-09-11 14:47:10,540:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/inducing_cytokine/checkpoints/checkpoint.pkl
# 2019-09-11 14:47:10,571:INFO:tcre.exec.v1.optim: Completed iteration 10 of 64 (score = -0.708333333333333)
# 2019-09-11 14:47:27,708:INFO:tcre.exec.v1.optim: Completed iteration 11 of 64 (score = -0.6567164179104471)
# 2019-09-11 14:47:44,691:INFO:tcre.exec.v1.optim: Completed iteration 12 of 64 (score = -0.6666666666666661)
# 2019-09-11 14:48:02,081:INFO:tcre.exec.v1.optim: Completed iteration 13 of 64 (score = -0.7499999999999991)
# 2019-09-11 14:48:20,234:INFO:tcre.exec.v1.optim: Completed iteration 14 of 64 (score = -0.7755102040816321)
# 2019-09-11 14:48:35,709:INFO:tcre.exec.v1.optim: Completed iteration 15 of 64 (score = -0.6666666666666661)
# 2019-09-11 14:49:04,169:INFO:tcre.exec.v1.optim: Completed iteration 16 of 64 (score = -0.785714285714285)
# 2019-09-11 14:49:19,772:INFO:tcre.exec.v1.optim: Completed iteration 17 of 64 (score = -0.618181818181818)
# 2019-09-11 14:49:37,406:INFO:tcre.exec.v1.optim: Completed iteration 18 of 64 (score = -0.769230769230769)
# 2019-09-11 14:49:54,258:INFO:tcre.exec.v1.optim: Completed iteration 19 of 64 (score = -0.68)
# 2019-09-11 14:50:12,109:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/inducing_cytokine/checkpoints/checkpoint.pkl
# 2019-09-11 14:50:12,147:INFO:tcre.exec.v1.optim: Completed iteration 20 of 64 (score = -0.76)
# 2019-09-11 14:50:30,262:INFO:tcre.exec.v1.optim: Completed iteration 21 of 64 (score = -0.7142857142857141)
# 2019-09-11 14:50:50,943:INFO:tcre.exec.v1.optim: Completed iteration 22 of 64 (score = -0.76)
# 2019-09-11 14:51:10,891:INFO:tcre.exec.v1.optim: Completed iteration 23 of 64 (score = -0.695652173913043)
# 2019-09-11 14:51:26,797:INFO:tcre.exec.v1.optim: Completed iteration 24 of 64 (score = -0.678571428571428)
# 2019-09-11 14:51:45,010:INFO:tcre.exec.v1.optim: Completed iteration 25 of 64 (score = -0.7499999999999991)
# 2019-09-11 14:52:06,483:INFO:tcre.exec.v1.optim: Completed iteration 26 of 64 (score = -0.693877551020408)
# 2019-09-11 14:52:26,777:INFO:tcre.exec.v1.optim: Completed iteration 27 of 64 (score = -0.7391304347826081)
# 2019-09-11 14:52:43,307:INFO:tcre.exec.v1.optim: Completed iteration 28 of 64 (score = -0.631578947368421)
# 2019-09-11 14:53:00,206:INFO:tcre.exec.v1.optim: Completed iteration 29 of 64 (score = -0.6666666666666661)
# 2019-09-11 14:53:17,373:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/inducing_cytokine/checkpoints/checkpoint.pkl
# 2019-09-11 14:53:17,416:INFO:tcre.exec.v1.optim: Completed iteration 30 of 64 (score = -0.5964912280701751)
# 2019-09-11 14:53:38,828:INFO:tcre.exec.v1.optim: Completed iteration 31 of 64 (score = -0.769230769230769)
# 2019-09-11 14:53:56,799:INFO:tcre.exec.v1.optim: Completed iteration 32 of 64 (score = -0.703703703703703)
# 2019-09-11 14:54:15,327:INFO:tcre.exec.v1.optim: Completed iteration 33 of 64 (score = -0.76)
# 2019-09-11 14:54:32,337:INFO:tcre.exec.v1.optim: Completed iteration 34 of 64 (score = -0.7659574468085101)
# 2019-09-11 14:54:57,203:INFO:tcre.exec.v1.optim: Completed iteration 35 of 64 (score = -0.7547169811320751)
# 2019-09-11 14:55:12,533:INFO:tcre.exec.v1.optim: Completed iteration 36 of 64 (score = -0.592592592592592)
# 2019-09-11 14:55:31,249:INFO:tcre.exec.v1.optim: Completed iteration 37 of 64 (score = -0.6461538461538461)
# 2019-09-11 14:55:49,996:INFO:tcre.exec.v1.optim: Completed iteration 38 of 64 (score = -0.6923076923076921)
# 2019-09-11 14:56:12,649:INFO:tcre.exec.v1.optim: Completed iteration 39 of 64 (score = -0.695652173913043)
# 2019-09-11 14:56:30,932:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/inducing_cytokine/checkpoints/checkpoint.pkl
# 2019-09-11 14:56:31,001:INFO:tcre.exec.v1.optim: Completed iteration 40 of 64 (score = -0.7234042553191491)
# 2019-09-11 14:56:47,601:INFO:tcre.exec.v1.optim: Completed iteration 41 of 64 (score = -0.620689655172413)
# 2019-09-11 14:57:03,538:INFO:tcre.exec.v1.optim: Completed iteration 42 of 64 (score = -0.647058823529411)
# 2019-09-11 14:57:20,497:INFO:tcre.exec.v1.optim: Completed iteration 43 of 64 (score = -0.7169811320754711)
# 2019-09-11 14:57:39,973:INFO:tcre.exec.v1.optim: Completed iteration 44 of 64 (score = -0.7755102040816321)
# 2019-09-11 14:57:57,694:INFO:tcre.exec.v1.optim: Completed iteration 45 of 64 (score = -0.60377358490566)
# 2019-09-11 14:58:14,467:INFO:tcre.exec.v1.optim: Completed iteration 46 of 64 (score = -0.69090909090909)
# 2019-09-11 14:58:34,461:INFO:tcre.exec.v1.optim: Completed iteration 47 of 64 (score = -0.711111111111111)
# 2019-09-11 14:58:53,925:INFO:tcre.exec.v1.optim: Completed iteration 48 of 64 (score = -0.7755102040816321)
# 2019-09-11 14:59:17,505:INFO:tcre.exec.v1.optim: Completed iteration 49 of 64 (score = -0.816326530612244)
# 2019-09-11 14:59:33,370:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/inducing_cytokine/checkpoints/checkpoint.pkl
# 2019-09-11 14:59:33,452:INFO:tcre.exec.v1.optim: Completed iteration 50 of 64 (score = -0.620689655172413)
# 2019-09-11 14:59:50,231:INFO:tcre.exec.v1.optim: Completed iteration 51 of 64 (score = -0.6666666666666661)
# 2019-09-11 15:00:07,253:INFO:tcre.exec.v1.optim: Completed iteration 52 of 64 (score = -0.7169811320754711)
# 2019-09-11 15:00:23,775:INFO:tcre.exec.v1.optim: Completed iteration 53 of 64 (score = -0.5964912280701751)
# 2019-09-11 15:00:40,486:INFO:tcre.exec.v1.optim: Completed iteration 54 of 64 (score = -0.7450980392156861)
# 2019-09-11 15:00:56,986:INFO:tcre.exec.v1.optim: Completed iteration 55 of 64 (score = -0.7391304347826081)
# 2019-09-11 15:01:14,237:INFO:tcre.exec.v1.optim: Completed iteration 56 of 64 (score = -0.799999999999999)
# 2019-09-11 15:01:36,403:INFO:tcre.exec.v1.optim: Completed iteration 57 of 64 (score = -0.75)
# 2019-09-11 15:01:55,654:INFO:tcre.exec.v1.optim: Completed iteration 58 of 64 (score = -0.73469387755102)
# 2019-09-11 15:02:10,889:INFO:tcre.exec.v1.optim: Completed iteration 59 of 64 (score = -0.6666666666666661)
# 2019-09-11 15:02:26,765:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/inducing_cytokine/checkpoints/checkpoint.pkl
# 2019-09-11 15:02:26,856:INFO:tcre.exec.v1.optim: Completed iteration 60 of 64 (score = -0.6885245901639341)
# 2019-09-11 15:02:46,249:INFO:tcre.exec.v1.optim: Completed iteration 61 of 64 (score = -0.695652173913043)
# 2019-09-11 15:03:03,564:INFO:tcre.exec.v1.optim: Completed iteration 62 of 64 (score = -0.703703703703703)
# 2019-09-11 15:03:20,418:INFO:tcre.exec.v1.optim: Completed iteration 63 of 64 (score = -0.7307692307692301)
# 2019-09-11 15:03:35,804:INFO:tcre.exec.v1.optim: Completed iteration 64 of 64 (score = -0.6666666666666661)
# 2019-09-11 15:03:35,962:INFO:root: Saved scores to /lab/data/results/modeling-rnn-strong/run4/inducing_cytokine/scores.feather
# 2019-09-11 15:03:35,964:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/inducing_cytokine/checkpoints/checkpoint.pkl
# 2019-09-11 15:03:36,056:INFO:root: Saved final result
# 2019-09-11 15:03:36,057:INFO:root: Running optimization for task secreted_cytokine
# 2019-09-11 15:03:36,058:INFO:tcre.exec.v1.optim: Beginning parameter search with max iterations 64
# 2019-09-11 15:03:56,581:INFO:tcre.exec.v1.optim: Completed iteration 1 of 64 (score = -0.7222222222222221)
# 2019-09-11 15:04:13,700:INFO:tcre.exec.v1.optim: Completed iteration 2 of 64 (score = -0.697247706422018)
# 2019-09-11 15:04:33,967:INFO:tcre.exec.v1.optim: Completed iteration 3 of 64 (score = -0.701754385964912)
# 2019-09-11 15:04:53,267:INFO:tcre.exec.v1.optim: Completed iteration 4 of 64 (score = -0.672268907563025)
# 2019-09-11 15:05:12,274:INFO:tcre.exec.v1.optim: Completed iteration 5 of 64 (score = -0.685185185185185)
# 2019-09-11 15:05:28,971:INFO:tcre.exec.v1.optim: Completed iteration 6 of 64 (score = -0.671874999999999)
# 2019-09-11 15:05:46,736:INFO:tcre.exec.v1.optim: Completed iteration 7 of 64 (score = -0.693548387096774)
# 2019-09-11 15:06:06,079:INFO:tcre.exec.v1.optim: Completed iteration 8 of 64 (score = -0.7154471544715441)
# 2019-09-11 15:06:23,562:INFO:tcre.exec.v1.optim: Completed iteration 9 of 64 (score = -0.6727272727272721)
# 2019-09-11 15:06:43,006:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/secreted_cytokine/checkpoints/checkpoint.pkl
# 2019-09-11 15:06:43,040:INFO:tcre.exec.v1.optim: Completed iteration 10 of 64 (score = -0.701754385964912)
# 2019-09-11 15:07:00,196:INFO:tcre.exec.v1.optim: Completed iteration 11 of 64 (score = -0.7000000000000001)
# 2019-09-11 15:07:18,011:INFO:tcre.exec.v1.optim: Completed iteration 12 of 64 (score = -0.645833333333333)
# 2019-09-11 15:07:35,513:INFO:tcre.exec.v1.optim: Completed iteration 13 of 64 (score = -0.6929133858267711)
# 2019-09-11 15:07:54,481:INFO:tcre.exec.v1.optim: Completed iteration 14 of 64 (score = -0.7256637168141591)
# 2019-09-11 15:08:11,518:INFO:tcre.exec.v1.optim: Completed iteration 15 of 64 (score = -0.6880000000000001)
# 2019-09-11 15:08:30,369:INFO:tcre.exec.v1.optim: Completed iteration 16 of 64 (score = -0.7213114754098361)
# 2019-09-11 15:08:49,246:INFO:tcre.exec.v1.optim: Completed iteration 17 of 64 (score = -0.704918032786885)
# 2019-09-11 15:09:07,239:INFO:tcre.exec.v1.optim: Completed iteration 18 of 64 (score = -0.678899082568807)
# 2019-09-11 15:09:24,722:INFO:tcre.exec.v1.optim: Completed iteration 19 of 64 (score = -0.710280373831775)
# 2019-09-11 15:09:43,597:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/secreted_cytokine/checkpoints/checkpoint.pkl
# 2019-09-11 15:09:43,640:INFO:tcre.exec.v1.optim: Completed iteration 20 of 64 (score = -0.704761904761904)
# 2019-09-11 15:10:01,494:INFO:tcre.exec.v1.optim: Completed iteration 21 of 64 (score = -0.6949152542372881)
# 2019-09-11 15:10:19,579:INFO:tcre.exec.v1.optim: Completed iteration 22 of 64 (score = -0.684684684684684)
# 2019-09-11 15:10:37,863:INFO:tcre.exec.v1.optim: Completed iteration 23 of 64 (score = -0.6981132075471691)
# 2019-09-11 15:10:55,692:INFO:tcre.exec.v1.optim: Completed iteration 24 of 64 (score = -0.683333333333333)
# 2019-09-11 15:11:13,551:INFO:tcre.exec.v1.optim: Completed iteration 25 of 64 (score = -0.6818181818181811)
# 2019-09-11 15:11:32,333:INFO:tcre.exec.v1.optim: Completed iteration 26 of 64 (score = -0.678899082568807)
# 2019-09-11 15:11:51,631:INFO:tcre.exec.v1.optim: Completed iteration 27 of 64 (score = -0.697247706422018)
# 2019-09-11 15:12:12,908:INFO:tcre.exec.v1.optim: Completed iteration 28 of 64 (score = -0.704918032786885)
# 2019-09-11 15:12:29,804:INFO:tcre.exec.v1.optim: Completed iteration 29 of 64 (score = -0.661016949152542)
# 2019-09-11 15:12:46,745:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/secreted_cytokine/checkpoints/checkpoint.pkl
# 2019-09-11 15:12:46,798:INFO:tcre.exec.v1.optim: Completed iteration 30 of 64 (score = -0.678899082568807)
# 2019-09-11 15:13:04,577:INFO:tcre.exec.v1.optim: Completed iteration 31 of 64 (score = -0.7027027027027021)
# 2019-09-11 15:13:22,830:INFO:tcre.exec.v1.optim: Completed iteration 32 of 64 (score = -0.679611650485436)
# 2019-09-11 15:13:44,644:INFO:tcre.exec.v1.optim: Completed iteration 33 of 64 (score = -0.6964285714285711)
# 2019-09-11 15:14:03,443:INFO:tcre.exec.v1.optim: Completed iteration 34 of 64 (score = -0.7155963302752291)
# 2019-09-11 15:14:24,616:INFO:tcre.exec.v1.optim: Completed iteration 35 of 64 (score = -0.689655172413793)
# 2019-09-11 15:14:42,036:INFO:tcre.exec.v1.optim: Completed iteration 36 of 64 (score = -0.661290322580645)
# 2019-09-11 15:14:59,370:INFO:tcre.exec.v1.optim: Completed iteration 37 of 64 (score = -0.6942148760330571)
# 2019-09-11 15:15:17,024:INFO:tcre.exec.v1.optim: Completed iteration 38 of 64 (score = -0.6551724137931031)
# 2019-09-11 15:15:35,490:INFO:tcre.exec.v1.optim: Completed iteration 39 of 64 (score = -0.703703703703703)
# 2019-09-11 15:15:53,808:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/secreted_cytokine/checkpoints/checkpoint.pkl
# 2019-09-11 15:15:53,864:INFO:tcre.exec.v1.optim: Completed iteration 40 of 64 (score = -0.704)
# 2019-09-11 15:16:11,984:INFO:tcre.exec.v1.optim: Completed iteration 41 of 64 (score = -0.672268907563025)
# 2019-09-11 15:16:29,719:INFO:tcre.exec.v1.optim: Completed iteration 42 of 64 (score = -0.7142857142857141)
# 2019-09-11 15:16:48,337:INFO:tcre.exec.v1.optim: Completed iteration 43 of 64 (score = -0.7058823529411761)
# 2019-09-11 15:17:06,358:INFO:tcre.exec.v1.optim: Completed iteration 44 of 64 (score = -0.7155963302752291)
# 2019-09-11 15:17:23,469:INFO:tcre.exec.v1.optim: Completed iteration 45 of 64 (score = -0.69090909090909)
# 2019-09-11 15:17:41,309:INFO:tcre.exec.v1.optim: Completed iteration 46 of 64 (score = -0.6538461538461531)
# 2019-09-11 15:18:00,510:INFO:tcre.exec.v1.optim: Completed iteration 47 of 64 (score = -0.7155963302752291)
# 2019-09-11 15:18:18,571:INFO:tcre.exec.v1.optim: Completed iteration 48 of 64 (score = -0.69090909090909)
# 2019-09-11 15:18:36,408:INFO:tcre.exec.v1.optim: Completed iteration 49 of 64 (score = -0.704918032786885)
# 2019-09-11 15:18:53,047:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/secreted_cytokine/checkpoints/checkpoint.pkl
# 2019-09-11 15:18:53,130:INFO:tcre.exec.v1.optim: Completed iteration 50 of 64 (score = -0.682539682539682)
# 2019-09-11 15:19:10,089:INFO:tcre.exec.v1.optim: Completed iteration 51 of 64 (score = -0.637931034482758)
# 2019-09-11 15:19:28,576:INFO:tcre.exec.v1.optim: Completed iteration 52 of 64 (score = -0.6732673267326731)
# 2019-09-11 15:19:45,687:INFO:tcre.exec.v1.optim: Completed iteration 53 of 64 (score = -0.6727272727272721)
# 2019-09-11 15:20:03,113:INFO:tcre.exec.v1.optim: Completed iteration 54 of 64 (score = -0.697247706422018)
# 2019-09-11 15:20:20,345:INFO:tcre.exec.v1.optim: Completed iteration 55 of 64 (score = -0.660550458715596)
# 2019-09-11 15:20:39,929:INFO:tcre.exec.v1.optim: Completed iteration 56 of 64 (score = -0.6976744186046511)
# 2019-09-11 15:20:58,099:INFO:tcre.exec.v1.optim: Completed iteration 57 of 64 (score = -0.7027027027027021)
# 2019-09-11 15:21:18,712:INFO:tcre.exec.v1.optim: Completed iteration 58 of 64 (score = -0.72)
# 2019-09-11 15:21:35,486:INFO:tcre.exec.v1.optim: Completed iteration 59 of 64 (score = -0.6911764705882351)
# 2019-09-11 15:21:52,386:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/secreted_cytokine/checkpoints/checkpoint.pkl
# 2019-09-11 15:21:52,475:INFO:tcre.exec.v1.optim: Completed iteration 60 of 64 (score = -0.661290322580645)
# 2019-09-11 15:22:11,100:INFO:tcre.exec.v1.optim: Completed iteration 61 of 64 (score = -0.685185185185185)
# 2019-09-11 15:22:29,404:INFO:tcre.exec.v1.optim: Completed iteration 62 of 64 (score = -0.703125)
# 2019-09-11 15:22:46,720:INFO:tcre.exec.v1.optim: Completed iteration 63 of 64 (score = -0.69090909090909)
# 2019-09-11 15:23:03,312:INFO:tcre.exec.v1.optim: Completed iteration 64 of 64 (score = -0.65079365079365)
# 2019-09-11 15:23:03,399:INFO:root: Saved scores to /lab/data/results/modeling-rnn-strong/run4/secreted_cytokine/scores.feather
# 2019-09-11 15:23:03,401:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/secreted_cytokine/checkpoints/checkpoint.pkl
# 2019-09-11 15:23:03,496:INFO:root: Saved final result
# 2019-09-11 15:23:03,497:INFO:root: Running optimization for task inducing_transcription_factor
# 2019-09-11 15:23:03,498:INFO:tcre.exec.v1.optim: Beginning parameter search with max iterations 64
# 2019-09-11 15:23:19,771:INFO:tcre.exec.v1.optim: Completed iteration 1 of 64 (score = -0.7358490566037731)
# 2019-09-11 15:23:39,812:INFO:tcre.exec.v1.optim: Completed iteration 2 of 64 (score = -0.752475247524752)
# 2019-09-11 15:23:56,458:INFO:tcre.exec.v1.optim: Completed iteration 3 of 64 (score = -0.73469387755102)
# 2019-09-11 15:24:15,545:INFO:tcre.exec.v1.optim: Completed iteration 4 of 64 (score = -0.8041237113402061)
# 2019-09-11 15:24:35,916:INFO:tcre.exec.v1.optim: Completed iteration 5 of 64 (score = -0.7500000000000001)
# 2019-09-11 15:24:52,033:INFO:tcre.exec.v1.optim: Completed iteration 6 of 64 (score = -0.7741935483870961)
# 2019-09-11 15:25:07,489:INFO:tcre.exec.v1.optim: Completed iteration 7 of 64 (score = -0.721649484536082)
# 2019-09-11 15:25:24,289:INFO:tcre.exec.v1.optim: Completed iteration 8 of 64 (score = -0.7526881720430101)
# 2019-09-11 15:25:40,028:INFO:tcre.exec.v1.optim: Completed iteration 9 of 64 (score = -0.755102040816326)
# 2019-09-11 15:25:56,997:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/inducing_transcription_factor/checkpoints/checkpoint.pkl
# 2019-09-11 15:25:57,033:INFO:tcre.exec.v1.optim: Completed iteration 10 of 64 (score = -0.76)
# 2019-09-11 15:26:15,057:INFO:tcre.exec.v1.optim: Completed iteration 11 of 64 (score = -0.7450980392156861)
# 2019-09-11 15:26:31,245:INFO:tcre.exec.v1.optim: Completed iteration 12 of 64 (score = -0.718446601941747)
# 2019-09-11 15:26:47,914:INFO:tcre.exec.v1.optim: Completed iteration 13 of 64 (score = -0.7272727272727271)
# 2019-09-11 15:27:04,868:INFO:tcre.exec.v1.optim: Completed iteration 14 of 64 (score = -0.7578947368421051)
# 2019-09-11 15:27:21,043:INFO:tcre.exec.v1.optim: Completed iteration 15 of 64 (score = -0.7659574468085101)
# 2019-09-11 15:27:41,412:INFO:tcre.exec.v1.optim: Completed iteration 16 of 64 (score = -0.76)
# 2019-09-11 15:27:58,188:INFO:tcre.exec.v1.optim: Completed iteration 17 of 64 (score = -0.7307692307692301)
# 2019-09-11 15:28:14,214:INFO:tcre.exec.v1.optim: Completed iteration 18 of 64 (score = -0.737864077669902)
# 2019-09-11 15:28:30,953:INFO:tcre.exec.v1.optim: Completed iteration 19 of 64 (score = -0.7339449541284401)
# 2019-09-11 15:28:47,558:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/inducing_transcription_factor/checkpoints/checkpoint.pkl
# 2019-09-11 15:28:47,599:INFO:tcre.exec.v1.optim: Completed iteration 20 of 64 (score = -0.74)
# 2019-09-11 15:29:03,540:INFO:tcre.exec.v1.optim: Completed iteration 21 of 64 (score = -0.7428571428571431)
# 2019-09-11 15:29:21,321:INFO:tcre.exec.v1.optim: Completed iteration 22 of 64 (score = -0.755102040816326)
# 2019-09-11 15:29:37,661:INFO:tcre.exec.v1.optim: Completed iteration 23 of 64 (score = -0.725490196078431)
# 2019-09-11 15:29:54,748:INFO:tcre.exec.v1.optim: Completed iteration 24 of 64 (score = -0.74)
# 2019-09-11 15:30:10,418:INFO:tcre.exec.v1.optim: Completed iteration 25 of 64 (score = -0.72072072072072)
# 2019-09-11 15:30:30,051:INFO:tcre.exec.v1.optim: Completed iteration 26 of 64 (score = -0.7446808510638291)
# 2019-09-11 15:30:46,220:INFO:tcre.exec.v1.optim: Completed iteration 27 of 64 (score = -0.74)
# 2019-09-11 15:31:02,299:INFO:tcre.exec.v1.optim: Completed iteration 28 of 64 (score = -0.7659574468085101)
# 2019-09-11 15:31:18,704:INFO:tcre.exec.v1.optim: Completed iteration 29 of 64 (score = -0.737864077669902)
# 2019-09-11 15:31:34,856:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/inducing_transcription_factor/checkpoints/checkpoint.pkl
# 2019-09-11 15:31:34,908:INFO:tcre.exec.v1.optim: Completed iteration 30 of 64 (score = -0.7500000000000001)
# 2019-09-11 15:31:50,831:INFO:tcre.exec.v1.optim: Completed iteration 31 of 64 (score = -0.74)
# 2019-09-11 15:32:07,051:INFO:tcre.exec.v1.optim: Completed iteration 32 of 64 (score = -0.7128712871287131)
# 2019-09-11 15:32:23,511:INFO:tcre.exec.v1.optim: Completed iteration 33 of 64 (score = -0.7358490566037731)
# 2019-09-11 15:32:41,041:INFO:tcre.exec.v1.optim: Completed iteration 34 of 64 (score = -0.7326732673267321)
# 2019-09-11 15:33:00,664:INFO:tcre.exec.v1.optim: Completed iteration 35 of 64 (score = -0.7628865979381441)
# 2019-09-11 15:33:16,278:INFO:tcre.exec.v1.optim: Completed iteration 36 of 64 (score = -0.725490196078431)
# 2019-09-11 15:33:32,066:INFO:tcre.exec.v1.optim: Completed iteration 37 of 64 (score = -0.74)
# 2019-09-11 15:33:48,804:INFO:tcre.exec.v1.optim: Completed iteration 38 of 64 (score = -0.7676767676767671)
# 2019-09-11 15:34:07,218:INFO:tcre.exec.v1.optim: Completed iteration 39 of 64 (score = -0.7446808510638291)
# 2019-09-11 15:34:24,580:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/inducing_transcription_factor/checkpoints/checkpoint.pkl
# 2019-09-11 15:34:24,645:INFO:tcre.exec.v1.optim: Completed iteration 40 of 64 (score = -0.7368421052631581)
# 2019-09-11 15:34:41,074:INFO:tcre.exec.v1.optim: Completed iteration 41 of 64 (score = -0.769230769230769)
# 2019-09-11 15:34:56,991:INFO:tcre.exec.v1.optim: Completed iteration 42 of 64 (score = -0.7474747474747471)
# 2019-09-11 15:35:12,745:INFO:tcre.exec.v1.optim: Completed iteration 43 of 64 (score = -0.7222222222222221)
# 2019-09-11 15:35:28,677:INFO:tcre.exec.v1.optim: Completed iteration 44 of 64 (score = -0.7450980392156861)
# 2019-09-11 15:35:44,565:INFO:tcre.exec.v1.optim: Completed iteration 45 of 64 (score = -0.755102040816326)
# 2019-09-11 15:36:01,676:INFO:tcre.exec.v1.optim: Completed iteration 46 of 64 (score = -0.7307692307692301)
# 2019-09-11 15:36:18,943:INFO:tcre.exec.v1.optim: Completed iteration 47 of 64 (score = -0.7474747474747471)
# 2019-09-11 15:36:34,659:INFO:tcre.exec.v1.optim: Completed iteration 48 of 64 (score = -0.747663551401869)
# 2019-09-11 15:36:50,664:INFO:tcre.exec.v1.optim: Completed iteration 49 of 64 (score = -0.7428571428571431)
# 2019-09-11 15:37:06,615:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/inducing_transcription_factor/checkpoints/checkpoint.pkl
# 2019-09-11 15:37:06,693:INFO:tcre.exec.v1.optim: Completed iteration 50 of 64 (score = -0.7304347826086951)
# 2019-09-11 15:37:22,642:INFO:tcre.exec.v1.optim: Completed iteration 51 of 64 (score = -0.737864077669902)
# 2019-09-11 15:37:38,955:INFO:tcre.exec.v1.optim: Completed iteration 52 of 64 (score = -0.7128712871287131)
# 2019-09-11 15:37:55,370:INFO:tcre.exec.v1.optim: Completed iteration 53 of 64 (score = -0.755102040816326)
# 2019-09-11 15:38:11,750:INFO:tcre.exec.v1.optim: Completed iteration 54 of 64 (score = -0.7321428571428571)
# 2019-09-11 15:38:27,069:INFO:tcre.exec.v1.optim: Completed iteration 55 of 64 (score = -0.7157894736842101)
# 2019-09-11 15:38:44,415:INFO:tcre.exec.v1.optim: Completed iteration 56 of 64 (score = -0.752475247524752)
# 2019-09-11 15:39:02,012:INFO:tcre.exec.v1.optim: Completed iteration 57 of 64 (score = -0.755102040816326)
# 2019-09-11 15:39:20,266:INFO:tcre.exec.v1.optim: Completed iteration 58 of 64 (score = -0.7916666666666661)
# 2019-09-11 15:39:35,947:INFO:tcre.exec.v1.optim: Completed iteration 59 of 64 (score = -0.7200000000000001)
# 2019-09-11 15:39:51,259:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/inducing_transcription_factor/checkpoints/checkpoint.pkl
# 2019-09-11 15:39:51,328:INFO:tcre.exec.v1.optim: Completed iteration 60 of 64 (score = -0.7272727272727271)
# 2019-09-11 15:40:08,571:INFO:tcre.exec.v1.optim: Completed iteration 61 of 64 (score = -0.74)
# 2019-09-11 15:40:24,607:INFO:tcre.exec.v1.optim: Completed iteration 62 of 64 (score = -0.76)
# 2019-09-11 15:40:40,369:INFO:tcre.exec.v1.optim: Completed iteration 63 of 64 (score = -0.7339449541284401)
# 2019-09-11 15:40:56,460:INFO:tcre.exec.v1.optim: Completed iteration 64 of 64 (score = -0.778947368421052)
# 2019-09-11 15:40:56,539:INFO:root: Saved scores to /lab/data/results/modeling-rnn-strong/run4/inducing_transcription_factor/scores.feather
# 2019-09-11 15:40:56,540:INFO:tcre.exec.v1.optim: Saving checkpoint to /lab/data/results/modeling-rnn-strong/run4/inducing_transcription_factor/checkpoints/checkpoint.pkl
# 2019-09-11 15:40:56,614:INFO:root: Saved final result

# %%
print(tasks[0])
res, scores, callbacks = results[tasks[0]]
# Out:
# inducing_cytokine

# %%
times = callbacks['timer'].iter_time
pd.Series(times).describe()
# Out:
# count    64.000000
# mean     18.179572
# std       2.455694
# min      15.235013
# 25%      16.682267
# 50%      17.352708
# 75%      19.286967
# max      28.460095
# dtype: float64

# %%
res.func_vals[:5]
# Out:
# array([-0.69387755, -0.65517241, -0.5862069 , -0.68      , -0.71111111])

# %%
pd.DataFrame(res.x_iters[:5], columns=[dim.name for dim in space])
# Out:
#   marker_list  use_secondary  use_swaps  use_positions wrd_embedding_type  \
# 0     doub_01           True       True           True        w2v_trained
# 1     doub_01          False       True           True        w2v_trained
# 2     doub_01          False       True           True         w2v_frozen
# 3     doub_01          False       True           True        w2v_trained
# 4     doub_01           True       True           True        w2v_trained
#
#   model_size  weight_decay  learning_rate  dropout cell_type  bidirectional
# 0       XXXL         0.000          0.010     0.75      LSTM          False
# 1       XXXL         0.005          0.050     0.25      LSTM          False
# 2      XXXXL         0.005          0.010     0.00      LSTM          False
# 3         XL         0.005          0.005     0.75      LSTM          False
# 4      XXXXL         0.001          0.005     0.00      LSTM          False

# %%
res.models[:5]
# Out:
# []

# %% [markdown]
# ## Analysis

# %%
output_dir
# Out:
# '/lab/data/results/modeling-rnn-strong/run4'

# %%
# !ls $output_dir
# Out:
# inducing_cytokine  inducing_transcription_factor  secreted_cytokine

# %%
import skopt
# Restore from serialized data

results = {}
for task in tasks:
    optimizer = optimizers[task]
    res = skopt.load(optimizer.get_checkpoints_file())
    
    scores = None
    scores_file = osp.join(optimizer.output_dir, 'scores.feather')
    if osp.exists(scores_file):
        scores = pd.read_feather(scores_file)
    
    results[task] = res, scores, globals().get('times')

# %%
def get_dfx(results):
    df = []
    for k in results:
        res = results[k][0]
        dfx = pd.DataFrame(res.x_iters, columns=[dim.name for dim in space])
        dfx['score'] = -res.func_vals
        dfx['task'] = k
        dfx['iteration'] = np.arange(len(dfx))
        df.append(dfx)
    return pd.concat(df)

# %%
dfx = get_dfx(results)
props = dfx.drop(['score', 'task', 'iteration'], axis=1).columns.tolist()
print(props)
dfx.head()
# Out:
# ['marker_list', 'use_secondary', 'use_swaps', 'use_positions', 'wrd_embedding_type', 'model_size', 'weight_decay', 'learning_rate', 'dropout', 'cell_type', 'bidirectional']
#   marker_list  use_secondary  use_swaps  use_positions wrd_embedding_type  \
# 0     doub_01           True       True           True        w2v_trained
# 1     doub_01          False       True           True        w2v_trained
# 2     doub_01          False       True           True         w2v_frozen
# 3     doub_01          False       True           True        w2v_trained
# 4     doub_01           True       True           True        w2v_trained
#
#   model_size  weight_decay  learning_rate  dropout cell_type  bidirectional  \
# 0       XXXL         0.000          0.010     0.75      LSTM          False
# 1       XXXL         0.005          0.050     0.25      LSTM          False
# 2      XXXXL         0.005          0.010     0.00      LSTM          False
# 3         XL         0.005          0.005     0.75      LSTM          False
# 4      XXXXL         0.001          0.005     0.00      LSTM          False
#
#       score               task  iteration
# 0  0.693878  inducing_cytokine          0
# 1  0.655172  inducing_cytokine          1
# 2  0.586207  inducing_cytokine          2
# 3  0.680000  inducing_cytokine          3
# 4  0.711111  inducing_cytokine          4

# %%
# Show top configs by task
pd.set_option('display.max_rows', 100)
dfx.groupby('task').apply(lambda g: g.sort_values('score', ascending=False).iloc[:8].reset_index(drop=True)).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row0_col8 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row0_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row0_col13 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row1_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row1_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row1_col8 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row1_col11 {
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row1_col13 {
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row2_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row2_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row2_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row2_col11 {
#             background-color:  #197db7;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row2_col13 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row3_col6 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row3_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row3_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row3_col11 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row3_col13 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row4_col6 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row4_col7 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row4_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row4_col11 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row4_col13 {
#             background-color:  #2081b9;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row5_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row5_col7 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row5_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row5_col11 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row5_col13 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row6_col6 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row6_col7 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row6_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row6_col11 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row6_col13 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row7_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row7_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row7_col8 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row7_col11 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row7_col13 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row8_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row8_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row8_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row8_col11 {
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row8_col13 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row9_col6 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row9_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row9_col8 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row9_col11 {
#             background-color:  #056fae;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row9_col13 {
#             background-color:  #045280;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row10_col6 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row10_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row10_col8 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row10_col11 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row10_col13 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row11_col6 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row11_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row11_col8 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row11_col11 {
#             background-color:  #4a98c5;
#             color:  #000000;
#         }    #T_0d7d34b0_d4b2_11e9_8a64_0242ac110002row11_col13 {
#             background-color:  #f3edf5

# %% [markdown]
# ### Parameter Regression

# %%
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, message='The default of the `iid` parameter.*')

def get_coefs(est):
    coefs = []
    grps = dfx.groupby(['task'])
    fig, axs = plt.subplots(1, len(grps))
    if len(grps) == 1:
        axs = [axs]
    fig.set_size_inches(18, 4)
    for i, (k, g) in enumerate(grps):
        X = pd.get_dummies(g.drop(['task', 'iteration', 'score'], axis=1).astype(str), prefix_sep=':')
        y = g['score'].values
        est = est.fit(X.values, y)
        y_pred = est.predict(X)
        score = max(r2_score(y, y_pred), 0)
        title = f'{est.__class__.__name__} {k} (R2={score:.2f})'
        pd.DataFrame({'y_true': y, 'y_pred': y_pred}).plot(kind='scatter', x='y_pred', y='y_true', ax=axs[i], title=title)
        coefs.append(
            pd.Series(est.coef_, index=X.columns.to_list()).sort_index()
            .append(pd.Series(dict(task=k, score=score, est=est.__class__.__name__)))
        )
    return est, pd.DataFrame(coefs)

def plot_coefs(est, coefs):
    return (
        pn.ggplot(
            coefs
                .set_index('task').rename_axis('metric', axis='columns').stack().rename('value').reset_index()
                .assign(metric=lambda df: pd.Categorical(df['metric'], ordered=True, categories=df.groupby('metric')['value'].mean().sort_values().index)), 
            pn.aes(x='metric', y='value', fill='task', color='task', group='task')
        ) + 
        pn.geom_point() +
        pn.geom_line() + 
        pn.ggtitle(type(est).__name__) + 
        pn.theme(figure_size=(12, 4), axis_text_x=pn.element_text(rotation=90, hjust=.5))
    )

# %%
from sklearn.linear_model import LassoCV, RidgeCV, ElasticNetCV

# %%
df_coef = pd.concat([
    get_coefs(RidgeCV(normalize=True, cv=5))[1],
    get_coefs(LassoCV(normalize=True, cv=5, random_state=1))[1],
    get_coefs(ElasticNetCV(normalize=True, cv=5, random_state=1))[1]
])

# Add weight for each model as R2 for model / R2 for all models
df_coef = df_coef.groupby('task', group_keys=False).apply(lambda g: g.assign(weight=(g['score'] / g['score'].sum())))
df_coef = df_coef.set_index(['task', 'score', 'est', 'weight'])

df_coef.head()
# Out:
#                                                               bidirectional:False  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253                  0.0
#                               0.724958 LassoCV      0.332290                  0.0
#                               0.725322 ElasticNetCV 0.332457                  0.0
# inducing_transcription_factor 0.280064 RidgeCV      0.351183                  0.0
#                               0.259473 LassoCV      0.325364                  0.0
#
#                                                               cell_type:LSTM  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253             0.0
#                               0.724958 LassoCV      0.332290             0.0
#                               0.725322 ElasticNetCV 0.332457             0.0
# inducing_transcription_factor 0.280064 RidgeCV      0.351183             0.0
#                               0.259473 LassoCV      0.325364             0.0
#
#                                                               dropout:0.0  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253    -0.007491
#                               0.724958 LassoCV      0.332290    -0.009909
#                               0.725322 ElasticNetCV 0.332457    -0.010040
# inducing_transcription_factor 0.280064 RidgeCV      0.351183    -0.000290
#                               0.259473 LassoCV      0.325364     0.000000
#
#                                                               dropout:0.25  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253     -0.010061
#                               0.724958 LassoCV      0.332290     -0.012520
#                               0.725322 ElasticNetCV 0.332457     -0.012567
# inducing_transcription_factor 0.280064 RidgeCV      0.351183     -0.002300
#                               0.259473 LassoCV      0.325364     -0.000000
#
#                                                               dropout:0.5  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253     0.006913
#                               0.724958 LassoCV      0.332290     0.000000
#                               0.725322 ElasticNetCV 0.332457     0.000000
# inducing_transcription_factor 0.280064 RidgeCV      0.351183    -0.001059
#                               0.259473 LassoCV      0.325364    -0.000000
#
#                                                               dropout:0.75  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253      0.007509
#                               0.724958 LassoCV      0.332290      0.001321
#                               0.725322 ElasticNetCV 0.332457      0.001395
# inducing_transcription_factor 0.280064 RidgeCV      0.351183      0.003591
#                               0.259473 LassoCV      0.325364      0.005164
#
#                                                               learning_rate:0.005  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253            -0.017022
#                               0.724958 LassoCV      0.332290            -0.016036
#                               0.725322 ElasticNetCV 0.332457            -0.016016
# inducing_transcription_factor 0.280064 RidgeCV      0.351183            -0.000522
#                               0.259473 LassoCV      0.325364            -0.000000
#
#                                                               learning_rate:0.01  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253            0.000007
#                               0.724958 LassoCV      0.332290            0.000000
#                               0.725322 ElasticNetCV 0.332457            0.000000
# inducing_transcription_factor 0.280064 RidgeCV      0.351183           -0.002631
#                               0.259473 LassoCV      0.325364           -0.000817
#
#                                                               learning_rate:0.05  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253            0.017955
#                               0.724958 LassoCV      0.332290            0.018269
#                               0.725322 ElasticNetCV 0.332457            0.018185
# inducing_transcription_factor 0.280064 RidgeCV      0.351183            0.002826
#                               0.259473 LassoCV      0.325364            0.003649
#
#                                                               marker_list:doub_01  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253                  0.0
#                               0.724958 LassoCV      0.332290                  0.0
#                               0.725322 ElasticNetCV 0.332457                  0.0
# inducing_transcription_factor 0.280064 RidgeCV      0.351183                  0.0
#                               0.259473 LassoCV      0.325364                  0.0
#
#                                                               ...  \
# task                          score    est          weight    ...
# inducing_cytokine             0.731422 RidgeCV      0.335253  ...
#                               0.724958 LassoCV      0.332290  ...
#                               0.725322 ElasticNetCV 0.332457  ...
# inducing_transcription_factor 0.280064 RidgeCV      0.351183  ...
#                               0.259473 LassoCV      0.325364  ...
#
#                                                               use_positions:True  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253                 0.0
#                               0.724958 LassoCV      0.332290                 0.0
#                               0.725322 ElasticNetCV 0.332457                 0.0
# inducing_transcription_factor 0.280064 RidgeCV      0.351183                 0.0
#                               0.259473 LassoCV      0.325364                 0.0
#
#                                                               use_secondary:False  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253            -0.046815
#                               0.724958 LassoCV      0.332290            -0.095483
#                               0.725322 ElasticNetCV 0.332457            -0.047689
# inducing_transcription_factor 0.280064 RidgeCV      0.351183             0.002722
#                               0.259473 LassoCV      0.325364             0.003777
#
#                                                               use_secondary:True  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253            0.046815
#                               0.724958 LassoCV      0.332290            0.000000
#                               0.725322 ElasticNetCV 0.332457            0.047285
# inducing_transcription_factor 0.280064 RidgeCV      0.351183           -0.002722
#                               0.259473 LassoCV      0.325364           -0.000000
#
#                                                               use_swaps:True  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253             0.0
#                               0.724958 LassoCV      0.332290             0.0
#                               0.725322 ElasticNetCV 0.332457             0.0
# inducing_transcription_factor 0.280064 RidgeCV      0.351183             0.0
#                               0.259473 LassoCV      0.325364             0.0
#
#                                                               weight_decay:0.0  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253         -0.005126
#                               0.724958 LassoCV      0.332290         -0.000136
#                               0.725322 ElasticNetCV 0.332457         -0.000650
# inducing_transcription_factor 0.280064 RidgeCV      0.351183         -0.002537
#                               0.259473 LassoCV      0.325364         -0.000178
#
#                                                               weight_decay:0.0001  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253            -0.011969
#                               0.724958 LassoCV      0.332290            -0.007601
#                               0.725322 ElasticNetCV 0.332457            -0.008035
# inducing_transcription_factor 0.280064 RidgeCV      0.351183            -0.002257
#                               0.259473 LassoCV      0.325364            -0.000000
#
#                                                               weight_decay:0.001  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253           -0.000139
#                               0.724958 LassoCV      0.332290            0.000000
#                               0.725322 ElasticNetCV 0.332457            0.000000
# inducing_transcription_factor 0.280064 RidgeCV      0.351183            0.000708
#                               0.259473 LassoCV      0.325364            0.000000
#
#                                                               weight_decay:0.005  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253            0.014190
#                               0.724958 LassoCV      0.332290            0.012999
#                               0.725322 ElasticNetCV 0.332457            0.012818
# inducing_transcription_factor 0.280064 RidgeCV      0.351183            0.003542
#                               0.259473 LassoCV      0.325364            0.004816
#
#                                                               wrd_embedding_type:w2v_frozen  \
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253                       0.003830
#                               0.724958 LassoCV      0.332290                       0.004557
#                               0.725322 ElasticNetCV 0.332457                       0.002386
# inducing_transcription_factor 0.280064 RidgeCV      0.351183                       0.001371
#                               0.259473 LassoCV      0.325364                       0.000692
#
#                                                               wrd_embedding_type:w2v_trained
# task                          score    est          weight
# inducing_cytokine             0.731422 RidgeCV      0.335253                   -3.830499e-03
#                               0.724958 LassoCV      0.332290                   -0.000000e+00
#                               0.725322 ElasticNetCV 0.332457                   -2.364714e-03
# inducing_transcription_factor 0.280064 RidgeCV      0.351183                   -1.371119e-03
#                               0.259473 LassoCV      0.325364                   -8.690608e-19
#
# [5 rows x 24 columns]

# %%
df_coef_lng = df_coef.rename_axis('parameter', axis='columns').stack().rename('value').reset_index()
df_coef_lng['weighted_value'] = df_coef_lng['value'] * df_coef_lng['weight']
df_coef_lng.head()
# Out:
#                 task     score      est    weight            parameter  \
# 0  inducing_cytokine  0.731422  RidgeCV  0.335253  bidirectional:False
# 1  inducing_cytokine  0.731422  RidgeCV  0.335253       cell_type:LSTM
# 2  inducing_cytokine  0.731422  RidgeCV  0.335253          dropout:0.0
# 3  inducing_cytokine  0.731422  RidgeCV  0.335253         dropout:0.25
# 4  inducing_cytokine  0.731422  RidgeCV  0.335253          dropout:0.5
#
#       value  weighted_value
# 0  0.000000        0.000000
# 1  0.000000        0.000000
# 2 -0.007491       -0.002511
# 3 -0.010061       -0.003373
# 4  0.006913        0.002318

# %%
(
    pn.ggplot(
        df_coef_lng.assign(parameter=lambda df: pd.Categorical(
            df['parameter'], ordered=True, 
            categories=df.groupby('parameter')['weighted_value'].mean().sort_values().index
        )), 
        pn.aes(x='parameter', y='value', fill='task', color='task', group='task')
    ) + 
    pn.geom_point() +
    pn.geom_line() + 
    pn.ggtitle('Parameter Coefficients by Model') + 
    pn.facet_wrap('~ est', ncol=1) +
    pn.theme(figure_size=(12, 8), axis_text_x=pn.element_text(rotation=90, hjust=.5))
)
# Out:
# <ggplot: (-9223363307607869664)>

# %% [markdown]
# ### Score Distributions

# %%
df_score = pd.concat([v[1].assign(task=k) for k, v in results.items()])
df_score.head()
# Out:
#    iteration  type    metric      value               task
# 0          0           epoch  22.000000  inducing_cytokine
# 1          0  test  accuracy   0.500000  inducing_cytokine
# 2          0  test        ct  58.000000  inducing_cytokine
# 3          0  test        f1   0.524590  inducing_cytokine
# 4          0  test      loss   2.640673  inducing_cytokine

# %%
# Label balance
df_lbl = df_cand.assign(label=lambda df: np.where(df['label'] > 0, 1, 0))
pd.concat([
    df_lbl.assign(agg='count').groupby(['task', 'split', 'agg'])['label'].value_counts().unstack([-2, -1]),
    df_lbl.assign(agg='percent').groupby(['task', 'split', 'agg'])['label'].value_counts(normalize=True).unstack([-2, -1]).round(2)
], axis=1)
# Out:
# agg                                   count      percent
# label                                     0    1       0    1
# task                          split
# inducing_cytokine             predict    23   23     0.5  0.5
#                               test       29   29     0.5  0.5
#                               train     145  145     0.5  0.5
#                               val        23   23     0.5  0.5
# inducing_transcription_factor predict    44   44     0.5  0.5
#                               test       58   58     0.5  0.5
#                               train     107  107     0.5  0.5
#                               val        44   44     0.5  0.5
# secreted_cytokine             predict    49   49     0.5  0.5
#                               test       64   64     0.5  0.5
#                               train     131  131     0.5  0.5
#                               val        49   49     0.5  0.5

# %%
(
    df_score
    .pivot_table(index=['task', 'iteration'], columns=['metric', 'type'], values='value')
    .head()[('epoch', '')]
)
# Out:
# task               iteration
# inducing_cytokine  0            22.0
#                    1            50.0
#                    2             1.0
#                    3            33.0
#                    4            12.0
# Name: (epoch, ), dtype: float64

# %%
df_score.head()
# Out:
#    iteration  type    metric      value               task
# 0          0           epoch  22.000000  inducing_cytokine
# 1          0  test  accuracy   0.500000  inducing_cytokine
# 2          0  test        ct  58.000000  inducing_cytokine
# 3          0  test        f1   0.524590  inducing_cytokine
# 4          0  test      loss   2.640673  inducing_cytokine

# %%
df_top_score = (
    df_score
    # Pivot to task and hyperparameter config number (all scores already filtered to best epoch)
    .pivot_table(index=['task', 'iteration'], columns=['metric', 'type'], values='value')
    # Remove models with early top score
    .pipe(lambda df: df[df[('epoch', '')] >= 5])
    # Filter to best model config based on validation score
    .pipe(lambda df: df.groupby('task').apply(lambda g: g.iloc[np.argmax(g[('f1', 'validation')].values)]))
)
df_top_score.head()
# Out:
# metric                         accuracy                          ct           \
# type                               test  training validation   test training
# task
# inducing_cytokine              0.568966  0.982759   0.804348   58.0    290.0
# inducing_transcription_factor  0.577586  0.691589   0.784091  116.0    214.0
# secreted_cytokine              0.578125  0.980916   0.683673  128.0    262.0
#
# metric                                   epoch        f1                       \
# type                          validation            test  training validation
# task
# inducing_cytokine                   46.0  52.0  0.545455  0.982578   0.816327
# inducing_transcription_factor       88.0  35.0  0.614173  0.707965   0.804124
# secreted_cytokine                   98.0  15.0  0.614286  0.981132   0.725664
#
# metric                         ... precision@70 precision@80            \
# type                           ...   validation         test  training
# task                           ...
# inducing_cytokine              ...     0.772727     0.619048  1.000000
# inducing_transcription_factor  ...     0.875000     0.000000  0.000000
# secreted_cytokine              ...     0.625000     0.472727  0.992126
#
# metric                                   precision@90                      \
# type                          validation         test training validation
# task
# inducing_cytokine               0.722222      0.62500      1.0   0.769231
# inducing_transcription_factor   0.000000      0.00000      0.0   0.000000
# secreted_cytokine               0.608696      0.44898      1.0   0.625000
#
# metric                           recall
# type                               test  training validation
# task
# inducing_cytokine              0.517241  0.972414   0.869565
# inducing_transcription_factor  0.672414  0.747664   0.886364
# secreted_cytokine              0.671875  0.992366   0.836735
#
# [3 rows x 34 columns]

# %%
# Scores at best validation F1 iteration
def get_scores_table(metrics):
    df_bal = (
        df_lbl.assign(metric='balance').groupby(['task', 'metric', 'split'])['label'].value_counts(normalize=True)
        .unstack().round(2)[1].unstack([-2, -1])
    )
    return (
        df_top_score
        .round(2)
        .pipe(lambda df: pd.concat([df, df_bal], axis=1, sort=True))
        .style.background_gradient(cmap='Greens', low=.1, high=.3)
    )

# %%
# Scores at best validation F1 iteration
get_scores_table(['ct', 'f1', 'accuracy', 'precision', 'recall'])
# Out:
# <style  type="text/css" >
#     #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col0 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col1 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col2 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col3 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col4 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col5 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col6 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col7 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col8 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col9 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col10 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col11 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col12 {
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col13 {
#             background-color:  #d0edca;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col14 {
#             background-color:  #d0edca;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col15 {
#             background-color:  #d0edca;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col16 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col17 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col18 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col19 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col20 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col21 {
#             background-color:  #2f984f;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col22 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col23 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col24 {
#             background-color:  #7ac77b;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col25 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col26 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col27 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col28 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col29 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col30 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col31 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col32 {
#             background-color:  #29914a;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col33 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col34 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col35 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col36 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row0_col37 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col0 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col1 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col2 {
#             background-color:  #37a055;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col3 {
#             background-color:  #38a156;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col4 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col5 {
#             background-color:  #3ca559;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col6 {
#             background-color:  #83cb82;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col7 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col8 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col9 {
#             background-color:  #40aa5d;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col10 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col11 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col12 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col13 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col14 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col15 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col16 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col17 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col18 {
#             background-color:  #43ac5e;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col19 {
#             background-color:  #8ed08b;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col20 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_27827672_d4b2_11e9_8a64_0242ac110002row1_col21 {
#             background-color:  #

# %%
# Median scores
p = (
    df_score
    .pipe(lambda df: df[df['metric'].isin(['precision', 'recall', 'f1'])])
    .groupby(['task', 'metric', 'type'])['value'].describe()[['mean', '25%', '50%', '75%']].unstack()['50%'].unstack()[['test', 'validation']]
    .round(3)
    .style.background_gradient(cmap='Greens', low=.3, high=.9)
)

# %%
p
# Out:
# <style  type="text/css" >
#     #T_27ddb532_d4b2_11e9_8a64_0242ac110002row0_col0 {
#             background-color:  #c8e9c1;
#             color:  #000000;
#         }    #T_27ddb532_d4b2_11e9_8a64_0242ac110002row0_col1 {
#             background-color:  #c6e8bf;
#             color:  #000000;
#         }    #T_27ddb532_d4b2_11e9_8a64_0242ac110002row0_col2 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_27ddb532_d4b2_11e9_8a64_0242ac110002row0_col3 {
#             background-color:  #dbf1d6;
#             color:  #000000;
#         }    #T_27ddb532_d4b2_11e9_8a64_0242ac110002row0_col4 {
#             background-color:  #a4da9e;
#             color:  #000000;
#         }    #T_27ddb532_d4b2_11e9_8a64_0242ac110002row0_col5 {
#             background-color:  #8ace88;
#             color:  #000000;
#         }    #T_27ddb532_d4b2_11e9_8a64_0242ac110002row1_col0 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_27ddb532_d4b2_11e9_8a64_0242ac110002row1_col1 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_27ddb532_d4b2_11e9_8a64_0242ac110002row1_col2 {
#             background-color:  #9ed798;
#             color:  #000000;
#         }    #T_27ddb532_d4b2_11e9_8a64_0242ac110002row1_col3 {
#             background-color:  #4eb264;
#             color:  #000000;
#         }    #T_27ddb532_d4b2_11e9_8a64_0242ac110002row1_col4 {
#             background-color:  #4eb264;
#             color:  #000000;
#         }    #T_27ddb532_d4b2_11e9_8a64_0242ac110002row1_col5 {
#             background-color:  #4eb264;
#             color:  #000000;
#         }    #T_27ddb532_d4b2_11e9_8a64_0242ac110002row2_col0 {
#             background-color:  #4eb264;
#             color:  #000000;
#         }    #T_27ddb532_d4b2_11e9_8a64_0242ac110002row2_col1 {
#             background-color:  #4eb264;
#             color:  #000000;
#         }    #T_27ddb532_d4b2_11e9_8a64_0242ac110002row2_col2 {
#             background-color:  #4eb264;
#             color:  #000000;
#         }    #T_27ddb532_d4b2_11e9_8a64_0242ac110002row2_col3 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_27ddb532_d4b2_11e9_8a64_0242ac110002row2_col4 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_27ddb532_d4b2_11e9_8a64_0242ac110002row2_col5 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }</style><table id="T_27ddb532_d4b2_11e9_8a64_0242ac110002" ><thead>    <tr>        <th class="index_name level0" >type</th>        <th class="col_heading level0 col0" colspan=3>test</th>        <th class="col_heading level0 col3" colspan=3>validation</th>    </tr>    <tr>        <th class="index_name level1" >metric</th>        <th class="col_heading level1 col0" >f1</th>        <th class="col_heading level1 col1" >precision</th>        <th class="col_heading level1 col2" >recall</th>        <th class="col_heading level1 col3" >f1</th>        <th class="col_heading level1 col4" >precision</th>        <th class="col_heading level1 col5" >recall</th>    </tr>    <tr>        <th class="index_name level0" >task</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_27ddb532_d4b2_11e9_8a64_0242ac110002level0_row0" class="row_heading level0 row0" >inducing_cytokine</th>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row0_col0" class="data row0 col0" >0.609</td>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row0_col1" class="data row0 col1" >0.547</td>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row0_col2" class="data row0 col2" >0.655</td>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row0_col3" class="data row0 col3" >0.696</td>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row0_col4" class="data row0 col4" >0.633</td>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row0_col5" class="data row0 col5" >0.826</td>
#             </tr>
#             <tr>
#                         <th id="T_27ddb532_d4b2_11e9_8a64_0242ac110002level0_row1" class="row_heading level0 row1" >inducing_transcription_factor</th>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row1_col0" class="data row1 col0" >0.601</td>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row1_col1" class="data row1 col1" >0.538</td>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row1_col2" class="data row1 col2" >0.69</td>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row1_col3" class="data row1 col3" >0.741</td>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row1_col4" class="data row1 col4" >0.661</td>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row1_col5" class="data row1 col5" >0.841</td>
#             </tr>
#             <tr>
#                         <th id="T_27ddb532_d4b2_11e9_8a64_0242ac110002level0_row2" class="row_heading level0 row2" >secreted_cytokine</th>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row2_col0" class="data row2 col0" >0.634</td>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row2_col1" class="data row2 col1" >0.572</td>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row2_col2" class="data row2 col2" >0.719</td>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row2_col3" class="data row2 col3" >0.693</td>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row2_col4" class="data row2 col4" >0.605</td>
#                         <td id="T_27ddb532_d4b2_11e9_8a64_0242ac110002row2_col5" class="data row2 col5" >0.796</td>
#             </tr>
#     </tbody></table>

# %%
(
    pn.ggplot(
        df_score.pipe(lambda df: df[df['metric'].isin(['f1'])]),
        pn.aes(x='type', y='value', fill='type')
    ) + 
    pn.geom_violin() + 
    pn.ylim(.4, 1) +
    pn.labs(y='F1', title='Dev Supervised Model Results', x='Dataset', fill='Dataset') + 
    pn.facet_grid('task ~ metric', scales='free') + 
    pn.theme(figure_size=(3, 7))
)
# Out:
# /opt/conda/envs/nlp/lib/python3.6/site-packages/plotnine/layer.py:360: UserWarning: stat_ydensity : Removed 1 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# <ggplot: (8729247377058)>

# %%
(
    pn.ggplot(
        df_score.pipe(lambda df: df[df['metric'].isin(['f1', 'accuracy', 'precision', 'recall'])]),
        pn.aes(x='type', y='value', fill='type')
    ) + 
    pn.geom_violin() + 
    pn.facet_grid('metric ~ task', scales='free') + 
    pn.theme(figure_size=(12, 8))
)
# Out:
# <ggplot: (8729247282124)>

# %%
(
    pn.ggplot(
        df_score.pipe(lambda df: df[df['metric'].isin(['f1'])]),
        pn.aes(x='type', y='value', fill='type')
    ) + 
    pn.geom_violin() + 
    pn.labs(y='F1', title='Labeling Function Model Results', x='Dataset', fill='Dataset') + 
    pn.facet_grid('metric ~ task', scales='free') + 
    pn.theme(figure_size=(12, 3))
)
# Out:
# <ggplot: (8729247308969)>

# %% [markdown]
# ## Export

# %% [markdown]
# Export scores:

# %%
df_exp = df_top_score.stack().stack().rename('value').reset_index().rename(columns={'type': 'split'}).assign(model='rnn-dev')
assert df_exp.groupby(['task', 'metric', 'split']).size().max() == 1
df_exp.head()
# Out:
#                 task split    metric      value    model
# 0  inducing_cytokine           epoch  52.000000  rnn-dev
# 1  inducing_cytokine  test  accuracy   0.568966  rnn-dev
# 2  inducing_cytokine  test        ct  58.000000  rnn-dev
# 3  inducing_cytokine  test        f1   0.545455  rnn-dev
# 4  inducing_cytokine  test      loss   1.126029  rnn-dev

# %%
df_exp[df_exp['metric'] == 'epoch']['value'].value_counts()
# Out:
# 15.0    1
# 35.0    1
# 52.0    1
# Name: value, dtype: int64

# %%
path = osp.join(output_dir, 'scores.csv')
df_exp.to_csv(path, index=False)
path
# Out:
# '/lab/data/results/modeling-rnn-strong/run4/scores.csv'

# %% [markdown]
# Export top model configurations for each task:

# %%
# Show top 3 models
dftm = dfx.groupby('task', group_keys=False)\
    .apply(lambda g: g.sort_values('score', ascending=False).iloc[:3].reset_index(drop=True).assign(rank=lambda df: 1+np.arange(len(df))))\
    .reset_index(drop=True)\
    .rename(columns={dim.name: f'param:{dim.name}' for dim in space})
dftm
# Out:
#   param:marker_list  param:use_secondary  param:use_swaps  \
# 0           doub_01                 True             True
# 1           doub_01                 True             True
# 2           doub_01                 True             True
# 3           doub_01                False             True
# 4           doub_01                 True             True
# 5           doub_01                False             True
# 6           doub_01                 True             True
# 7           doub_01                 True             True
# 8           doub_01                 True             True
#
#    param:use_positions param:wrd_embedding_type param:model_size  \
# 0                 True              w2v_trained             XXXL
# 1                 True               w2v_frozen              XXL
# 2                 True               w2v_frozen            XXXXL
# 3                 True              w2v_trained               XL
# 4                 True              w2v_trained            XXXXL
# 5                 True               w2v_frozen               XL
# 6                 True               w2v_frozen              XXL
# 7                 True              w2v_trained             XXXL
# 8                 True               w2v_frozen            XXXXL
#
#    param:weight_decay  param:learning_rate  param:dropout param:cell_type  \
# 0              0.0050                0.050           0.25            LSTM
# 1              0.0050                0.050           0.50            LSTM
# 2              0.0050                0.050           0.00            LSTM
# 3              0.0050                0.005           0.75            LSTM
# 4              0.0010                0.050           0.50            LSTM
# 5              0.0001                0.050           0.50            LSTM
# 6              0.0010                0.050           0.75            LSTM
# 7              0.0000                0.010           0.75            LSTM
# 8              0.0050                0.050           0.00            LSTM
#
#    param:bidirectional     score                           task  iteration  \
# 0                False  0.816327              inducing_cytokine         48
# 1                False  0.800000              inducing_cytokine         55
# 2                False  0.785714              inducing_cytokine         15
# 3                False  0.804124  inducing_transcription_factor          3
# 4                False  0.791667  inducing_transcription_factor         57
# 5                False  0.778947  inducing_transcription_factor         63
# 6                False  0.725664              secreted_cytokine         13
# 7                False  0.722222              secreted_cytokine          0
# 8                False  0.721311              secreted_cytokine         15
#
#    rank
# 0     1
# 1     2
# 2     3
# 3     1
# 4     2
# 5     3
# 6     1
# 7     2
# 8     3

# %%
path = osp.join(output_dir, 'top_model_configurations.json')
dftm.to_json(path)
path
# Out:
# '/lab/data/results/modeling-rnn-strong/run4/top_model_configurations.json'

# %% [markdown]
# ## Debug

# %%
debug_task = tasks[1]
optimizer = optimizers[debug_task]
debug_task
# Out:
# 'secreted_cytokine'

# %%
model_config = dfx.groupby('task').apply(lambda g: g.sort_values('score', ascending=False).iloc[0]).loc[debug_task]
model_config
# Out:
# marker_list                     doub_01
# use_secondary                     False
# use_swaps                          True
# use_positions                      True
# wrd_embedding_type          w2v_trained
# model_size                          XXL
# weight_decay                          0
# learning_rate                      0.01
# dropout                            0.25
# cell_type                          LSTM
# bidirectional                     False
# score                          0.424242
# task                  secreted_cytokine
# iteration                            49
# Name: secreted_cytokine, dtype: object

# %%
#model_config['model_size'] = 'XL'

# %%
# Train on top config
train_args = dict(optimizer.train_args([model_config[dim.name] for dim in space]))
train_args['use_checkpoints'] = True
del train_args['save_keys']
args = dict(cli=optimizer.cli_args(), train=train_args)
cmd = optimizer.format(optimizer.client.cmd(**args))
print(cmd)
optimizer.client.execute(cmd)
# Out:
# python /lab/repos/t-cell-relation-extraction/src/tcre/exec/v1/cli.py --relation-class=secreted_cytokine --device="cuda:1" --output-dir=/lab/data/results/gridsearch-dev/run2/secreted_cytokine/data --batch-size=512 train --splits-file=/lab/data/results/gridsearch-dev/run2/secreted_cytokine/splits/splits.json --use-checkpoints=True --marker-list=doub_01 --use-secondary=False --use-swaps=True --use-positions=True --wrd-embedding-type=w2v_trained --model-size=XXL --weight-decay=0.0 --learning-rate=0.01 --dropout=0.25 --cell-type=LSTM --bidirectional=False > /lab/data/results/gridsearch-dev/run2/secreted_cytokine/log/log.txt 2>&1
# 0

# %%
pd.read_json(osp.join(optimizer.output_dir, 'data', 'history.json'))\
    .set_index(['epoch', 'type'])['f1'].unstack().plot()

# %%
# Predict with trained model
predict_args = dict(splits_file=optimizer.get_splits_file())
args = dict(cli=optimizer.cli_args(), predict=predict_args)
cmd = optimizer.format(optimizer.client.cmd(**args))
print(cmd)
optimizer.client.execute(cmd)
# Out:
# python /lab/repos/t-cell-relation-extraction/src/tcre/exec/v1/cli.py --relation-class=secreted_cytokine --device="cuda:1" --output-dir=/lab/data/results/gridsearch-dev/run2/secreted_cytokine/data --batch-size=512 predict --splits-file=/lab/data/results/gridsearch-dev/run2/secreted_cytokine/splits/splits.json > /lab/data/results/gridsearch-dev/run2/secreted_cytokine/log/log.txt 2>&1
# 0

# %%
from tcre import visualization
import imp
imp.reload(visualization)

df_pred = pd.read_json(osp.join(optimizer.output_dir, 'data', 'predictions.json')).set_index('id')
pred_cands = session.query(Candidate).filter(Candidate.type == debug_task).all()
pred_cands = [c for c in pred_cands if c.id in df_pred.index]
assert len(pred_cands) == len(df_pred)
df_pred = pd.merge(df_pred.reset_index(), visualization.candidate_df(pred_cands), on='id', how='inner')
df_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 0 to 97
# Data columns (total 8 columns):
# id        98 non-null int64
# y_true    98 non-null int64
# y_pred    98 non-null float64
# type      98 non-null object
# split     98 non-null int64
# e1        98 non-null object
# e2        98 non-null object
# text      98 non-null object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 6.9+ KB

# %%
df_pred['y_true'].unique(), (df_pred['y_true'] > .5).value_counts()
# Out:
# (array([0, 1]), False    79
#  True     19
#  Name: y_true, dtype: int64)

# %%
(df_pred['y_pred'] > .5).value_counts()
# Out:
# False    89
# True      9
# Name: y_pred, dtype: int64

# %%
from IPython.display import HTML
pd.set_option('display.max_colwidth', 600)
#HTML(df_pred.sort_values('y_pred', ascending=False).head(25).to_html(escape=False))
HTML(df_pred[df_pred['y_true'] == 1].sort_values('y_pred', ascending=False).head(25).to_html(escape=False))
#HTML(df_pred[df_pred['y_pred'] > .5].sort_values('y_pred', ascending=False).head(25).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>y_true</th>
#       <th>y_pred</th>
#       <th>type</th>
#       <th>split</th>
#       <th>e1</th>
#       <th>e2</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>60</th>
#       <td>291424</td>
#       <td>1</td>
#       <td>0.995636</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IFN-γ</td>
#       <td>γδT</td>
#       <td>We next sought to determine if the production of <div style="color:blue;display:inline" title="CK128EC732B281BF60:CK128EC732B281BF60">IFN-γ</div> by CD161 + <div style="color:red;display:inline" title="CT7DC8DD80306E71A2:CT7DC8DD80306E71A2">γδT</div> cells in response to TCR - independent cytokine stimulation occurred in both the Vδ1 + and Vδ2 + γδT cell subsets .</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>364562</td>
#       <td>1</td>
#       <td>0.990747</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IL-23</td>
#       <td>Th17</td>
#       <td>Th17 cells express the <div style="color:blue;display:inline" title="CK128EF9AC08AC594D:CK9EDC256C75A00BC5">IL-23</div> receptor ( IL-23R ) , and the exquisite pathogenicity of <div style="color:red;display:inline" title="CTBFBDE5121B6748D1:CTBFBDE5121B6748D1">Th17</div> cells may be associated with their capacity to respond to IL-23 (; ; ; ) . \n</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>333888</td>
#       <td>1</td>
#       <td>0.981965</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IL-4</td>
#       <td>Th2</td>
#       <td>For example , the cytokines typically produced by <div style="color:red;display:inline" title="CTE7B12DC660323A0E:CTE7B12DC660323A0E">Th2</div> cells , including <div style="color:blue;display:inline" title="CK6FE135B3F86FB707:CK6FE135B3F86FB707">IL-4</div> , IL-5 and IL-13 , are silenced in Th1 cells through histone modification [ ] .</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>288940</td>
#       <td>1</td>
#       <td>0.634935</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>TNF-α</td>
#       <td>Th1</td>
#       <td>Supporting this hypothesis , we also found that <div style="color:blue;display:inline" title="CKE50C068CBDAC0F8F:CK80A1A727AC173EE7">TNF-α</div> , a cytokine , which can be produced by Th17 and <div style="color:red;display:inline" title="CTC3A8C3CBC245616A:CTC3A8C3CBC245616A">Th1</div> cells , neither influenced the CD44 level of IL-17 + nor IFN-γ+CD4 + T cells .</td>
#     </tr>
#     <tr>
#       <th>94</th>
#       <td>298139</td>
#       <td>1</td>
#       <td>0.527107</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IL-4</td>
#       <td>Th2</td>
#       <td><div style="color:red;display:inline" title="CTE7B12DC660323A0E:CTE7B12DC660323A0E">Th2</div> cells express <div style="color:blue;display:inline" title="CK6FE135B3F86FB707:CK6FE135B3F86FB707">IL-4</div> , IL-5 , and IL-13 , which stimulates mucosal immunity against parasite infections ( – ) .</td>
#     </tr>
#     <tr>
#       <th>90</th>
#       <td>327843</td>
#       <td>1</td>
#       <td>0.200419</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IL-21</td>
#       <td>Th17</td>
#       <td>Another subset that has become increasingly important is <div style="color:red;display:inline" title="CTBFBDE5121B6748D1:CTBFBDE5121B6748D1">Th17</div> cells that produce a variety of cytokines including IL-17A , <div style="color:blue;display:inline" title="CKE72A17870C23A2D1:CK284ADEA6187E1FF3">IL-21</div> and IL-22 .</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>58853</td>
#       <td>1</td>
#       <td>0.192096</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IFN-γ</td>
#       <td>NKT</td>
#       <td>Based on the expression of an invariant TCRα chain ( Vα14-Jα18 in mice , Vα24-Jα18 in humans ) , CD1d - dependent NKT cells can be classified into type I and type II <div style="color:red;display:inline" title="CT459998F048BE65F2:CT459998F048BE65F2">NKT</div> cells , both of which can produce <div style="color:blue;display:inline" title="CK1B71668FDDECE3CF:CK128EC732B281BF60">IFN-γ</div> , the Th1 cytokine , and IL-4 , a Th2 cytokine , and participate in the regulation of innate and adaptive immunity .</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>365585</td>
#       <td>1</td>
#       <td>0.147616</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IL-17</td>
#       <td>Th17</td>
#       <td>The signaling cascade of <div style="color:blue;display:inline" title="CK2741EFAE1F31AD65:CK2741EFAE1F31AD65">IL-17</div> , the signature cytokine of <div style="color:red;display:inline" title="CTBFBDE5121B6748D1:CTBFBDE5121B6748D1">Th17</div> cells , requires a key signaling molecule , Act1 ( also known as TRAF3IP2 or CIKS ) to propagate downstream signaling events in tissue cells , including activation of the transcription factor NF-κB. The absence of Act1 leads to resistance to IL-17-mediated inflammation in mouse models of experimental autoimmune encephalomyelitis ( EAE ) and asthma .</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>347530</td>
#       <td>1</td>
#       <td>0.131577</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IL-13</td>
#       <td>Th2</td>
#       <td>Dominance of Th2 responses ( – ) and <div style="color:red;display:inline" title="CTE7B12DC660323A0E:CTE7B12DC660323A0E">Th2</div> cytokines IL-4 ( – ) , IL-10 ( ) , and <div style="color:blue;display:inline" title="CK713350DF0E9099E8:CK713350DF0E9099E8">IL-13</div> ( ) , can protect against autoimmunity , but their effects are variable . Th2</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>323721</td>
#       <td>1</td>
#       <td>0.126618</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IL-10</td>
#       <td>TH17</td>
#       <td>a Quantitative RT - PCR analysis of gene expression in human IL-10– and <div style="color:blue;display:inline" title="CK3A3EC71E6A0C53F0:CKC5CC1A269C01EC48">IL-10</div> + <div style="color:red;display:inline" title="CTBFBDE5121B6748D1:CTBFBDE5121B6748D1">TH17</div> clones isolated from healthy donors ( two tailed , paired Student ’s t test , mean   ±   s.d .</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>105315</td>
#       <td>1</td>
#       <td>0.064663</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>TNF</td>
#       <td>Th1</td>
#       <td>These cells have a limited capacity to mediate control of Mtb infection , but produce significant amounts of <div style="color:red;display:inline" title="CTC3A8C3CBC245616A:CTC3A8C3CBC245616A">Th1</div> related cytokines like IFN-γ and <div style="color:blue;display:inline" title="CK9F74D00862D05D5F:CK80A1A727AC173EE7">TNF</div> .</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>317312</td>
#       <td>1</td>
#       <td>0.045519</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IL-5</td>
#       <td>Th2</td>
#       <td>Consistent with above results , mice that received Ova - specific Batf KO Tfh cells revealed decreased numbers of total infiltrated cells , eosinophils and lymphocytes ( ) along with decreased expression of <div style="color:red;display:inline" title="CTE7B12DC660323A0E:CTE7B12DC660323A0E">Th2</div> cytokines IL-4 , <div style="color:blue;display:inline" title="CK7026891CEAA3C8F9:CK7026891CEAA3C8F9">IL-5</div> and IL-13 by Ova - restimulated splenocytes ( ) compared with mice that received WT Tfh cells .</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>358115</td>
#       <td>1</td>
#       <td>0.006491</td>
#       <td>secreted_cytokine</td>
#       <td>4</td>
#       <td>IFNγ</td>
#       <td>Th17</td>
#       <td>We asked whether STAT4 signaling was critical for the induction of <div style="color:blue;display:inline" title="CK8074B95EB01901B1:CK128EC732B281BF60">IFNγ</div> production by <div style="color:red;display:inline" title="CTBFBDE5121B6748D1:CTBFBDE5121B6748D1">Th17</div> cells upon stimulation with IL-12 and IL-18 .</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>3
