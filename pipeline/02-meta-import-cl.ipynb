# %%
import pronto
import os.path as osp
import re
import os
import pandas as pd
import numpy as np
from tcre.env import *

# %%
# Download cl.owl from http://purl.obolibrary.org/obo/cl.owl
onto = pronto.Ontology(osp.join(os.environ['DATA_DIR'], 'meta', 'cl', 'cl.owl'))

# %%
# Get terms for "T Cell" and "natural killer cell"; see:
# https://www.ebi.ac.uk/ols/ontologies/cl/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCL_0000084
# https://www.ebi.ac.uk/ols/ontologies/cl/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCL_0000623
parents = [onto['CL:0000084'], onto['CL:0000623']]
parents
# Out:
# [<CL:0000084: T cell>, <CL:0000623: natural killer cell>]

# %%
def _dist(terms, target, ct, max_dist):
    for t in terms:
        if t.id == target.id:
            return ct
    terms = [p for t in terms for p in t.parents]
    if not terms or ct > max_dist:
        return None
    return _dist(terms, target, ct + 1, max_dist)

def distance_to(term, target, max_dist=100):
    """Get difference in depth between a term and a target term (returns None if not in same subtree)"""
    return _dist([term], target, 0, max_dist)

# %%
[len(list(t.rchildren())) for t in parents]
# Out:
# [135, 27]

# %%
terms = [(t, p) for p in parents for t in [p] + list(p.rchildren())]
len(terms)
# Out:
# 164

# %%
pd.Series([
    s.scope
    for t in terms
    for s in t[0].synonyms
]).value_counts()
# Out:
# EXACT      481
# BROAD       63
# RELATED     21
# NARROW       3
# dtype: int64

# %%
def get_row(t, p, s, syn_typ):
    # Get relative distance between term and root term
    depth = distance_to(t, p)
    return dict(
        id=t.id, root=p.id, label=t.name, desc=str(t.desc),
        depth=depth, syn=s.desc,
        syn_typ=syn_typ if syn_typ else s.scope.lower()
    )

def get_frame(syn_fn, syn_typ=None):    
    return pd.DataFrame([
        get_row(t[0], t[1], s, syn_typ)
        for t in terms
        for s in syn_fn(t[0])
    ])
            
dfa = pd.concat([
    get_frame(lambda t: t.synonyms),
    get_frame(lambda t: [pronto.Synonym(t.name)], 'label')
])
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 732 entries, 0 to 163
# Data columns (total 7 columns):
# depth      732 non-null int64
# desc       732 non-null object
# id         732 non-null object
# label      732 non-null object
# root       732 non-null object
# syn        732 non-null object
# syn_typ    732 non-null object
# dtypes: int64(1), object(6)
# memory usage: 45.8+ KB

# %%
dfa['depth'].value_counts()
# Out:
# 4    331
# 3    184
# 5    105
# 2     76
# 1     26
# 0     10
# Name: depth, dtype: int64

# %%
dfa['syn_typ'].value_counts()
# Out:
# exact      481
# label      164
# broad       63
# related     21
# narrow       3
# Name: syn_typ, dtype: int64

# %%
dfa['root'].value_counts()
# Out:
# CL:0000084    662
# CL:0000623     70
# Name: root, dtype: int64

# %%
cts = dfa.groupby('syn')['id'].nunique()
cts.value_counts()
# Out:
# 1    684
# 2      8
# 3      6
# 7      2
# Name: id, dtype: int64

# %%
cts[cts > 1]
# Out:
# syn
# IEL                           7
# NKT.44+.NK1.1-.Th             2
# cytotoxic T cell              2
# cytotoxic T lymphocyte        2
# cytotoxic T-cell              2
# cytotoxic T-lymphocyte        2
# early cortical thymocyte      2
# immature T cell               3
# immature T-cell               2
# intraepithelial lymphocyte    7
# mature T cell                 2
# p-NK                          3
# suppressor T cell             3
# suppressor T lymphocyte       3
# suppressor T-cell             3
# suppressor T-lymphocyte       3
# Name: id, dtype: int64

# %%
# Resolve conflicting tokens using synonym type preference
SYN_TYPES = {'label': 5, 'exact': 4, 'narrow': 3, 'related': 2, 'broad': 1}

def assign_syn_typ_id(df):
    df['syn_typ_id'] = df['syn_typ'].map(SYN_TYPES)
    assert df['syn_typ_id'].notnull().all()
    return df

dfr = (
    dfa
    .pipe(assign_syn_typ_id)
    # Note that NA values will are last by default (i.e. lowest)
    .sort_values(['syn', 'syn_typ_id', 'id'], ascending=False)
    .groupby(['syn'], group_keys=False).head(1)
)
assert dfr.groupby(['syn']).size().max() == 1
dfr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 700 entries, 413 to 186
# Data columns (total 8 columns):
# depth         700 non-null int64
# desc          700 non-null object
# id            700 non-null object
# label         700 non-null object
# root          700 non-null object
# syn           700 non-null object
# syn_typ       700 non-null object
# syn_typ_id    700 non-null int64
# dtypes: int64(2), object(6)
# memory usage: 49.2+ KB

# %%
# Ensure that labels and ids are mutually exclusive
assert dfr.groupby('label')['id'].nunique().max() == 1
assert dfr.groupby('id')['label'].nunique().max() == 1

# %%
dfr[dfr['syn'].str.contains('17')]
# Out:
#      depth                                               desc          id  \
# 118      4  A CD4-positive, alpha-beta T cell that has the...  CL:0001051
# 268      4  A CD8-positive, alpha-beta T cell that has the...  CL:0001052
# 145      5  CD4-positive, alpha-beta T cell with the pheno...  CL:0000899
# 433      3  A circulating gamma-delta T cell that expresse...  CL:0002125
# 140      5  CD4-positive, alpha-beta T cell with the pheno...  CL:0000899
# 144      5  CD4-positive, alpha-beta T cell with the pheno...  CL:0000899
# 143      5  CD4-positive, alpha-beta T cell with the pheno...  CL:0000899
# 147      5  CD4-positive, alpha-beta T cell with the pheno...  CL:0000899
# 142      5  CD4-positive, alpha-beta T cell with the pheno...  CL:0000899
# 146      5  CD4-positive, alpha-beta T cell with the pheno...  CL:0000899
# 74       5  A CD8-positive, alpha-beta T cell that has the...  CL:0002128
# 321      5  A CD8-positive, alpha-beta T cell that has the...  CL:0002128
# 323      5  A CD8-positive, alpha-beta T cell that has the...  CL:0002128
# 320      5  A CD8-positive, alpha-beta T cell that has the...  CL:0002128
# 324      5  A CD8-positive, alpha-beta T cell that has the...  CL:0002128
# 322      5  A CD8-positive, alpha-beta T cell that has the...  CL:0002128
# 41       5  CD4-positive, alpha-beta T cell with the pheno...  CL:0000899
# 138      5  CD4-positive, alpha-beta T cell with the pheno...  CL:0000899
# 141      5  CD4-positive, alpha-beta T cell with the pheno...  CL:0000899
# 139      5  CD4-positive, alpha-beta T cell with the pheno...  CL:0000899
#
#                                                  label        root  \
# 118  CD4-positive, CXCR3-negative, CCR6-negative, a...  CL:0000084
# 268  CD8-positive, CXCR3-negative, CCR6-negative, a...  CL:0000084
# 145                                   T-helper 17 cell  CL:0000084
# 433                   CD27-negative gamma-delta T cell  CL:0000084
# 140                                   T-helper 17 cell  CL:0000084
# 144                                   T-helper 17 cell  CL:0000084
# 143                                   T-helper 17 cell  CL:0000084
# 147                                   T-helper 17 cell  CL:0000084
# 142                                   T-helper 17 cell  CL:0000084
# 146                                   T-helper 17 cell  CL:0000084
# 74                                           Tc17 cell  CL:0000084
# 321                                          Tc17 cell  CL:0000084
# 323                                          Tc17 cell  CL:0000084
# 320                                          Tc17 cell  CL:0000084
# 324                                          Tc17 cell  CL:0000084
# 322                                          Tc17 cell  CL:0000084
# 41                                    T-helper 17 cell  CL:0000084
# 138                                   T-helper 17 cell  CL:0000084
# 141                                   T-helper 17 cell  CL:0000084
# 139                                   T-helper 17 cell  CL:0000084
#
#                                syn syn_typ  syn_typ_id
# 118       non-Th1/Th17 CD4+ T cell   broad           1
# 268       non-Tc1/Tc17 CD8+ T cell   broad           1
# 145          helper T cell type 17   exact           4
# 433            gammadelta-17 cells   exact           4
# 140                      Th17 cell   exact           4
# 144              Th17 T-lymphocyte   exact           4
# 143                    Th17 T-cell   exact           4
# 147              Th17 T lymphocyte   exact           4
# 142                    Th17 T cell   exact           4
# 146               Th17 CD4+ T cell   exact           4
# 74                       Tc17 cell   label           5
# 321              Tc17 T-lymphocyte   exact           4
# 323                    Tc17 T-cell   exact           4
# 320              Tc17 T lymphocyte   exact           4
# 324                    Tc17 T cell   exact           4
# 322               Tc17 CD8+ T cell   exact           4
# 41                T-helper 17 cell   label           5
# 138                   T(H)-17 cell   exact           4
# 141         T helper cells type 17   exact           4
# 139  IL-17-producing CD4+ T helper   exact           4

# %%
dfr[dfr['syn'].str.contains('NK') & (dfr['root'] == 'CL:0000623')]
# Out:
#      depth                                               desc          id  \
# 537      2  An immature natural killer cell that is NK1.1-...  CL:0002345
# 534      1  Cell committed to natural killer cell lineage ...  CL:0000937
# 536      2  A natural killer cell that is developmentally ...  CL:0002344
# 532      1  A natural killer cell that is developmentally ...  CL:0000824
# 529      1  A natural killer cell that is developmentally ...  CL:0000823
# 551      2  A natural killer cell subset that is found in ...  CL:0002343
# 550      2  A natural killer cell subset that is found in ...  CL:0002343
# 547      2  A mature natural killer cell that has the phen...  CL:0000939
# 150      3    A NK1.1-positive T cell that is NKGA2-positive.  CL:0002439
# 148      2           A mature NK cell that is NK1.1-positive.  CL:0002438
# 552      2           A mature NK cell that is NK1.1-positive.  CL:0002438
# 553      2           A mature NK cell that is NK1.1-positive.  CL:0002438
# 554      3    A NK1.1-positive T cell that is NKGA2-positive.  CL:0002439
# 563      3     A NK1.1-positive T cell that is CD94-negative.  CL:0002447
# 556      3     A NK1.1-positive T cell that is CD94-positive.  CL:0002441
# 560      3    A NK1.1-positive T cell that is Ly49D-negative.  CL:0002445
# 555      3    A NK1.1-positive T cell that is Ly49D-positive.  CL:0002440
# 566      4  A NK1.1-positive T cell that is CD94-negative ...  CL:0002442
# 562      3   A NK1.1-positive T cell that is Ly49Cl-negative.  CL:0002446
# 565      4  A NK1.1-positive T cell that is CD94-positive ...  CL:0002449
# 558      3   A NK1.1-positive T cell that is Ly49Cl-positive.  CL:0002443
# 528      0  A lymphocyte that can spontaneously kill a var...  CL:0000623
# 557      3   A NK1.1-positive T cell that is Ly49Cl-positive.  CL:0002443
# 561      3   A NK1.1-positive T cell that is Ly49Cl-negative.  CL:0002446
# 144      2  An immature natural killer cell that is NK1.1-...  CL:0002346
# 567      4  A NK1.1-positive T cell that is CD94-negative ...  CL:0002442
# 539      2  NK cell that has the phenotype CD56-bright, CD...  CL:0000938
# 543      2  A mature natural killer cell that has the phen...  CL:0000939
# 542      2  A mature natural killer cell that has the phen...  CL:0000939
# 546      2  A mature natural killer cell that has the phen...  CL:0000939
# 540      2  NK cell that has the phenotype CD56-bright, CD...  CL:0000938
# 541      2  NK cell that has the phenotype CD56-bright, CD...  CL:0000938
# 545      2  A mature natural killer cell that has the phen...  CL:0000939
#
#                                                  label        root  \
# 537   CD27-low, CD11b-low immature natural killer cell  CL:0000623
# 534                            pre-natural killer cell  CL:0000623
# 536  CD56-negative, CD161-positive immature natural...  CL:0000623
# 532                         mature natural killer cell  CL:0000623
# 529                       immature natural killer cell  CL:0000623
# 551                       decidual natural killer cell  CL:0000623
# 550                       decidual natural killer cell  CL:0000623
# 547        CD16-positive, CD56-dim natural killer cell  CL:0000623
# 150                 NKGA2-positive natural killer cell  CL:0000623
# 148                 NK1.1-positive natural killer cell  CL:0000623
# 552                 NK1.1-positive natural killer cell  CL:0000623
# 553                 NK1.1-positive natural killer cell  CL:0000623
# 554                 NKGA2-positive natural killer cell  CL:0000623
# 563                  CD94-negative natural killer cell  CL:0000623
# 556                  CD94-positive natural killer cell  CL:0000623
# 560                 Ly49D-negative natural killer cell  CL:0000623
# 555                 Ly49D-positive natural killer cell  CL:0000623
# 566  CD94-negative, Ly49CI-negative natural killer ...  CL:0000623
# 562                Ly49CI-negative natural killer cell  CL:0000623
# 565  CD94-positive Ly49CI-positive natural killer cell  CL:0000623
# 558                Ly49CI-positive natural killer cell  CL:0000623
# 528                                natural killer cell  CL:0000623
# 557                Ly49CI-positive natural killer cell  CL:0000623
# 561                Ly49CI-negative natural killer cell  CL:0000623
# 144  Dx5-negative, NK1.1-positive immature natural ...  CL:0000623
# 567  CD94-negative, Ly49CI-negative natural killer ...  CL:0000623
# 539     CD16-negative, CD56-bright natural killer cell  CL:0000623
# 543        CD16-positive, CD56-dim natural killer cell  CL:0000623
# 542        CD16-positive, CD56-dim natural killer cell  CL:0000623
# 546        CD16-positive, CD56-dim natural killer cell  CL:0000623
# 540     CD16-negative, CD56-bright natural killer cell  CL:0000623
# 541     CD16-negative, CD56-bright natural killer cell  CL:0000623
# 545        CD16-positive, CD56-dim natural killer cell  CL:0000623
#
#                                                    syn  syn_typ  syn_typ_id
# 537                                           preNK.BM    broad           1
# 534                                        pre-NK cell    exact           4
# 536                                               p-NK  related           2
# 532                                     mature NK cell    exact           4
# 529                                   immature NK cell    exact           4
# 551                                   decidual NK cell    exact           4
# 550                                           dNK cell    exact           4
# 547                         cytotoxic CD56-dim NK cell    exact           4
# 150                 NKGA2-positive natural killer cell    label           5
# 148                 NK1.1-positive natural killer cell    label           5
# 552                             NK1.1-positive NK cell    exact           4
# 553                                              NK.sp    exact           4
# 554                                         NK.G2A+.SP    exact           4
# 563                                          NK.94-.Sp    exact           4
# 556                                          NK.94+.Sp    exact           4
# 560                                         NK.49D-.Sp    exact           4
# 555                                         NK.49D+.Sp    exact           4
# 566                                     NK.49Cl-94-.Sp    exact           4
# 562                                        NK.49Cl-.Sp    exact           4
# 565                                     NK.49Cl+94+.Sp    exact           4
# 558                                        NK.49Cl+.Sp    exact           4
# 528                                            NK cell    exact           4
# 557                             Ly49I-positive NK cell    exact           4
# 561                             Ly49I-negative NK cell    exact           4
# 144  Dx5-negative, NK1.1-positive immature natural ...    label           5
# 567                       CD94- Ly49I-negative NK cell    exact           4
# 539             CD56-bright cytokine secreting NK cell    exact           4
# 543               CD16-positive, CD56-positive NK cell    exact           4
# 542                    CD16-positive, CD56-low NK cell    exact           4
# 546                    CD16-positive, CD56-dim NK cell    exact           4
# 540                 CD16-negative, CD56-bright NK cell    exact           4
# 541                            CD16-CD56bright NK cell    exact           4
# 545                                 CD16+CD56+ NK cell    exact           4

# %% [markdown]
# ### Export

# %%
path = osp.join(META_DATA_DIR, 'raw', 'cl.raw.csv')
dfr.to_csv(path, index=False)
path
# Out:
# '/lab/repos/t-cell-relation-extraction/data/meta/raw/cl.raw.csv'
