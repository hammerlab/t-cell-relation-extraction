# %%
from Bio import Entrez
import os
import re
import os.path as osp
import logging
import traceback
import pandas as pd
from bs4 import BeautifulSoup
# %run src/logging.py
# %run env.py
#Entrez.email = 'eric@hammerlab.org'
Entrez.email = 'eczech52@gmail.com'

# %%
def search(query, retstart=0, retmax=1000):
    handle = Entrez.esearch(db='pmc', 
                            sort='relevance', 
                            retmax=str(retmax),
                            retstart=str(retstart),
                            retmode='xml', 
                            term=query)
    results = Entrez.read(handle)
    return results

def fetch_details(id_list):
    ids = ','.join(id_list)
    handle = Entrez.efetch(db='pmc', rettype="full", retmode='xml', id=ids)
    return handle.read()

def parse(soup):
    res = {}
    res['id'] = [t for t in soup.find('article-meta').find_all('article-id') if t['pub-id-type'] == 'pmc'][0].text
    res['title'] = soup.find('title-group').find('article-title').text
    res['xml'] = str(soup)
    
    try:
        res['abstract'] = soup.find('abstract').text
    except:
        res['abstract'] = None
    
    try:
        res['has_text'] = len(soup.find('body').text.strip()) > 0
    except:
        res['has_text'] = False
        
    try:
        date = [t for t in soup.find('history').find_all('date') if t['date-type'] == 'received'][0]
        res['date'] = pd.to_datetime('{}-{}-{}'.format(
            date.find('year').text,
            date.find('month').text if date.find('month') else '00',
            date.find('day').text if date.find('day') else '00'
        ))
    except:
        res['date'] = None
    return res

def to_df(dets):
    soup = BeautifulSoup(dets, 'xml')
    return pd.DataFrame([parse(article) for article in soup.find_all('article')])

def collect(query, output_file, start_index=0, batch_size=100, batch_limit=None, max_failures=5):
    i = start_index
    ct = 0
    failures = 0
    if not osp.exists(osp.dirname(output_file)):
        os.makedirs(osp.dirname(output_file))
    while True:
        try:
            ids = search(query, retstart=i, retmax=batch_size)['IdList']
            if len(ids) == 0:
                break
            logger.info('Processing batch at start index {} (num ids = {})'.format(i, len(ids)))
            dets = fetch_details(ids)
            df = to_df(dets)
            df.to_csv(output_file, index=False, header=not osp.exists(output_file), mode='a')
            ct += 1
            i += batch_size
            if batch_limit and ct >= batch_limit:
                break
        except:
            traceback.print_exc()
            failures += 1
            if failures > max_failures:
                raise ValueError('Max failure threshold ({}) exceeded'.format(max_failures))
            logger.warning('Error occurred at index {}. Will retry up to {} times'.format(i, max_failures))
    logger.info('Collection complete (num failures = {})'.format(failures))

# %%
output_file = osp.join(IMPORT_DATA_DIR_02, 'data.csv')
batch_size, batch_limit = 25, 816
output_file
# Out:
# '/Users/eczech/data/research/hammer/nlp/20190311-pubmed-tcell-relation/articles/import/20190501/data.csv'

# %%
# Efetch docs: https://www.ncbi.nlm.nih.gov/books/NBK25499/#chapter4.EFetch
# Get doc details: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pmc&id=212403
# 124720 results as of 2019-03-11
# Test single article: 
#query = '5360497'

# %%
query = '(human) AND ((t cell) OR (t lymphocyte)) AND (cytokine) AND ((differentiate) OR (differentiation) OR (differentiated)) AND ((polarization) OR (polarize) OR (induce) OR (induction))'

# %%
![ -e $output_file ] && rm $output_file

collect(
    query, output_file, 
    batch_size=batch_size, batch_limit=batch_limit,
    start_index=0, max_failures=1000000
)
# Out:
# 2019-05-01 13:15:19,128:INFO:root: Processing batch at start index 0 (num ids = 25)
# 2019-05-01 13:15:29,249:INFO:root: Processing batch at start index 25 (num ids = 25)
# 2019-05-01 13:15:34,418:INFO:root: Processing batch at start index 50 (num ids = 25)
# 2019-05-01 13:15:43,201:INFO:root: Processing batch at start index 75 (num ids = 25)
# 2019-05-01 13:15:56,086:INFO:root: Processing batch at start index 100 (num ids = 25)
# 2019-05-01 13:16:04,217:INFO:root: Processing batch at start index 125 (num ids = 25)
# 2019-05-01 13:16:15,270:INFO:root: Processing batch at start index 150 (num ids = 25)
# 2019-05-01 13:16:27,020:INFO:root: Processing batch at start index 175 (num ids = 25)
# 2019-05-01 13:16:34,642:INFO:root: Processing batch at start index 200 (num ids = 25)
# 2019-05-01 13:16:45,715:INFO:root: Processing batch at start index 225 (num ids = 25)
# 2019-05-01 13:16:54,426:INFO:root: Processing batch at start index 250 (num ids = 25)
# 2019-05-01 13:17:01,656:INFO:root: Processing batch at start index 275 (num ids = 25)
# 2019-05-01 13:17:06,233:INFO:root: Processing batch at start index 300 (num ids = 25)
# 2019-05-01 13:17:15,788:INFO:root: Processing batch at start index 325 (num ids = 25)
# 2019-05-01 13:17:22,609:INFO:root: Processing batch at start index 350 (num ids = 25)
# 2019-05-01 13:17:32,300:INFO:root: Processing batch at start index 375 (num ids = 25)
# 2019-05-01 13:17:36,685:INFO:root: Processing batch at start index 400 (num ids = 25)
# 2019-05-01 13:17:45,177:INFO:root: Processing batch at start index 425 (num ids = 25)
# 2019-05-01 13:18:03,418:INFO:root: Processing batch at start index 450 (num ids = 25)
# 2019-05-01 13:18:08,436:INFO:root: Processing batch at start index 475 (num ids = 25)
# 2019-05-01 13:18:16,556:INFO:root: Processing batch at start index 500 (num ids = 25)
# 2019-05-01 13:18:24,045:INFO:root: Processing batch at start index 525 (num ids = 25)
# 2019-05-01 13:18:28,457:INFO:root: Processing batch at start index 550 (num ids = 25)
# 2019-05-01 13:18:36,846:INFO:root: Processing batch at start index 575 (num ids = 25)
# 2019-05-01 13:18:42,611:INFO:root: Processing batch at start index 600 (num ids = 25)
# 2019-05-01 13:18:49,484:INFO:root: Processing batch at start index 625 (num ids = 25)
# 2019-05-01 13:18:57,929:INFO:root: Processing batch at start index 650 (num ids = 25)
# 2019-05-01 13:19:05,211:INFO:root: Processing batch at start index 675 (num ids = 25)
# 2019-05-01 13:19:09,760:INFO:root: Processing batch at start index 700 (num ids = 25)
# 2019-05-01 13:19:18,393:INFO:root: Processing batch at start index 725 (num ids = 25)
# 2019-05-01 13:19:27,679:INFO:root: Processing batch at start index 750 (num ids = 25)
# 2019-05-01 13:19:34,169:INFO:root: Processing batch at start index 775 (num ids = 25)
# 2019-05-01 13:19:42,450:INFO:root: Processing batch at start index 800 (num ids = 25)
# 2019-05-01 13:19:51,542:INFO:root: Processing batch at start index 825 (num ids = 25)
# 2019-05-01 13:20:00,759:INFO:root: Processing batch at start index 850 (num ids = 25)
# 2019-05-01 13:20:09,674:INFO:root: Processing batch at start index 875 (num ids = 25)
# 2019-05-01 13:20:15,358:INFO:root: Processing batch at start index 900 (num ids = 25)
# 2019-05-01 13:20:20,729:INFO:root: Processing batch at start index 925 (num ids = 25)
# 2019-05-01 13:20:27,855:INFO:root: Processing batch at start index 950 (num ids = 25)
# 2019-05-01 13:20:31,621:INFO:root: Processing batch at start index 975 (num ids = 25)
# 2019-05-01 13:20:40,245:INFO:root: Processing batch at start index 1000 (num ids = 25)
# 2019-05-01 13:20:48,347:INFO:root: Processing batch at start index 1025 (num ids = 25)
# 2019-05-01 13:20:58,080:INFO:root: Processing batch at start index 1050 (num ids = 25)
# 2019-05-01 13:21:02,505:INFO:root: Processing batch at start index 1075 (num ids = 25)
# 2019-05-01 13:21:17,973:INFO:root: Processing batch at start index 1100 (num ids = 25)
# 2019-05-01 13:21:31,687:INFO:root: Processing batch at start index 1125 (num ids = 25)
# 2019-05-01 13:21:41,212:INFO:root: Processing batch at start index 1150 (num ids = 25)
# 2019-05-01 13:21:47,975:INFO:root: Processing batch at start index 1175 (num ids = 25)
# 2019-05-01 13:21:54,733:INFO:root: Processing batch at start index 1200 (num ids = 25)
# 2019-05-01 13:22:03,240:INFO:root: Processing batch at start index 1225 (num ids = 25)
# 2019-05-01 13:22:11,055:INFO:root: Processing batch at start index 1250 (num ids = 25)
# 2019-05-01 13:22:15,618:INFO:root: Processing batch at start index 1275 (num ids = 25)
# 2019-05-01 13:22:23,836:INFO:root: Processing batch at start index 1300 (num ids = 25)
# 2019-05-01 13:22:32,034:INFO:root: Processing batch at start index 1325 (num ids = 25)
# 2019-05-01 13:22:39,313:INFO:root: Processing batch at start index 1350 (num ids = 25)
# 2019-05-01 13:22:45,114:INFO:root: Processing batch at start index 1375 (num ids = 25)
# 2019-05-01 13:22:55,618:INFO:root: Processing batch at start index 1400 (num ids = 25)
# 2019-05-01 13:23:04,158:INFO:root: Processing batch at start index 1425 (num ids = 25)
# 2019-05-01 13:23:12,235:INFO:root: Processing batch at start index 1450 (num ids = 25)
# 2019-05-01 13:23:17,981:INFO:root: Processing batch at start index 1475 (num ids = 25)
# 2019-05-01 13:23:27,200:INFO:root: Processing batch at start index 1500 (num ids = 25)
# 2019-05-01 13:23:44,709:INFO:root: Processing batch at start index 1525 (num ids = 25)
# 2019-05-01 13:23:49,019:INFO:root: Processing batch at start index 1550 (num ids = 25)
# 2019-05-01 13:23:58,230:INFO:root: Processing batch at start index 1575 (num ids = 25)
# 2019-05-01 13:24:08,361:INFO:root: Processing batch at start index 1600 (num ids = 25)
# 2019-05-01 13:24:15,992:INFO:root: Processing batch at start index 1625 (num ids = 25)
# 2019-05-01 13:24:20,964:INFO:root: Processing batch at start index 1650 (num ids = 25)
# 2019-05-01 13:24:32,697:INFO:root: Processing batch at start index 1675 (num ids = 25)
# 2019-05-01 13:24:39,720:INFO:root: Processing batch at start index 1700 (num ids = 25)
# 2019-05-01 13:24:46,540:INFO:root: Processing batch at start index 1725 (num ids = 25)
# 2019-05-01 13:24:51,066:INFO:root: Processing batch at start index 1750 (num ids = 25)
# 2019-05-01 13:25:02,123:INFO:root: Processing batch at start index 1775 (num ids = 25)
# 2019-05-01 13:25:10,951:INFO:root: Processing batch at start index 1800 (num ids = 25)
# 2019-05-01 13:25:18,155:INFO:root: Processing batch at start index 1825 (num ids = 25)
# 2019-05-01 13:25:23,011:INFO:root: Processing batch at start index 1850 (num ids = 25)
# 2019-05-01 13:25:38,678:INFO:root: Processing batch at start index 1875 (num ids = 25)
# 2019-05-01 13:25:42,727:INFO:root: Processing batch at start index 1900 (num ids = 25)
# 2019-05-01 13:25:50,967:INFO:root: Processing batch at start index 1925 (num ids = 25)
# 2019-05-01 13:25:59,105:INFO:root: Processing batch at start index 1950 (num ids = 25)
# 2019-05-01 13:26:03,570:INFO:root: Processing batch at start index 1975 (num ids = 25)
# 2019-05-01 13:26:11,623:INFO:root: Processing batch at start index 2000 (num ids = 25)
# 2019-05-01 13:26:18,550:INFO:root: Processing batch at start index 2025 (num ids = 25)
# 2019-05-01 13:26:28,891:INFO:root: Processing batch at start index 2050 (num ids = 25)
# 2019-05-01 13:26:33,100:INFO:root: Processing batch at start index 2075 (num ids = 25)
# 2019-05-01 13:26:40,807:INFO:root: Processing batch at start index 2100 (num ids = 25)
# 2019-05-01 13:26:46,711:INFO:root: Processing batch at start index 2125 (num ids = 25)
# 2019-05-01 13:26:54,174:INFO:root: Processing batch at start index 2150 (num ids = 25)
# 2019-05-01 13:27:10,387:INFO:root: Processing batch at start index 2175 (num ids = 25)
# 2019-05-01 13:27:15,469:INFO:root: Processing batch at start index 2200 (num ids = 25)
# 2019-05-01 13:27:25,291:INFO:root: Processing batch at start index 2225 (num ids = 25)
# 2019-05-01 13:27:35,001:INFO:root: Processing batch at start index 2250 (num ids = 25)
# 2019-05-01 13:27:41,767:INFO:root: Processing batch at start index 2275 (num ids = 25)
# 2019-05-01 13:27:45,861:INFO:root: Processing batch at start index 2300 (num ids = 25)
# 2019-05-01 13:27:57,098:INFO:root: Processing batch at start index 2325 (num ids = 25)
# 2019-05-01 13:28:06,043:INFO:root: Processing batch at start index 2350 (num ids = 25)
# 2019-05-01 13:28:16,661:INFO:root: Processing batch at start index 2375 (num ids = 25)
# 2019-05-01 13:28:27,948:INFO:root: Processing batch at start index 2400 (num ids = 25)
# 2019-05-01 13:28:36,799:INFO:root: Processing batch at start index 2425 (num ids = 25)
# 2019-05-01 13:28:44,028:INFO:root: Processing batch at start index 2450 (num ids = 25)
# 2019-05-01 13:28:53,373:INFO:root: Processing batch at start index 2475 (num ids = 25)
# 2019-05-01 13:28:58,988:INFO:root: Processing batch at start index 2500 (num ids = 25)
# 2019-05-01 13:29:07,449:INFO:root: Processing batch at start index 2525 (num ids = 25)
# 2019-05-01 13:29:14,882:INFO:root: Processing batch at start index 2550 (num ids = 25)
# 2019-05-01 13:29:19,166:INFO:root: Processing batch at start index 2575 (num ids = 25)
# 2019-05-01 13:29:29,088:INFO:root: Processing batch at start index 2600 (num ids = 25)
# 2019-05-01 13:29:40,500:INFO:root: Processing batch at start index 2625 (num ids = 25)
# 2019-05-01 13:29:49,976:INFO:root: Processing batch at start index 2650 (num ids = 25)
# 2019-05-01 13:29:57,344:INFO:root: Processing batch at start index 2675 (num ids = 25)
# 2019-05-01 13:30:06,560:INFO:root: Processing batch at start index 2700 (num ids = 25)
# 2019-05-01 13:30:11,169:INFO:root: Processing batch at start index 2725 (num ids = 25)
# 2019-05-01 13:30:20,361:INFO:root: Processing batch at start index 2750 (num ids = 25)
# 2019-05-01 13:30:31,081:INFO:root: Processing batch at start index 2775 (num ids = 25)
# 2019-05-01 13:30:40,968:INFO:root: Processing batch at start index 2800 (num ids = 25)
# 2019-05-01 13:30:50,439:INFO:root: Processing batch at start index 2825 (num ids = 25)
# 2019-05-01 13:30:56,949:INFO:root: Processing batch at start index 2850 (num ids = 25)
# 2019-05-01 13:31:02,473:INFO:root: Processing batch at start index 2875 (num ids = 25)
# 2019-05-01 13:31:10,642:INFO:root: Processing batch at start index 2900 (num ids = 25)
# 2019-05-01 13:31:18,765:INFO:root: Processing batch at start index 2925 (num ids = 25)
# 2019-05-01 13:31:23,361:INFO:root: Processing batch at start index 2950 (num ids = 25)
# 2019-05-01 13:31:33,191:INFO:root: Processing batch at start index 2975 (num ids = 25)
# 2019-05-01 13:31:41,183:INFO:root: Processing batch at start index 3000 (num ids = 25)
# 2019-05-01 13:31:48,538:INFO:root: Processing batch at start index 3025 (num ids = 25)
# 2019-05-01 13:31:54,082:INFO:root: Processing batch at start index 3050 (num ids = 25)
# 2019-05-01 13:32:03,184:INFO:root: Processing batch at start index 3075 (num ids = 25)
# 2019-05-01 13:32:10,746:INFO:root: Processing batch at start index 3100 (num ids = 25)
# 2019-05-01 13:32:14,974:INFO:root: Processing batch at start index 3125 (num ids = 25)
# 2019-05-01 13:32:23,883:INFO:root: Processing batch at start index 3150 (num ids = 25)
# 2019-05-01 13:32:33,224:INFO:root: Processing batch at start index 3175 (num ids = 25)
# 2019-05-01 13:32:41,152:INFO:root: Processing batch at start index 3200 (num ids = 25)
# 2019-05-01 13:32:44,802:INFO:root: Processing batch at start index 3225 (num ids = 25)
# 2019-05-01 13:32:51,596:INFO:root: Processing batch at start index 3250 (num ids = 25)
# 2019-05-01 13:32:56,137:INFO:root: Processing batch at start index 3275 (num ids = 25)
# 2019-05-01 13:33:05,045:INFO:root: Processing batch at start index 3300 (num ids = 25)
# 2019-05-01 13:33:14,050:INFO:root: Processing batch at start index 3325 (num ids = 25)
# 2019-05-01 13:33:22,026:INFO:root: Processing batch at start index 3350 (num ids = 25)
# 2019-05-01 13:33:26,164:INFO:root: Processing batch at start index 3375 (num ids = 25)
# 2019-05-01 13:33:35,466:INFO:root: Processing batch at start index 3400 (num ids = 25)
# 2019-05-01 13:33:44,927:INFO:root: Processing batch at start index 3425 (num ids = 25)
# 2019-05-01 13:33:53,303:INFO:root: Processing batch at start index 3450 (num ids = 25)
# 2019-05-01 13:33:57,360:INFO:root: Processing batch at start index 3475 (num ids = 25)
# 2019-05-01 13:34:06,184:INFO:root: Processing batch at start index 3500 (num ids = 25)
# 2019-05-01 13:34:14,165:INFO:root: Processing batch at start index 3525 (num ids = 25)
# 2019-05-01 13:34:18,450:INFO:root: Processing batch at start index 3550 (num ids = 25)
# 2019-05-01 13:34:28,296:INFO:root: Processing batch at start index 3575 (num ids = 25)
# 2019-05-01 13:34:37,737:INFO:root: Processing batch at start index 3600 (num ids = 25)
# 2019-05-01 13:34:48,396:INFO:root: Processing batch at start index 3625 (num ids = 25)
# 2019-05-01 13:34:56,314:INFO:root: Processing batch at start index 3650 (num ids = 25)
# 2019-05-01 13:35:01,848:INFO:root: Processing batch at start index 3675 (num ids = 25)
# 2019-05-01 13:35:11,000:INFO:root: Processing batch at start index 3700 (num ids = 25)
# 2019-05-01 13:35:21,757:INFO:root: Processing batch at start index 3725 (num ids = 25)
# 2019-05-01 13:35:30,662:INFO:root: Processing batch at start index 3750 (num ids = 25)
# 2019-05-01 13:35:38,043:INFO:root: Processing batch at start index 3775 (num ids = 25)
# 2019-05-01 13:35:42,813:INFO:root: Processing batch at start index 3800 (num ids = 25)
# 2019-05-01 13:35:51,247:INFO:root: Processing batch at start index 3825 (num ids = 25)
# 2019-05-01 13:36:00,770:INFO:root: Processing batch at start index 3850 (num ids = 25)
# 2019-05-01 13:36:09,124:INFO:root: Processing batch at start index 3875 (num ids = 25)
# 2019-05-01 13:36:14,988:INFO:root: Processing batch at start index 3900 (num ids = 25)
# 2019-05-01 13:36:23,570:INFO:root: Processing batch at start index 3925 (num ids = 25)
# 2019-05-01 13:36:32,470:INFO:root: Processing batch at start index 3950 (num ids = 25)
# 2019-05-01 13:36:40,150:INFO:root: Processing batch at start index 3975 (num ids = 25)
# 2019-05-01 13:36:44,626:INFO:root: Processing batch at start index 4000 (num ids = 25)
# 2019-05-01 13:36:53,966:INFO:root: Processing batch at start index 4025 (num ids = 25)
# 2019-05-01 13:37:01,594:INFO:root: Processing batch at start index 4050 (num ids = 25)
# 2019-05-01 13:37:06,278:INFO:root: Processing batch at start index 4075 (num ids = 25)
# 2019-05-01 13:37:15,109:INFO:root: Processing batch at start index 4100 (num ids = 25)
# 2019-05-01 13:37:24,939:INFO:root: Processing batch at start index 4125 (num ids = 25)
# 2019-05-01 13:37:29,669:INFO:root: Processing batch at start index 4150 (num ids = 25)
# 2019-05-01 13:37:35,992:INFO:root: Processing batch at start index 4175 (num ids = 25)
# 2019-05-01 13:37:48,410:INFO:root: Processing batch at start index 4200 (num ids = 25)
# 2019-05-01 13:37:56,431:INFO:root: Processing batch at start index 4225 (num ids = 25)
# 2019-05-01 13:38:03,954:INFO:root: Processing batch at start index 4250 (num ids = 25)
# 2019-05-01 13:38:11,379:INFO:root: Processing batch at start index 4275 (num ids = 25)
# 2019-05-01 13:38:16,856:INFO:root: Processing batch at start index 4300 (num ids = 25)
# 2019-05-01 13:38:24,487:INFO:root: Processing batch at start index 4325 (num ids = 25)
# 2019-05-01 13:38:29,202:INFO:root: Processing batch at start index 4350 (num ids = 25)
# 2019-05-01 13:38:38,360:INFO:root: Processing batch at start index 4375 (num ids = 25)
# 2019-05-01 13:38:47,578:INFO:root: Processing batch at start index 4400 (num ids = 25)
# 2019-05-01 13:38:58,943:INFO:root: Processing batch at start index 4425 (num ids = 25)
# 2019-05-01 13:39:09,084:INFO:root: Processing batch at start index 4450 (num ids = 25)
# 2019-05-01 13:39:18,363:INFO:root: Processing batch at start index 4475 (num ids = 25)
# 2019-05-01 13:39:24,967:INFO:root: Processing batch at start index 4500 (num ids = 25)
# 2019-05-01 13:39:29,663:INFO:root: Processing batch at start index 4525 (num ids = 25)
# 2019-05-01 13:39:37,037:INFO:root: Processing batch at start index 4550 (num ids = 25)
# 2019-05-01 13:39:45,415:INFO:root: Processing batch at start index 4575 (num ids = 25)
# 2019-05-01 13:39:49,460:INFO:root: Processing batch at start index 4600 (num ids = 25)
# 2019-05-01 13:39:57,512:INFO:root: Processing batch at start index 4625 (num ids = 25)
# 2019-05-01 13:40:01,998:INFO:root: Processing batch at start index 4650 (num ids = 25)
# 2019-05-01 13:40:09,900:INFO:root: Processing batch at start index 4675 (num ids = 25)
# 2019-05-01 13:40:18,025:INFO:root: Processing batch at start index 4700 (num ids = 25)
# 2019-05-01 13:40:22,504:INFO:root: Processing batch at start index 4725 (num ids = 25)
# 2019-05-01 13:40:30,181:INFO:root: Processing batch at start index 4750 (num ids = 25)
# 2019-05-01 13:40:38,477:INFO:root: Processing batch at start index 4775 (num ids = 25)
# 2019-05-01 13:40:43,000:INFO:root: Processing batch at start index 4800 (num ids = 25)
# 2019-05-01 13:40:50,150:INFO:root: Processing batch at start index 4825 (num ids = 25)
# 2019-05-01 13:40:57,578:INFO:root: Processing batch at start index 4850 (num ids = 25)
# 2019-05-01 13:41:07,723:INFO:root: Processing batch at start index 4875 (num ids = 25)
# 2019-05-01 13:41:11,583:INFO:root: Processing batch at start index 4900 (num ids = 25)
# 2019-05-01 13:41:19,949:INFO:root: Processing batch at start index 4925 (num ids = 25)
# 2019-05-01 13:41:26,875:INFO:root: Processing batch at start index 4950 (num ids = 25)
# 2019-05-01 13:41:32,009:INFO:root: Processing batch at start index 4975 (num ids = 25)
# 2019-05-01 13:41:42,265:INFO:root: Processing batch at start index 5000 (num ids = 25)
# 2019-05-01 13:41:50,979:INFO:root: Processing batch at start index 5025 (num ids = 25)
# 2019-05-01 13:41:56,949:INFO:root: Processing batch at start index 5050 (num ids = 25)
# 2019-05-01 13:42:02,344:INFO:root: Processing batch at start index 5075 (num ids = 25)
# 2019-05-01 13:42:11,725:INFO:root: Processing batch at start index 5100 (num ids = 25)
# 2019-05-01 13:42:19,600:INFO:root: Processing batch at start index 5125 (num ids = 25)
# 2019-05-01 13:42:23,845:INFO:root: Processing batch at start index 5150 (num ids = 25)
# 2019-05-01 13:42:32,447:INFO:root: Processing batch at start index 5175 (num ids = 25)
# 2019-05-01 13:42:42,585:INFO:root: Processing batch at start index 5200 (num ids = 25)
# 2019-05-01 13:42:48,199:INFO:root: Processing batch at start index 5225 (num ids = 25)
# 2019-05-01 13:42:53,338:INFO:root: Processing batch at start index 5250 (num ids = 25)
# 2019-05-01 13:43:02,247:INFO:root: Processing batch at start index 5275 (num ids = 25)
# 2019-05-01 13:43:09,668:INFO:root: Processing batch at start index 5300 (num ids = 25)
# 2019-05-01 13:43:14,843:INFO:root: Processing batch at start index 5325 (num ids = 25)
# 2019-05-01 13:43:24,777:INFO:root: Processing batch at start index 5350 (num ids = 25)
# 2019-05-01 13:43:32,964:INFO:root: Processing batch at start index 5375 (num ids = 25)
# 2019-05-01 13:43:40,955:INFO:root: Processing batch at start index 5400 (num ids = 25)
# 2019-05-01 13:43:45,561:INFO:root: Processing batch at start index 5425 (num ids = 25)
# 2019-05-01 13:43:54,776:INFO:root: Processing batch at start index 5450 (num ids = 25)
# 2019-05-01 13:44:01,903:INFO:root: Processing batch at start index 5475 (num ids = 25)
# 2019-05-01 13:44:07,451:INFO:root: Processing batch at start index 5500 (num ids = 25)
# 2019-05-01 13:44:15,052:INFO:root: Processing batch at start index 5525 (num ids = 25)
# 2019-05-01 13:44:25,190:INFO:root: Processing batch at start index 5550 (num ids = 25)
# 2019-05-01 13:44:32,217:INFO:root: Processing batch at start index 5575 (num ids = 25)
# 2019-05-01 13:44:36,441:INFO:root: Processing batch at start index 5600 (num ids = 25)
# 2019-05-01 13:44:45,984:INFO:root: Processing batch at start index 5625 (num ids = 25)
# 2019-05-01 13:44:52,009:INFO:root: Processing batch at start index 5650 (num ids = 25)
# 2019-05-01 13:44:58,946:INFO:root: Processing batch at start index 5675 (num ids = 25)
# 2019-05-01 13:45:07,421:INFO:root: Processing batch at start index 5700 (num ids = 25)
# 2019-05-01 13:45:16,287:INFO:root: Processing batch at start index 5725 (num ids = 25)
# 2019-05-01 13:45:23,924:INFO:root: Processing batch at start index 5750 (num ids = 25)
# 2019-05-01 13:45:33,511:INFO:root: Processing batch at start index 5775 (num ids = 25)
# 2019-05-01 13:45:37,282:INFO:root: Processing batch at start index 5800 (num ids = 25)
# 2019-05-01 13:45:46,910:INFO:root: Processing batch at start index 5825 (num ids = 25)
# 2019-05-01 13:45:54,953:INFO:root: Processing batch at start index 5850 (num ids = 25)
# 2019-05-01 13:46:03,317:INFO:root: Processing batch at start index 5875 (num ids = 25)
# 2019-05-01 13:46:09,027:INFO:root: Processing batch at start index 5900 (num ids = 25)
# 2019-05-01 13:46:21,375:INFO:root: Processing batch at start index 5925 (num ids = 25)
# 2019-05-01 13:46:29,611:INFO:root: Processing batch at start index 5950 (num ids = 25)
# 2019-05-01 13:46:39,440:INFO:root: Processing batch at start index 5975 (num ids = 25)
# 2019-05-01 13:46:48,254:INFO:root: Processing batch at start index 6000 (num ids = 25)
# 2019-05-01 13:46:56,701:INFO:root: Processing batch at start index 6025 (num ids = 25)
# 2019-05-01 13:47:01,864:INFO:root: Processing batch at start index 6050 (num ids = 25)
# 2019-05-01 13:47:14,670:INFO:root: Processing batch at start index 6075 (num ids = 25)
# 2019-05-01 13:47:25,701:INFO:root: Processing batch at start index 6100 (num ids = 25)
# 2019-05-01 13:47:37,659:INFO:root: Processing batch at start index 6125 (num ids = 25)
# 2019-05-01 13:47:41,929:INFO:root: Processing batch at start index 6150 (num ids = 25)
# Traceback (most recent call last):
#   File "<ipython-input-2-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-2-6c5b1272821b>", line 14, in fetch_details
#     return handle.read()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 456, in read
#     return self._readall_chunked()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 566, in _readall_chunked
#     value.append(self._safe_read(chunk_left))
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 612, in _safe_read
#     chunk = self.fp.read(min(amt, MAXAMOUNT))
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/ssl.py", line 1012, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/ssl.py", line 874, in read
#     return self._sslobj.read(len, buffer)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/ssl.py", line 631, in read
#     v = self._sslobj.read(len, buffer)
# KeyboardInterrupt
# 2019-05-01 14:22:26,157:WARNING:root: Error occurred at index 6150. Will retry up to 1000000 times
# 2019-05-01 14:22:27,406:INFO:root: Processing batch at start index 6150 (num ids = 25)
# 2019-05-01 14:22:35,288:INFO:root: Processing batch at start index 6175 (num ids = 25)
# 2019-05-01 14:22:40,916:INFO:root: Processing batch at start index 6200 (num ids = 25)
# 2019-05-01 14:22:49,901:INFO:root: Processing batch at start index 6225 (num ids = 25)
# 2019-05-01 14:22:53,149:INFO:root: Processing batch at start index 6250 (num ids = 25)
# 2019-05-01 14:23:00,157:INFO:root: Processing batch at start index 6275 (num ids = 25)
# 2019-05-01 14:23:07,703:INFO:root: Processing batch at start index 6300 (num ids = 25)
# 2019-05-01 14:23:11,766:INFO:root: Processing batch at start index 6325 (num ids = 25)
# 2019-05-01 14:23:21,186:INFO:root: Processing batch at start index 6350 (num ids = 25)
# 2019-05-01 14:23:27,719:INFO:root: Processing batch at start index 6375 (num ids = 25)
# 2019-05-01 14:23:32,527:INFO:root: Processing batch at start index 6400 (num ids = 25)
# 2019-05-01 14:23:42,333:INFO:root: Processing batch at start index 6425 (num ids = 25)
# 2019-05-01 14:23:51,135:INFO:root: Processing batch at start index 6450 (num ids = 25)
# 2019-05-01 14:23:57,085:INFO:root: Processing batch at start index 6475 (num ids = 25)
# 2019-05-01 14:24:01,711:INFO:root: Processing batch at start index 6500 (num ids = 25)
# 2019-05-01 14:24:09,147:INFO:root: Processing batch at start index 6525 (num ids = 25)
# 2019-05-01 14:24:14,304:INFO:root: Processing batch at start index 6550 (num ids = 25)
# 2019-05-01 14:24:21,372:INFO:root: Processing batch at start index 6575 (num ids = 25)
# 2019-05-01 14:24:27,942:INFO:root: Processing batch at start index 6600 (num ids = 25)
# 2019-05-01 14:24:33,046:INFO:root: Processing batch at start index 6625 (num ids = 25)
# 2019-05-01 14:24:38,234:INFO:root: Processing batch at start index 6650 (num ids = 25)
# 2019-05-01 14:24:43,800:INFO:root: Processing batch at start index 6675 (num ids = 25)
# 2019-05-01 14:24:52,172:INFO:root: Processing batch at start index 6700 (num ids = 25)
# 2019-05-01 14:25:00,446:INFO:root: Processing batch at start index 6725 (num ids = 25)
# 2019-05-01 14:25:04,384:INFO:root: Processing batch at start index 6750 (num ids = 25)
# 2019-05-01 14:25:12,376:INFO:root: Processing batch at start index 6775 (num ids = 25)
# 2019-05-01 14:25:17,274:INFO:root: Processing batch at start index 6800 (num ids = 25)
# 2019-05-01 14:25:24,659:INFO:root: Processing batch at start index 6825 (num ids = 25)
# 2019-05-01 14:25:33,731:INFO:root: Processing batch at start index 6850 (num ids = 25)
# 2019-05-01 14:25:40,637:INFO:root: Processing batch at start index 6875 (num ids = 25)
# 2019-05-01 14:25:45,240:INFO:root: Processing batch at start index 6900 (num ids = 25)
# 2019-05-01 14:25:53,841:INFO:root: Processing batch at start index 6925 (num ids = 25)
# 2019-05-01 14:26:02,433:INFO:root: Processing batch at start index 6950 (num ids = 25)
# 2019-05-01 14:26:08,213:INFO:root: Processing batch at start index 6975 (num ids = 25)
# 2019-05-01 14:26:17,600:INFO:root: Processing batch at start index 7000 (num ids = 25)
# 2019-05-01 14:26:29,382:INFO:root: Processing batch at start index 7025 (num ids = 25)
# 2019-05-01 14:26:37,840:INFO:root: Processing batch at start index 7050 (num ids = 25)
# 2019-05-01 14:26:46,678:INFO:root: Processing batch at start index 7075 (num ids = 25)
# 2019-05-01 14:26:54,605:INFO:root: Processing batch at start index 7100 (num ids = 25)
# 2019-05-01 14:26:58,467:INFO:root: Processing batch at start index 7125 (num ids = 25)
# 2019-05-01 14:27:07,611:INFO:root: Processing batch at start index 7150 (num ids = 25)
# 2019-05-01 14:27:27,716:INFO:root: Processing batch at start index 7175 (num ids = 25)
# 2019-05-01 14:27:33,691:INFO:root: Processing batch at start index 7200 (num ids = 25)
# 2019-05-01 14:27:41,493:INFO:root: Processing batch at start index 7225 (num ids = 25)
# 2019-05-01 14:27:53,178:INFO:root: Processing batch at start index 7250 (num ids = 25)
# 2019-05-01 14:28:01,445:INFO:root: Processing batch at start index 7275 (num ids = 25)
# 2019-05-01 14:28:08,030:INFO:root: Processing batch at start index 7300 (num ids = 25)
# 2019-05-01 14:28:12,818:INFO:root: Processing batch at start index 7325 (num ids = 25)
# 2019-05-01 14:28:22,175:INFO:root: Processing batch at start index 7350 (num ids = 25)
# 2019-05-01 14:28:28,696:INFO:root: Processing batch at start index 7375 (num ids = 25)
# 2019-05-01 14:28:33,967:INFO:root: Processing batch at start index 7400 (num ids = 25)
# 2019-05-01 14:28:43,527:INFO:root: Processing batch at start index 7425 (num ids = 25)
# 2019-05-01 14:28:52,141:INFO:root: Processing batch at start index 7450 (num ids = 25)
# 2019-05-01 14:29:00,124:INFO:root: Processing batch at start index 7475 (num ids = 25)
# 2019-05-01 14:29:04,892:INFO:root: Processing batch at start index 7500 (num ids = 25)
# 2019-05-01 14:29:13,635:INFO:root: Processing batch at start index 7525 (num ids = 25)
# 2019-05-01 14:29:19,067:INFO:root: Processing batch at start index 7550 (num ids = 25)
# 2019-05-01 14:29:25,525:INFO:root: Processing batch at start index 7575 (num ids = 25)
# 2019-05-01 14:29:33,603:INFO:root: Processing batch at start index 7600 (num ids = 25)
# 2019-05-01 14:29:41,896:INFO:root: Processing batch at start index 7625 (num ids = 25)
# 2019-05-01 14:29:51,784:INFO:root: Processing batch at start index 7650 (num ids = 25)
# 2019-05-01 14:29:56,033:INFO:root: Processing batch at start index 7675 (num ids = 25)
# 2019-05-01 14:30:05,195:INFO:root: Processing batch at start index 7700 (num ids = 25)
# 2019-05-01 14:30:15,692:INFO:root: Processing batch at start index 7725 (num ids = 25)
# 2019-05-01 14:30:27,055:INFO:root: Processing batch at start index 7750 (num ids = 25)
# 2019-05-01 14:30:34,812:INFO:root: Processing batch at start index 7775 (num ids = 25)
# 2019-05-01 14:30:43,042:INFO:root: Processing batch at start index 7800 (num ids = 25)
# 2019-05-01 14:30:47,023:INFO:root: Processing batch at start index 7825 (num ids = 25)
# 2019-05-01 14:30:56,587:INFO:root: Processing batch at start index 7850 (num ids = 25)
# 2019-05-01 14:31:02,806:INFO:root: Processing batch at start index 7875 (num ids = 25)
# 2019-05-01 14:31:07,021:INFO:root: Processing batch at start index 7900 (num ids = 25)
# 2019-05-01 14:31:16,107:INFO:root: Processing batch at start index 7925 (num ids = 25)
# 2019-05-01 14:31:23,947:INFO:root: Processing batch at start index 7950 (num ids = 25)
# 2019-05-01 14:31:28,804:INFO:root: Processing batch at start index 7975 (num ids = 25)
# 2019-05-01 14:31:38,017:INFO:root: Processing batch at start index 8000 (num ids = 25)
# 2019-05-01 14:31:43,587:INFO:root: Processing batch at start index 8025 (num ids = 25)
# 2019-05-01 14:31:47,539:INFO:root: Processing batch at start index 8050 (num ids = 25)
# 2019-05-01 14:31:57,070:INFO:root: Processing batch at start index 8075 (num ids = 25)
# 2019-05-01 14:32:04,755:INFO:root: Processing batch at start index 8100 (num ids = 25)
# 2019-05-01 14:32:09,976:INFO:root: Processing batch at start index 8125 (num ids = 25)
# 2019-05-01 14:32:19,450:INFO:root: Processing batch at start index 8150 (num ids = 25)
# 2019-05-01 14:32:28,707:INFO:root: Processing batch at start index 8175 (num ids = 25)
# 2019-05-01 14:32:39,152:INFO:root: Processing batch at start index 8200 (num ids = 25)
# 2019-05-01 14:32:46,283:INFO:root: Processing batch at start index 8225 (num ids = 25)
# 2019-05-01 14:32:50,830:INFO:root: Processing batch at start index 8250 (num ids = 25)
# 2019-05-01 14:33:00,116:INFO:root: Processing batch at start index 8275 (num ids = 25)
# 2019-05-01 14:33:10,176:INFO:root: Processing batch at start index 8300 (num ids = 25)
# 2019-05-01 14:33:19,395:INFO:root: Processing batch at start index 8325 (num ids = 25)
# 2019-05-01 14:33:27,444:INFO:root: Processing batch at start index 8350 (num ids = 25)
# 2019-05-01 14:33:31,375:INFO:root: Processing batch at start index 8375 (num ids = 25)
# 2019-05-01 14:33:39,976:INFO:root: Processing batch at start index 8400 (num ids = 25)
# 2019-05-01 14:33:47,054:INFO:root: Processing batch at start index 8425 (num ids = 25)
# 2019-05-01 14:33:51,344:INFO:root: Processing batch at start index 8450 (num ids = 25)
# 2019-05-01 14:33:58,784:INFO:root: Processing batch at start index 8475 (num ids = 25)
# 2019-05-01 14:34:04,332:INFO:root: Processing batch at start index 8500 (num ids = 25)
# 2019-05-01 14:34:12,231:INFO:root: Processing batch at start index 8525 (num ids = 25)
# 2019-05-01 14:34:18,040:INFO:root: Processing batch at start index 8550 (num ids = 25)
# 2019-05-01 14:34:23,295:INFO:root: Processing batch at start index 8575 (num ids = 25)
# 2019-05-01 14:34:31,759:INFO:root: Processing batch at start index 8600 (num ids = 25)
# 2019-05-01 14:34:38,904:INFO:root: Processing batch at start index 8625 (num ids = 25)
# 2019-05-01 14:34:43,260:INFO:root: Processing batch at start index 8650 (num ids = 25)
# 2019-05-01 14:34:51,557:INFO:root: Processing batch at start index 8675 (num ids = 25)
# 2019-05-01 14:34:55,861:INFO:root: Processing batch at start index 8700 (num ids = 25)
# 2019-05-01 14:35:04,214:INFO:root: Processing batch at start index 8725 (num ids = 25)
# 2019-05-01 14:35:12,754:INFO:root: Processing batch at start index 8750 (num ids = 25)
# 2019-05-01 14:35:17,682:INFO:root: Processing batch at start index 8775 (num ids = 25)
# 2019-05-01 14:35:24,631:INFO:root: Processing batch at start index 8800 (num ids = 25)
# 2019-05-01 14:35:34,461:INFO:root: Processing batch at start index 8825 (num ids = 25)
# 2019-05-01 14:35:40,544:INFO:root: Processing batch at start index 8850 (num ids = 25)
# 2019-05-01 14:35:45,318:INFO:root: Processing batch at start index 8875 (num ids = 25)
# 2019-05-01 14:35:55,596:INFO:root: Processing batch at start index 8900 (num ids = 25)
# 2019-05-01 14:36:05,028:INFO:root: Processing batch at start index 8925 (num ids = 25)
# 2019-05-01 14:36:23,189:INFO:root: Processing batch at start index 8950 (num ids = 25)
# 2019-05-01 14:36:30,426:INFO:root: Processing batch at start index 8975 (num ids = 25)
# 2019-05-01 14:36:37,416:INFO:root: Processing batch at start index 9000 (num ids = 25)
# 2019-05-01 14:36:43,590:INFO:root: Processing batch at start index 9025 (num ids = 25)
# 2019-05-01 14:36:48,796:INFO:root: Processing batch at start index 9050 (num ids = 25)
# 2019-05-01 14:37:02,938:INFO:root: Processing batch at start index 9075 (num ids = 25)
# 2019-05-01 14:37:10,299:INFO:root: Processing batch at start index 9100 (num ids = 25)
# 2019-05-01 14:37:19,876:INFO:root: Processing batch at start index 9125 (num ids = 25)
# 2019-05-01 14:37:29,652:INFO:root: Processing batch at start index 9150 (num ids = 25)
# 2019-05-01 14:37:35,045:INFO:root: Processing batch at start index 9175 (num ids = 25)
# 2019-05-01 14:37:40,854:INFO:root: Processing batch at start index 9200 (num ids = 25)
# 2019-05-01 14:37:50,236:INFO:root: Processing batch at start index 9225 (num ids = 25)
# 2019-05-01 14:37:58,284:INFO:root: Processing batch at start index 9250 (num ids = 25)
# 2019-05-01 14:38:03,231:INFO:root: Processing batch at start index 9275 (num ids = 25)
# 2019-05-01 14:38:12,048:INFO:root: Processing batch at start index 9300 (num ids = 25)
# 2019-05-01 14:38:19,176:INFO:root: Processing batch at start index 9325 (num ids = 25)
# 2019-05-01 14:38:22,175:INFO:root: Processing batch at start index 9350 (num ids = 25)
# 2019-05-01 14:38:29,627:INFO:root: Processing batch at start index 9375 (num ids = 25)
# 2019-05-01 14:38:34,470:INFO:root: Processing batch at start index 9400 (num ids = 25)
# 2019-05-01 14:38:43,078:INFO:root: Processing batch at start index 9425 (num ids = 25)
# 2019-05-01 14:38:54,442:INFO:root: Processing batch at start index 9450 (num ids = 25)
# 2019-05-01 14:39:02,737:INFO:root: Processing batch at start index 9475 (num ids = 25)
# 2019-05-01 14:39:10,777:INFO:root: Processing batch at start index 9500 (num ids = 25)
# 2019-05-01 14:39:15,332:INFO:root: Processing batch at start index 9525 (num ids = 25)
# 2019-05-01 14:39:23,108:INFO:root: Processing batch at start index 9550 (num ids = 25)
# 2019-05-01 14:39:31,370:INFO:root: Processing batch at start index 9575 (num ids = 25)
# 2019-05-01 14:39:35,840:INFO:root: Processing batch at start index 9600 (num ids = 25)
# 2019-05-01 14:39:45,440:INFO:root: Processing batch at start index 9625 (num ids = 25)
# 2019-05-01 14:39:53,479:INFO:root: Processing batch at start index 9650 (num ids = 25)
# 2019-05-01 14:40:02,028:INFO:root: Processing batch at start index 9675 (num ids = 25)
# 2019-05-01 14:40:07,177:INFO:root: Processing batch at start index 9700 (num ids = 25)
# 2019-05-01 14:40:15,235:INFO:root: Processing batch at start index 9725 (num ids = 25)
# 2019-05-01 14:40:21,782:INFO:root: Processing batch at start index 9750 (num ids = 25)
# 2019-05-01 14:40:25,680:INFO:root: Processing batch at start index 9775 (num ids = 25)
# 2019-05-01 14:40:31,284:INFO:root: Processing batch at start index 9800 (num ids = 25)
# 2019-05-01 14:40:37,049:INFO:root: Processing batch at start index 9825 (num ids = 25)
# 2019-05-01 14:40:45,954:INFO:root: Processing batch at start index 9850 (num ids = 25)
# 2019-05-01 14:40:52,736:INFO:root: Processing batch at start index 9875 (num ids = 25)
# 2019-05-01 14:40:57,015:INFO:root: Processing batch at start index 9900 (num ids = 25)
# 2019-05-01 14:41:05,925:INFO:root: Processing batch at start index 9925 (num ids = 25)
# 2019-05-01 14:41:10,723:INFO:root: Processing batch at start index 9950 (num ids = 25)
# 2019-05-01 14:41:19,135:INFO:root: Processing batch at start index 9975 (num ids = 25)
# 2019-05-01 14:41:26,507:INFO:root: Processing batch at start index 10000 (num ids = 25)
# 2019-05-01 14:41:35,474:INFO:root: Processing batch at start index 10025 (num ids = 25)
# 2019-05-01 14:41:39,968:INFO:root: Processing batch at start index 10050 (num ids = 25)
# 2019-05-01 14:41:51,318:INFO:root: Processing batch at start index 10075 (num ids = 25)
# 2019-05-01 14:41:58,795:INFO:root: Processing batch at start index 10100 (num ids = 25)
# 2019-05-01 14:42:06,753:INFO:root: Processing batch at start index 10125 (num ids = 25)
# 2019-05-01 14:42:10,115:INFO:root: Processing batch at start index 10150 (num ids = 25)
# 2019-05-01 14:42:20,898:INFO:root: Processing batch at start index 10175 (num ids = 25)
# 2019-05-01 14:42:29,490:INFO:root: Processing batch at start index 10200 (num ids = 25)
# 2019-05-01 14:42:37,164:INFO:root: Processing batch at start index 10225 (num ids = 25)
# 2019-05-01 14:42:47,168:INFO:root: Processing batch at start index 10250 (num ids = 25)
# 2019-05-01 14:42:54,628:INFO:root: Processing batch at start index 10275 (num ids = 25)
# 2019-05-01 14:43:01,468:INFO:root: Processing batch at start index 10300 (num ids = 25)
# 2019-05-01 14:43:09,423:INFO:root: Processing batch at start index 10325 (num ids = 25)
# 2019-05-01 14:43:13,334:INFO:root: Processing batch at start index 10350 (num ids = 25)
# 2019-05-01 14:43:20,483:INFO:root: Processing batch at start index 10375 (num ids = 25)
# 2019-05-01 14:43:28,161:INFO:root: Processing batch at start index 10400 (num ids = 25)
# 2019-05-01 14:43:32,156:INFO:root: Processing batch at start index 10425 (num ids = 25)
# 2019-05-01 14:43:40,756:INFO:root: Processing batch at start index 10450 (num ids = 25)
# 2019-05-01 14:43:48,803:INFO:root: Processing batch at start index 10475 (num ids = 25)
# 2019-05-01 14:43:53,050:INFO:root: Processing batch at start index 10500 (num ids = 25)
# 2019-05-01 14:44:01,030:INFO:root: Processing batch at start index 10525 (num ids = 25)
# 2019-05-01 14:44:09,143:INFO:root: Processing batch at start index 10550 (num ids = 25)
# 2019-05-01 14:44:13,398:INFO:root: Processing batch at start index 10575 (num ids = 25)
# 2019-05-01 14:44:21,310:INFO:root: Processing batch at start index 10600 (num ids = 25)
# 2019-05-01 14:44:29,870:INFO:root: Processing batch at start index 10625 (num ids = 25)
# 2019-05-01 14:44:34,382:INFO:root: Processing batch at start index 10650 (num ids = 25)
# 2019-05-01 14:44:43,130:INFO:root: Processing batch at start index 10675 (num ids = 25)
# 2019-05-01 14:44:49,205:INFO:root: Processing batch at start index 10700 (num ids = 25)
# 2019-05-01 14:44:54,178:INFO:root: Processing batch at start index 10725 (num ids = 25)
# 2019-05-01 14:45:02,880:INFO:root: Processing batch at start index 10750 (num ids = 25)
# 2019-05-01 14:45:13,532:INFO:root: Processing batch at start index 10775 (num ids = 25)
# 2019-05-01 14:45:21,278:INFO:root: Processing batch at start index 10800 (num ids = 25)
# 2019-05-01 14:45:25,513:INFO:root: Processing batch at start index 10825 (num ids = 25)
# 2019-05-01 14:45:35,037:INFO:root: Processing batch at start index 10850 (num ids = 25)
# 2019-05-01 14:45:44,258:INFO:root: Processing batch at start index 10875 (num ids = 25)
# 2019-05-01 14:45:51,930:INFO:root: Processing batch at start index 10900 (num ids = 25)
# 2019-05-01 14:45:56,847:INFO:root: Processing batch at start index 10925 (num ids = 25)
# 2019-05-01 14:46:10,697:INFO:root: Processing batch at start index 10950 (num ids = 25)
# 2019-05-01 14:46:16,100:INFO:root: Processing batch at start index 10975 (num ids = 25)
# 2019-05-01 14:46:25,414:INFO:root: Processing batch at start index 11000 (num ids = 25)
# 2019-05-01 14:46:28,822:INFO:root: Processing batch at start index 11025 (num ids = 25)
# 2019-05-01 14:46:36,873:INFO:root: Processing batch at start index 11050 (num ids = 25)
# 2019-05-01 14:46:46,592:INFO:root: Processing batch at start index 11075 (num ids = 25)
# 2019-05-01 14:46:53,862:INFO:root: Processing batch at start index 11100 (num ids = 25)
# 2019-05-01 14:46:57,991:INFO:root: Processing batch at start index 11125 (num ids = 25)
# 2019-05-01 14:47:08,117:INFO:root: Processing batch at start index 11150 (num ids = 25)
# 2019-05-01 14:47:16,776:INFO:root: Processing batch at start index 11175 (num ids = 25)
# 2019-05-01 14:47:20,576:INFO:root: Processing batch at start index 11200 (num ids = 25)
# 2019-05-01 14:47:29,290:INFO:root: Processing batch at start index 11225 (num ids = 25)
# 2019-05-01 14:47:37,599:INFO:root: Processing batch at start index 11250 (num ids = 25)
# 2019-05-01 14:47:43,813:INFO:root: Processing batch at start index 11275 (num ids = 25)
# 2019-05-01 14:47:49,823:INFO:root: Processing batch at start index 11300 (num ids = 25)
# 2019-05-01 14:47:57,887:INFO:root: Processing batch at start index 11325 (num ids = 25)
# 2019-05-01 14:48:01,885:INFO:root: Processing batch at start index 11350 (num ids = 25)
# 2019-05-01 14:48:09,252:INFO:root: Processing batch at start index 11375 (num ids = 25)
# 2019-05-01 14:48:19,080:INFO:root: Processing batch at start index 11400 (num ids = 25)
# 2019-05-01 14:48:27,128:INFO:root: Processing batch at start index 11425 (num ids = 25)
# 2019-05-01 14:48:31,782:INFO:root: Processing batch at start index 11450 (num ids = 25)
# 2019-05-01 14:48:40,577:INFO:root: Processing batch at start index 11475 (num ids = 25)
# 2019-05-01 14:48:47,651:INFO:root: Processing batch at start index 11500 (num ids = 25)
# 2019-05-01 14:48:52,607:INFO:root: Processing batch at start index 11525 (num ids = 25)
# 2019-05-01 14:49:01,782:INFO:root: Processing batch at start index 11550 (num ids = 25)
# 2019-05-01 14:49:08,789:INFO:root: Processing batch at start index 11575 (num ids = 25)
# 2019-05-01 14:49:13,769:INFO:root: Processing batch at start index 11600 (num ids = 25)
# 2019-05-01 14:49:22,462:INFO:root: Processing batch at start index 11625 (num ids = 25)
# 2019-05-01 14:49:32,212:INFO:root: Processing batch at start index 11650 (num ids = 25)
# 2019-05-01 14:49:41,415:INFO:root: Processing batch at start index 11675 (num ids = 25)
# 2019-05-01 14:49:49,508:INFO:root: Processing batch at start index 11700 (num ids = 25)
# 2019-05-01 14:49:55,690:INFO:root: Processing batch at start index 11725 (num ids = 25)
# 2019-05-01 14:50:01,999:INFO:root: Processing batch at start index 11750 (num ids = 25)
# 2019-05-01 14:50:06,568:INFO:root: Processing batch at start index 11775 (num ids = 25)
# 2019-05-01 14:50:13,982:INFO:root: Processing batch at start index 11800 (num ids = 25)
# 2019-05-01 14:50:23,807:INFO:root: Processing batch at start index 11825 (num ids = 25)
# 2019-05-01 14:50:30,876:INFO:root: Processing batch at start index 11850 (num ids = 25)
# 2019-05-01 14:50:35,832:INFO:root: Processing batch at start index 11875 (num ids = 25)
# 2019-05-01 14:50:44,059:INFO:root: Processing batch at start index 11900 (num ids = 25)
# 2019-05-01 14:50:49,566:INFO:root: Processing batch at start index 11925 (num ids = 25)
# 2019-05-01 14:50:57,293:INFO:root: Processing batch at start index 11950 (num ids = 25)
# 2019-05-01 14:51:05,591:INFO:root: Processing batch at start index 11975 (num ids = 25)
# 2019-05-01 14:51:13,838:INFO:root: Processing batch at start index 12000 (num ids = 25)
# 2019-05-01 14:51:22,372:INFO:root: Processing batch at start index 12025 (num ids = 25)
# 2019-05-01 14:51:28,098:INFO:root: Processing batch at start index 12050 (num ids = 25)
# 2019-05-01 14:51:35,391:INFO:root: Processing batch at start index 12075 (num ids = 25)
# 2019-05-01 14:51:40,911:INFO:root: Processing batch at start index 12100 (num ids = 25)
# 2019-05-01 14:51:46,432:INFO:root: Processing batch at start index 12125 (num ids = 25)
# 2019-05-01 14:51:52,678:INFO:root: Processing batch at start index 12150 (num ids = 25)
# 2019-05-01 14:51:58,837:INFO:root: Processing batch at start index 12175 (num ids = 25)
# 2019-05-01 14:52:07,032:INFO:root: Processing batch at start index 12200 (num ids = 25)
# 2019-05-01 14:52:15,667:INFO:root: Processing batch at start index 12225 (num ids = 25)
# 2019-05-01 14:52:23,615:INFO:root: Processing batch at start index 12250 (num ids = 25)
# 2019-05-01 14:52:27,334:INFO:root: Processing batch at start index 12275 (num ids = 25)
# 2019-05-01 14:52:34,187:INFO:root: Processing batch at start index 12300 (num ids = 25)
# 2019-05-01 14:52:38,414:INFO:root: Processing batch at start index 12325 (num ids = 25)
# 2019-05-01 14:52:47,887:INFO:root: Processing batch at start index 12350 (num ids = 25)
# 2019-05-01 14:52:57,099:INFO:root: Processing batch at start index 12375 (num ids = 25)
# 2019-05-01 14:53:04,842:INFO:root: Processing batch at start index 12400 (num ids = 25)
# 2019-05-01 14:53:09,076:INFO:root: Processing batch at start index 12425 (num ids = 25)
# 2019-05-01 14:53:17,991:INFO:root: Processing batch at start index 12450 (num ids = 25)
# 2019-05-01 14:53:25,677:INFO:root: Processing batch at start index 12475 (num ids = 25)
# 2019-05-01 14:53:30,281:INFO:root: Processing batch at start index 12500 (num ids = 25)
# 2019-05-01 14:53:39,187:INFO:root: Processing batch at start index 12525 (num ids = 25)
# 2019-05-01 14:53:48,565:INFO:root: Processing batch at start index 12550 (num ids = 25)
# 2019-05-01 14:53:56,453:INFO:root: Processing batch at start index 12575 (num ids = 25)
# 2019-05-01 14:54:01,871:INFO:root: Processing batch at start index 12600 (num ids = 25)
# 2019-05-01 14:54:09,905:INFO:root: Processing batch at start index 12625 (num ids = 25)
# 2019-05-01 14:54:20,519:INFO:root: Processing batch at start index 12650 (num ids = 25)
# 2019-05-01 14:54:28,542:INFO:root: Processing batch at start index 12675 (num ids = 25)
# 2019-05-01 14:54:32,740:INFO:root: Processing batch at start index 12700 (num ids = 25)
# 2019-05-01 14:54:41,860:INFO:root: Processing batch at start index 12725 (num ids = 25)
# 2019-05-01 14:54:50,501:INFO:root: Processing batch at start index 12750 (num ids = 25)
# 2019-05-01 14:54:56,584:INFO:root: Processing batch at start index 12775 (num ids = 25)
# 2019-05-01 14:55:01,518:INFO:root: Processing batch at start index 12800 (num ids = 25)
# 2019-05-01 14:55:11,462:INFO:root: Processing batch at start index 12825 (num ids = 25)
# 2019-05-01 14:55:20,561:INFO:root: Processing batch at start index 12850 (num ids = 25)
# 2019-05-01 14:55:27,216:INFO:root: Processing batch at start index 12875 (num ids = 25)
# 2019-05-01 14:55:32,223:INFO:root: Processing batch at start index 12900 (num ids = 25)
# 2019-05-01 14:55:39,111:INFO:root: Processing batch at start index 12925 (num ids = 25)
# 2019-05-01 14:55:43,912:INFO:root: Processing batch at start index 12950 (num ids = 25)
# 2019-05-01 14:55:51,591:INFO:root: Processing batch at start index 12975 (num ids = 25)
# 2019-05-01 14:55:55,627:INFO:root: Processing batch at start index 13000 (num ids = 25)
# 2019-05-01 14:56:02,383:INFO:root: Processing batch at start index 13025 (num ids = 25)
# 2019-05-01 14:56:10,028:INFO:root: Processing batch at start index 13050 (num ids = 25)
# 2019-05-01 14:56:17,391:INFO:root: Processing batch at start index 13075 (num ids = 25)
# 2019-05-01 14:56:23,538:INFO:root: Processing batch at start index 13100 (num ids = 25)
# 2019-05-01 14:56:31,841:INFO:root: Processing batch at start index 13125 (num ids = 25)
# 2019-05-01 14:56:35,225:INFO:root: Processing batch at start index 13150 (num ids = 25)
# 2019-05-01 14:56:45,351:INFO:root: Processing batch at start index 13175 (num ids = 25)
# 2019-05-01 14:56:53,032:INFO:root: Processing batch at start index 13200 (num ids = 25)
# 2019-05-01 14:56:56,854:INFO:root: Processing batch at start index 13225 (num ids = 25)
# 2019-05-01 14:57:05,226:INFO:root: Processing batch at start index 13250 (num ids = 25)
# 2019-05-01 14:57:13,309:INFO:root: Processing batch at start index 13275 (num ids = 25)
# 2019-05-01 14:57:22,238:INFO:root: Processing batch at start index 13300 (num ids = 25)
# 2019-05-01 14:57:26,518:INFO:root: Processing batch at start index 13325 (num ids = 25)
# ...
# 2019-05-01 15:29:26,532:INFO:root: Processing batch at start index 19000 (num ids = 25)
# 2019-05-01 15:29:31,279:INFO:root: Processing batch at start index 19025 (num ids = 25)
# 2019-05-01 15:29:36,805:INFO:root: Processing batch at start index 19050 (num ids = 25)
# 2019-05-01 15:29:44,573:INFO:root: Processing batch at start index 19075 (num ids = 25)
# 2019-05-01 15:29:48,199:INFO:root: Processing batch at start index 19100 (num ids = 25)
# 2019-05-01 15:29:57,252:INFO:root: Processing batch at start index 19125 (num ids = 25)
# 2019-05-01 15:30:01,777:INFO:root: Processing batch at start index 19150 (num ids = 25)
# 2019-05-01 15:30:08,871:INFO:root: Processing batch at start index 19175 (num ids = 25)
# 2019-05-01 15:30:17,799:INFO:root: Processing batch at start index 19200 (num ids = 25)
# 2019-05-01 15:30:26,187:INFO:root: Processing batch at start index 19225 (num ids = 25)
# 2019-05-01 15:30:34,887:INFO:root: Processing batch at start index 19250 (num ids = 25)
# 2019-05-01 15:30:40,569:INFO:root: Processing batch at start index 19275 (num ids = 25)
# 2019-05-01 15:30:50,706:INFO:root: Processing batch at start index 19300 (num ids = 25)
# 2019-05-01 15:30:57,831:INFO:root: Processing batch at start index 19325 (num ids = 25)
# 2019-05-01 15:31:02,379:INFO:root: Processing batch at start index 19350 (num ids = 25)
# 2019-05-01 15:31:11,487:INFO:root: Processing batch at start index 19375 (num ids = 25)
# 2019-05-01 15:31:17,951:INFO:root: Processing batch at start index 19400 (num ids = 25)
# 2019-05-01 15:31:22,961:INFO:root: Processing batch at start index 19425 (num ids = 25)
# 2019-05-01 15:31:32,177:INFO:root: Processing batch at start index 19450 (num ids = 25)
# 2019-05-01 15:31:39,302:INFO:root: Processing batch at start index 19475 (num ids = 25)
# 2019-05-01 15:31:43,237:INFO:root: Processing batch at start index 19500 (num ids = 25)
# 2019-05-01 15:31:52,474:INFO:root: Processing batch at start index 19525 (num ids = 25)
# 2019-05-01 15:31:59,826:INFO:root: Processing batch at start index 19550 (num ids = 25)
# 2019-05-01 15:32:04,129:INFO:root: Processing batch at start index 19575 (num ids = 25)
# 2019-05-01 15:32:11,946:INFO:root: Processing batch at start index 19600 (num ids = 25)
# 2019-05-01 15:32:18,484:INFO:root: Processing batch at start index 19625 (num ids = 25)
# 2019-05-01 15:32:23,481:INFO:root: Processing batch at start index 19650 (num ids = 25)
# 2019-05-01 15:32:30,604:INFO:root: Processing batch at start index 19675 (num ids = 25)
# 2019-05-01 15:32:35,460:INFO:root: Processing batch at start index 19700 (num ids = 25)
# 2019-05-01 15:32:44,839:INFO:root: Processing batch at start index 19725 (num ids = 25)
# 2019-05-01 15:32:50,334:INFO:root: Processing batch at start index 19750 (num ids = 25)
# 2019-05-01 15:32:54,196:INFO:root: Processing batch at start index 19775 (num ids = 25)
# 2019-05-01 15:33:02,246:INFO:root: Processing batch at start index 19800 (num ids = 25)
# 2019-05-01 15:33:05,795:INFO:root: Processing batch at start index 19825 (num ids = 25)
# 2019-05-01 15:33:15,037:INFO:root: Processing batch at start index 19850 (num ids = 25)
# 2019-05-01 15:33:22,775:INFO:root: Processing batch at start index 19875 (num ids = 25)
# 2019-05-01 15:33:26,456:INFO:root: Processing batch at start index 19900 (num ids = 25)
# 2019-05-01 15:33:32,746:INFO:root: Processing batch at start index 19925 (num ids = 25)
# 2019-05-01 15:33:36,320:INFO:root: Processing batch at start index 19950 (num ids = 25)
# 2019-05-01 15:33:45,183:INFO:root: Processing batch at start index 19975 (num ids = 25)
# 2019-05-01 15:33:53,291:INFO:root: Processing batch at start index 20000 (num ids = 25)
# 2019-05-01 15:33:57,178:INFO:root: Processing batch at start index 20025 (num ids = 25)
# 2019-05-01 15:34:03,993:INFO:root: Processing batch at start index 20050 (num ids = 25)
# 2019-05-01 15:34:08,058:INFO:root: Processing batch at start index 20075 (num ids = 25)
# 2019-05-01 15:34:17,122:INFO:root: Processing batch at start index 20100 (num ids = 25)
# 2019-05-01 15:34:24,575:INFO:root: Processing batch at start index 20125 (num ids = 25)
# 2019-05-01 15:34:29,433:INFO:root: Processing batch at start index 20150 (num ids = 25)
# 2019-05-01 15:34:37,538:INFO:root: Processing batch at start index 20175 (num ids = 25)
# 2019-05-01 15:34:45,466:INFO:root: Processing batch at start index 20200 (num ids = 25)
# 2019-05-01 15:34:49,367:INFO:root: Processing batch at start index 20225 (num ids = 25)
# 2019-05-01 15:34:57,644:INFO:root: Processing batch at start index 20250 (num ids = 25)
# 2019-05-01 15:35:01,511:INFO:root: Processing batch at start index 20275 (num ids = 25)
# 2019-05-01 15:35:08,755:INFO:root: Processing batch at start index 20300 (num ids = 25)
# 2019-05-01 15:35:16,127:INFO:root: Processing batch at start index 20325 (num ids = 25)
# 2019-05-01 15:35:20,123:INFO:root: Processing batch at start index 20350 (num ids = 25)
# 2019-05-01 15:35:28,415:INFO:root: Processing batch at start index 20375 (num ids = 25)
# 2019-05-01 15:35:37,017:INFO:root: Processing batch at start index 20400 (num ids = 25)
# 2019-05-01 15:35:41,312:INFO:root: Processing batch at start index 20425 (num ids = 25)
# Traceback (most recent call last):
#   File "<ipython-input-2-6c5b1272821b>", line 59, in collect
#     dets = fetch_details(ids)
#   File "<ipython-input-2-6c5b1272821b>", line 14, in fetch_details
#     return handle.read()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 456, in read
#     return self._readall_chunked()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 563, in _readall_chunked
#     chunk_left = self._get_chunk_left()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 546, in _get_chunk_left
#     chunk_left = self._read_next_chunk_size()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 506, in _read_next_chunk_size
#     line = self.fp.readline(_MAXLINE + 1)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/ssl.py", line 1012, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/ssl.py", line 874, in read
#     return self._sslobj.read(len, buffer)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/ssl.py", line 631, in read
#     v = self._sslobj.read(len, buffer)
# KeyboardInterrupt
# 2019-05-01 15:35:44,600:WARNING:root: Error occurred at index 20425. Will retry up to 1000000 times
# Traceback (most recent call last):
#   File "<ipython-input-2-6c5b1272821b>", line 55, in collect
#     ids = search(query, retstart=i, retmax=batch_size)['IdList']
#   File "<ipython-input-2-6c5b1272821b>", line 7, in search
#     term=query)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 220, in esearch
#     return _open(cgi, variables)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 526, in open
#     response = self._open(req, data)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 544, in _open
#     '_open', req)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 1361, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 1318, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1392, in connect
#     super().connect()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 936, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/socket.py", line 713, in create_connection
#     sock.connect(sa)
# KeyboardInterrupt
# 2019-05-01 15:35:44,762:WARNING:root: Error occurred at index 20425. Will retry up to 1000000 times
# Traceback (most recent call last):
#   File "<ipython-input-2-6c5b1272821b>", line 55, in collect
#     ids = search(query, retstart=i, retmax=batch_size)['IdList']
#   File "<ipython-input-2-6c5b1272821b>", line 7, in search
#     term=query)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 220, in esearch
#     return _open(cgi, variables)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 529, in _open
#     time.sleep(wait)
# KeyboardInterrupt
# 2019-05-01 15:35:44,907:WARNING:root: Error occurred at index 20425. Will retry up to 1000000 times
# Traceback (most recent call last):
#   File "<ipython-input-2-6c5b1272821b>", line 55, in collect
#     ids = search(query, retstart=i, retmax=batch_size)['IdList']
#   File "<ipython-input-2-6c5b1272821b>", line 7, in search
#     term=query)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 220, in esearch
#     return _open(cgi, variables)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 526, in open
#     response = self._open(req, data)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 544, in _open
#     '_open', req)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 1361, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 1318, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1392, in connect
#     super().connect()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 936, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/socket.py", line 713, in create_connection
#     sock.connect(sa)
# KeyboardInterrupt
# 2019-05-01 15:35:45,052:WARNING:root: Error occurred at index 20425. Will retry up to 1000000 times
# Traceback (most recent call last):
#   File "<ipython-input-2-6c5b1272821b>", line 55, in collect
#     ids = search(query, retstart=i, retmax=batch_size)['IdList']
#   File "<ipython-input-2-6c5b1272821b>", line 7, in search
#     term=query)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 220, in esearch
#     return _open(cgi, variables)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 543, in _open
#     handle = _urlopen(cgi)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 526, in open
#     response = self._open(req, data)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 544, in _open
#     '_open', req)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 1361, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/urllib/request.py", line 1318, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 1392, in connect
#     super().connect()
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/http/client.py", line 936, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/socket.py", line 713, in create_connection
#     sock.connect(sa)
# KeyboardInterrupt
# 2019-05-01 15:35:45,365:WARNING:root: Error occurred at index 20425. Will retry up to 1000000 times
# Traceback (most recent call last):
#   File "<ipython-input-2-6c5b1272821b>", line 55, in collect
#     ids = search(query, retstart=i, retmax=batch_size)['IdList']
#   File "<ipython-input-2-6c5b1272821b>", line 7, in search
#     term=query)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 220, in esearch
#     return _open(cgi, variables)
#   File "/Users/eczech/anaconda3/envs/pubmed-nlp/lib/python3.6/site-packages/Bio/Entrez/__init__.py", line 529, in _open
#     time.sleep(wait)
# KeyboardInterrupt
# 2019-05-01 15:35:45,590:WARNING:root: Error occurred at index 20425. Will retry up to 1000000 times
# 2019-05-01 15:35:47,749:INFO:root: Processing batch at start index 20425 (num ids = 25)

# %%
df = pd.read_csv(output_file)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20450 entries, 0 to 20449
# Data columns (total 6 columns):
# abstract    20334 non-null object
# date        13014 non-null object
# has_text    20450 non-null bool
# id          20450 non-null int64
# title       20450 non-null object
# xml         20450 non-null object
# dtypes: bool(1), int64(1), object(4)
# memory usage: 818.9+ KB

# %%
df['has_text'].value_counts()
# Out:
# False    10540
# True      9910
# Name: has_text, dtype: int64

# %%
assert df['id'].value_counts().max() == 1
# Out:
# 1
